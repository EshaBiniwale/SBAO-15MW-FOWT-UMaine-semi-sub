# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

sns.set_style("darkgrid")

# %% [markdown]
#     299 : ESYS line2 SENSOR 84 - Tension at Fairlead - Trained on Max values

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_299.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Max']]

# %%
print('Maximum value of tension at fairlead (Line 2): %.6f' % df['Max'].max())
print('Minimum value of tension at fairlead (Line 2): %.6f' % df['Max'].min())
print('Range for tension at fairlead (Line 2): %.6f' % (df['Max'].max()-df['Max'].min()))
print('Mean for tension at fairlead (Line 2): %.6f' % (np.mean(df['Max'])))
# Out:
# Maximum value of tension at fairlead (Line 2): 13715510.517060
# Minimum value of tension at fairlead (Line 2): 2969873.815507
# Range for tension at fairlead (Line 2): 10745636.701553
# Mean for tension at fairlead (Line 2): 5009838.909825

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 0             800       800           0  5.338525e+06
# 1             800       800           1  5.203296e+06
# 2             800       800           2  5.179131e+06
# 3             800       800           3  5.130967e+06
# 4             800       800           4  5.061462e+06

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values      0
# R_anchor      0
# z_fairlead    0
# Max           0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 1194          850       840          14  1.096353e+07

# %% [markdown]
# # Sensitivity analysis

# %%
#varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

#varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

#varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
#Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum tension at fairlead for line 2', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='Max', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[0].set_title('Variation of T vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="Max", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[1].set_title('Variation of T vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="Max", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[2].set_title('Variation of T vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['Max']<= df['Max'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_299.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label (Line 2)')

#L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='Max',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Max Tension at fairlead (Line 2)', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
#plot heat map
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#              count          mean           std           min           max
# L_values    1300.0  8.449231e+02  2.328807e+01  8.000000e+02  8.800000e+02
# R_anchor    1300.0  8.347692e+02  2.626962e+01  8.000000e+02  9.000000e+02
# z_fairlead  1300.0  9.500000e+00  5.768500e+00  0.000000e+00  1.900000e+01
# Max         1300.0  5.009839e+06  2.381226e+06  2.969874e+06  1.371551e+07

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['Max']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_299.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_299.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Max
# File_ID
# 0             0.0       0.0    0.000000  0.138086
# 1             0.0       0.0    0.052632  0.081274
# 2             0.0       0.0    0.105263  0.071122
# 3             0.0       0.0    0.157895  0.050888
# 4             0.0       0.0    0.210526  0.021688

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %% [markdown]
# It draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / fan_in) where fan_in is the number of input units in the weight tensor.

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 3.0989 - mse: 3.0989 - val_loss: 2.5254 - val_mse: 2.5254 - 671ms/epoch - 56ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 2.1346 - mse: 2.1346 - val_loss: 1.8443 - val_mse: 1.8443 - 41ms/epoch - 3ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 1.5664 - mse: 1.5664 - val_loss: 1.5212 - val_mse: 1.5212 - 42ms/epoch - 3ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 1.2940 - mse: 1.2940 - val_loss: 1.3748 - val_mse: 1.3748 - 46ms/epoch - 4ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 1.1731 - mse: 1.1731 - val_loss: 1.2834 - val_mse: 1.2834 - 47ms/epoch - 4ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 1.1004 - mse: 1.1004 - val_loss: 1.2176 - val_mse: 1.2176 - 59ms/epoch - 5ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 1.0545 - mse: 1.0545 - val_loss: 1.1668 - val_mse: 1.1668 - 49ms/epoch - 4ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 1.0226 - mse: 1.0226 - val_loss: 1.1318 - val_mse: 1.1318 - 48ms/epoch - 4ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.9964 - mse: 0.9964 - val_loss: 1.1036 - val_mse: 1.1036 - 49ms/epoch - 4ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.9772 - mse: 0.9772 - val_loss: 1.0862 - val_mse: 1.0862 - 50ms/epoch - 4ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.9598 - mse: 0.9598 - val_loss: 1.0680 - val_mse: 1.0680 - 49ms/epoch - 4ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.9452 - mse: 0.9452 - val_loss: 1.0554 - val_mse: 1.0554 - 51ms/epoch - 4ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.9315 - mse: 0.9315 - val_loss: 1.0424 - val_mse: 1.0424 - 54ms/epoch - 4ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.9192 - mse: 0.9192 - val_loss: 1.0344 - val_mse: 1.0344 - 44ms/epoch - 4ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.9074 - mse: 0.9074 - val_loss: 1.0256 - val_mse: 1.0256 - 44ms/epoch - 4ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.8965 - mse: 0.8965 - val_loss: 1.0149 - val_mse: 1.0149 - 44ms/epoch - 4ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.8857 - mse: 0.8857 - val_loss: 1.0010 - val_mse: 1.0010 - 57ms/epoch - 5ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.8765 - mse: 0.8765 - val_loss: 0.9954 - val_mse: 0.9954 - 45ms/epoch - 4ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.8664 - mse: 0.8664 - val_loss: 0.9779 - val_mse: 0.9779 - 55ms/epoch - 5ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.8532 - mse: 0.8532 - val_loss: 0.9719 - val_mse: 0.9719 - 48ms/epoch - 4ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.8419 - mse: 0.8419 - val_loss: 0.9612 - val_mse: 0.9612 - 49ms/epoch - 4ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.8305 - mse: 0.8305 - val_loss: 0.9427 - val_mse: 0.9427 - 44ms/epoch - 4ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.8188 - mse: 0.8188 - val_loss: 0.9336 - val_mse: 0.9336 - 43ms/epoch - 4ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.8091 - mse: 0.8091 - val_loss: 0.9261 - val_mse: 0.9261 - 45ms/epoch - 4ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.7986 - mse: 0.7986 - val_loss: 0.9087 - val_mse: 0.9087 - 43ms/epoch - 4ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.7873 - mse: 0.7873 - val_loss: 0.8995 - val_mse: 0.8995 - 42ms/epoch - 3ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.7768 - mse: 0.7768 - val_loss: 0.8885 - val_mse: 0.8885 - 42ms/epoch - 3ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.7669 - mse: 0.7669 - val_loss: 0.8782 - val_mse: 0.8782 - 42ms/epoch - 3ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.7574 - mse: 0.7574 - val_loss: 0.8652 - val_mse: 0.8652 - 46ms/epoch - 4ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.7483 - mse: 0.7483 - val_loss: 0.8596 - val_mse: 0.8596 - 67ms/epoch - 6ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.7414 - mse: 0.7414 - val_loss: 0.8425 - val_mse: 0.8425 - 67ms/epoch - 6ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.7310 - mse: 0.7310 - val_loss: 0.8418 - val_mse: 0.8418 - 58ms/epoch - 5ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.7228 - mse: 0.7228 - val_loss: 0.8274 - val_mse: 0.8274 - 57ms/epoch - 5ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.7137 - mse: 0.7137 - val_loss: 0.8126 - val_mse: 0.8126 - 63ms/epoch - 5ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.7075 - mse: 0.7075 - val_loss: 0.8110 - val_mse: 0.8110 - 55ms/epoch - 5ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.6986 - mse: 0.6986 - val_loss: 0.7961 - val_mse: 0.7961 - 51ms/epoch - 4ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.6902 - mse: 0.6902 - val_loss: 0.7896 - val_mse: 0.7896 - 53ms/epoch - 4ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.6832 - mse: 0.6832 - val_loss: 0.7853 - val_mse: 0.7853 - 53ms/epoch - 4ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.6769 - mse: 0.6769 - val_loss: 0.7707 - val_mse: 0.7707 - 54ms/epoch - 4ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.6721 - mse: 0.6721 - val_loss: 0.7701 - val_mse: 0.7701 - 52ms/epoch - 4ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.6644 - mse: 0.6644 - val_loss: 0.7536 - val_mse: 0.7536 - 50ms/epoch - 4ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.6587 - mse: 0.6587 - val_loss: 0.7540 - val_mse: 0.7540 - 60ms/epoch - 5ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.6539 - mse: 0.6539 - val_loss: 0.7495 - val_mse: 0.7495 - 55ms/epoch - 5ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.6469 - mse: 0.6469 - val_loss: 0.7389 - val_mse: 0.7389 - 55ms/epoch - 5ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.6428 - mse: 0.6428 - val_loss: 0.7357 - val_mse: 0.7357 - 53ms/epoch - 4ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.6365 - mse: 0.6365 - val_loss: 0.7239 - val_mse: 0.7239 - 53ms/epoch - 4ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.6321 - mse: 0.6321 - val_loss: 0.7226 - val_mse: 0.7226 - 55ms/epoch - 5ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.6267 - mse: 0.6267 - val_loss: 0.7136 - val_mse: 0.7136 - 55ms/epoch - 5ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.6217 - mse: 0.6217 - val_loss: 0.7118 - val_mse: 0.7118 - 53ms/epoch - 4ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.6172 - mse: 0.6172 - val_loss: 0.7040 - val_mse: 0.7040 - 57ms/epoch - 5ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.6132 - mse: 0.6132 - val_loss: 0.7053 - val_mse: 0.7053 - 58ms/epoch - 5ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.6110 - mse: 0.6110 - val_loss: 0.6897 - val_mse: 0.6897 - 59ms/epoch - 5ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.6046 - mse: 0.6046 - val_loss: 0.7002 - val_mse: 0.7002 - 59ms/epoch - 5ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.6028 - mse: 0.6028 - val_loss: 0.6873 - val_mse: 0.6873 - 60ms/epoch - 5ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.6007 - mse: 0.6007 - val_loss: 0.6815 - val_mse: 0.6815 - 53ms/epoch - 4ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.5970 - mse: 0.5970 - val_loss: 0.6763 - val_mse: 0.6763 - 52ms/epoch - 4ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.5923 - mse: 0.5923 - val_loss: 0.6802 - val_mse: 0.6802 - 53ms/epoch - 4ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.5902 - mse: 0.5902 - val_loss: 0.6736 - val_mse: 0.6736 - 52ms/epoch - 4ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.5887 - mse: 0.5887 - val_loss: 0.6667 - val_mse: 0.6667 - 57ms/epoch - 5ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.5845 - mse: 0.5845 - val_loss: 0.6636 - val_mse: 0.6636 - 55ms/epoch - 5ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.5828 - mse: 0.5828 - val_loss: 0.6652 - val_mse: 0.6652 - 53ms/epoch - 4ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.5860 - mse: 0.5860 - val_loss: 0.6603 - val_mse: 0.6603 - 58ms/epoch - 5ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.5796 - mse: 0.5796 - val_loss: 0.6568 - val_mse: 0.6568 - 58ms/epoch - 5ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.5759 - mse: 0.5759 - val_loss: 0.6606 - val_mse: 0.6606 - 53ms/epoch - 4ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.5749 - mse: 0.5749 - val_loss: 0.6588 - val_mse: 0.6588 - 57ms/epoch - 5ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.5731 - mse: 0.5731 - val_loss: 0.6520 - val_mse: 0.6520 - 55ms/epoch - 5ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.5703 - mse: 0.5703 - val_loss: 0.6555 - val_mse: 0.6555 - 62ms/epoch - 5ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.5698 - mse: 0.5698 - val_loss: 0.6508 - val_mse: 0.6508 - 57ms/epoch - 5ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.5705 - mse: 0.5705 - val_loss: 0.6480 - val_mse: 0.6480 - 59ms/epoch - 5ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.5697 - mse: 0.5697 - val_loss: 0.6437 - val_mse: 0.6437 - 56ms/epoch - 5ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.5652 - mse: 0.5652 - val_loss: 0.6502 - val_mse: 0.6502 - 53ms/epoch - 4ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.5654 - mse: 0.5654 - val_loss: 0.6438 - val_mse: 0.6438 - 60ms/epoch - 5ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.5642 - mse: 0.5642 - val_loss: 0.6394 - val_mse: 0.6394 - 58ms/epoch - 5ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.5617 - mse: 0.5617 - val_loss: 0.6465 - val_mse: 0.6465 - 55ms/epoch - 5ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.5592 - mse: 0.5592 - val_loss: 0.6395 - val_mse: 0.6395 - 64ms/epoch - 5ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.5590 - mse: 0.5590 - val_loss: 0.6389 - val_mse: 0.6389 - 62ms/epoch - 5ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.5575 - mse: 0.5575 - val_loss: 0.6376 - val_mse: 0.6376 - 63ms/epoch - 5ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.5580 - mse: 0.5580 - val_loss: 0.6428 - val_mse: 0.6428 - 69ms/epoch - 6ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.5576 - mse: 0.5576 - val_loss: 0.6388 - val_mse: 0.6388 - 67ms/epoch - 6ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.5540 - mse: 0.5540 - val_loss: 0.6350 - val_mse: 0.6350 - 61ms/epoch - 5ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.5524 - mse: 0.5524 - val_loss: 0.6349 - val_mse: 0.6349 - 62ms/epoch - 5ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.5530 - mse: 0.5530 - val_loss: 0.6308 - val_mse: 0.6308 - 58ms/epoch - 5ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.5518 - mse: 0.5518 - val_loss: 0.6358 - val_mse: 0.6358 - 53ms/epoch - 4ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.5513 - mse: 0.5513 - val_loss: 0.6276 - val_mse: 0.6276 - 55ms/epoch - 5ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.5504 - mse: 0.5504 - val_loss: 0.6345 - val_mse: 0.6345 - 58ms/epoch - 5ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.5487 - mse: 0.5487 - val_loss: 0.6297 - val_mse: 0.6297 - 65ms/epoch - 5ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.5535 - mse: 0.5535 - val_loss: 0.6300 - val_mse: 0.6300 - 73ms/epoch - 6ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.5494 - mse: 0.5494 - val_loss: 0.6242 - val_mse: 0.6242 - 63ms/epoch - 5ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.5460 - mse: 0.5460 - val_loss: 0.6298 - val_mse: 0.6298 - 69ms/epoch - 6ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.5460 - mse: 0.5460 - val_loss: 0.6288 - val_mse: 0.6288 - 89ms/epoch - 7ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.5479 - mse: 0.5479 - val_loss: 0.6295 - val_mse: 0.6295 - 92ms/epoch - 8ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.5442 - mse: 0.5442 - val_loss: 0.6305 - val_mse: 0.6305 - 81ms/epoch - 7ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.5434 - mse: 0.5434 - val_loss: 0.6231 - val_mse: 0.6231 - 69ms/epoch - 6ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.5435 - mse: 0.5435 - val_loss: 0.6286 - val_mse: 0.6286 - 65ms/epoch - 5ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.5417 - mse: 0.5417 - val_loss: 0.6223 - val_mse: 0.6223 - 66ms/epoch - 5ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.5426 - mse: 0.5426 - val_loss: 0.6287 - val_mse: 0.6287 - 58ms/epoch - 5ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.5433 - mse: 0.5433 - val_loss: 0.6263 - val_mse: 0.6263 - 58ms/epoch - 5ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.5408 - mse: 0.5408 - val_loss: 0.6249 - val_mse: 0.6249 - 61ms/epoch - 5ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.5420 - mse: 0.5420 - val_loss: 0.6259 - val_mse: 0.6259 - 75ms/epoch - 6ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.5429 - mse: 0.5429 - val_loss: 0.6190 - val_mse: 0.6190 - 61ms/epoch - 5ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.5393 - mse: 0.5393 - val_loss: 0.6215 - val_mse: 0.6215 - 57ms/epoch - 5ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.5391 - mse: 0.5391 - val_loss: 0.6208 - val_mse: 0.6208 - 66ms/epoch - 5ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.5399 - mse: 0.5399 - val_loss: 0.6173 - val_mse: 0.6173 - 57ms/epoch - 5ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.5399 - mse: 0.5399 - val_loss: 0.6194 - val_mse: 0.6194 - 64ms/epoch - 5ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.5375 - mse: 0.5375 - val_loss: 0.6228 - val_mse: 0.6228 - 70ms/epoch - 6ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.5373 - mse: 0.5373 - val_loss: 0.6185 - val_mse: 0.6185 - 58ms/epoch - 5ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.5360 - mse: 0.5360 - val_loss: 0.6165 - val_mse: 0.6165 - 58ms/epoch - 5ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.5391 - mse: 0.5391 - val_loss: 0.6255 - val_mse: 0.6255 - 53ms/epoch - 4ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.5358 - mse: 0.5358 - val_loss: 0.6217 - val_mse: 0.6217 - 57ms/epoch - 5ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.5349 - mse: 0.5349 - val_loss: 0.6164 - val_mse: 0.6164 - 59ms/epoch - 5ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.5331 - mse: 0.5331 - val_loss: 0.6142 - val_mse: 0.6142 - 57ms/epoch - 5ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.5344 - mse: 0.5344 - val_loss: 0.6136 - val_mse: 0.6136 - 53ms/epoch - 4ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.5332 - mse: 0.5332 - val_loss: 0.6180 - val_mse: 0.6180 - 51ms/epoch - 4ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.5325 - mse: 0.5325 - val_loss: 0.6162 - val_mse: 0.6162 - 57ms/epoch - 5ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.5320 - mse: 0.5320 - val_loss: 0.6140 - val_mse: 0.6140 - 57ms/epoch - 5ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.5325 - mse: 0.5325 - val_loss: 0.6141 - val_mse: 0.6141 - 60ms/epoch - 5ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.5309 - mse: 0.5309 - val_loss: 0.6128 - val_mse: 0.6128 - 52ms/epoch - 4ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.5313 - mse: 0.5313 - val_loss: 0.6114 - val_mse: 0.6114 - 54ms/epoch - 4ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.5308 - mse: 0.5308 - val_loss: 0.6132 - val_mse: 0.6132 - 50ms/epoch - 4ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.5292 - mse: 0.5292 - val_loss: 0.6121 - val_mse: 0.6121 - 53ms/epoch - 4ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.5287 - mse: 0.5287 - val_loss: 0.6143 - val_mse: 0.6143 - 52ms/epoch - 4ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.5281 - mse: 0.5281 - val_loss: 0.6120 - val_mse: 0.6120 - 51ms/epoch - 4ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.5294 - mse: 0.5294 - val_loss: 0.6148 - val_mse: 0.6148 - 53ms/epoch - 4ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.5283 - mse: 0.5283 - val_loss: 0.6113 - val_mse: 0.6113 - 51ms/epoch - 4ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.5291 - mse: 0.5291 - val_loss: 0.6131 - val_mse: 0.6131 - 52ms/epoch - 4ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.5277 - mse: 0.5277 - val_loss: 0.6121 - val_mse: 0.6121 - 50ms/epoch - 4ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.5267 - mse: 0.5267 - val_loss: 0.6117 - val_mse: 0.6117 - 54ms/epoch - 4ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.5268 - mse: 0.5268 - val_loss: 0.6113 - val_mse: 0.6113 - 57ms/epoch - 5ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.5296 - mse: 0.5296 - val_loss: 0.6089 - val_mse: 0.6089 - 75ms/epoch - 6ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.5274 - mse: 0.5274 - val_loss: 0.6126 - val_mse: 0.6126 - 70ms/epoch - 6ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.5249 - mse: 0.5249 - val_loss: 0.6069 - val_mse: 0.6069 - 66ms/epoch - 5ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.5256 - mse: 0.5256 - val_loss: 0.6064 - val_mse: 0.6064 - 63ms/epoch - 5ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.5277 - mse: 0.5277 - val_loss: 0.6101 - val_mse: 0.6101 - 57ms/epoch - 5ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.5249 - mse: 0.5249 - val_loss: 0.6054 - val_mse: 0.6054 - 56ms/epoch - 5ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.5242 - mse: 0.5242 - val_loss: 0.6117 - val_mse: 0.6117 - 55ms/epoch - 5ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.5242 - mse: 0.5242 - val_loss: 0.6062 - val_mse: 0.6062 - 69ms/epoch - 6ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.5229 - mse: 0.5229 - val_loss: 0.6049 - val_mse: 0.6049 - 56ms/epoch - 5ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.5225 - mse: 0.5225 - val_loss: 0.6071 - val_mse: 0.6071 - 55ms/epoch - 5ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.5258 - mse: 0.5258 - val_loss: 0.6086 - val_mse: 0.6086 - 59ms/epoch - 5ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.5209 - mse: 0.5209 - val_loss: 0.6054 - val_mse: 0.6054 - 52ms/epoch - 4ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.5216 - mse: 0.5216 - val_loss: 0.6035 - val_mse: 0.6035 - 55ms/epoch - 5ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.5228 - mse: 0.5228 - val_loss: 0.5995 - val_mse: 0.5995 - 47ms/epoch - 4ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.5215 - mse: 0.5215 - val_loss: 0.6091 - val_mse: 0.6091 - 53ms/epoch - 4ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.5220 - mse: 0.5220 - val_loss: 0.5987 - val_mse: 0.5987 - 52ms/epoch - 4ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.5190 - mse: 0.5190 - val_loss: 0.6118 - val_mse: 0.6118 - 56ms/epoch - 5ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.5182 - mse: 0.5182 - val_loss: 0.6027 - val_mse: 0.6027 - 54ms/epoch - 4ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.5185 - mse: 0.5185 - val_loss: 0.6051 - val_mse: 0.6051 - 64ms/epoch - 5ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.5183 - mse: 0.5183 - val_loss: 0.6057 - val_mse: 0.6057 - 56ms/epoch - 5ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.5186 - mse: 0.5186 - val_loss: 0.5974 - val_mse: 0.5974 - 57ms/epoch - 5ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.5174 - mse: 0.5174 - val_loss: 0.6045 - val_mse: 0.6045 - 58ms/epoch - 5ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.5175 - mse: 0.5175 - val_loss: 0.6020 - val_mse: 0.6020 - 59ms/epoch - 5ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.5178 - mse: 0.5178 - val_loss: 0.6060 - val_mse: 0.6060 - 56ms/epoch - 5ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.5163 - mse: 0.5163 - val_loss: 0.6008 - val_mse: 0.6008 - 60ms/epoch - 5ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.5154 - mse: 0.5154 - val_loss: 0.6052 - val_mse: 0.6052 - 65ms/epoch - 5ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.5158 - mse: 0.5158 - val_loss: 0.6001 - val_mse: 0.6001 - 64ms/epoch - 5ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.5150 - mse: 0.5150 - val_loss: 0.6008 - val_mse: 0.6008 - 63ms/epoch - 5ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.5190 - mse: 0.5190 - val_loss: 0.5989 - val_mse: 0.5989 - 63ms/epoch - 5ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.5137 - mse: 0.5137 - val_loss: 0.6039 - val_mse: 0.6039 - 60ms/epoch - 5ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.5133 - mse: 0.5133 - val_loss: 0.5977 - val_mse: 0.5977 - 57ms/epoch - 5ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.5124 - mse: 0.5124 - val_loss: 0.5970 - val_mse: 0.5970 - 61ms/epoch - 5ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.5113 - mse: 0.5113 - val_loss: 0.5936 - val_mse: 0.5936 - 78ms/epoch - 6ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.5119 - mse: 0.5119 - val_loss: 0.5957 - val_mse: 0.5957 - 101ms/epoch - 8ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.5117 - mse: 0.5117 - val_loss: 0.5994 - val_mse: 0.5994 - 75ms/epoch - 6ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.5146 - mse: 0.5146 - val_loss: 0.5998 - val_mse: 0.5998 - 63ms/epoch - 5ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.5111 - mse: 0.5111 - val_loss: 0.5957 - val_mse: 0.5957 - 58ms/epoch - 5ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.5083 - mse: 0.5083 - val_loss: 0.5942 - val_mse: 0.5942 - 62ms/epoch - 5ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.5093 - mse: 0.5093 - val_loss: 0.5972 - val_mse: 0.5972 - 62ms/epoch - 5ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.5118 - mse: 0.5118 - val_loss: 0.5962 - val_mse: 0.5962 - 60ms/epoch - 5ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.5121 - mse: 0.5121 - val_loss: 0.6052 - val_mse: 0.6052 - 68ms/epoch - 6ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.5079 - mse: 0.5079 - val_loss: 0.5913 - val_mse: 0.5913 - 60ms/epoch - 5ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.5085 - mse: 0.5085 - val_loss: 0.5964 - val_mse: 0.5964 - 60ms/epoch - 5ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.5059 - mse: 0.5059 - val_loss: 0.5912 - val_mse: 0.5912 - 67ms/epoch - 6ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.5046 - mse: 0.5046 - val_loss: 0.5979 - val_mse: 0.5979 - 89ms/epoch - 7ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.5053 - mse: 0.5053 - val_loss: 0.5938 - val_mse: 0.5938 - 94ms/epoch - 8ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.5051 - mse: 0.5051 - val_loss: 0.5950 - val_mse: 0.5950 - 77ms/epoch - 6ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.5020 - mse: 0.5020 - val_loss: 0.5883 - val_mse: 0.5883 - 71ms/epoch - 6ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.5042 - mse: 0.5042 - val_loss: 0.5906 - val_mse: 0.5906 - 69ms/epoch - 6ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.5028 - mse: 0.5028 - val_loss: 0.5921 - val_mse: 0.5921 - 71ms/epoch - 6ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.5007 - mse: 0.5007 - val_loss: 0.5868 - val_mse: 0.5868 - 71ms/epoch - 6ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.5015 - mse: 0.5015 - val_loss: 0.5901 - val_mse: 0.5901 - 77ms/epoch - 6ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.5003 - mse: 0.5003 - val_loss: 0.5878 - val_mse: 0.5878 - 76ms/epoch - 6ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.4998 - mse: 0.4998 - val_loss: 0.5871 - val_mse: 0.5871 - 88ms/epoch - 7ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.4991 - mse: 0.4991 - val_loss: 0.5949 - val_mse: 0.5949 - 62ms/epoch - 5ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.4981 - mse: 0.4981 - val_loss: 0.5868 - val_mse: 0.5868 - 66ms/epoch - 5ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.4975 - mse: 0.4975 - val_loss: 0.5873 - val_mse: 0.5873 - 70ms/epoch - 6ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.4974 - mse: 0.4974 - val_loss: 0.5900 - val_mse: 0.5900 - 66ms/epoch - 6ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.4973 - mse: 0.4973 - val_loss: 0.5883 - val_mse: 0.5883 - 78ms/epoch - 6ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.4951 - mse: 0.4951 - val_loss: 0.5914 - val_mse: 0.5914 - 76ms/epoch - 6ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.4971 - mse: 0.4971 - val_loss: 0.5789 - val_mse: 0.5789 - 68ms/epoch - 6ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.4944 - mse: 0.4944 - val_loss: 0.5868 - val_mse: 0.5868 - 64ms/epoch - 5ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.4932 - mse: 0.4932 - val_loss: 0.5799 - val_mse: 0.5799 - 73ms/epoch - 6ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.4928 - mse: 0.4928 - val_loss: 0.5826 - val_mse: 0.5826 - 77ms/epoch - 6ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.4939 - mse: 0.4939 - val_loss: 0.5843 - val_mse: 0.5843 - 67ms/epoch - 6ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.4930 - mse: 0.4930 - val_loss: 0.5791 - val_mse: 0.5791 - 64ms/epoch - 5ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.4915 - mse: 0.4915 - val_loss: 0.5800 - val_mse: 0.5800 - 66ms/epoch - 5ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.4897 - mse: 0.4897 - val_loss: 0.5803 - val_mse: 0.5803 - 67ms/epoch - 6ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.4887 - mse: 0.4887 - val_loss: 0.5765 - val_mse: 0.5765 - 55ms/epoch - 5ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.4889 - mse: 0.4889 - val_loss: 0.5748 - val_mse: 0.5748 - 64ms/epoch - 5ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.4890 - mse: 0.4890 - val_loss: 0.5789 - val_mse: 0.5789 - 71ms/epoch - 6ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.4909 - mse: 0.4909 - val_loss: 0.5788 - val_mse: 0.5788 - 57ms/epoch - 5ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.4865 - mse: 0.4865 - val_loss: 0.5767 - val_mse: 0.5767 - 84ms/epoch - 7ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.4849 - mse: 0.4849 - val_loss: 0.5811 - val_mse: 0.5811 - 85ms/epoch - 7ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.4851 - mse: 0.4851 - val_loss: 0.5754 - val_mse: 0.5754 - 76ms/epoch - 6ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.4850 - mse: 0.4850 - val_loss: 0.5795 - val_mse: 0.5795 - 68ms/epoch - 6ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.4842 - mse: 0.4842 - val_loss: 0.5794 - val_mse: 0.5794 - 68ms/epoch - 6ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.4822 - mse: 0.4822 - val_loss: 0.5784 - val_mse: 0.5784 - 67ms/epoch - 6ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.4813 - mse: 0.4813 - val_loss: 0.5751 - val_mse: 0.5751 - 66ms/epoch - 5ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.4801 - mse: 0.4801 - val_loss: 0.5731 - val_mse: 0.5731 - 71ms/epoch - 6ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.4825 - mse: 0.4825 - val_loss: 0.5746 - val_mse: 0.5746 - 82ms/epoch - 7ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.4814 - mse: 0.4814 - val_loss: 0.5720 - val_mse: 0.5720 - 74ms/epoch - 6ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.4779 - mse: 0.4779 - val_loss: 0.5780 - val_mse: 0.5780 - 76ms/epoch - 6ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.4783 - mse: 0.4783 - val_loss: 0.5695 - val_mse: 0.5695 - 80ms/epoch - 7ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.4777 - mse: 0.4777 - val_loss: 0.5712 - val_mse: 0.5712 - 74ms/epoch - 6ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.4757 - mse: 0.4757 - val_loss: 0.5663 - val_mse: 0.5663 - 84ms/epoch - 7ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.4767 - mse: 0.4767 - val_loss: 0.5737 - val_mse: 0.5737 - 91ms/epoch - 8ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.4745 - mse: 0.4745 - val_loss: 0.5656 - val_mse: 0.5656 - 79ms/epoch - 7ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.4754 - mse: 0.4754 - val_loss: 0.5643 - val_mse: 0.5643 - 80ms/epoch - 7ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.4727 - mse: 0.4727 - val_loss: 0.5692 - val_mse: 0.5692 - 90ms/epoch - 7ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.4717 - mse: 0.4717 - val_loss: 0.5649 - val_mse: 0.5649 - 77ms/epoch - 6ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.4722 - mse: 0.4722 - val_loss: 0.5672 - val_mse: 0.5672 - 75ms/epoch - 6ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.4711 - mse: 0.4711 - val_loss: 0.5630 - val_mse: 0.5630 - 73ms/epoch - 6ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.4697 - mse: 0.4697 - val_loss: 0.5662 - val_mse: 0.5662 - 72ms/epoch - 6ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.4714 - mse: 0.4714 - val_loss: 0.5650 - val_mse: 0.5650 - 81ms/epoch - 7ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.4687 - mse: 0.4687 - val_loss: 0.5638 - val_mse: 0.5638 - 83ms/epoch - 7ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.4679 - mse: 0.4679 - val_loss: 0.5609 - val_mse: 0.5609 - 82ms/epoch - 7ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.4691 - mse: 0.4691 - val_loss: 0.5585 - val_mse: 0.5585 - 86ms/epoch - 7ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.4671 - mse: 0.4671 - val_loss: 0.5718 - val_mse: 0.5718 - 82ms/epoch - 7ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.4679 - mse: 0.4679 - val_loss: 0.5655 - val_mse: 0.5655 - 73ms/epoch - 6ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.4644 - mse: 0.4644 - val_loss: 0.5565 - val_mse: 0.5565 - 79ms/epoch - 7ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.4618 - mse: 0.4618 - val_loss: 0.5613 - val_mse: 0.5613 - 79ms/epoch - 7ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.4611 - mse: 0.4611 - val_loss: 0.5559 - val_mse: 0.5559 - 78ms/epoch - 6ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.4605 - mse: 0.4605 - val_loss: 0.5556 - val_mse: 0.5556 - 73ms/epoch - 6ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.4597 - mse: 0.4597 - val_loss: 0.5560 - val_mse: 0.5560 - 77ms/epoch - 6ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.4599 - mse: 0.4599 - val_loss: 0.5658 - val_mse: 0.5658 - 85ms/epoch - 7ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.4619 - mse: 0.4619 - val_loss: 0.5564 - val_mse: 0.5564 - 137ms/epoch - 11ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.4566 - mse: 0.4566 - val_loss: 0.5506 - val_mse: 0.5506 - 100ms/epoch - 8ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.4576 - mse: 0.4576 - val_loss: 0.5529 - val_mse: 0.5529 - 98ms/epoch - 8ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.4569 - mse: 0.4569 - val_loss: 0.5509 - val_mse: 0.5509 - 88ms/epoch - 7ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.4544 - mse: 0.4544 - val_loss: 0.5512 - val_mse: 0.5512 - 81ms/epoch - 7ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.4527 - mse: 0.4527 - val_loss: 0.5532 - val_mse: 0.5532 - 77ms/epoch - 6ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.4525 - mse: 0.4525 - val_loss: 0.5481 - val_mse: 0.5481 - 69ms/epoch - 6ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.4522 - mse: 0.4522 - val_loss: 0.5471 - val_mse: 0.5471 - 69ms/epoch - 6ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.4500 - mse: 0.4500 - val_loss: 0.5487 - val_mse: 0.5487 - 66ms/epoch - 5ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.4499 - mse: 0.4499 - val_loss: 0.5431 - val_mse: 0.5431 - 70ms/epoch - 6ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.4515 - mse: 0.4515 - val_loss: 0.5479 - val_mse: 0.5479 - 67ms/epoch - 6ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.4499 - mse: 0.4499 - val_loss: 0.5500 - val_mse: 0.5500 - 65ms/epoch - 5ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 0.4505 - mse: 0.4505 - val_loss: 0.5555 - val_mse: 0.5555 - 64ms/epoch - 5ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 0.4528 - mse: 0.4528 - val_loss: 0.5455 - val_mse: 0.5455 - 68ms/epoch - 6ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 0.4470 - mse: 0.4470 - val_loss: 0.5456 - val_mse: 0.5456 - 64ms/epoch - 5ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 0.4449 - mse: 0.4449 - val_loss: 0.5369 - val_mse: 0.5369 - 63ms/epoch - 5ms/step
# Epoch 251/2000
# 12/12 - 0s - loss: 0.4431 - mse: 0.4431 - val_loss: 0.5449 - val_mse: 0.5449 - 72ms/epoch - 6ms/step
# Epoch 252/2000
# 12/12 - 0s - loss: 0.4427 - mse: 0.4427 - val_loss: 0.5419 - val_mse: 0.5419 - 86ms/epoch - 7ms/step
# Epoch 253/2000
# 12/12 - 0s - loss: 0.4411 - mse: 0.4411 - val_loss: 0.5408 - val_mse: 0.5408 - 76ms/epoch - 6ms/step
# Epoch 254/2000
# 12/12 - 0s - loss: 0.4386 - mse: 0.4386 - val_loss: 0.5421 - val_mse: 0.5421 - 101ms/epoch - 8ms/step
# Epoch 255/2000
# 12/12 - 0s - loss: 0.4377 - mse: 0.4377 - val_loss: 0.5390 - val_mse: 0.5390 - 112ms/epoch - 9ms/step
# Epoch 256/2000
# 12/12 - 0s - loss: 0.4372 - mse: 0.4372 - val_loss: 0.5394 - val_mse: 0.5394 - 102ms/epoch - 8ms/step
# Epoch 257/2000
# 12/12 - 0s - loss: 0.4378 - mse: 0.4378 - val_loss: 0.5380 - val_mse: 0.5380 - 134ms/epoch - 11ms/step
# Epoch 258/2000
# 12/12 - 0s - loss: 0.4370 - mse: 0.4370 - val_loss: 0.5399 - val_mse: 0.5399 - 113ms/epoch - 9ms/step
# Epoch 259/2000
# 12/12 - 0s - loss: 0.4339 - mse: 0.4339 - val_loss: 0.5334 - val_mse: 0.5334 - 114ms/epoch - 10ms/step
# Epoch 260/2000
# 12/12 - 0s - loss: 0.4325 - mse: 0.4325 - val_loss: 0.5388 - val_mse: 0.5388 - 84ms/epoch - 7ms/step
# Epoch 261/2000
# 12/12 - 0s - loss: 0.4329 - mse: 0.4329 - val_loss: 0.5380 - val_mse: 0.5380 - 92ms/epoch - 8ms/step
# Epoch 262/2000
# 12/12 - 0s - loss: 0.4337 - mse: 0.4337 - val_loss: 0.5340 - val_mse: 0.5340 - 75ms/epoch - 6ms/step
# Epoch 263/2000
# 12/12 - 0s - loss: 0.4281 - mse: 0.4281 - val_loss: 0.5328 - val_mse: 0.5328 - 80ms/epoch - 7ms/step
# Epoch 264/2000
# 12/12 - 0s - loss: 0.4289 - mse: 0.4289 - val_loss: 0.5303 - val_mse: 0.5303 - 76ms/epoch - 6ms/step
# Epoch 265/2000
# 12/12 - 0s - loss: 0.4275 - mse: 0.4275 - val_loss: 0.5312 - val_mse: 0.5312 - 80ms/epoch - 7ms/step
# Epoch 266/2000
# 12/12 - 0s - loss: 0.4249 - mse: 0.4249 - val_loss: 0.5244 - val_mse: 0.5244 - 70ms/epoch - 6ms/step
# Epoch 267/2000
# 12/12 - 0s - loss: 0.4251 - mse: 0.4251 - val_loss: 0.5280 - val_mse: 0.5280 - 79ms/epoch - 7ms/step
# Epoch 268/2000
# 12/12 - 0s - loss: 0.4262 - mse: 0.4262 - val_loss: 0.5277 - val_mse: 0.5277 - 72ms/epoch - 6ms/step
# Epoch 269/2000
# 12/12 - 0s - loss: 0.4212 - mse: 0.4212 - val_loss: 0.5207 - val_mse: 0.5207 - 73ms/epoch - 6ms/step
# Epoch 270/2000
# 12/12 - 0s - loss: 0.4220 - mse: 0.4220 - val_loss: 0.5252 - val_mse: 0.5252 - 75ms/epoch - 6ms/step
# Epoch 271/2000
# 12/12 - 0s - loss: 0.4194 - mse: 0.4194 - val_loss: 0.5261 - val_mse: 0.5261 - 68ms/epoch - 6ms/step
# Epoch 272/2000
# 12/12 - 0s - loss: 0.4211 - mse: 0.4211 - val_loss: 0.5255 - val_mse: 0.5255 - 77ms/epoch - 6ms/step
# Epoch 273/2000
# 12/12 - 0s - loss: 0.4170 - mse: 0.4170 - val_loss: 0.5183 - val_mse: 0.5183 - 84ms/epoch - 7ms/step
# Epoch 274/2000
# 12/12 - 0s - loss: 0.4151 - mse: 0.4151 - val_loss: 0.5162 - val_mse: 0.5162 - 82ms/epoch - 7ms/step
# Epoch 275/2000
# 12/12 - 0s - loss: 0.4158 - mse: 0.4158 - val_loss: 0.5164 - val_mse: 0.5164 - 81ms/epoch - 7ms/step
# Epoch 276/2000
# 12/12 - 0s - loss: 0.4141 - mse: 0.4141 - val_loss: 0.5139 - val_mse: 0.5139 - 79ms/epoch - 7ms/step
# Epoch 277/2000
# 12/12 - 0s - loss: 0.4119 - mse: 0.4119 - val_loss: 0.5203 - val_mse: 0.5203 - 67ms/epoch - 6ms/step
# Epoch 278/2000
# 12/12 - 0s - loss: 0.4115 - mse: 0.4115 - val_loss: 0.5183 - val_mse: 0.5183 - 70ms/epoch - 6ms/step
# Epoch 279/2000
# 12/12 - 0s - loss: 0.4087 - mse: 0.4087 - val_loss: 0.5134 - val_mse: 0.5134 - 76ms/epoch - 6ms/step
# Epoch 280/2000
# 12/12 - 0s - loss: 0.4079 - mse: 0.4079 - val_loss: 0.5122 - val_mse: 0.5122 - 87ms/epoch - 7ms/step
# Epoch 281/2000
# 12/12 - 0s - loss: 0.4059 - mse: 0.4059 - val_loss: 0.5115 - val_mse: 0.5115 - 86ms/epoch - 7ms/step
# Epoch 282/2000
# 12/12 - 0s - loss: 0.4050 - mse: 0.4050 - val_loss: 0.5170 - val_mse: 0.5170 - 81ms/epoch - 7ms/step
# Epoch 283/2000
# 12/12 - 0s - loss: 0.4043 - mse: 0.4043 - val_loss: 0.5099 - val_mse: 0.5099 - 78ms/epoch - 6ms/step
# Epoch 284/2000
# 12/12 - 0s - loss: 0.4064 - mse: 0.4064 - val_loss: 0.5153 - val_mse: 0.5153 - 97ms/epoch - 8ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 0.4041 - mse: 0.4041 - val_loss: 0.5195 - val_mse: 0.5195 - 110ms/epoch - 9ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 0.4048 - mse: 0.4048 - val_loss: 0.5090 - val_mse: 0.5090 - 127ms/epoch - 11ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 0.3995 - mse: 0.3995 - val_loss: 0.5035 - val_mse: 0.5035 - 137ms/epoch - 11ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 0.3963 - mse: 0.3963 - val_loss: 0.5076 - val_mse: 0.5076 - 105ms/epoch - 9ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 0.3976 - mse: 0.3976 - val_loss: 0.5129 - val_mse: 0.5129 - 121ms/epoch - 10ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 0.3986 - mse: 0.3986 - val_loss: 0.5024 - val_mse: 0.5024 - 113ms/epoch - 9ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 0.3928 - mse: 0.3928 - val_loss: 0.5021 - val_mse: 0.5021 - 89ms/epoch - 7ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 0.3925 - mse: 0.3925 - val_loss: 0.5112 - val_mse: 0.5112 - 89ms/epoch - 7ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 0.3912 - mse: 0.3912 - val_loss: 0.4995 - val_mse: 0.4995 - 85ms/epoch - 7ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 0.3921 - mse: 0.3921 - val_loss: 0.4980 - val_mse: 0.4980 - 85ms/epoch - 7ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 0.3870 - mse: 0.3870 - val_loss: 0.4968 - val_mse: 0.4968 - 91ms/epoch - 8ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 0.3840 - mse: 0.3840 - val_loss: 0.4954 - val_mse: 0.4954 - 96ms/epoch - 8ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 0.3828 - mse: 0.3828 - val_loss: 0.4917 - val_mse: 0.4917 - 85ms/epoch - 7ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 0.3807 - mse: 0.3807 - val_loss: 0.4967 - val_mse: 0.4967 - 86ms/epoch - 7ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 0.3800 - mse: 0.3800 - val_loss: 0.4949 - val_mse: 0.4949 - 95ms/epoch - 8ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 0.3781 - mse: 0.3781 - val_loss: 0.4969 - val_mse: 0.4969 - 90ms/epoch - 7ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 0.3769 - mse: 0.3769 - val_loss: 0.4854 - val_mse: 0.4854 - 78ms/epoch - 6ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 0.3737 - mse: 0.3737 - val_loss: 0.4926 - val_mse: 0.4926 - 85ms/epoch - 7ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 0.3735 - mse: 0.3735 - val_loss: 0.4898 - val_mse: 0.4898 - 74ms/epoch - 6ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 0.3736 - mse: 0.3736 - val_loss: 0.4876 - val_mse: 0.4876 - 73ms/epoch - 6ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 0.3709 - mse: 0.3709 - val_loss: 0.4863 - val_mse: 0.4863 - 84ms/epoch - 7ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 0.3685 - mse: 0.3685 - val_loss: 0.4837 - val_mse: 0.4837 - 87ms/epoch - 7ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 0.3701 - mse: 0.3701 - val_loss: 0.4809 - val_mse: 0.4809 - 91ms/epoch - 8ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 0.3718 - mse: 0.3718 - val_loss: 0.4834 - val_mse: 0.4834 - 122ms/epoch - 10ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 0.3662 - mse: 0.3662 - val_loss: 0.4796 - val_mse: 0.4796 - 153ms/epoch - 13ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 0.3636 - mse: 0.3636 - val_loss: 0.4778 - val_mse: 0.4778 - 134ms/epoch - 11ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 0.3609 - mse: 0.3609 - val_loss: 0.4776 - val_mse: 0.4776 - 116ms/epoch - 10ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 0.3601 - mse: 0.3601 - val_loss: 0.4704 - val_mse: 0.4704 - 110ms/epoch - 9ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 0.3557 - mse: 0.3557 - val_loss: 0.4787 - val_mse: 0.4787 - 107ms/epoch - 9ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 0.3550 - mse: 0.3550 - val_loss: 0.4708 - val_mse: 0.4708 - 93ms/epoch - 8ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 0.3536 - mse: 0.3536 - val_loss: 0.4661 - val_mse: 0.4661 - 92ms/epoch - 8ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 0.3541 - mse: 0.3541 - val_loss: 0.4614 - val_mse: 0.4614 - 85ms/epoch - 7ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 0.3514 - mse: 0.3514 - val_loss: 0.4657 - val_mse: 0.4657 - 79ms/epoch - 7ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 0.3478 - mse: 0.3478 - val_loss: 0.4720 - val_mse: 0.4720 - 79ms/epoch - 7ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 0.3481 - mse: 0.3481 - val_loss: 0.4659 - val_mse: 0.4659 - 71ms/epoch - 6ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 0.3462 - mse: 0.3462 - val_loss: 0.4618 - val_mse: 0.4618 - 71ms/epoch - 6ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 0.3450 - mse: 0.3450 - val_loss: 0.4572 - val_mse: 0.4572 - 64ms/epoch - 5ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 0.3445 - mse: 0.3445 - val_loss: 0.4594 - val_mse: 0.4594 - 80ms/epoch - 7ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 0.3445 - mse: 0.3445 - val_loss: 0.4589 - val_mse: 0.4589 - 84ms/epoch - 7ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 0.3396 - mse: 0.3396 - val_loss: 0.4544 - val_mse: 0.4544 - 117ms/epoch - 10ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 0.3379 - mse: 0.3379 - val_loss: 0.4522 - val_mse: 0.4522 - 100ms/epoch - 8ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 0.3361 - mse: 0.3361 - val_loss: 0.4539 - val_mse: 0.4539 - 79ms/epoch - 7ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 0.3365 - mse: 0.3365 - val_loss: 0.4489 - val_mse: 0.4489 - 81ms/epoch - 7ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 0.3363 - mse: 0.3363 - val_loss: 0.4499 - val_mse: 0.4499 - 79ms/epoch - 7ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 0.3356 - mse: 0.3356 - val_loss: 0.4432 - val_mse: 0.4432 - 84ms/epoch - 7ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 0.3311 - mse: 0.3311 - val_loss: 0.4556 - val_mse: 0.4556 - 92ms/epoch - 8ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 0.3313 - mse: 0.3313 - val_loss: 0.4472 - val_mse: 0.4472 - 84ms/epoch - 7ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 0.3272 - mse: 0.3272 - val_loss: 0.4447 - val_mse: 0.4447 - 79ms/epoch - 7ms/step
# Epoch 333/2000
# 12/12 - 0s - loss: 0.3255 - mse: 0.3255 - val_loss: 0.4511 - val_mse: 0.4511 - 74ms/epoch - 6ms/step
# Epoch 334/2000
# 12/12 - 0s - loss: 0.3252 - mse: 0.3252 - val_loss: 0.4480 - val_mse: 0.4480 - 78ms/epoch - 6ms/step
# Epoch 335/2000
# 12/12 - 0s - loss: 0.3226 - mse: 0.3226 - val_loss: 0.4381 - val_mse: 0.4381 - 82ms/epoch - 7ms/step
# Epoch 336/2000
# 12/12 - 0s - loss: 0.3217 - mse: 0.3217 - val_loss: 0.4432 - val_mse: 0.4432 - 78ms/epoch - 6ms/step
# Epoch 337/2000
# 12/12 - 0s - loss: 0.3190 - mse: 0.3190 - val_loss: 0.4366 - val_mse: 0.4366 - 70ms/epoch - 6ms/step
# Epoch 338/2000
# 12/12 - 0s - loss: 0.3187 - mse: 0.3187 - val_loss: 0.4447 - val_mse: 0.4447 - 97ms/epoch - 8ms/step
# Epoch 339/2000
# 12/12 - 0s - loss: 0.3176 - mse: 0.3176 - val_loss: 0.4359 - val_mse: 0.4359 - 105ms/epoch - 9ms/step
# Epoch 340/2000
# 12/12 - 0s - loss: 0.3160 - mse: 0.3160 - val_loss: 0.4368 - val_mse: 0.4368 - 87ms/epoch - 7ms/step
# Epoch 341/2000
# 12/12 - 0s - loss: 0.3151 - mse: 0.3151 - val_loss: 0.4417 - val_mse: 0.4417 - 77ms/epoch - 6ms/step
# Epoch 342/2000
# 12/12 - 0s - loss: 0.3130 - mse: 0.3130 - val_loss: 0.4366 - val_mse: 0.4366 - 74ms/epoch - 6ms/step
# Epoch 343/2000
# 12/12 - 0s - loss: 0.3112 - mse: 0.3112 - val_loss: 0.4350 - val_mse: 0.4350 - 75ms/epoch - 6ms/step
# Epoch 344/2000
# 12/12 - 0s - loss: 0.3097 - mse: 0.3097 - val_loss: 0.4319 - val_mse: 0.4319 - 70ms/epoch - 6ms/step
# Epoch 345/2000
# 12/12 - 0s - loss: 0.3105 - mse: 0.3105 - val_loss: 0.4290 - val_mse: 0.4290 - 81ms/epoch - 7ms/step
# Epoch 346/2000
# 12/12 - 0s - loss: 0.3151 - mse: 0.3151 - val_loss: 0.4373 - val_mse: 0.4373 - 79ms/epoch - 7ms/step
# Epoch 347/2000
# 12/12 - 0s - loss: 0.3084 - mse: 0.3084 - val_loss: 0.4360 - val_mse: 0.4360 - 81ms/epoch - 7ms/step
# Epoch 348/2000
# 12/12 - 0s - loss: 0.3048 - mse: 0.3048 - val_loss: 0.4266 - val_mse: 0.4266 - 85ms/epoch - 7ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 0.3042 - mse: 0.3042 - val_loss: 0.4320 - val_mse: 0.4320 - 74ms/epoch - 6ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 0.3028 - mse: 0.3028 - val_loss: 0.4331 - val_mse: 0.4331 - 73ms/epoch - 6ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 0.3013 - mse: 0.3013 - val_loss: 0.4276 - val_mse: 0.4276 - 72ms/epoch - 6ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 0.3009 - mse: 0.3009 - val_loss: 0.4278 - val_mse: 0.4278 - 74ms/epoch - 6ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 0.3014 - mse: 0.3014 - val_loss: 0.4213 - val_mse: 0.4213 - 80ms/epoch - 7ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 0.2982 - mse: 0.2982 - val_loss: 0.4399 - val_mse: 0.4399 - 80ms/epoch - 7ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 0.3000 - mse: 0.3000 - val_loss: 0.4200 - val_mse: 0.4200 - 91ms/epoch - 8ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 0.2963 - mse: 0.2963 - val_loss: 0.4220 - val_mse: 0.4220 - 76ms/epoch - 6ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 0.2954 - mse: 0.2954 - val_loss: 0.4238 - val_mse: 0.4238 - 73ms/epoch - 6ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 0.2922 - mse: 0.2922 - val_loss: 0.4224 - val_mse: 0.4224 - 80ms/epoch - 7ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 0.2920 - mse: 0.2920 - val_loss: 0.4232 - val_mse: 0.4232 - 78ms/epoch - 6ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 0.2905 - mse: 0.2905 - val_loss: 0.4192 - val_mse: 0.4192 - 85ms/epoch - 7ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 0.2884 - mse: 0.2884 - val_loss: 0.4133 - val_mse: 0.4133 - 82ms/epoch - 7ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 0.2903 - mse: 0.2903 - val_loss: 0.4167 - val_mse: 0.4167 - 84ms/epoch - 7ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 0.2873 - mse: 0.2873 - val_loss: 0.4135 - val_mse: 0.4135 - 78ms/epoch - 6ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 0.2859 - mse: 0.2859 - val_loss: 0.4154 - val_mse: 0.4154 - 83ms/epoch - 7ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 0.2890 - mse: 0.2890 - val_loss: 0.4253 - val_mse: 0.4253 - 76ms/epoch - 6ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 0.2860 - mse: 0.2860 - val_loss: 0.4247 - val_mse: 0.4247 - 76ms/epoch - 6ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 0.2839 - mse: 0.2839 - val_loss: 0.4103 - val_mse: 0.4103 - 76ms/epoch - 6ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 0.2830 - mse: 0.2830 - val_loss: 0.4100 - val_mse: 0.4100 - 79ms/epoch - 7ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 0.2813 - mse: 0.2813 - val_loss: 0.4091 - val_mse: 0.4091 - 81ms/epoch - 7ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 0.2806 - mse: 0.2806 - val_loss: 0.4010 - val_mse: 0.4010 - 69ms/epoch - 6ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 0.2807 - mse: 0.2807 - val_loss: 0.4049 - val_mse: 0.4049 - 75ms/epoch - 6ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 0.2801 - mse: 0.2801 - val_loss: 0.4052 - val_mse: 0.4052 - 76ms/epoch - 6ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 0.2774 - mse: 0.2774 - val_loss: 0.4074 - val_mse: 0.4074 - 74ms/epoch - 6ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 0.2753 - mse: 0.2753 - val_loss: 0.4002 - val_mse: 0.4002 - 73ms/epoch - 6ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 0.2742 - mse: 0.2742 - val_loss: 0.4042 - val_mse: 0.4042 - 88ms/epoch - 7ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 0.2752 - mse: 0.2752 - val_loss: 0.4160 - val_mse: 0.4160 - 88ms/epoch - 7ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 0.2787 - mse: 0.2787 - val_loss: 0.4015 - val_mse: 0.4015 - 84ms/epoch - 7ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 0.2759 - mse: 0.2759 - val_loss: 0.3999 - val_mse: 0.3999 - 86ms/epoch - 7ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 0.2762 - mse: 0.2762 - val_loss: 0.4018 - val_mse: 0.4018 - 80ms/epoch - 7ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 0.2807 - mse: 0.2807 - val_loss: 0.3967 - val_mse: 0.3967 - 82ms/epoch - 7ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 0.2765 - mse: 0.2765 - val_loss: 0.3989 - val_mse: 0.3989 - 79ms/epoch - 7ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 0.2694 - mse: 0.2694 - val_loss: 0.3997 - val_mse: 0.3997 - 80ms/epoch - 7ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 0.2669 - mse: 0.2669 - val_loss: 0.3952 - val_mse: 0.3952 - 75ms/epoch - 6ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 0.2663 - mse: 0.2663 - val_loss: 0.3955 - val_mse: 0.3955 - 84ms/epoch - 7ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 0.2646 - mse: 0.2646 - val_loss: 0.3933 - val_mse: 0.3933 - 98ms/epoch - 8ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 0.2640 - mse: 0.2640 - val_loss: 0.3976 - val_mse: 0.3976 - 105ms/epoch - 9ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 0.2654 - mse: 0.2654 - val_loss: 0.3954 - val_mse: 0.3954 - 98ms/epoch - 8ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 0.2633 - mse: 0.2633 - val_loss: 0.3937 - val_mse: 0.3937 - 86ms/epoch - 7ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 0.2614 - mse: 0.2614 - val_loss: 0.3913 - val_mse: 0.3913 - 125ms/epoch - 10ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 0.2607 - mse: 0.2607 - val_loss: 0.4008 - val_mse: 0.4008 - 104ms/epoch - 9ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 0.2609 - mse: 0.2609 - val_loss: 0.3916 - val_mse: 0.3916 - 102ms/epoch - 8ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 0.2631 - mse: 0.2631 - val_loss: 0.3847 - val_mse: 0.3847 - 93ms/epoch - 8ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 0.2600 - mse: 0.2600 - val_loss: 0.3891 - val_mse: 0.3891 - 86ms/epoch - 7ms/step
# Epoch 394/2000
# 12/12 - 0s - loss: 0.2593 - mse: 0.2593 - val_loss: 0.3821 - val_mse: 0.3821 - 76ms/epoch - 6ms/step
# Epoch 395/2000
# 12/12 - 0s - loss: 0.2574 - mse: 0.2574 - val_loss: 0.3938 - val_mse: 0.3938 - 73ms/epoch - 6ms/step
# Epoch 396/2000
# 12/12 - 0s - loss: 0.2582 - mse: 0.2582 - val_loss: 0.3845 - val_mse: 0.3845 - 77ms/epoch - 6ms/step
# Epoch 397/2000
# 12/12 - 0s - loss: 0.2559 - mse: 0.2559 - val_loss: 0.3848 - val_mse: 0.3848 - 69ms/epoch - 6ms/step
# Epoch 398/2000
# 12/12 - 0s - loss: 0.2550 - mse: 0.2550 - val_loss: 0.3822 - val_mse: 0.3822 - 76ms/epoch - 6ms/step
# Epoch 399/2000
# 12/12 - 0s - loss: 0.2548 - mse: 0.2548 - val_loss: 0.3836 - val_mse: 0.3836 - 77ms/epoch - 6ms/step
# Epoch 400/2000
# 12/12 - 0s - loss: 0.2519 - mse: 0.2519 - val_loss: 0.3802 - val_mse: 0.3802 - 73ms/epoch - 6ms/step
# Epoch 401/2000
# 12/12 - 0s - loss: 0.2534 - mse: 0.2534 - val_loss: 0.3825 - val_mse: 0.3825 - 72ms/epoch - 6ms/step
# Epoch 402/2000
# 12/12 - 0s - loss: 0.2614 - mse: 0.2614 - val_loss: 0.4001 - val_mse: 0.4001 - 69ms/epoch - 6ms/step
# Epoch 403/2000
# 12/12 - 0s - loss: 0.2517 - mse: 0.2517 - val_loss: 0.3851 - val_mse: 0.3851 - 75ms/epoch - 6ms/step
# Epoch 404/2000
# 12/12 - 0s - loss: 0.2499 - mse: 0.2499 - val_loss: 0.3785 - val_mse: 0.3785 - 73ms/epoch - 6ms/step
# Epoch 405/2000
# 12/12 - 0s - loss: 0.2474 - mse: 0.2474 - val_loss: 0.3794 - val_mse: 0.3794 - 67ms/epoch - 6ms/step
# Epoch 406/2000
# 12/12 - 0s - loss: 0.2472 - mse: 0.2472 - val_loss: 0.3765 - val_mse: 0.3765 - 69ms/epoch - 6ms/step
# Epoch 407/2000
# 12/12 - 0s - loss: 0.2483 - mse: 0.2483 - val_loss: 0.3720 - val_mse: 0.3720 - 77ms/epoch - 6ms/step
# Epoch 408/2000
# 12/12 - 0s - loss: 0.2455 - mse: 0.2455 - val_loss: 0.3899 - val_mse: 0.3899 - 106ms/epoch - 9ms/step
# Epoch 409/2000
# 12/12 - 0s - loss: 0.2493 - mse: 0.2493 - val_loss: 0.3816 - val_mse: 0.3816 - 89ms/epoch - 7ms/step
# Epoch 410/2000
# 12/12 - 0s - loss: 0.2479 - mse: 0.2479 - val_loss: 0.3756 - val_mse: 0.3756 - 93ms/epoch - 8ms/step
# Epoch 411/2000
# 12/12 - 0s - loss: 0.2444 - mse: 0.2444 - val_loss: 0.3744 - val_mse: 0.3744 - 86ms/epoch - 7ms/step
# Epoch 412/2000
# 12/12 - 0s - loss: 0.2423 - mse: 0.2423 - val_loss: 0.3716 - val_mse: 0.3716 - 75ms/epoch - 6ms/step
# Epoch 413/2000
# 12/12 - 0s - loss: 0.2464 - mse: 0.2464 - val_loss: 0.3758 - val_mse: 0.3758 - 71ms/epoch - 6ms/step
# Epoch 414/2000
# 12/12 - 0s - loss: 0.2430 - mse: 0.2430 - val_loss: 0.3786 - val_mse: 0.3786 - 71ms/epoch - 6ms/step
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 12/12 - 0s - loss: 0.0127 - mse: 0.0127 - val_loss: 0.0301 - val_mse: 0.0301 - 130ms/epoch - 11ms/step
# Epoch 1866/2000
# 12/12 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0280 - val_mse: 0.0280 - 102ms/epoch - 8ms/step
# Epoch 1867/2000
# 12/12 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0271 - val_mse: 0.0271 - 90ms/epoch - 7ms/step
# Epoch 1868/2000
# 12/12 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0278 - val_mse: 0.0278 - 80ms/epoch - 7ms/step
# Epoch 1869/2000
# 12/12 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0278 - val_mse: 0.0278 - 88ms/epoch - 7ms/step
# Epoch 1870/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0271 - val_mse: 0.0271 - 84ms/epoch - 7ms/step
# Epoch 1871/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0287 - val_mse: 0.0287 - 80ms/epoch - 7ms/step
# Epoch 1872/2000
# 12/12 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0270 - val_mse: 0.0270 - 76ms/epoch - 6ms/step
# Epoch 1873/2000
# 12/12 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0277 - val_mse: 0.0277 - 83ms/epoch - 7ms/step
# Epoch 1874/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0271 - val_mse: 0.0271 - 82ms/epoch - 7ms/step
# Epoch 1875/2000
# 12/12 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0273 - val_mse: 0.0273 - 88ms/epoch - 7ms/step
# Epoch 1876/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0277 - val_mse: 0.0277 - 75ms/epoch - 6ms/step
# Epoch 1877/2000
# 12/12 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0271 - val_mse: 0.0271 - 82ms/epoch - 7ms/step
# Epoch 1878/2000
# 12/12 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0263 - val_mse: 0.0263 - 76ms/epoch - 6ms/step
# Epoch 1879/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0280 - val_mse: 0.0280 - 77ms/epoch - 6ms/step
# Epoch 1880/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0266 - val_mse: 0.0266 - 82ms/epoch - 7ms/step
# Epoch 1881/2000
# 12/12 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0254 - val_mse: 0.0254 - 140ms/epoch - 12ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0282 - val_mse: 0.0282 - 99ms/epoch - 8ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0279 - val_mse: 0.0279 - 98ms/epoch - 8ms/step
# Epoch 1884/2000
# 12/12 - 0s - loss: 0.0135 - mse: 0.0135 - val_loss: 0.0256 - val_mse: 0.0256 - 84ms/epoch - 7ms/step
# Epoch 1885/2000
# 12/12 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0281 - val_mse: 0.0281 - 84ms/epoch - 7ms/step
# Epoch 1886/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0252 - val_mse: 0.0252 - 80ms/epoch - 7ms/step
# Epoch 1887/2000
# 12/12 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0259 - val_mse: 0.0259 - 88ms/epoch - 7ms/step
# Epoch 1888/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0266 - val_mse: 0.0266 - 79ms/epoch - 7ms/step
# Epoch 1889/2000
# 12/12 - 0s - loss: 0.0118 - mse: 0.0118 - val_loss: 0.0258 - val_mse: 0.0258 - 78ms/epoch - 6ms/step
# Epoch 1890/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0255 - val_mse: 0.0255 - 80ms/epoch - 7ms/step
# Epoch 1891/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0288 - val_mse: 0.0288 - 82ms/epoch - 7ms/step
# Epoch 1892/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0271 - val_mse: 0.0271 - 83ms/epoch - 7ms/step
# Epoch 1893/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0266 - val_mse: 0.0266 - 80ms/epoch - 7ms/step
# Epoch 1894/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0259 - val_mse: 0.0259 - 83ms/epoch - 7ms/step
# Epoch 1895/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0273 - val_mse: 0.0273 - 78ms/epoch - 7ms/step
# Epoch 1896/2000
# 12/12 - 0s - loss: 0.0122 - mse: 0.0122 - val_loss: 0.0269 - val_mse: 0.0269 - 78ms/epoch - 6ms/step
# Epoch 1897/2000
# 12/12 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0263 - val_mse: 0.0263 - 89ms/epoch - 7ms/step
# Epoch 1898/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0259 - val_mse: 0.0259 - 79ms/epoch - 7ms/step
# Epoch 1899/2000
# 12/12 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0265 - val_mse: 0.0265 - 97ms/epoch - 8ms/step
# Epoch 1900/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0265 - val_mse: 0.0265 - 116ms/epoch - 10ms/step
# Epoch 1901/2000
# 12/12 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0256 - val_mse: 0.0256 - 120ms/epoch - 10ms/step
# Epoch 1902/2000
# 12/12 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0251 - val_mse: 0.0251 - 97ms/epoch - 8ms/step
# Epoch 1903/2000
# 12/12 - 0s - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0293 - val_mse: 0.0293 - 87ms/epoch - 7ms/step
# Epoch 1904/2000
# 12/12 - 0s - loss: 0.0131 - mse: 0.0131 - val_loss: 0.0253 - val_mse: 0.0253 - 80ms/epoch - 7ms/step
# Epoch 1905/2000
# 12/12 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0256 - val_mse: 0.0256 - 85ms/epoch - 7ms/step
# Epoch 1906/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0247 - val_mse: 0.0247 - 80ms/epoch - 7ms/step
# Epoch 1907/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0261 - val_mse: 0.0261 - 84ms/epoch - 7ms/step
# Epoch 1908/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0259 - val_mse: 0.0259 - 83ms/epoch - 7ms/step
# Epoch 1909/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0247 - val_mse: 0.0247 - 75ms/epoch - 6ms/step
# Epoch 1910/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0245 - val_mse: 0.0245 - 79ms/epoch - 7ms/step
# Epoch 1911/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0248 - val_mse: 0.0248 - 89ms/epoch - 7ms/step
# Epoch 1912/2000
# 12/12 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0280 - val_mse: 0.0280 - 116ms/epoch - 10ms/step
# Epoch 1913/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0245 - val_mse: 0.0245 - 98ms/epoch - 8ms/step
# Epoch 1914/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0259 - val_mse: 0.0259 - 98ms/epoch - 8ms/step
# Epoch 1915/2000
# 12/12 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0268 - val_mse: 0.0268 - 94ms/epoch - 8ms/step
# Epoch 1916/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0249 - val_mse: 0.0249 - 78ms/epoch - 6ms/step
# Epoch 1917/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0246 - val_mse: 0.0246 - 84ms/epoch - 7ms/step
# Epoch 1918/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0254 - val_mse: 0.0254 - 82ms/epoch - 7ms/step
# Epoch 1919/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0262 - val_mse: 0.0262 - 82ms/epoch - 7ms/step
# Epoch 1920/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0272 - val_mse: 0.0272 - 80ms/epoch - 7ms/step
# Epoch 1921/2000
# 12/12 - 0s - loss: 0.0128 - mse: 0.0128 - val_loss: 0.0247 - val_mse: 0.0247 - 75ms/epoch - 6ms/step
# Epoch 1922/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0259 - val_mse: 0.0259 - 79ms/epoch - 7ms/step
# Epoch 1923/2000
# 12/12 - 0s - loss: 0.0125 - mse: 0.0125 - val_loss: 0.0241 - val_mse: 0.0241 - 81ms/epoch - 7ms/step
# Epoch 1924/2000
# 12/12 - 0s - loss: 0.0129 - mse: 0.0129 - val_loss: 0.0334 - val_mse: 0.0334 - 76ms/epoch - 6ms/step
# Epoch 1925/2000
# 12/12 - 0s - loss: 0.0123 - mse: 0.0123 - val_loss: 0.0262 - val_mse: 0.0262 - 107ms/epoch - 9ms/step
# Epoch 1926/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0250 - val_mse: 0.0250 - 108ms/epoch - 9ms/step
# Epoch 1927/2000
# 12/12 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0247 - val_mse: 0.0247 - 102ms/epoch - 8ms/step
# Epoch 1928/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0267 - val_mse: 0.0267 - 83ms/epoch - 7ms/step
# Epoch 1929/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0274 - val_mse: 0.0274 - 88ms/epoch - 7ms/step
# Epoch 1930/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0248 - val_mse: 0.0248 - 80ms/epoch - 7ms/step
# Epoch 1931/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0247 - val_mse: 0.0247 - 98ms/epoch - 8ms/step
# Epoch 1932/2000
# 12/12 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0262 - val_mse: 0.0262 - 90ms/epoch - 7ms/step
# Epoch 1933/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0238 - val_mse: 0.0238 - 87ms/epoch - 7ms/step
# Epoch 1934/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0251 - val_mse: 0.0251 - 81ms/epoch - 7ms/step
# Epoch 1935/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0244 - val_mse: 0.0244 - 88ms/epoch - 7ms/step
# Epoch 1936/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0247 - val_mse: 0.0247 - 82ms/epoch - 7ms/step
# Epoch 1937/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0261 - val_mse: 0.0261 - 76ms/epoch - 6ms/step
# Epoch 1938/2000
# 12/12 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0253 - val_mse: 0.0253 - 73ms/epoch - 6ms/step
# Epoch 1939/2000
# 12/12 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0237 - val_mse: 0.0237 - 76ms/epoch - 6ms/step
# Epoch 1940/2000
# 12/12 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0249 - val_mse: 0.0249 - 94ms/epoch - 8ms/step
# Epoch 1941/2000
# 12/12 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0239 - val_mse: 0.0239 - 88ms/epoch - 7ms/step
# Epoch 1942/2000
# 12/12 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0274 - val_mse: 0.0274 - 83ms/epoch - 7ms/step
# Epoch 1943/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0245 - val_mse: 0.0245 - 78ms/epoch - 6ms/step
# Epoch 1944/2000
# 12/12 - 0s - loss: 0.0112 - mse: 0.0112 - val_loss: 0.0262 - val_mse: 0.0262 - 87ms/epoch - 7ms/step
# Epoch 1945/2000
# 12/12 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0234 - val_mse: 0.0234 - 85ms/epoch - 7ms/step
# Epoch 1946/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0252 - val_mse: 0.0252 - 151ms/epoch - 13ms/step
# Epoch 1947/2000
# 12/12 - 0s - loss: 0.0113 - mse: 0.0113 - val_loss: 0.0240 - val_mse: 0.0240 - 120ms/epoch - 10ms/step
# Epoch 1948/2000
# 12/12 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0271 - val_mse: 0.0271 - 93ms/epoch - 8ms/step
# Epoch 1949/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0240 - val_mse: 0.0240 - 87ms/epoch - 7ms/step
# Epoch 1950/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0242 - val_mse: 0.0242 - 87ms/epoch - 7ms/step
# Epoch 1951/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0250 - val_mse: 0.0250 - 95ms/epoch - 8ms/step
# Epoch 1952/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0264 - val_mse: 0.0264 - 94ms/epoch - 8ms/step
# Epoch 1953/2000
# 12/12 - 0s - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0262 - val_mse: 0.0262 - 83ms/epoch - 7ms/step
# Epoch 1954/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0239 - val_mse: 0.0239 - 77ms/epoch - 6ms/step
# Epoch 1955/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0235 - val_mse: 0.0235 - 122ms/epoch - 10ms/step
# Epoch 1956/2000
# 12/12 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0261 - val_mse: 0.0261 - 120ms/epoch - 10ms/step
# Epoch 1957/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0262 - val_mse: 0.0262 - 92ms/epoch - 8ms/step
# Epoch 1958/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0253 - val_mse: 0.0253 - 90ms/epoch - 7ms/step
# Epoch 1959/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0244 - val_mse: 0.0244 - 85ms/epoch - 7ms/step
# Epoch 1960/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0237 - val_mse: 0.0237 - 92ms/epoch - 8ms/step
# Epoch 1961/2000
# 12/12 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0231 - val_mse: 0.0231 - 85ms/epoch - 7ms/step
# Epoch 1962/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0233 - val_mse: 0.0233 - 77ms/epoch - 6ms/step
# Epoch 1963/2000
# 12/12 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0277 - val_mse: 0.0277 - 79ms/epoch - 7ms/step
# Epoch 1964/2000
# 12/12 - 0s - loss: 0.0117 - mse: 0.0117 - val_loss: 0.0306 - val_mse: 0.0306 - 74ms/epoch - 6ms/step
# Epoch 1965/2000
# 12/12 - 0s - loss: 0.0130 - mse: 0.0130 - val_loss: 0.0232 - val_mse: 0.0232 - 85ms/epoch - 7ms/step
# Epoch 1966/2000
# 12/12 - 0s - loss: 0.0105 - mse: 0.0105 - val_loss: 0.0235 - val_mse: 0.0235 - 79ms/epoch - 7ms/step
# Epoch 1967/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0242 - val_mse: 0.0242 - 119ms/epoch - 10ms/step
# Epoch 1968/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0259 - val_mse: 0.0259 - 118ms/epoch - 10ms/step
# Epoch 1969/2000
# 12/12 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0227 - val_mse: 0.0227 - 97ms/epoch - 8ms/step
# Epoch 1970/2000
# 12/12 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0233 - val_mse: 0.0233 - 87ms/epoch - 7ms/step
# Epoch 1971/2000
# 12/12 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0239 - val_mse: 0.0239 - 88ms/epoch - 7ms/step
# Epoch 1972/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0224 - val_mse: 0.0224 - 80ms/epoch - 7ms/step
# Epoch 1973/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0245 - val_mse: 0.0245 - 78ms/epoch - 6ms/step
# Epoch 1974/2000
# 12/12 - 0s - loss: 0.0114 - mse: 0.0114 - val_loss: 0.0227 - val_mse: 0.0227 - 86ms/epoch - 7ms/step
# Epoch 1975/2000
# 12/12 - 0s - loss: 0.0106 - mse: 0.0106 - val_loss: 0.0224 - val_mse: 0.0224 - 79ms/epoch - 7ms/step
# Epoch 1976/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0226 - val_mse: 0.0226 - 79ms/epoch - 7ms/step
# Epoch 1977/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0229 - val_mse: 0.0229 - 82ms/epoch - 7ms/step
# Epoch 1978/2000
# 12/12 - 0s - loss: 0.0109 - mse: 0.0109 - val_loss: 0.0225 - val_mse: 0.0225 - 100ms/epoch - 8ms/step
# Epoch 1979/2000
# 12/12 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0230 - val_mse: 0.0230 - 99ms/epoch - 8ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0234 - val_mse: 0.0234 - 100ms/epoch - 8ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 0.0110 - mse: 0.0110 - val_loss: 0.0222 - val_mse: 0.0222 - 76ms/epoch - 6ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0247 - val_mse: 0.0247 - 91ms/epoch - 8ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0240 - val_mse: 0.0240 - 81ms/epoch - 7ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0240 - val_mse: 0.0240 - 84ms/epoch - 7ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0251 - val_mse: 0.0251 - 79ms/epoch - 7ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 0.0121 - mse: 0.0121 - val_loss: 0.0236 - val_mse: 0.0236 - 79ms/epoch - 7ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0305 - val_mse: 0.0305 - 76ms/epoch - 6ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 0.0119 - mse: 0.0119 - val_loss: 0.0249 - val_mse: 0.0249 - 80ms/epoch - 7ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0244 - val_mse: 0.0244 - 80ms/epoch - 7ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0226 - val_mse: 0.0226 - 80ms/epoch - 7ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 0.0102 - mse: 0.0102 - val_loss: 0.0244 - val_mse: 0.0244 - 83ms/epoch - 7ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 0.0116 - mse: 0.0116 - val_loss: 0.0298 - val_mse: 0.0298 - 125ms/epoch - 10ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 0.0108 - mse: 0.0108 - val_loss: 0.0235 - val_mse: 0.0235 - 126ms/epoch - 10ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0244 - val_mse: 0.0244 - 104ms/epoch - 9ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0237 - val_mse: 0.0237 - 87ms/epoch - 7ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0224 - val_mse: 0.0224 - 99ms/epoch - 8ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 0.0098 - mse: 0.0098 - val_loss: 0.0217 - val_mse: 0.0217 - 89ms/epoch - 7ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0221 - val_mse: 0.0221 - 94ms/epoch - 8ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0218 - val_mse: 0.0218 - 93ms/epoch - 8ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0223 - val_mse: 0.0223 - 91ms/epoch - 8ms/step

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

#recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
# plt.title('model loss')
# plt.xlim([-20, 1800])
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 20)                80
#
#  second_layer (Dense)        (None, 10)                210
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.090

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.982

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
# plt.plot(y_test.iloc[:,0], y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2.5, -0.5))
plt.annotate("MAE = {:.3f}".format(error), (2.5, -0.8))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
# plt.title('Validation of the prediction model')     
plt.grid(True)

# plt.savefig('model validation.png', transparent=True)
plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_299')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_299\assets
