# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

sns.set_style("darkgrid")

# %% [markdown]
#     219 : ESYS line2 SENSOR 4 - Tension at Anchor - Trained on Max values

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_219.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Max']]

# %%
print('Maximum value of tension at anchor (Line 2): %.6f' % df['Max'].max())
print('Minimum value of tension at anchor (Line 2): %.6f' % df['Max'].min())
print('Range for tension at anchor (Line 2): %.6f' % (df['Max'].max()-df['Max'].min()))
print('Mean for tension at anchor (Line 2): %.6f' % (np.mean(df['Max'])))
# Out:
# Maximum value of tension at anchor (Line 2): 12552122.344282
# Minimum value of tension at anchor (Line 2): 1780633.063357
# Range for tension at anchor (Line 2): 10771489.280925
# Mean for tension at anchor (Line 2): 3850563.409145

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 0             800       800           0  4.137950e+06
# 1             800       800           1  4.030663e+06
# 2             800       800           2  3.982488e+06
# 3             800       800           3  3.922873e+06
# 4             800       800           4  3.892788e+06

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values      0
# R_anchor      0
# z_fairlead    0
# Max           0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 1194          850       840          14  9.842373e+06

# %% [markdown]
# # Sensitivity analysis

# %%
#varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

#varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

#varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
#Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum tension at anchor for line 2', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='Max', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[0].set_title('Variation of T vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="Max", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[1].set_title('Variation of T vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="Max", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[2].set_title('Variation of T vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['Max']<= df['Max'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_219.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label (Line 2)')

#L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='Max',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Max Tension at anchor (Line 2)', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
#plot heat map
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#              count          mean           std           min           max
# L_values    1300.0  8.449231e+02  2.328807e+01  8.000000e+02  8.800000e+02
# R_anchor    1300.0  8.347692e+02  2.626962e+01  8.000000e+02  9.000000e+02
# z_fairlead  1300.0  9.500000e+00  5.768500e+00  0.000000e+00  1.900000e+01
# Max         1300.0  3.850563e+06  2.385836e+06  1.780633e+06  1.255212e+07

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['Max']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_219.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_219.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Max
# File_ID
# 0             0.0       0.0    0.000000  0.120502
# 1             0.0       0.0    0.052632  0.075516
# 2             0.0       0.0    0.105263  0.055316
# 3             0.0       0.0    0.157895  0.030319
# 4             0.0       0.0    0.210526  0.017705

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %% [markdown]
# he_normal :It draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / fan_in) where fan_in is the number of input units in the weight tensor.

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 1.2612 - mse: 1.2612 - val_loss: 1.1924 - val_mse: 1.1924 - 1s/epoch - 106ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 1.1035 - mse: 1.1035 - val_loss: 1.1056 - val_mse: 1.1056 - 64ms/epoch - 5ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 1.0246 - mse: 1.0246 - val_loss: 1.0779 - val_mse: 1.0779 - 77ms/epoch - 6ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 0.9995 - mse: 0.9995 - val_loss: 1.0686 - val_mse: 1.0686 - 66ms/epoch - 6ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 0.9841 - mse: 0.9841 - val_loss: 1.0590 - val_mse: 1.0590 - 67ms/epoch - 6ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 0.9682 - mse: 0.9682 - val_loss: 1.0443 - val_mse: 1.0443 - 72ms/epoch - 6ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 0.9509 - mse: 0.9509 - val_loss: 1.0292 - val_mse: 1.0292 - 71ms/epoch - 6ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 0.9322 - mse: 0.9322 - val_loss: 1.0197 - val_mse: 1.0197 - 69ms/epoch - 6ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.9183 - mse: 0.9183 - val_loss: 1.0117 - val_mse: 1.0117 - 70ms/epoch - 6ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.9036 - mse: 0.9036 - val_loss: 0.9995 - val_mse: 0.9995 - 71ms/epoch - 6ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.8896 - mse: 0.8896 - val_loss: 0.9902 - val_mse: 0.9902 - 67ms/epoch - 6ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.8772 - mse: 0.8772 - val_loss: 0.9828 - val_mse: 0.9828 - 67ms/epoch - 6ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.8660 - mse: 0.8660 - val_loss: 0.9730 - val_mse: 0.9730 - 73ms/epoch - 6ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.8537 - mse: 0.8537 - val_loss: 0.9633 - val_mse: 0.9633 - 76ms/epoch - 6ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.8394 - mse: 0.8394 - val_loss: 0.9511 - val_mse: 0.9511 - 83ms/epoch - 7ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.8272 - mse: 0.8272 - val_loss: 0.9392 - val_mse: 0.9392 - 74ms/epoch - 6ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.8138 - mse: 0.8138 - val_loss: 0.9251 - val_mse: 0.9251 - 68ms/epoch - 6ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.8009 - mse: 0.8009 - val_loss: 0.9131 - val_mse: 0.9131 - 71ms/epoch - 6ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.7895 - mse: 0.7895 - val_loss: 0.9035 - val_mse: 0.9035 - 72ms/epoch - 6ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.7793 - mse: 0.7793 - val_loss: 0.8932 - val_mse: 0.8932 - 73ms/epoch - 6ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.7696 - mse: 0.7696 - val_loss: 0.8856 - val_mse: 0.8856 - 75ms/epoch - 6ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.7611 - mse: 0.7611 - val_loss: 0.8776 - val_mse: 0.8776 - 69ms/epoch - 6ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.7546 - mse: 0.7546 - val_loss: 0.8679 - val_mse: 0.8679 - 71ms/epoch - 6ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.7463 - mse: 0.7463 - val_loss: 0.8637 - val_mse: 0.8637 - 74ms/epoch - 6ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.7386 - mse: 0.7386 - val_loss: 0.8587 - val_mse: 0.8587 - 74ms/epoch - 6ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.7318 - mse: 0.7318 - val_loss: 0.8516 - val_mse: 0.8516 - 72ms/epoch - 6ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.7250 - mse: 0.7250 - val_loss: 0.8395 - val_mse: 0.8395 - 72ms/epoch - 6ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.7179 - mse: 0.7179 - val_loss: 0.8372 - val_mse: 0.8372 - 70ms/epoch - 6ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.7106 - mse: 0.7106 - val_loss: 0.8268 - val_mse: 0.8268 - 65ms/epoch - 5ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.7042 - mse: 0.7042 - val_loss: 0.8196 - val_mse: 0.8196 - 65ms/epoch - 5ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.6984 - mse: 0.6984 - val_loss: 0.8094 - val_mse: 0.8094 - 65ms/epoch - 5ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.6917 - mse: 0.6917 - val_loss: 0.8094 - val_mse: 0.8094 - 82ms/epoch - 7ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.6851 - mse: 0.6851 - val_loss: 0.7969 - val_mse: 0.7969 - 70ms/epoch - 6ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.6789 - mse: 0.6789 - val_loss: 0.7951 - val_mse: 0.7951 - 71ms/epoch - 6ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.6720 - mse: 0.6720 - val_loss: 0.7826 - val_mse: 0.7826 - 74ms/epoch - 6ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.6646 - mse: 0.6646 - val_loss: 0.7737 - val_mse: 0.7737 - 65ms/epoch - 5ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.6589 - mse: 0.6589 - val_loss: 0.7691 - val_mse: 0.7691 - 69ms/epoch - 6ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.6517 - mse: 0.6517 - val_loss: 0.7592 - val_mse: 0.7592 - 71ms/epoch - 6ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.6463 - mse: 0.6463 - val_loss: 0.7546 - val_mse: 0.7546 - 68ms/epoch - 6ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.6397 - mse: 0.6397 - val_loss: 0.7476 - val_mse: 0.7476 - 71ms/epoch - 6ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.6330 - mse: 0.6330 - val_loss: 0.7437 - val_mse: 0.7437 - 65ms/epoch - 5ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.6287 - mse: 0.6287 - val_loss: 0.7355 - val_mse: 0.7355 - 66ms/epoch - 5ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.6218 - mse: 0.6218 - val_loss: 0.7345 - val_mse: 0.7345 - 70ms/epoch - 6ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.6176 - mse: 0.6176 - val_loss: 0.7273 - val_mse: 0.7273 - 75ms/epoch - 6ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.6111 - mse: 0.6111 - val_loss: 0.7234 - val_mse: 0.7234 - 66ms/epoch - 5ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.6056 - mse: 0.6056 - val_loss: 0.7103 - val_mse: 0.7103 - 66ms/epoch - 5ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.6012 - mse: 0.6012 - val_loss: 0.7069 - val_mse: 0.7069 - 67ms/epoch - 6ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.5964 - mse: 0.5964 - val_loss: 0.7056 - val_mse: 0.7056 - 72ms/epoch - 6ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.5913 - mse: 0.5913 - val_loss: 0.7021 - val_mse: 0.7021 - 75ms/epoch - 6ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.5873 - mse: 0.5873 - val_loss: 0.6913 - val_mse: 0.6913 - 87ms/epoch - 7ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.5828 - mse: 0.5828 - val_loss: 0.6913 - val_mse: 0.6913 - 80ms/epoch - 7ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.5786 - mse: 0.5786 - val_loss: 0.6865 - val_mse: 0.6865 - 68ms/epoch - 6ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.5749 - mse: 0.5749 - val_loss: 0.6849 - val_mse: 0.6849 - 93ms/epoch - 8ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.5720 - mse: 0.5720 - val_loss: 0.6799 - val_mse: 0.6799 - 74ms/epoch - 6ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.5680 - mse: 0.5680 - val_loss: 0.6731 - val_mse: 0.6731 - 96ms/epoch - 8ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.5664 - mse: 0.5664 - val_loss: 0.6739 - val_mse: 0.6739 - 89ms/epoch - 7ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.5632 - mse: 0.5632 - val_loss: 0.6706 - val_mse: 0.6706 - 114ms/epoch - 9ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.5580 - mse: 0.5580 - val_loss: 0.6678 - val_mse: 0.6678 - 132ms/epoch - 11ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.5553 - mse: 0.5553 - val_loss: 0.6639 - val_mse: 0.6639 - 88ms/epoch - 7ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.5539 - mse: 0.5539 - val_loss: 0.6648 - val_mse: 0.6648 - 81ms/epoch - 7ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.5507 - mse: 0.5507 - val_loss: 0.6595 - val_mse: 0.6595 - 85ms/epoch - 7ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.5456 - mse: 0.5456 - val_loss: 0.6598 - val_mse: 0.6598 - 98ms/epoch - 8ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.5425 - mse: 0.5425 - val_loss: 0.6549 - val_mse: 0.6549 - 108ms/epoch - 9ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.5393 - mse: 0.5393 - val_loss: 0.6489 - val_mse: 0.6489 - 98ms/epoch - 8ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.5362 - mse: 0.5362 - val_loss: 0.6528 - val_mse: 0.6528 - 83ms/epoch - 7ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.5341 - mse: 0.5341 - val_loss: 0.6512 - val_mse: 0.6512 - 82ms/epoch - 7ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.5317 - mse: 0.5317 - val_loss: 0.6485 - val_mse: 0.6485 - 80ms/epoch - 7ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.5298 - mse: 0.5298 - val_loss: 0.6451 - val_mse: 0.6451 - 84ms/epoch - 7ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.5272 - mse: 0.5272 - val_loss: 0.6425 - val_mse: 0.6425 - 79ms/epoch - 7ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.5286 - mse: 0.5286 - val_loss: 0.6485 - val_mse: 0.6485 - 95ms/epoch - 8ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.5212 - mse: 0.5212 - val_loss: 0.6373 - val_mse: 0.6373 - 133ms/epoch - 11ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.5219 - mse: 0.5219 - val_loss: 0.6402 - val_mse: 0.6402 - 103ms/epoch - 9ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.5219 - mse: 0.5219 - val_loss: 0.6434 - val_mse: 0.6434 - 99ms/epoch - 8ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.5187 - mse: 0.5187 - val_loss: 0.6415 - val_mse: 0.6415 - 91ms/epoch - 8ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.5182 - mse: 0.5182 - val_loss: 0.6375 - val_mse: 0.6375 - 86ms/epoch - 7ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.5141 - mse: 0.5141 - val_loss: 0.6326 - val_mse: 0.6326 - 87ms/epoch - 7ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.5126 - mse: 0.5126 - val_loss: 0.6314 - val_mse: 0.6314 - 124ms/epoch - 10ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.5105 - mse: 0.5105 - val_loss: 0.6313 - val_mse: 0.6313 - 105ms/epoch - 9ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.5072 - mse: 0.5072 - val_loss: 0.6327 - val_mse: 0.6327 - 114ms/epoch - 9ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.5052 - mse: 0.5052 - val_loss: 0.6274 - val_mse: 0.6274 - 89ms/epoch - 7ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.5061 - mse: 0.5061 - val_loss: 0.6271 - val_mse: 0.6271 - 76ms/epoch - 6ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.5018 - mse: 0.5018 - val_loss: 0.6241 - val_mse: 0.6241 - 79ms/epoch - 7ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.5008 - mse: 0.5008 - val_loss: 0.6238 - val_mse: 0.6238 - 83ms/epoch - 7ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.4979 - mse: 0.4979 - val_loss: 0.6269 - val_mse: 0.6269 - 80ms/epoch - 7ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.4960 - mse: 0.4960 - val_loss: 0.6210 - val_mse: 0.6210 - 119ms/epoch - 10ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.4956 - mse: 0.4956 - val_loss: 0.6236 - val_mse: 0.6236 - 95ms/epoch - 8ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.4972 - mse: 0.4972 - val_loss: 0.6156 - val_mse: 0.6156 - 80ms/epoch - 7ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.4921 - mse: 0.4921 - val_loss: 0.6204 - val_mse: 0.6204 - 70ms/epoch - 6ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.4909 - mse: 0.4909 - val_loss: 0.6205 - val_mse: 0.6205 - 84ms/epoch - 7ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.4904 - mse: 0.4904 - val_loss: 0.6153 - val_mse: 0.6153 - 79ms/epoch - 7ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.4887 - mse: 0.4887 - val_loss: 0.6190 - val_mse: 0.6190 - 71ms/epoch - 6ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.4906 - mse: 0.4906 - val_loss: 0.6198 - val_mse: 0.6198 - 75ms/epoch - 6ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.4875 - mse: 0.4875 - val_loss: 0.6168 - val_mse: 0.6168 - 70ms/epoch - 6ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.4840 - mse: 0.4840 - val_loss: 0.6141 - val_mse: 0.6141 - 71ms/epoch - 6ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.4840 - mse: 0.4840 - val_loss: 0.6094 - val_mse: 0.6094 - 71ms/epoch - 6ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.4820 - mse: 0.4820 - val_loss: 0.6111 - val_mse: 0.6111 - 65ms/epoch - 5ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.4799 - mse: 0.4799 - val_loss: 0.6140 - val_mse: 0.6140 - 64ms/epoch - 5ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.4775 - mse: 0.4775 - val_loss: 0.6095 - val_mse: 0.6095 - 65ms/epoch - 5ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.4772 - mse: 0.4772 - val_loss: 0.6087 - val_mse: 0.6087 - 63ms/epoch - 5ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.4771 - mse: 0.4771 - val_loss: 0.6138 - val_mse: 0.6138 - 61ms/epoch - 5ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.4751 - mse: 0.4751 - val_loss: 0.6069 - val_mse: 0.6069 - 61ms/epoch - 5ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.4721 - mse: 0.4721 - val_loss: 0.6062 - val_mse: 0.6062 - 62ms/epoch - 5ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.4717 - mse: 0.4717 - val_loss: 0.6058 - val_mse: 0.6058 - 59ms/epoch - 5ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.4690 - mse: 0.4690 - val_loss: 0.6053 - val_mse: 0.6053 - 68ms/epoch - 6ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.4677 - mse: 0.4677 - val_loss: 0.6050 - val_mse: 0.6050 - 62ms/epoch - 5ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.4704 - mse: 0.4704 - val_loss: 0.5988 - val_mse: 0.5988 - 71ms/epoch - 6ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.4659 - mse: 0.4659 - val_loss: 0.6029 - val_mse: 0.6029 - 65ms/epoch - 5ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.4653 - mse: 0.4653 - val_loss: 0.6061 - val_mse: 0.6061 - 64ms/epoch - 5ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.4623 - mse: 0.4623 - val_loss: 0.5951 - val_mse: 0.5951 - 62ms/epoch - 5ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.4609 - mse: 0.4609 - val_loss: 0.5938 - val_mse: 0.5938 - 71ms/epoch - 6ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.4600 - mse: 0.4600 - val_loss: 0.5947 - val_mse: 0.5947 - 64ms/epoch - 5ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.4589 - mse: 0.4589 - val_loss: 0.5973 - val_mse: 0.5973 - 65ms/epoch - 5ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.4579 - mse: 0.4579 - val_loss: 0.5986 - val_mse: 0.5986 - 61ms/epoch - 5ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.4580 - mse: 0.4580 - val_loss: 0.5933 - val_mse: 0.5933 - 61ms/epoch - 5ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.4553 - mse: 0.4553 - val_loss: 0.5903 - val_mse: 0.5903 - 63ms/epoch - 5ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.4540 - mse: 0.4540 - val_loss: 0.5932 - val_mse: 0.5932 - 62ms/epoch - 5ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.4548 - mse: 0.4548 - val_loss: 0.5907 - val_mse: 0.5907 - 64ms/epoch - 5ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.4513 - mse: 0.4513 - val_loss: 0.5905 - val_mse: 0.5905 - 62ms/epoch - 5ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.4531 - mse: 0.4531 - val_loss: 0.5901 - val_mse: 0.5901 - 60ms/epoch - 5ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.4493 - mse: 0.4493 - val_loss: 0.5882 - val_mse: 0.5882 - 64ms/epoch - 5ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.4494 - mse: 0.4494 - val_loss: 0.5849 - val_mse: 0.5849 - 61ms/epoch - 5ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.4499 - mse: 0.4499 - val_loss: 0.5831 - val_mse: 0.5831 - 64ms/epoch - 5ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.4470 - mse: 0.4470 - val_loss: 0.5824 - val_mse: 0.5824 - 65ms/epoch - 5ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.4455 - mse: 0.4455 - val_loss: 0.5861 - val_mse: 0.5861 - 60ms/epoch - 5ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.4447 - mse: 0.4447 - val_loss: 0.5829 - val_mse: 0.5829 - 63ms/epoch - 5ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.4441 - mse: 0.4441 - val_loss: 0.5853 - val_mse: 0.5853 - 66ms/epoch - 6ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.4450 - mse: 0.4450 - val_loss: 0.5842 - val_mse: 0.5842 - 64ms/epoch - 5ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.4490 - mse: 0.4490 - val_loss: 0.5821 - val_mse: 0.5821 - 67ms/epoch - 6ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.4506 - mse: 0.4506 - val_loss: 0.5849 - val_mse: 0.5849 - 66ms/epoch - 5ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.4430 - mse: 0.4430 - val_loss: 0.5826 - val_mse: 0.5826 - 73ms/epoch - 6ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.4401 - mse: 0.4401 - val_loss: 0.5796 - val_mse: 0.5796 - 65ms/epoch - 5ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.4409 - mse: 0.4409 - val_loss: 0.5834 - val_mse: 0.5834 - 68ms/epoch - 6ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.4407 - mse: 0.4407 - val_loss: 0.5812 - val_mse: 0.5812 - 66ms/epoch - 5ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.4376 - mse: 0.4376 - val_loss: 0.5749 - val_mse: 0.5749 - 61ms/epoch - 5ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.4378 - mse: 0.4378 - val_loss: 0.5737 - val_mse: 0.5737 - 60ms/epoch - 5ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.4354 - mse: 0.4354 - val_loss: 0.5735 - val_mse: 0.5735 - 68ms/epoch - 6ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.4356 - mse: 0.4356 - val_loss: 0.5731 - val_mse: 0.5731 - 62ms/epoch - 5ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.4341 - mse: 0.4341 - val_loss: 0.5746 - val_mse: 0.5746 - 66ms/epoch - 5ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.4329 - mse: 0.4329 - val_loss: 0.5737 - val_mse: 0.5737 - 60ms/epoch - 5ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.4317 - mse: 0.4317 - val_loss: 0.5748 - val_mse: 0.5748 - 64ms/epoch - 5ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.4312 - mse: 0.4312 - val_loss: 0.5726 - val_mse: 0.5726 - 63ms/epoch - 5ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.4296 - mse: 0.4296 - val_loss: 0.5698 - val_mse: 0.5698 - 72ms/epoch - 6ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.4298 - mse: 0.4298 - val_loss: 0.5676 - val_mse: 0.5676 - 76ms/epoch - 6ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.4282 - mse: 0.4282 - val_loss: 0.5686 - val_mse: 0.5686 - 95ms/epoch - 8ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.4279 - mse: 0.4279 - val_loss: 0.5693 - val_mse: 0.5693 - 96ms/epoch - 8ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.4263 - mse: 0.4263 - val_loss: 0.5687 - val_mse: 0.5687 - 77ms/epoch - 6ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.4276 - mse: 0.4276 - val_loss: 0.5667 - val_mse: 0.5667 - 73ms/epoch - 6ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.4242 - mse: 0.4242 - val_loss: 0.5686 - val_mse: 0.5686 - 73ms/epoch - 6ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.4240 - mse: 0.4240 - val_loss: 0.5670 - val_mse: 0.5670 - 114ms/epoch - 9ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.4232 - mse: 0.4232 - val_loss: 0.5662 - val_mse: 0.5662 - 93ms/epoch - 8ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.4215 - mse: 0.4215 - val_loss: 0.5682 - val_mse: 0.5682 - 93ms/epoch - 8ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.4214 - mse: 0.4214 - val_loss: 0.5636 - val_mse: 0.5636 - 83ms/epoch - 7ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.4209 - mse: 0.4209 - val_loss: 0.5609 - val_mse: 0.5609 - 74ms/epoch - 6ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.4195 - mse: 0.4195 - val_loss: 0.5632 - val_mse: 0.5632 - 68ms/epoch - 6ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.4188 - mse: 0.4188 - val_loss: 0.5653 - val_mse: 0.5653 - 70ms/epoch - 6ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.4174 - mse: 0.4174 - val_loss: 0.5575 - val_mse: 0.5575 - 65ms/epoch - 5ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.4180 - mse: 0.4180 - val_loss: 0.5608 - val_mse: 0.5608 - 65ms/epoch - 5ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.4184 - mse: 0.4184 - val_loss: 0.5612 - val_mse: 0.5612 - 63ms/epoch - 5ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.4185 - mse: 0.4185 - val_loss: 0.5635 - val_mse: 0.5635 - 65ms/epoch - 5ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.4167 - mse: 0.4167 - val_loss: 0.5549 - val_mse: 0.5549 - 64ms/epoch - 5ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.4163 - mse: 0.4163 - val_loss: 0.5589 - val_mse: 0.5589 - 70ms/epoch - 6ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.4124 - mse: 0.4124 - val_loss: 0.5574 - val_mse: 0.5574 - 68ms/epoch - 6ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.4120 - mse: 0.4120 - val_loss: 0.5562 - val_mse: 0.5562 - 72ms/epoch - 6ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.4121 - mse: 0.4121 - val_loss: 0.5511 - val_mse: 0.5511 - 68ms/epoch - 6ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.4138 - mse: 0.4138 - val_loss: 0.5499 - val_mse: 0.5499 - 65ms/epoch - 5ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.4104 - mse: 0.4104 - val_loss: 0.5518 - val_mse: 0.5518 - 67ms/epoch - 6ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.4091 - mse: 0.4091 - val_loss: 0.5555 - val_mse: 0.5555 - 62ms/epoch - 5ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.4098 - mse: 0.4098 - val_loss: 0.5525 - val_mse: 0.5525 - 62ms/epoch - 5ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.4112 - mse: 0.4112 - val_loss: 0.5487 - val_mse: 0.5487 - 63ms/epoch - 5ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.4077 - mse: 0.4077 - val_loss: 0.5560 - val_mse: 0.5560 - 59ms/epoch - 5ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.4068 - mse: 0.4068 - val_loss: 0.5494 - val_mse: 0.5494 - 60ms/epoch - 5ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.4056 - mse: 0.4056 - val_loss: 0.5465 - val_mse: 0.5465 - 64ms/epoch - 5ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.4047 - mse: 0.4047 - val_loss: 0.5473 - val_mse: 0.5473 - 69ms/epoch - 6ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.4031 - mse: 0.4031 - val_loss: 0.5479 - val_mse: 0.5479 - 60ms/epoch - 5ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.4022 - mse: 0.4022 - val_loss: 0.5466 - val_mse: 0.5466 - 70ms/epoch - 6ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.4013 - mse: 0.4013 - val_loss: 0.5449 - val_mse: 0.5449 - 62ms/epoch - 5ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.4024 - mse: 0.4024 - val_loss: 0.5449 - val_mse: 0.5449 - 61ms/epoch - 5ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.4012 - mse: 0.4012 - val_loss: 0.5474 - val_mse: 0.5474 - 61ms/epoch - 5ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.3990 - mse: 0.3990 - val_loss: 0.5438 - val_mse: 0.5438 - 61ms/epoch - 5ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.3977 - mse: 0.3977 - val_loss: 0.5419 - val_mse: 0.5419 - 70ms/epoch - 6ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.3968 - mse: 0.3968 - val_loss: 0.5428 - val_mse: 0.5428 - 73ms/epoch - 6ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.3974 - mse: 0.3974 - val_loss: 0.5449 - val_mse: 0.5449 - 61ms/epoch - 5ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.3958 - mse: 0.3958 - val_loss: 0.5386 - val_mse: 0.5386 - 65ms/epoch - 5ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.3971 - mse: 0.3971 - val_loss: 0.5423 - val_mse: 0.5423 - 63ms/epoch - 5ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.3937 - mse: 0.3937 - val_loss: 0.5375 - val_mse: 0.5375 - 57ms/epoch - 5ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.3937 - mse: 0.3937 - val_loss: 0.5383 - val_mse: 0.5383 - 60ms/epoch - 5ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.3928 - mse: 0.3928 - val_loss: 0.5427 - val_mse: 0.5427 - 73ms/epoch - 6ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.3938 - mse: 0.3938 - val_loss: 0.5367 - val_mse: 0.5367 - 77ms/epoch - 6ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.3911 - mse: 0.3911 - val_loss: 0.5379 - val_mse: 0.5379 - 89ms/epoch - 7ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.3900 - mse: 0.3900 - val_loss: 0.5334 - val_mse: 0.5334 - 107ms/epoch - 9ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.3895 - mse: 0.3895 - val_loss: 0.5324 - val_mse: 0.5324 - 79ms/epoch - 7ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.3880 - mse: 0.3880 - val_loss: 0.5329 - val_mse: 0.5329 - 73ms/epoch - 6ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.3880 - mse: 0.3880 - val_loss: 0.5317 - val_mse: 0.5317 - 71ms/epoch - 6ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.3882 - mse: 0.3882 - val_loss: 0.5354 - val_mse: 0.5354 - 71ms/epoch - 6ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.3901 - mse: 0.3901 - val_loss: 0.5264 - val_mse: 0.5264 - 71ms/epoch - 6ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.3852 - mse: 0.3852 - val_loss: 0.5290 - val_mse: 0.5290 - 67ms/epoch - 6ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.3853 - mse: 0.3853 - val_loss: 0.5326 - val_mse: 0.5326 - 72ms/epoch - 6ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.3835 - mse: 0.3835 - val_loss: 0.5290 - val_mse: 0.5290 - 64ms/epoch - 5ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.3825 - mse: 0.3825 - val_loss: 0.5249 - val_mse: 0.5249 - 66ms/epoch - 5ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.3823 - mse: 0.3823 - val_loss: 0.5284 - val_mse: 0.5284 - 68ms/epoch - 6ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.3824 - mse: 0.3824 - val_loss: 0.5242 - val_mse: 0.5242 - 69ms/epoch - 6ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.3795 - mse: 0.3795 - val_loss: 0.5193 - val_mse: 0.5193 - 66ms/epoch - 5ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.3787 - mse: 0.3787 - val_loss: 0.5242 - val_mse: 0.5242 - 67ms/epoch - 6ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.3784 - mse: 0.3784 - val_loss: 0.5200 - val_mse: 0.5200 - 63ms/epoch - 5ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.3794 - mse: 0.3794 - val_loss: 0.5193 - val_mse: 0.5193 - 68ms/epoch - 6ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.3757 - mse: 0.3757 - val_loss: 0.5214 - val_mse: 0.5214 - 61ms/epoch - 5ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.3756 - mse: 0.3756 - val_loss: 0.5186 - val_mse: 0.5186 - 64ms/epoch - 5ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.3761 - mse: 0.3761 - val_loss: 0.5191 - val_mse: 0.5191 - 66ms/epoch - 5ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.3729 - mse: 0.3729 - val_loss: 0.5214 - val_mse: 0.5214 - 61ms/epoch - 5ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.3731 - mse: 0.3731 - val_loss: 0.5160 - val_mse: 0.5160 - 64ms/epoch - 5ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.3709 - mse: 0.3709 - val_loss: 0.5186 - val_mse: 0.5186 - 64ms/epoch - 5ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.3704 - mse: 0.3704 - val_loss: 0.5162 - val_mse: 0.5162 - 72ms/epoch - 6ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.3704 - mse: 0.3704 - val_loss: 0.5149 - val_mse: 0.5149 - 72ms/epoch - 6ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.3680 - mse: 0.3680 - val_loss: 0.5092 - val_mse: 0.5092 - 60ms/epoch - 5ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.3693 - mse: 0.3693 - val_loss: 0.5151 - val_mse: 0.5151 - 64ms/epoch - 5ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.3670 - mse: 0.3670 - val_loss: 0.5167 - val_mse: 0.5167 - 67ms/epoch - 6ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.3655 - mse: 0.3655 - val_loss: 0.5084 - val_mse: 0.5084 - 59ms/epoch - 5ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.3643 - mse: 0.3643 - val_loss: 0.5063 - val_mse: 0.5063 - 61ms/epoch - 5ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.3667 - mse: 0.3667 - val_loss: 0.5128 - val_mse: 0.5128 - 61ms/epoch - 5ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.3654 - mse: 0.3654 - val_loss: 0.5043 - val_mse: 0.5043 - 63ms/epoch - 5ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.3618 - mse: 0.3618 - val_loss: 0.5130 - val_mse: 0.5130 - 68ms/epoch - 6ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.3607 - mse: 0.3607 - val_loss: 0.5031 - val_mse: 0.5031 - 60ms/epoch - 5ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.3610 - mse: 0.3610 - val_loss: 0.5001 - val_mse: 0.5001 - 62ms/epoch - 5ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.3574 - mse: 0.3574 - val_loss: 0.5045 - val_mse: 0.5045 - 61ms/epoch - 5ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4999 - val_mse: 0.4999 - 60ms/epoch - 5ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4982 - val_mse: 0.4982 - 88ms/epoch - 7ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.3551 - mse: 0.3551 - val_loss: 0.5000 - val_mse: 0.5000 - 86ms/epoch - 7ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.3560 - mse: 0.3560 - val_loss: 0.5035 - val_mse: 0.5035 - 72ms/epoch - 6ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4971 - val_mse: 0.4971 - 69ms/epoch - 6ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.3509 - mse: 0.3509 - val_loss: 0.4973 - val_mse: 0.4973 - 63ms/epoch - 5ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.3500 - mse: 0.3500 - val_loss: 0.4882 - val_mse: 0.4882 - 70ms/epoch - 6ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.3467 - mse: 0.3467 - val_loss: 0.4905 - val_mse: 0.4905 - 71ms/epoch - 6ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.3464 - mse: 0.3464 - val_loss: 0.4889 - val_mse: 0.4889 - 68ms/epoch - 6ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.3445 - mse: 0.3445 - val_loss: 0.4836 - val_mse: 0.4836 - 72ms/epoch - 6ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.3429 - mse: 0.3429 - val_loss: 0.4891 - val_mse: 0.4891 - 69ms/epoch - 6ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.3431 - mse: 0.3431 - val_loss: 0.4840 - val_mse: 0.4840 - 76ms/epoch - 6ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.3393 - mse: 0.3393 - val_loss: 0.4840 - val_mse: 0.4840 - 75ms/epoch - 6ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.3376 - mse: 0.3376 - val_loss: 0.4849 - val_mse: 0.4849 - 74ms/epoch - 6ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.3374 - mse: 0.3374 - val_loss: 0.4832 - val_mse: 0.4832 - 77ms/epoch - 6ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.3359 - mse: 0.3359 - val_loss: 0.4814 - val_mse: 0.4814 - 66ms/epoch - 5ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.3360 - mse: 0.3360 - val_loss: 0.4776 - val_mse: 0.4776 - 60ms/epoch - 5ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.3321 - mse: 0.3321 - val_loss: 0.4807 - val_mse: 0.4807 - 64ms/epoch - 5ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.3339 - mse: 0.3339 - val_loss: 0.4765 - val_mse: 0.4765 - 64ms/epoch - 5ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.3329 - mse: 0.3329 - val_loss: 0.4735 - val_mse: 0.4735 - 64ms/epoch - 5ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.3310 - mse: 0.3310 - val_loss: 0.4758 - val_mse: 0.4758 - 62ms/epoch - 5ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.3287 - mse: 0.3287 - val_loss: 0.4707 - val_mse: 0.4707 - 64ms/epoch - 5ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 0.3266 - mse: 0.3266 - val_loss: 0.4711 - val_mse: 0.4711 - 66ms/epoch - 5ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 0.3253 - mse: 0.3253 - val_loss: 0.4694 - val_mse: 0.4694 - 60ms/epoch - 5ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 0.3239 - mse: 0.3239 - val_loss: 0.4659 - val_mse: 0.4659 - 61ms/epoch - 5ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 0.3235 - mse: 0.3235 - val_loss: 0.4645 - val_mse: 0.4645 - 60ms/epoch - 5ms/step
# Epoch 251/2000
# 12/12 - 0s - loss: 0.3224 - mse: 0.3224 - val_loss: 0.4628 - val_mse: 0.4628 - 59ms/epoch - 5ms/step
# Epoch 252/2000
# 12/12 - 0s - loss: 0.3219 - mse: 0.3219 - val_loss: 0.4615 - val_mse: 0.4615 - 69ms/epoch - 6ms/step
# Epoch 253/2000
# 12/12 - 0s - loss: 0.3187 - mse: 0.3187 - val_loss: 0.4602 - val_mse: 0.4602 - 58ms/epoch - 5ms/step
# Epoch 254/2000
# 12/12 - 0s - loss: 0.3200 - mse: 0.3200 - val_loss: 0.4639 - val_mse: 0.4639 - 64ms/epoch - 5ms/step
# Epoch 255/2000
# 12/12 - 0s - loss: 0.3177 - mse: 0.3177 - val_loss: 0.4554 - val_mse: 0.4554 - 62ms/epoch - 5ms/step
# Epoch 256/2000
# 12/12 - 0s - loss: 0.3141 - mse: 0.3141 - val_loss: 0.4659 - val_mse: 0.4659 - 59ms/epoch - 5ms/step
# Epoch 257/2000
# 12/12 - 0s - loss: 0.3163 - mse: 0.3163 - val_loss: 0.4564 - val_mse: 0.4564 - 103ms/epoch - 9ms/step
# Epoch 258/2000
# 12/12 - 0s - loss: 0.3162 - mse: 0.3162 - val_loss: 0.4545 - val_mse: 0.4545 - 92ms/epoch - 8ms/step
# Epoch 259/2000
# 12/12 - 0s - loss: 0.3105 - mse: 0.3105 - val_loss: 0.4531 - val_mse: 0.4531 - 73ms/epoch - 6ms/step
# Epoch 260/2000
# 12/12 - 0s - loss: 0.3088 - mse: 0.3088 - val_loss: 0.4562 - val_mse: 0.4562 - 71ms/epoch - 6ms/step
# Epoch 261/2000
# 12/12 - 0s - loss: 0.3081 - mse: 0.3081 - val_loss: 0.4503 - val_mse: 0.4503 - 76ms/epoch - 6ms/step
# Epoch 262/2000
# 12/12 - 0s - loss: 0.3073 - mse: 0.3073 - val_loss: 0.4492 - val_mse: 0.4492 - 66ms/epoch - 6ms/step
# Epoch 263/2000
# 12/12 - 0s - loss: 0.3053 - mse: 0.3053 - val_loss: 0.4472 - val_mse: 0.4472 - 75ms/epoch - 6ms/step
# Epoch 264/2000
# 12/12 - 0s - loss: 0.3050 - mse: 0.3050 - val_loss: 0.4473 - val_mse: 0.4473 - 67ms/epoch - 6ms/step
# Epoch 265/2000
# 12/12 - 0s - loss: 0.3040 - mse: 0.3040 - val_loss: 0.4447 - val_mse: 0.4447 - 70ms/epoch - 6ms/step
# Epoch 266/2000
# 12/12 - 0s - loss: 0.3032 - mse: 0.3032 - val_loss: 0.4434 - val_mse: 0.4434 - 63ms/epoch - 5ms/step
# Epoch 267/2000
# 12/12 - 0s - loss: 0.3006 - mse: 0.3006 - val_loss: 0.4395 - val_mse: 0.4395 - 66ms/epoch - 5ms/step
# Epoch 268/2000
# 12/12 - 0s - loss: 0.2989 - mse: 0.2989 - val_loss: 0.4401 - val_mse: 0.4401 - 73ms/epoch - 6ms/step
# Epoch 269/2000
# 12/12 - 0s - loss: 0.2978 - mse: 0.2978 - val_loss: 0.4388 - val_mse: 0.4388 - 71ms/epoch - 6ms/step
# Epoch 270/2000
# 12/12 - 0s - loss: 0.2977 - mse: 0.2977 - val_loss: 0.4404 - val_mse: 0.4404 - 71ms/epoch - 6ms/step
# Epoch 271/2000
# 12/12 - 0s - loss: 0.2960 - mse: 0.2960 - val_loss: 0.4349 - val_mse: 0.4349 - 66ms/epoch - 5ms/step
# Epoch 272/2000
# 12/12 - 0s - loss: 0.2935 - mse: 0.2935 - val_loss: 0.4385 - val_mse: 0.4385 - 64ms/epoch - 5ms/step
# Epoch 273/2000
# 12/12 - 0s - loss: 0.2956 - mse: 0.2956 - val_loss: 0.4316 - val_mse: 0.4316 - 69ms/epoch - 6ms/step
# Epoch 274/2000
# 12/12 - 0s - loss: 0.2915 - mse: 0.2915 - val_loss: 0.4324 - val_mse: 0.4324 - 74ms/epoch - 6ms/step
# Epoch 275/2000
# 12/12 - 0s - loss: 0.2916 - mse: 0.2916 - val_loss: 0.4307 - val_mse: 0.4307 - 78ms/epoch - 6ms/step
# Epoch 276/2000
# 12/12 - 0s - loss: 0.2898 - mse: 0.2898 - val_loss: 0.4284 - val_mse: 0.4284 - 64ms/epoch - 5ms/step
# Epoch 277/2000
# 12/12 - 0s - loss: 0.2893 - mse: 0.2893 - val_loss: 0.4272 - val_mse: 0.4272 - 68ms/epoch - 6ms/step
# Epoch 278/2000
# 12/12 - 0s - loss: 0.2879 - mse: 0.2879 - val_loss: 0.4239 - val_mse: 0.4239 - 65ms/epoch - 5ms/step
# Epoch 279/2000
# 12/12 - 0s - loss: 0.2853 - mse: 0.2853 - val_loss: 0.4329 - val_mse: 0.4329 - 67ms/epoch - 6ms/step
# Epoch 280/2000
# 12/12 - 0s - loss: 0.2863 - mse: 0.2863 - val_loss: 0.4256 - val_mse: 0.4256 - 68ms/epoch - 6ms/step
# Epoch 281/2000
# 12/12 - 0s - loss: 0.2846 - mse: 0.2846 - val_loss: 0.4237 - val_mse: 0.4237 - 71ms/epoch - 6ms/step
# Epoch 282/2000
# 12/12 - 0s - loss: 0.2846 - mse: 0.2846 - val_loss: 0.4270 - val_mse: 0.4270 - 66ms/epoch - 5ms/step
# Epoch 283/2000
# 12/12 - 0s - loss: 0.2815 - mse: 0.2815 - val_loss: 0.4170 - val_mse: 0.4170 - 69ms/epoch - 6ms/step
# Epoch 284/2000
# 12/12 - 0s - loss: 0.2816 - mse: 0.2816 - val_loss: 0.4154 - val_mse: 0.4154 - 64ms/epoch - 5ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 0.2789 - mse: 0.2789 - val_loss: 0.4133 - val_mse: 0.4133 - 63ms/epoch - 5ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 0.2861 - mse: 0.2861 - val_loss: 0.4190 - val_mse: 0.4190 - 62ms/epoch - 5ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 0.2817 - mse: 0.2817 - val_loss: 0.4212 - val_mse: 0.4212 - 59ms/epoch - 5ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 0.2757 - mse: 0.2757 - val_loss: 0.4094 - val_mse: 0.4094 - 61ms/epoch - 5ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 0.2755 - mse: 0.2755 - val_loss: 0.4103 - val_mse: 0.4103 - 63ms/epoch - 5ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 0.2757 - mse: 0.2757 - val_loss: 0.4087 - val_mse: 0.4087 - 70ms/epoch - 6ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 0.2727 - mse: 0.2727 - val_loss: 0.4103 - val_mse: 0.4103 - 58ms/epoch - 5ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 0.2722 - mse: 0.2722 - val_loss: 0.4135 - val_mse: 0.4135 - 65ms/epoch - 5ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 0.2718 - mse: 0.2718 - val_loss: 0.4095 - val_mse: 0.4095 - 68ms/epoch - 6ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 0.2699 - mse: 0.2699 - val_loss: 0.4023 - val_mse: 0.4023 - 61ms/epoch - 5ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 0.2709 - mse: 0.2709 - val_loss: 0.4004 - val_mse: 0.4004 - 61ms/epoch - 5ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 0.2665 - mse: 0.2665 - val_loss: 0.3998 - val_mse: 0.3998 - 65ms/epoch - 5ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 0.2672 - mse: 0.2672 - val_loss: 0.4020 - val_mse: 0.4020 - 89ms/epoch - 7ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 0.2663 - mse: 0.2663 - val_loss: 0.3986 - val_mse: 0.3986 - 88ms/epoch - 7ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 0.2684 - mse: 0.2684 - val_loss: 0.4056 - val_mse: 0.4056 - 76ms/epoch - 6ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 0.2658 - mse: 0.2658 - val_loss: 0.3985 - val_mse: 0.3985 - 70ms/epoch - 6ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 0.2638 - mse: 0.2638 - val_loss: 0.3986 - val_mse: 0.3986 - 72ms/epoch - 6ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 0.2615 - mse: 0.2615 - val_loss: 0.3971 - val_mse: 0.3971 - 62ms/epoch - 5ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 0.2619 - mse: 0.2619 - val_loss: 0.3945 - val_mse: 0.3945 - 71ms/epoch - 6ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 0.2569 - mse: 0.2569 - val_loss: 0.3876 - val_mse: 0.3876 - 64ms/epoch - 5ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 0.2570 - mse: 0.2570 - val_loss: 0.3892 - val_mse: 0.3892 - 62ms/epoch - 5ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 0.2556 - mse: 0.2556 - val_loss: 0.3895 - val_mse: 0.3895 - 71ms/epoch - 6ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 0.2530 - mse: 0.2530 - val_loss: 0.3852 - val_mse: 0.3852 - 78ms/epoch - 6ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 0.2524 - mse: 0.2524 - val_loss: 0.3857 - val_mse: 0.3857 - 63ms/epoch - 5ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 0.2518 - mse: 0.2518 - val_loss: 0.3823 - val_mse: 0.3823 - 65ms/epoch - 5ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 0.2537 - mse: 0.2537 - val_loss: 0.3860 - val_mse: 0.3860 - 65ms/epoch - 5ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 0.2514 - mse: 0.2514 - val_loss: 0.3789 - val_mse: 0.3789 - 60ms/epoch - 5ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 0.2484 - mse: 0.2484 - val_loss: 0.3791 - val_mse: 0.3791 - 69ms/epoch - 6ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 0.2473 - mse: 0.2473 - val_loss: 0.3799 - val_mse: 0.3799 - 65ms/epoch - 5ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 0.2497 - mse: 0.2497 - val_loss: 0.3795 - val_mse: 0.3795 - 63ms/epoch - 5ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 0.2468 - mse: 0.2468 - val_loss: 0.3808 - val_mse: 0.3808 - 67ms/epoch - 6ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 0.2453 - mse: 0.2453 - val_loss: 0.3774 - val_mse: 0.3774 - 63ms/epoch - 5ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 0.2426 - mse: 0.2426 - val_loss: 0.3724 - val_mse: 0.3724 - 68ms/epoch - 6ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 0.2436 - mse: 0.2436 - val_loss: 0.3745 - val_mse: 0.3745 - 67ms/epoch - 6ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 0.2415 - mse: 0.2415 - val_loss: 0.3729 - val_mse: 0.3729 - 70ms/epoch - 6ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 0.2418 - mse: 0.2418 - val_loss: 0.3700 - val_mse: 0.3700 - 67ms/epoch - 6ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 0.2425 - mse: 0.2425 - val_loss: 0.3697 - val_mse: 0.3697 - 65ms/epoch - 5ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 0.2400 - mse: 0.2400 - val_loss: 0.3693 - val_mse: 0.3693 - 67ms/epoch - 6ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 0.2366 - mse: 0.2366 - val_loss: 0.3609 - val_mse: 0.3609 - 68ms/epoch - 6ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 0.2350 - mse: 0.2350 - val_loss: 0.3661 - val_mse: 0.3661 - 71ms/epoch - 6ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 0.2363 - mse: 0.2363 - val_loss: 0.3638 - val_mse: 0.3638 - 76ms/epoch - 6ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 0.2353 - mse: 0.2353 - val_loss: 0.3629 - val_mse: 0.3629 - 70ms/epoch - 6ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 0.2323 - mse: 0.2323 - val_loss: 0.3602 - val_mse: 0.3602 - 70ms/epoch - 6ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 0.2314 - mse: 0.2314 - val_loss: 0.3615 - val_mse: 0.3615 - 69ms/epoch - 6ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 0.2313 - mse: 0.2313 - val_loss: 0.3589 - val_mse: 0.3589 - 75ms/epoch - 6ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 0.2304 - mse: 0.2304 - val_loss: 0.3578 - val_mse: 0.3578 - 68ms/epoch - 6ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 0.2291 - mse: 0.2291 - val_loss: 0.3573 - val_mse: 0.3573 - 67ms/epoch - 6ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 0.2261 - mse: 0.2261 - val_loss: 0.3530 - val_mse: 0.3530 - 68ms/epoch - 6ms/step
# Epoch 333/2000
# 12/12 - 0s - loss: 0.2258 - mse: 0.2258 - val_loss: 0.3533 - val_mse: 0.3533 - 71ms/epoch - 6ms/step
# Epoch 334/2000
# 12/12 - 0s - loss: 0.2244 - mse: 0.2244 - val_loss: 0.3513 - val_mse: 0.3513 - 70ms/epoch - 6ms/step
# Epoch 335/2000
# 12/12 - 0s - loss: 0.2245 - mse: 0.2245 - val_loss: 0.3533 - val_mse: 0.3533 - 68ms/epoch - 6ms/step
# Epoch 336/2000
# 12/12 - 0s - loss: 0.2254 - mse: 0.2254 - val_loss: 0.3496 - val_mse: 0.3496 - 69ms/epoch - 6ms/step
# Epoch 337/2000
# 12/12 - 0s - loss: 0.2229 - mse: 0.2229 - val_loss: 0.3489 - val_mse: 0.3489 - 107ms/epoch - 9ms/step
# Epoch 338/2000
# 12/12 - 0s - loss: 0.2249 - mse: 0.2249 - val_loss: 0.3502 - val_mse: 0.3502 - 95ms/epoch - 8ms/step
# Epoch 339/2000
# 12/12 - 0s - loss: 0.2208 - mse: 0.2208 - val_loss: 0.3472 - val_mse: 0.3472 - 84ms/epoch - 7ms/step
# Epoch 340/2000
# 12/12 - 0s - loss: 0.2194 - mse: 0.2194 - val_loss: 0.3446 - val_mse: 0.3446 - 76ms/epoch - 6ms/step
# Epoch 341/2000
# 12/12 - 0s - loss: 0.2179 - mse: 0.2179 - val_loss: 0.3438 - val_mse: 0.3438 - 77ms/epoch - 6ms/step
# Epoch 342/2000
# 12/12 - 0s - loss: 0.2177 - mse: 0.2177 - val_loss: 0.3411 - val_mse: 0.3411 - 74ms/epoch - 6ms/step
# Epoch 343/2000
# 12/12 - 0s - loss: 0.2184 - mse: 0.2184 - val_loss: 0.3383 - val_mse: 0.3383 - 77ms/epoch - 6ms/step
# Epoch 344/2000
# 12/12 - 0s - loss: 0.2194 - mse: 0.2194 - val_loss: 0.3387 - val_mse: 0.3387 - 76ms/epoch - 6ms/step
# Epoch 345/2000
# 12/12 - 0s - loss: 0.2172 - mse: 0.2172 - val_loss: 0.3466 - val_mse: 0.3466 - 72ms/epoch - 6ms/step
# Epoch 346/2000
# 12/12 - 0s - loss: 0.2159 - mse: 0.2159 - val_loss: 0.3393 - val_mse: 0.3393 - 78ms/epoch - 6ms/step
# Epoch 347/2000
# 12/12 - 0s - loss: 0.2133 - mse: 0.2133 - val_loss: 0.3346 - val_mse: 0.3346 - 73ms/epoch - 6ms/step
# Epoch 348/2000
# 12/12 - 0s - loss: 0.2127 - mse: 0.2127 - val_loss: 0.3343 - val_mse: 0.3343 - 71ms/epoch - 6ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 0.2096 - mse: 0.2096 - val_loss: 0.3345 - val_mse: 0.3345 - 78ms/epoch - 7ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 0.2107 - mse: 0.2107 - val_loss: 0.3336 - val_mse: 0.3336 - 81ms/epoch - 7ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 0.2087 - mse: 0.2087 - val_loss: 0.3325 - val_mse: 0.3325 - 74ms/epoch - 6ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 0.2081 - mse: 0.2081 - val_loss: 0.3334 - val_mse: 0.3334 - 69ms/epoch - 6ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 0.2073 - mse: 0.2073 - val_loss: 0.3327 - val_mse: 0.3327 - 70ms/epoch - 6ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 0.2051 - mse: 0.2051 - val_loss: 0.3281 - val_mse: 0.3281 - 67ms/epoch - 6ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 0.2062 - mse: 0.2062 - val_loss: 0.3269 - val_mse: 0.3269 - 65ms/epoch - 5ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 0.2051 - mse: 0.2051 - val_loss: 0.3289 - val_mse: 0.3289 - 75ms/epoch - 6ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 0.2050 - mse: 0.2050 - val_loss: 0.3280 - val_mse: 0.3280 - 75ms/epoch - 6ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 0.2049 - mse: 0.2049 - val_loss: 0.3272 - val_mse: 0.3272 - 73ms/epoch - 6ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 0.2024 - mse: 0.2024 - val_loss: 0.3253 - val_mse: 0.3253 - 72ms/epoch - 6ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 0.1997 - mse: 0.1997 - val_loss: 0.3211 - val_mse: 0.3211 - 71ms/epoch - 6ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 0.2000 - mse: 0.2000 - val_loss: 0.3218 - val_mse: 0.3218 - 71ms/epoch - 6ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 0.2002 - mse: 0.2002 - val_loss: 0.3209 - val_mse: 0.3209 - 69ms/epoch - 6ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 0.1979 - mse: 0.1979 - val_loss: 0.3212 - val_mse: 0.3212 - 70ms/epoch - 6ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 0.1974 - mse: 0.1974 - val_loss: 0.3180 - val_mse: 0.3180 - 68ms/epoch - 6ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 0.1972 - mse: 0.1972 - val_loss: 0.3187 - val_mse: 0.3187 - 70ms/epoch - 6ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 0.1948 - mse: 0.1948 - val_loss: 0.3118 - val_mse: 0.3118 - 76ms/epoch - 6ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 0.1945 - mse: 0.1945 - val_loss: 0.3150 - val_mse: 0.3150 - 67ms/epoch - 6ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 0.1972 - mse: 0.1972 - val_loss: 0.3223 - val_mse: 0.3223 - 75ms/epoch - 6ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 0.1959 - mse: 0.1959 - val_loss: 0.3120 - val_mse: 0.3120 - 70ms/epoch - 6ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 0.1925 - mse: 0.1925 - val_loss: 0.3141 - val_mse: 0.3141 - 71ms/epoch - 6ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 0.1917 - mse: 0.1917 - val_loss: 0.3101 - val_mse: 0.3101 - 114ms/epoch - 9ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 0.1916 - mse: 0.1916 - val_loss: 0.3110 - val_mse: 0.3110 - 94ms/epoch - 8ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 0.1906 - mse: 0.1906 - val_loss: 0.3089 - val_mse: 0.3089 - 80ms/epoch - 7ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 0.1894 - mse: 0.1894 - val_loss: 0.3070 - val_mse: 0.3070 - 80ms/epoch - 7ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 0.1878 - mse: 0.1878 - val_loss: 0.3072 - val_mse: 0.3072 - 80ms/epoch - 7ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 0.1874 - mse: 0.1874 - val_loss: 0.3075 - val_mse: 0.3075 - 81ms/epoch - 7ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 0.1863 - mse: 0.1863 - val_loss: 0.3067 - val_mse: 0.3067 - 75ms/epoch - 6ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 0.1880 - mse: 0.1880 - val_loss: 0.3071 - val_mse: 0.3071 - 72ms/epoch - 6ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 0.1864 - mse: 0.1864 - val_loss: 0.3064 - val_mse: 0.3064 - 76ms/epoch - 6ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 0.1841 - mse: 0.1841 - val_loss: 0.3021 - val_mse: 0.3021 - 74ms/epoch - 6ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 0.1836 - mse: 0.1836 - val_loss: 0.3000 - val_mse: 0.3000 - 70ms/epoch - 6ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 0.1850 - mse: 0.1850 - val_loss: 0.3011 - val_mse: 0.3011 - 70ms/epoch - 6ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 0.1835 - mse: 0.1835 - val_loss: 0.3077 - val_mse: 0.3077 - 76ms/epoch - 6ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 0.1847 - mse: 0.1847 - val_loss: 0.3022 - val_mse: 0.3022 - 71ms/epoch - 6ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 0.1832 - mse: 0.1832 - val_loss: 0.2993 - val_mse: 0.2993 - 71ms/epoch - 6ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 0.1796 - mse: 0.1796 - val_loss: 0.2957 - val_mse: 0.2957 - 69ms/epoch - 6ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 0.1792 - mse: 0.1792 - val_loss: 0.2965 - val_mse: 0.2965 - 68ms/epoch - 6ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 0.1791 - mse: 0.1791 - val_loss: 0.2943 - val_mse: 0.2943 - 62ms/epoch - 5ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 0.1777 - mse: 0.1777 - val_loss: 0.2987 - val_mse: 0.2987 - 60ms/epoch - 5ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 0.1816 - mse: 0.1816 - val_loss: 0.2972 - val_mse: 0.2972 - 68ms/epoch - 6ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 0.1781 - mse: 0.1781 - val_loss: 0.2888 - val_mse: 0.2888 - 64ms/epoch - 5ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 0.1776 - mse: 0.1776 - val_loss: 0.2902 - val_mse: 0.2902 - 62ms/epoch - 5ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 0.1751 - mse: 0.1751 - val_loss: 0.2894 - val_mse: 0.2894 - 66ms/epoch - 6ms/step
# Epoch 394/2000
# 12/12 - 0s - loss: 0.1759 - mse: 0.1759 - val_loss: 0.2968 - val_mse: 0.2968 - 67ms/epoch - 6ms/step
# Epoch 395/2000
# 12/12 - 0s - loss: 0.1764 - mse: 0.1764 - val_loss: 0.2891 - val_mse: 0.2891 - 68ms/epoch - 6ms/step
# Epoch 396/2000
# 12/12 - 0s - loss: 0.1744 - mse: 0.1744 - val_loss: 0.2856 - val_mse: 0.2856 - 63ms/epoch - 5ms/step
# Epoch 397/2000
# 12/12 - 0s - loss: 0.1730 - mse: 0.1730 - val_loss: 0.2824 - val_mse: 0.2824 - 72ms/epoch - 6ms/step
# Epoch 398/2000
# 12/12 - 0s - loss: 0.1712 - mse: 0.1712 - val_loss: 0.2872 - val_mse: 0.2872 - 70ms/epoch - 6ms/step
# Epoch 399/2000
# 12/12 - 0s - loss: 0.1707 - mse: 0.1707 - val_loss: 0.2815 - val_mse: 0.2815 - 68ms/epoch - 6ms/step
# Epoch 400/2000
# 12/12 - 0s - loss: 0.1768 - mse: 0.1768 - val_loss: 0.2812 - val_mse: 0.2812 - 66ms/epoch - 5ms/step
# Epoch 401/2000
# 12/12 - 0s - loss: 0.1693 - mse: 0.1693 - val_loss: 0.2802 - val_mse: 0.2802 - 69ms/epoch - 6ms/step
# Epoch 402/2000
# 12/12 - 0s - loss: 0.1702 - mse: 0.1702 - val_loss: 0.2838 - val_mse: 0.2838 - 68ms/epoch - 6ms/step
# Epoch 403/2000
# 12/12 - 0s - loss: 0.1693 - mse: 0.1693 - val_loss: 0.2779 - val_mse: 0.2779 - 73ms/epoch - 6ms/step
# Epoch 404/2000
# 12/12 - 0s - loss: 0.1683 - mse: 0.1683 - val_loss: 0.2802 - val_mse: 0.2802 - 102ms/epoch - 8ms/step
# Epoch 405/2000
# 12/12 - 0s - loss: 0.1694 - mse: 0.1694 - val_loss: 0.2837 - val_mse: 0.2837 - 108ms/epoch - 9ms/step
# Epoch 406/2000
# 12/12 - 0s - loss: 0.1679 - mse: 0.1679 - val_loss: 0.2725 - val_mse: 0.2725 - 82ms/epoch - 7ms/step
# Epoch 407/2000
# 12/12 - 0s - loss: 0.1656 - mse: 0.1656 - val_loss: 0.2752 - val_mse: 0.2752 - 79ms/epoch - 7ms/step
# Epoch 408/2000
# 12/12 - 0s - loss: 0.1640 - mse: 0.1640 - val_loss: 0.2765 - val_mse: 0.2765 - 71ms/epoch - 6ms/step
# Epoch 409/2000
# 12/12 - 0s - loss: 0.1637 - mse: 0.1637 - val_loss: 0.2775 - val_mse: 0.2775 - 80ms/epoch - 7ms/step
# Epoch 410/2000
# 12/12 - 0s - loss: 0.1650 - mse: 0.1650 - val_loss: 0.2771 - val_mse: 0.2771 - 78ms/epoch - 6ms/step
# Epoch 411/2000
# 12/12 - 0s - loss: 0.1637 - mse: 0.1637 - val_loss: 0.2755 - val_mse: 0.2755 - 71ms/epoch - 6ms/step
# Epoch 412/2000
# 12/12 - 0s - loss: 0.1621 - mse: 0.1621 - val_loss: 0.2705 - val_mse: 0.2705 - 71ms/epoch - 6ms/step
# Epoch 413/2000
# 12/12 - 0s - loss: 0.1617 - mse: 0.1617 - val_loss: 0.2712 - val_mse: 0.2712 - 78ms/epoch - 6ms/step
# Epoch 414/2000
# 12/12 - 0s - loss: 0.1596 - mse: 0.1596 - val_loss: 0.2703 - val_mse: 0.2703 - 79ms/epoch - 7ms/step
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0206 - val_mse: 0.0206 - 69ms/epoch - 6ms/step
# Epoch 1866/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0199 - val_mse: 0.0199 - 70ms/epoch - 6ms/step
# Epoch 1867/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0192 - val_mse: 0.0192 - 70ms/epoch - 6ms/step
# Epoch 1868/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0188 - val_mse: 0.0188 - 62ms/epoch - 5ms/step
# Epoch 1869/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0180 - val_mse: 0.0180 - 79ms/epoch - 7ms/step
# Epoch 1870/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0187 - val_mse: 0.0187 - 79ms/epoch - 7ms/step
# Epoch 1871/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0185 - val_mse: 0.0185 - 70ms/epoch - 6ms/step
# Epoch 1872/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0216 - val_mse: 0.0216 - 70ms/epoch - 6ms/step
# Epoch 1873/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0179 - val_mse: 0.0179 - 69ms/epoch - 6ms/step
# Epoch 1874/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0187 - val_mse: 0.0187 - 98ms/epoch - 8ms/step
# Epoch 1875/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0188 - val_mse: 0.0188 - 87ms/epoch - 7ms/step
# Epoch 1876/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0190 - val_mse: 0.0190 - 79ms/epoch - 7ms/step
# Epoch 1877/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0188 - val_mse: 0.0188 - 72ms/epoch - 6ms/step
# Epoch 1878/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0188 - val_mse: 0.0188 - 71ms/epoch - 6ms/step
# Epoch 1879/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0188 - val_mse: 0.0188 - 84ms/epoch - 7ms/step
# Epoch 1880/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0180 - val_mse: 0.0180 - 82ms/epoch - 7ms/step
# Epoch 1881/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0196 - val_mse: 0.0196 - 70ms/epoch - 6ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0190 - val_mse: 0.0190 - 69ms/epoch - 6ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0187 - val_mse: 0.0187 - 66ms/epoch - 5ms/step
# Epoch 1884/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0182 - val_mse: 0.0182 - 70ms/epoch - 6ms/step
# Epoch 1885/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0181 - val_mse: 0.0181 - 65ms/epoch - 5ms/step
# Epoch 1886/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0184 - val_mse: 0.0184 - 66ms/epoch - 6ms/step
# Epoch 1887/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0182 - val_mse: 0.0182 - 106ms/epoch - 9ms/step
# Epoch 1888/2000
# 12/12 - 0s - loss: 0.0090 - mse: 0.0090 - val_loss: 0.0213 - val_mse: 0.0213 - 90ms/epoch - 7ms/step
# Epoch 1889/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0183 - val_mse: 0.0183 - 68ms/epoch - 6ms/step
# Epoch 1890/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0181 - val_mse: 0.0181 - 74ms/epoch - 6ms/step
# Epoch 1891/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0186 - val_mse: 0.0186 - 73ms/epoch - 6ms/step
# Epoch 1892/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0197 - val_mse: 0.0197 - 71ms/epoch - 6ms/step
# Epoch 1893/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0193 - val_mse: 0.0193 - 69ms/epoch - 6ms/step
# Epoch 1894/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0193 - val_mse: 0.0193 - 64ms/epoch - 5ms/step
# Epoch 1895/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0181 - val_mse: 0.0181 - 69ms/epoch - 6ms/step
# Epoch 1896/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0189 - val_mse: 0.0189 - 67ms/epoch - 6ms/step
# Epoch 1897/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0192 - val_mse: 0.0192 - 65ms/epoch - 5ms/step
# Epoch 1898/2000
# 12/12 - 0s - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0202 - val_mse: 0.0202 - 87ms/epoch - 7ms/step
# Epoch 1899/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0187 - val_mse: 0.0187 - 96ms/epoch - 8ms/step
# Epoch 1900/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0191 - val_mse: 0.0191 - 73ms/epoch - 6ms/step
# Epoch 1901/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0176 - val_mse: 0.0176 - 72ms/epoch - 6ms/step
# Epoch 1902/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0177 - val_mse: 0.0177 - 74ms/epoch - 6ms/step
# Epoch 1903/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0199 - val_mse: 0.0199 - 67ms/epoch - 6ms/step
# Epoch 1904/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0177 - val_mse: 0.0177 - 75ms/epoch - 6ms/step
# Epoch 1905/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0189 - val_mse: 0.0189 - 65ms/epoch - 5ms/step
# Epoch 1906/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0194 - val_mse: 0.0194 - 66ms/epoch - 6ms/step
# Epoch 1907/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0220 - val_mse: 0.0220 - 77ms/epoch - 6ms/step
# Epoch 1908/2000
# 12/12 - 0s - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0210 - val_mse: 0.0210 - 64ms/epoch - 5ms/step
# Epoch 1909/2000
# 12/12 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0185 - val_mse: 0.0185 - 63ms/epoch - 5ms/step
# Epoch 1910/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0212 - val_mse: 0.0212 - 59ms/epoch - 5ms/step
# Epoch 1911/2000
# 12/12 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0218 - val_mse: 0.0218 - 65ms/epoch - 5ms/step
# Epoch 1912/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0196 - val_mse: 0.0196 - 63ms/epoch - 5ms/step
# Epoch 1913/2000
# 12/12 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0200 - val_mse: 0.0200 - 69ms/epoch - 6ms/step
# Epoch 1914/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0201 - val_mse: 0.0201 - 111ms/epoch - 9ms/step
# Epoch 1915/2000
# 12/12 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0206 - val_mse: 0.0206 - 76ms/epoch - 6ms/step
# Epoch 1916/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0242 - val_mse: 0.0242 - 83ms/epoch - 7ms/step
# Epoch 1917/2000
# 12/12 - 0s - loss: 0.0101 - mse: 0.0101 - val_loss: 0.0182 - val_mse: 0.0182 - 73ms/epoch - 6ms/step
# Epoch 1918/2000
# 12/12 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0208 - val_mse: 0.0208 - 78ms/epoch - 6ms/step
# Epoch 1919/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0191 - val_mse: 0.0191 - 67ms/epoch - 6ms/step
# Epoch 1920/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0178 - val_mse: 0.0178 - 68ms/epoch - 6ms/step
# Epoch 1921/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0207 - val_mse: 0.0207 - 70ms/epoch - 6ms/step
# Epoch 1922/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0218 - val_mse: 0.0218 - 68ms/epoch - 6ms/step
# Epoch 1923/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0199 - val_mse: 0.0199 - 72ms/epoch - 6ms/step
# Epoch 1924/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0208 - val_mse: 0.0208 - 70ms/epoch - 6ms/step
# Epoch 1925/2000
# 12/12 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0197 - val_mse: 0.0197 - 65ms/epoch - 5ms/step
# Epoch 1926/2000
# 12/12 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0243 - val_mse: 0.0243 - 70ms/epoch - 6ms/step
# Epoch 1927/2000
# 12/12 - 0s - loss: 0.0099 - mse: 0.0099 - val_loss: 0.0196 - val_mse: 0.0196 - 78ms/epoch - 6ms/step
# Epoch 1928/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0179 - val_mse: 0.0179 - 69ms/epoch - 6ms/step
# Epoch 1929/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0191 - val_mse: 0.0191 - 90ms/epoch - 7ms/step
# Epoch 1930/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0187 - val_mse: 0.0187 - 105ms/epoch - 9ms/step
# Epoch 1931/2000
# 12/12 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0185 - val_mse: 0.0185 - 83ms/epoch - 7ms/step
# Epoch 1932/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0203 - val_mse: 0.0203 - 71ms/epoch - 6ms/step
# Epoch 1933/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0175 - val_mse: 0.0175 - 73ms/epoch - 6ms/step
# Epoch 1934/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0180 - val_mse: 0.0180 - 72ms/epoch - 6ms/step
# Epoch 1935/2000
# 12/12 - 0s - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0183 - val_mse: 0.0183 - 68ms/epoch - 6ms/step
# Epoch 1936/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0190 - val_mse: 0.0190 - 70ms/epoch - 6ms/step
# Epoch 1937/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0176 - val_mse: 0.0176 - 80ms/epoch - 7ms/step
# Epoch 1938/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0212 - val_mse: 0.0212 - 84ms/epoch - 7ms/step
# Epoch 1939/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0190 - val_mse: 0.0190 - 72ms/epoch - 6ms/step
# Epoch 1940/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0186 - val_mse: 0.0186 - 71ms/epoch - 6ms/step
# Epoch 1941/2000
# 12/12 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0211 - val_mse: 0.0211 - 68ms/epoch - 6ms/step
# Epoch 1942/2000
# 12/12 - 0s - loss: 0.0089 - mse: 0.0089 - val_loss: 0.0189 - val_mse: 0.0189 - 69ms/epoch - 6ms/step
# Epoch 1943/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0190 - val_mse: 0.0190 - 70ms/epoch - 6ms/step
# Epoch 1944/2000
# 12/12 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0187 - val_mse: 0.0187 - 89ms/epoch - 7ms/step
# Epoch 1945/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0202 - val_mse: 0.0202 - 99ms/epoch - 8ms/step
# Epoch 1946/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0186 - val_mse: 0.0186 - 88ms/epoch - 7ms/step
# Epoch 1947/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0205 - val_mse: 0.0205 - 99ms/epoch - 8ms/step
# Epoch 1948/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0184 - val_mse: 0.0184 - 87ms/epoch - 7ms/step
# Epoch 1949/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0185 - val_mse: 0.0185 - 77ms/epoch - 6ms/step
# Epoch 1950/2000
# 12/12 - 0s - loss: 0.0096 - mse: 0.0096 - val_loss: 0.0179 - val_mse: 0.0179 - 79ms/epoch - 7ms/step
# Epoch 1951/2000
# 12/12 - 0s - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0195 - val_mse: 0.0195 - 79ms/epoch - 7ms/step
# Epoch 1952/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0185 - val_mse: 0.0185 - 68ms/epoch - 6ms/step
# Epoch 1953/2000
# 12/12 - 0s - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0179 - val_mse: 0.0179 - 74ms/epoch - 6ms/step
# Epoch 1954/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0188 - val_mse: 0.0188 - 74ms/epoch - 6ms/step
# Epoch 1955/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0179 - val_mse: 0.0179 - 74ms/epoch - 6ms/step
# Epoch 1956/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0218 - val_mse: 0.0218 - 86ms/epoch - 7ms/step
# Epoch 1957/2000
# 12/12 - 0s - loss: 0.0104 - mse: 0.0104 - val_loss: 0.0180 - val_mse: 0.0180 - 100ms/epoch - 8ms/step
# Epoch 1958/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0204 - val_mse: 0.0204 - 109ms/epoch - 9ms/step
# Epoch 1959/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0193 - val_mse: 0.0193 - 91ms/epoch - 8ms/step
# Epoch 1960/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0184 - val_mse: 0.0184 - 80ms/epoch - 7ms/step
# Epoch 1961/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0179 - val_mse: 0.0179 - 81ms/epoch - 7ms/step
# Epoch 1962/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0183 - val_mse: 0.0183 - 75ms/epoch - 6ms/step
# Epoch 1963/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0177 - val_mse: 0.0177 - 72ms/epoch - 6ms/step
# Epoch 1964/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0176 - val_mse: 0.0176 - 74ms/epoch - 6ms/step
# Epoch 1965/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0185 - val_mse: 0.0185 - 75ms/epoch - 6ms/step
# Epoch 1966/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0183 - val_mse: 0.0183 - 69ms/epoch - 6ms/step
# Epoch 1967/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0191 - val_mse: 0.0191 - 70ms/epoch - 6ms/step
# Epoch 1968/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0177 - val_mse: 0.0177 - 67ms/epoch - 6ms/step
# Epoch 1969/2000
# 12/12 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0184 - val_mse: 0.0184 - 68ms/epoch - 6ms/step
# Epoch 1970/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0194 - val_mse: 0.0194 - 102ms/epoch - 8ms/step
# Epoch 1971/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0178 - val_mse: 0.0178 - 94ms/epoch - 8ms/step
# Epoch 1972/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0184 - val_mse: 0.0184 - 83ms/epoch - 7ms/step
# Epoch 1973/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0174 - val_mse: 0.0174 - 78ms/epoch - 6ms/step
# Epoch 1974/2000
# 12/12 - 0s - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0174 - val_mse: 0.0174 - 77ms/epoch - 6ms/step
# Epoch 1975/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0183 - val_mse: 0.0183 - 76ms/epoch - 6ms/step
# Epoch 1976/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0172 - val_mse: 0.0172 - 76ms/epoch - 6ms/step
# Epoch 1977/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0178 - val_mse: 0.0178 - 75ms/epoch - 6ms/step
# Epoch 1978/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0187 - val_mse: 0.0187 - 68ms/epoch - 6ms/step
# Epoch 1979/2000
# 12/12 - 0s - loss: 0.0075 - mse: 0.0075 - val_loss: 0.0189 - val_mse: 0.0189 - 66ms/epoch - 5ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0190 - val_mse: 0.0190 - 67ms/epoch - 6ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 0.0092 - mse: 0.0092 - val_loss: 0.0181 - val_mse: 0.0181 - 75ms/epoch - 6ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0204 - val_mse: 0.0204 - 74ms/epoch - 6ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0175 - val_mse: 0.0175 - 70ms/epoch - 6ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 0.0079 - mse: 0.0079 - val_loss: 0.0183 - val_mse: 0.0183 - 76ms/epoch - 6ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0173 - val_mse: 0.0173 - 74ms/epoch - 6ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0175 - val_mse: 0.0175 - 70ms/epoch - 6ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0185 - val_mse: 0.0185 - 65ms/epoch - 5ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0190 - val_mse: 0.0190 - 71ms/epoch - 6ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 0.0080 - mse: 0.0080 - val_loss: 0.0175 - val_mse: 0.0175 - 66ms/epoch - 6ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 0.0073 - mse: 0.0073 - val_loss: 0.0190 - val_mse: 0.0190 - 71ms/epoch - 6ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0176 - val_mse: 0.0176 - 68ms/epoch - 6ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 0.0083 - mse: 0.0083 - val_loss: 0.0201 - val_mse: 0.0201 - 69ms/epoch - 6ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0176 - val_mse: 0.0176 - 71ms/epoch - 6ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0177 - val_mse: 0.0177 - 74ms/epoch - 6ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0184 - val_mse: 0.0184 - 66ms/epoch - 5ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 0.0076 - mse: 0.0076 - val_loss: 0.0223 - val_mse: 0.0223 - 83ms/epoch - 7ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 0.0085 - mse: 0.0085 - val_loss: 0.0184 - val_mse: 0.0184 - 105ms/epoch - 9ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 0.0082 - mse: 0.0082 - val_loss: 0.0185 - val_mse: 0.0185 - 92ms/epoch - 8ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 0.0078 - mse: 0.0078 - val_loss: 0.0191 - val_mse: 0.0191 - 75ms/epoch - 6ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 0.0074 - mse: 0.0074 - val_loss: 0.0194 - val_mse: 0.0194 - 77ms/epoch - 6ms/step

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

#recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
# plt.title('model loss')
# plt.xlim([-20, 1800])
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 20)                80
#
#  second_layer (Dense)        (None, 10)                210
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performane

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.077

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.985

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
# plt.plot(y_test.iloc[:,0], y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2.5, -0.5))
plt.annotate("MAE = {:.3f}".format(error), (2.5, -0.8))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
# plt.title('Validation of the prediction model')     
plt.grid(True)

# plt.savefig('model validation.png', transparent=True)
plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_219')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_219\assets
