# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)

# %% [markdown]
#     99  : ESYS floater SENSOR 5	Pitch displacement - Trained on absolute values of max

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_99.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Min', 'Max']]

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Min       Max
# File_ID
# 0             800       800           0 -0.186880  0.103785
# 1             800       800           1 -0.162317  0.068588
# 2             800       800           2 -0.162615  0.068558
# 3             800       800           3 -0.207440  0.107342
# 4             800       800           4 -0.163160  0.067956

# %%
df['Min'] = df['Min'].abs()
df['Max'] = df['Max'].abs()

# %%
print('Maximum value of abs(minimum pitch): %.6f' % df['Min'].max())
print('Minimum value of abs(minimum pitch): %.6f' % df['Min'].min())
print('Range for minimum abs(pitch): %.6f' % (df['Min'].max()-df['Min'].min()))

print('\nMaximum value of abs(maximum pitch): %.6f' % df['Max'].max())
print('Minimum value of abs(maximum pitch): %.6f' % df['Max'].min())
print('Range for maximum abs(pitch): %.6f' % (df['Max'].max()-df['Max'].min()))
# Out:
# Maximum value of abs(minimum pitch): 0.229754
# Minimum value of abs(minimum pitch): 0.121239
# Range for minimum abs(pitch): 0.108515
#
# Maximum value of abs(maximum pitch): 0.143786
# Minimum value of abs(maximum pitch): 0.003171
# Range for maximum abs(pitch): 0.140614

# %%
df['max (min, max)'] = df[['Min','Max']].max(axis=1)

# %%
df = df.drop(["Min", "Max"], axis=1)

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead  max (min, max)
# File_ID
# 0             800       800           0        0.186880
# 1             800       800           1        0.162317
# 2             800       800           2        0.162615
# 3             800       800           3        0.207440
# 4             800       800           4        0.163160

# %%
print('Maximum value of max(abs(max, min)) pitch: %.6f' % df['max (min, max)'].max())
print('Minimum value of max(abs(max, min)) pitch: %.6f' % df['max (min, max)'].min())
print('Range for max(abs(max, min)) pitch: %.6f' % (df['max (min, max)'].max()-df['max (min, max)'].min()))
print('Mean for max(abs(max, min)) pitch: %.6f' % (np.mean(df['max (min, max)'])))
# Out:
# Maximum value of max(abs(max, min)) pitch: 0.229754
# Minimum value of max(abs(max, min)) pitch: 0.121239
# Range for max(abs(max, min)) pitch: 0.108515
# Mean for max(abs(max, min)) pitch: 0.183331

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values          0
# R_anchor          0
# z_fairlead        0
# max (min, max)    0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead  max (min, max)
# File_ID
# 1194          850       840          14        0.153587

# %% [markdown]
# # Sensitivity analysis

# %%
# varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

# varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

# varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
# Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum pitch of platform', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='max (min, max)', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum pitch of platform [$\degree$]" , size = 12 )
axes[0].set_title('Variation of pitch vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="max (min, max)", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum pitch of platform [$\degree$]" , size = 12 )
axes[1].set_title('Variation of pitch vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="max (min, max)", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum pitch of platform [$\degree$]" , size = 12 )
axes[2].set_title('Variation of pitch vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['max (min, max)']<= df['max (min, max)'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_99.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label')

# L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='max (min, max)',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Maximum pitch of platform [$\degree$]', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
# pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
plt.show()

# %%
# plot heat map
plt.rcParams.update({'font.size': 14})
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                  count        mean        std         min         max
# L_values        1300.0  844.923077  23.288073  800.000000  880.000000
# R_anchor        1300.0  834.769231  26.269621  800.000000  900.000000
# z_fairlead      1300.0    9.500000   5.768500    0.000000   19.000000
# max (min, max)  1300.0    0.183331   0.023274    0.121239    0.229754

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['max (min, max)']

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler=MinMaxScaler()

# %%
x_train = scaler.fit_transform(x_train.values)
x_test = scaler.transform(x_test.values)

# %%
import pickle 

pickle.dump(scaler, open('scaler_99.pkl','wb'))

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)

# %% [markdown]
# # Model build

# %%
from tensorflow.keras import layers
from keras.callbacks import History

# %%
from keras.layers import Dense
from keras.models import Sequential

# define the keras model
model = Sequential()
model.add(Dense(10, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(5, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 1.1449 - mse: 1.1449 - val_loss: 0.8220 - val_mse: 0.8220 - 1s/epoch - 96ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 0.7996 - mse: 0.7996 - val_loss: 0.5821 - val_mse: 0.5821 - 108ms/epoch - 9ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 0.5656 - mse: 0.5656 - val_loss: 0.4199 - val_mse: 0.4199 - 112ms/epoch - 9ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 0.4068 - mse: 0.4068 - val_loss: 0.3108 - val_mse: 0.3108 - 108ms/epoch - 9ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 0.2982 - mse: 0.2982 - val_loss: 0.2345 - val_mse: 0.2345 - 111ms/epoch - 9ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 0.2217 - mse: 0.2217 - val_loss: 0.1808 - val_mse: 0.1808 - 97ms/epoch - 8ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 0.1697 - mse: 0.1697 - val_loss: 0.1417 - val_mse: 0.1417 - 94ms/epoch - 8ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 0.1324 - mse: 0.1324 - val_loss: 0.1131 - val_mse: 0.1131 - 102ms/epoch - 8ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.1044 - mse: 0.1044 - val_loss: 0.0918 - val_mse: 0.0918 - 120ms/epoch - 10ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.0843 - mse: 0.0843 - val_loss: 0.0751 - val_mse: 0.0751 - 115ms/epoch - 10ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.0684 - mse: 0.0684 - val_loss: 0.0627 - val_mse: 0.0627 - 118ms/epoch - 10ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.0572 - mse: 0.0572 - val_loss: 0.0529 - val_mse: 0.0529 - 108ms/epoch - 9ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.0482 - mse: 0.0482 - val_loss: 0.0454 - val_mse: 0.0454 - 99ms/epoch - 8ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0396 - val_mse: 0.0396 - 185ms/epoch - 15ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.0359 - mse: 0.0359 - val_loss: 0.0347 - val_mse: 0.0347 - 133ms/epoch - 11ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.0316 - mse: 0.0316 - val_loss: 0.0308 - val_mse: 0.0308 - 96ms/epoch - 8ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.0282 - mse: 0.0282 - val_loss: 0.0277 - val_mse: 0.0277 - 84ms/epoch - 7ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.0255 - mse: 0.0255 - val_loss: 0.0251 - val_mse: 0.0251 - 87ms/epoch - 7ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0228 - val_mse: 0.0228 - 80ms/epoch - 7ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.0212 - mse: 0.0212 - val_loss: 0.0209 - val_mse: 0.0209 - 84ms/epoch - 7ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.0195 - mse: 0.0195 - val_loss: 0.0190 - val_mse: 0.0190 - 86ms/epoch - 7ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.0180 - mse: 0.0180 - val_loss: 0.0176 - val_mse: 0.0176 - 94ms/epoch - 8ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.0166 - mse: 0.0166 - val_loss: 0.0163 - val_mse: 0.0163 - 82ms/epoch - 7ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0151 - val_mse: 0.0151 - 79ms/epoch - 7ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.0143 - mse: 0.0143 - val_loss: 0.0140 - val_mse: 0.0140 - 81ms/epoch - 7ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.0133 - mse: 0.0133 - val_loss: 0.0130 - val_mse: 0.0130 - 91ms/epoch - 8ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.0124 - mse: 0.0124 - val_loss: 0.0121 - val_mse: 0.0121 - 82ms/epoch - 7ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0112 - val_mse: 0.0112 - 95ms/epoch - 8ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0104 - val_mse: 0.0104 - 80ms/epoch - 7ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0097 - val_mse: 0.0097 - 148ms/epoch - 12ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.0093 - mse: 0.0093 - val_loss: 0.0091 - val_mse: 0.0091 - 87ms/epoch - 7ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.0087 - mse: 0.0087 - val_loss: 0.0084 - val_mse: 0.0084 - 96ms/epoch - 8ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.0081 - mse: 0.0081 - val_loss: 0.0080 - val_mse: 0.0080 - 110ms/epoch - 9ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.0077 - mse: 0.0077 - val_loss: 0.0074 - val_mse: 0.0074 - 87ms/epoch - 7ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0070 - val_mse: 0.0070 - 92ms/epoch - 8ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.0068 - mse: 0.0068 - val_loss: 0.0066 - val_mse: 0.0066 - 93ms/epoch - 8ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.0064 - mse: 0.0064 - val_loss: 0.0062 - val_mse: 0.0062 - 98ms/epoch - 8ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.0061 - mse: 0.0061 - val_loss: 0.0058 - val_mse: 0.0058 - 82ms/epoch - 7ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.0057 - mse: 0.0057 - val_loss: 0.0055 - val_mse: 0.0055 - 86ms/epoch - 7ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0052 - val_mse: 0.0052 - 79ms/epoch - 7ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0050 - val_mse: 0.0050 - 78ms/epoch - 6ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0047 - val_mse: 0.0047 - 82ms/epoch - 7ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0044 - val_mse: 0.0044 - 86ms/epoch - 7ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0042 - val_mse: 0.0042 - 112ms/epoch - 9ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0041 - val_mse: 0.0041 - 104ms/epoch - 9ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0038 - val_mse: 0.0038 - 106ms/epoch - 9ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.0039 - mse: 0.0039 - val_loss: 0.0037 - val_mse: 0.0037 - 122ms/epoch - 10ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.0037 - mse: 0.0037 - val_loss: 0.0035 - val_mse: 0.0035 - 168ms/epoch - 14ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.0036 - mse: 0.0036 - val_loss: 0.0034 - val_mse: 0.0034 - 144ms/epoch - 12ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.0034 - mse: 0.0034 - val_loss: 0.0032 - val_mse: 0.0032 - 119ms/epoch - 10ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.0033 - mse: 0.0033 - val_loss: 0.0031 - val_mse: 0.0031 - 91ms/epoch - 8ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.0032 - mse: 0.0032 - val_loss: 0.0029 - val_mse: 0.0029 - 98ms/epoch - 8ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.0031 - mse: 0.0031 - val_loss: 0.0029 - val_mse: 0.0029 - 87ms/epoch - 7ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0027 - val_mse: 0.0027 - 95ms/epoch - 8ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.0029 - mse: 0.0029 - val_loss: 0.0027 - val_mse: 0.0027 - 84ms/epoch - 7ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0026 - val_mse: 0.0026 - 108ms/epoch - 9ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.0028 - mse: 0.0028 - val_loss: 0.0025 - val_mse: 0.0025 - 96ms/epoch - 8ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.0027 - mse: 0.0027 - val_loss: 0.0025 - val_mse: 0.0025 - 100ms/epoch - 8ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0024 - val_mse: 0.0024 - 91ms/epoch - 8ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.0026 - mse: 0.0026 - val_loss: 0.0023 - val_mse: 0.0023 - 95ms/epoch - 8ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.0025 - mse: 0.0025 - val_loss: 0.0023 - val_mse: 0.0023 - 96ms/epoch - 8ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0022 - val_mse: 0.0022 - 101ms/epoch - 8ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.0024 - mse: 0.0024 - val_loss: 0.0022 - val_mse: 0.0022 - 156ms/epoch - 13ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0021 - val_mse: 0.0021 - 109ms/epoch - 9ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.0023 - mse: 0.0023 - val_loss: 0.0020 - val_mse: 0.0020 - 120ms/epoch - 10ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0020 - val_mse: 0.0020 - 91ms/epoch - 8ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.0022 - mse: 0.0022 - val_loss: 0.0020 - val_mse: 0.0020 - 95ms/epoch - 8ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0019 - val_mse: 0.0019 - 106ms/epoch - 9ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.0021 - mse: 0.0021 - val_loss: 0.0018 - val_mse: 0.0018 - 87ms/epoch - 7ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0018 - val_mse: 0.0018 - 86ms/epoch - 7ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0018 - val_mse: 0.0018 - 91ms/epoch - 8ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0018 - val_mse: 0.0018 - 85ms/epoch - 7ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017 - 90ms/epoch - 7ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017 - 90ms/epoch - 7ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017 - 92ms/epoch - 8ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.0019 - mse: 0.0019 - val_loss: 0.0017 - val_mse: 0.0017 - 88ms/epoch - 7ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017 - 101ms/epoch - 8ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0017 - val_mse: 0.0017 - 113ms/epoch - 9ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016 - 113ms/epoch - 9ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016 - 92ms/epoch - 8ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016 - 78ms/epoch - 6ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.0018 - mse: 0.0018 - val_loss: 0.0016 - val_mse: 0.0016 - 82ms/epoch - 7ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 84ms/epoch - 7ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 87ms/epoch - 7ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 100ms/epoch - 8ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0016 - val_mse: 0.0016 - 78ms/epoch - 6ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015 - 83ms/epoch - 7ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015 - 82ms/epoch - 7ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015 - 97ms/epoch - 8ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.0017 - mse: 0.0017 - val_loss: 0.0015 - val_mse: 0.0015 - 90ms/epoch - 7ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 113ms/epoch - 9ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 86ms/epoch - 7ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 83ms/epoch - 7ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 93ms/epoch - 8ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 133ms/epoch - 11ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 105ms/epoch - 9ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014 - 97ms/epoch - 8ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0015 - val_mse: 0.0015 - 88ms/epoch - 7ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014 - 89ms/epoch - 7ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014 - 83ms/epoch - 7ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014 - 78ms/epoch - 6ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.0016 - mse: 0.0016 - val_loss: 0.0014 - val_mse: 0.0014 - 79ms/epoch - 7ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 76ms/epoch - 6ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 95ms/epoch - 8ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 72ms/epoch - 6ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 75ms/epoch - 6ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 68ms/epoch - 6ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 76ms/epoch - 6ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 77ms/epoch - 6ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 79ms/epoch - 7ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 72ms/epoch - 6ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 80ms/epoch - 7ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 72ms/epoch - 6ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 66ms/epoch - 5ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 69ms/epoch - 6ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.0015 - mse: 0.0015 - val_loss: 0.0014 - val_mse: 0.0014 - 59ms/epoch - 5ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 62ms/epoch - 5ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 55ms/epoch - 5ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 68ms/epoch - 6ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 71ms/epoch - 6ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 67ms/epoch - 6ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 61ms/epoch - 5ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 66ms/epoch - 5ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 71ms/epoch - 6ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 67ms/epoch - 6ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 69ms/epoch - 6ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 67ms/epoch - 6ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 69ms/epoch - 6ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 73ms/epoch - 6ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 69ms/epoch - 6ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 65ms/epoch - 5ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 64ms/epoch - 5ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 76ms/epoch - 6ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.0014 - mse: 0.0014 - val_loss: 0.0013 - val_mse: 0.0013 - 73ms/epoch - 6ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 109ms/epoch - 9ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 74ms/epoch - 6ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 66ms/epoch - 5ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 66ms/epoch - 5ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 64ms/epoch - 5ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 67ms/epoch - 6ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 75ms/epoch - 6ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 62ms/epoch - 5ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 62ms/epoch - 5ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 61ms/epoch - 5ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 65ms/epoch - 5ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 65ms/epoch - 5ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 64ms/epoch - 5ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 56ms/epoch - 5ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 57ms/epoch - 5ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 57ms/epoch - 5ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 53ms/epoch - 4ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 56ms/epoch - 5ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 57ms/epoch - 5ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 73ms/epoch - 6ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 72ms/epoch - 6ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 71ms/epoch - 6ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0013 - val_mse: 0.0013 - 66ms/epoch - 5ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 57ms/epoch - 5ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 57ms/epoch - 5ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 58ms/epoch - 5ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 63ms/epoch - 5ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 70ms/epoch - 6ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 58ms/epoch - 5ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 57ms/epoch - 5ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012 - 55ms/epoch - 5ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 54ms/epoch - 4ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 56ms/epoch - 5ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 57ms/epoch - 5ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 58ms/epoch - 5ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 61ms/epoch - 5ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 58ms/epoch - 5ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 63ms/epoch - 5ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 62ms/epoch - 5ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 57ms/epoch - 5ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 55ms/epoch - 5ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 54ms/epoch - 4ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 59ms/epoch - 5ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 60ms/epoch - 5ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 61ms/epoch - 5ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 65ms/epoch - 5ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 64ms/epoch - 5ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 62ms/epoch - 5ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 67ms/epoch - 6ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 60ms/epoch - 5ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 58ms/epoch - 5ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 58ms/epoch - 5ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 54ms/epoch - 4ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0012 - val_mse: 0.0012 - 56ms/epoch - 5ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 61ms/epoch - 5ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 64ms/epoch - 5ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 62ms/epoch - 5ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 70ms/epoch - 6ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 88ms/epoch - 7ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.0012 - mse: 0.0012 - val_loss: 0.0011 - val_mse: 0.0011 - 77ms/epoch - 6ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 62ms/epoch - 5ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 66ms/epoch - 5ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 72ms/epoch - 6ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 73ms/epoch - 6ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 69ms/epoch - 6ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 66ms/epoch - 5ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 69ms/epoch - 6ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 65ms/epoch - 5ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 69ms/epoch - 6ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 82ms/epoch - 7ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 76ms/epoch - 6ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 74ms/epoch - 6ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 66ms/epoch - 5ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 66ms/epoch - 5ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 62ms/epoch - 5ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 68ms/epoch - 6ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 69ms/epoch - 6ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 64ms/epoch - 5ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 64ms/epoch - 5ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 91ms/epoch - 8ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 76ms/epoch - 6ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 68ms/epoch - 6ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 71ms/epoch - 6ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 70ms/epoch - 6ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 68ms/epoch - 6ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 69ms/epoch - 6ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 67ms/epoch - 6ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 68ms/epoch - 6ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 66ms/epoch - 5ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 59ms/epoch - 5ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 55ms/epoch - 5ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0010 - val_mse: 0.0010 - 57ms/epoch - 5ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 53ms/epoch - 4ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.0011 - mse: 0.0011 - val_loss: 0.0011 - val_mse: 0.0011 - 56ms/epoch - 5ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 52ms/epoch - 4ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 52ms/epoch - 4ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 51ms/epoch - 4ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 51ms/epoch - 4ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 54ms/epoch - 4ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 53ms/epoch - 4ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 71ms/epoch - 6ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 74ms/epoch - 6ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 67ms/epoch - 6ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 59ms/epoch - 5ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 57ms/epoch - 5ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 0.0010 - val_mse: 0.0010 - 63ms/epoch - 5ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.0010 - mse: 0.0010 - val_loss: 9.9733e-04 - val_mse: 9.9733e-04 - 55ms/epoch - 5ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 9.9413e-04 - mse: 9.9413e-04 - val_loss: 0.0010 - val_mse: 0.0010 - 55ms/epoch - 5ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 9.9706e-04 - mse: 9.9706e-04 - val_loss: 0.0010 - val_mse: 0.0010 - 52ms/epoch - 4ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 9.9120e-04 - mse: 9.9120e-04 - val_loss: 9.8953e-04 - val_mse: 9.8953e-04 - 57ms/epoch - 5ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 9.9107e-04 - mse: 9.9107e-04 - val_loss: 9.7967e-04 - val_mse: 9.7967e-04 - 54ms/epoch - 4ms/step
# Epoch 251/2000
# Epoch 284/2000
# 12/12 - 0s - loss: 8.6423e-04 - mse: 8.6423e-04 - val_loss: 8.7226e-04 - val_mse: 8.7226e-04 - 52ms/epoch - 4ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 8.5803e-04 - mse: 8.5803e-04 - val_loss: 8.5991e-04 - val_mse: 8.5991e-04 - 50ms/epoch - 4ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 8.6456e-04 - mse: 8.6456e-04 - val_loss: 8.7169e-04 - val_mse: 8.7169e-04 - 53ms/epoch - 4ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 8.5238e-04 - mse: 8.5238e-04 - val_loss: 8.5892e-04 - val_mse: 8.5892e-04 - 53ms/epoch - 4ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 8.4667e-04 - mse: 8.4667e-04 - val_loss: 8.6185e-04 - val_mse: 8.6185e-04 - 51ms/epoch - 4ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 8.4649e-04 - mse: 8.4649e-04 - val_loss: 8.5098e-04 - val_mse: 8.5098e-04 - 55ms/epoch - 5ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 8.4429e-04 - mse: 8.4429e-04 - val_loss: 8.4648e-04 - val_mse: 8.4648e-04 - 52ms/epoch - 4ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 8.4736e-04 - mse: 8.4736e-04 - val_loss: 8.5482e-04 - val_mse: 8.5482e-04 - 57ms/epoch - 5ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 8.3931e-04 - mse: 8.3931e-04 - val_loss: 8.3132e-04 - val_mse: 8.3132e-04 - 58ms/epoch - 5ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 8.4895e-04 - mse: 8.4895e-04 - val_loss: 8.5253e-04 - val_mse: 8.5253e-04 - 52ms/epoch - 4ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 8.3754e-04 - mse: 8.3754e-04 - val_loss: 8.3169e-04 - val_mse: 8.3169e-04 - 54ms/epoch - 4ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 8.3123e-04 - mse: 8.3123e-04 - val_loss: 8.2629e-04 - val_mse: 8.2629e-04 - 54ms/epoch - 4ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 8.2559e-04 - mse: 8.2559e-04 - val_loss: 8.2421e-04 - val_mse: 8.2421e-04 - 57ms/epoch - 5ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 8.2144e-04 - mse: 8.2144e-04 - val_loss: 8.2499e-04 - val_mse: 8.2499e-04 - 64ms/epoch - 5ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 8.1906e-04 - mse: 8.1906e-04 - val_loss: 8.2382e-04 - val_mse: 8.2382e-04 - 66ms/epoch - 5ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 8.1717e-04 - mse: 8.1717e-04 - val_loss: 8.1933e-04 - val_mse: 8.1933e-04 - 71ms/epoch - 6ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 8.1377e-04 - mse: 8.1377e-04 - val_loss: 8.0830e-04 - val_mse: 8.0830e-04 - 72ms/epoch - 6ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 8.1196e-04 - mse: 8.1196e-04 - val_loss: 8.1486e-04 - val_mse: 8.1486e-04 - 67ms/epoch - 6ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 8.0939e-04 - mse: 8.0939e-04 - val_loss: 8.0771e-04 - val_mse: 8.0771e-04 - 66ms/epoch - 5ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 8.0418e-04 - mse: 8.0418e-04 - val_loss: 8.1078e-04 - val_mse: 8.1078e-04 - 63ms/epoch - 5ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 8.0255e-04 - mse: 8.0255e-04 - val_loss: 8.0150e-04 - val_mse: 8.0150e-04 - 65ms/epoch - 5ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 8.0428e-04 - mse: 8.0428e-04 - val_loss: 8.0918e-04 - val_mse: 8.0918e-04 - 67ms/epoch - 6ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 8.0195e-04 - mse: 8.0195e-04 - val_loss: 7.8819e-04 - val_mse: 7.8819e-04 - 67ms/epoch - 6ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 7.9976e-04 - mse: 7.9976e-04 - val_loss: 8.0048e-04 - val_mse: 8.0048e-04 - 86ms/epoch - 7ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 7.9811e-04 - mse: 7.9811e-04 - val_loss: 7.8767e-04 - val_mse: 7.8767e-04 - 86ms/epoch - 7ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 7.9299e-04 - mse: 7.9299e-04 - val_loss: 7.8752e-04 - val_mse: 7.8752e-04 - 77ms/epoch - 6ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 7.8814e-04 - mse: 7.8814e-04 - val_loss: 7.7911e-04 - val_mse: 7.7911e-04 - 70ms/epoch - 6ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 7.8809e-04 - mse: 7.8809e-04 - val_loss: 7.8163e-04 - val_mse: 7.8163e-04 - 73ms/epoch - 6ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 7.8210e-04 - mse: 7.8210e-04 - val_loss: 7.8483e-04 - val_mse: 7.8483e-04 - 66ms/epoch - 5ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 7.8542e-04 - mse: 7.8542e-04 - val_loss: 7.9432e-04 - val_mse: 7.9432e-04 - 63ms/epoch - 5ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 7.8300e-04 - mse: 7.8300e-04 - val_loss: 7.7265e-04 - val_mse: 7.7265e-04 - 72ms/epoch - 6ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 7.7540e-04 - mse: 7.7540e-04 - val_loss: 7.6535e-04 - val_mse: 7.6535e-04 - 67ms/epoch - 6ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 7.7408e-04 - mse: 7.7408e-04 - val_loss: 7.5766e-04 - val_mse: 7.5766e-04 - 65ms/epoch - 5ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 7.7619e-04 - mse: 7.7619e-04 - val_loss: 8.0573e-04 - val_mse: 8.0573e-04 - 64ms/epoch - 5ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 7.7997e-04 - mse: 7.7997e-04 - val_loss: 7.5624e-04 - val_mse: 7.5624e-04 - 59ms/epoch - 5ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 7.7898e-04 - mse: 7.7898e-04 - val_loss: 7.6934e-04 - val_mse: 7.6934e-04 - 68ms/epoch - 6ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 7.6312e-04 - mse: 7.6312e-04 - val_loss: 7.5282e-04 - val_mse: 7.5282e-04 - 62ms/epoch - 5ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 7.6307e-04 - mse: 7.6307e-04 - val_loss: 7.4592e-04 - val_mse: 7.4592e-04 - 66ms/epoch - 6ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 7.5833e-04 - mse: 7.5833e-04 - val_loss: 7.5134e-04 - val_mse: 7.5134e-04 - 60ms/epoch - 5ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 7.5490e-04 - mse: 7.5490e-04 - val_loss: 7.5972e-04 - val_mse: 7.5972e-04 - 57ms/epoch - 5ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 7.6208e-04 - mse: 7.6208e-04 - val_loss: 7.4062e-04 - val_mse: 7.4062e-04 - 59ms/epoch - 5ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 7.5703e-04 - mse: 7.5703e-04 - val_loss: 7.3485e-04 - val_mse: 7.3485e-04 - 55ms/epoch - 5ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 7.5009e-04 - mse: 7.5009e-04 - val_loss: 7.5240e-04 - val_mse: 7.5240e-04 - 60ms/epoch - 5ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 7.4436e-04 - mse: 7.4436e-04 - val_loss: 7.3520e-04 - val_mse: 7.3520e-04 - 86ms/epoch - 7ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 7.4303e-04 - mse: 7.4303e-04 - val_loss: 7.4495e-04 - val_mse: 7.4495e-04 - 73ms/epoch - 6ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 7.4110e-04 - mse: 7.4110e-04 - val_loss: 7.3219e-04 - val_mse: 7.3219e-04 - 68ms/epoch - 6ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 7.3781e-04 - mse: 7.3781e-04 - val_loss: 7.3281e-04 - val_mse: 7.3281e-04 - 70ms/epoch - 6ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 7.3594e-04 - mse: 7.3594e-04 - val_loss: 7.5060e-04 - val_mse: 7.5060e-04 - 63ms/epoch - 5ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 6.8740e-04 - mse: 6.8740e-04 - val_loss: 6.8144e-04 - val_mse: 6.8144e-04 - 62ms/epoch - 5ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 6.8351e-04 - mse: 6.8351e-04 - val_loss: 6.7114e-04 - val_mse: 6.7114e-04 - 70ms/epoch - 6ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 6.8616e-04 - mse: 6.8616e-04 - val_loss: 6.8155e-04 - val_mse: 6.8155e-04 - 66ms/epoch - 5ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 6.7883e-04 - mse: 6.7883e-04 - val_loss: 6.6729e-04 - val_mse: 6.6729e-04 - 66ms/epoch - 5ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 6.8235e-04 - mse: 6.8235e-04 - val_loss: 6.7511e-04 - val_mse: 6.7511e-04 - 64ms/epoch - 5ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 6.7492e-04 - mse: 6.7492e-04 - val_loss: 6.5868e-04 - val_mse: 6.5868e-04 - 143ms/epoch - 12ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 6.7541e-04 - mse: 6.7541e-04 - val_loss: 6.6473e-04 - val_mse: 6.6473e-04 - 88ms/epoch - 7ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 6.7223e-04 - mse: 6.7223e-04 - val_loss: 6.5938e-04 - val_mse: 6.5938e-04 - 81ms/epoch - 7ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 6.6984e-04 - mse: 6.6984e-04 - val_loss: 6.6775e-04 - val_mse: 6.6775e-04 - 79ms/epoch - 7ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 6.7943e-04 - mse: 6.7943e-04 - val_loss: 6.6506e-04 - val_mse: 6.6506e-04 - 73ms/epoch - 6ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 6.8942e-04 - mse: 6.8942e-04 - val_loss: 6.9757e-04 - val_mse: 6.9757e-04 - 80ms/epoch - 7ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 6.6587e-04 - mse: 6.6587e-04 - val_loss: 6.4741e-04 - val_mse: 6.4741e-04 - 67ms/epoch - 6ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 6.5350e-04 - mse: 6.5350e-04 - val_loss: 6.6216e-04 - val_mse: 6.6216e-04 - 68ms/epoch - 6ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 6.5865e-04 - mse: 6.5865e-04 - val_loss: 6.4802e-04 - val_mse: 6.4802e-04 - 61ms/epoch - 5ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 6.4996e-04 - mse: 6.4996e-04 - val_loss: 6.5047e-04 - val_mse: 6.5047e-04 - 74ms/epoch - 6ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 6.4738e-04 - mse: 6.4738e-04 - val_loss: 6.4607e-04 - val_mse: 6.4607e-04 - 71ms/epoch - 6ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 6.4993e-04 - mse: 6.4993e-04 - val_loss: 6.6205e-04 - val_mse: 6.6205e-04 - 94ms/epoch - 8ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 6.4795e-04 - mse: 6.4795e-04 - val_loss: 6.4258e-04 - val_mse: 6.4258e-04 - 80ms/epoch - 7ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 6.4236e-04 - mse: 6.4236e-04 - val_loss: 6.3815e-04 - val_mse: 6.3815e-04 - 79ms/epoch - 7ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 6.4172e-04 - mse: 6.4172e-04 - val_loss: 6.4053e-04 - val_mse: 6.4053e-04 - 78ms/epoch - 6ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 6.3879e-04 - mse: 6.3879e-04 - val_loss: 6.4268e-04 - val_mse: 6.4268e-04 - 75ms/epoch - 6ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 6.3599e-04 - mse: 6.3599e-04 - val_loss: 6.3467e-04 - val_mse: 6.3467e-04 - 117ms/epoch - 10ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 6.3217e-04 - mse: 6.3217e-04 - val_loss: 6.3206e-04 - val_mse: 6.3206e-04 - 98ms/epoch - 8ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 6.3355e-04 - mse: 6.3355e-04 - val_loss: 6.3946e-04 - val_mse: 6.3946e-04 - 88ms/epoch - 7ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 6.3696e-04 - mse: 6.3696e-04 - val_loss: 6.2430e-04 - val_mse: 6.2430e-04 - 98ms/epoch - 8ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 6.2802e-04 - mse: 6.2802e-04 - val_loss: 6.3943e-04 - val_mse: 6.3943e-04 - 96ms/epoch - 8ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 6.2833e-04 - mse: 6.2833e-04 - val_loss: 6.2717e-04 - val_mse: 6.2717e-04 - 89ms/epoch - 7ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 6.2888e-04 - mse: 6.2888e-04 - val_loss: 6.2418e-04 - val_mse: 6.2418e-04 - 83ms/epoch - 7ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 6.3097e-04 - mse: 6.3097e-04 - val_loss: 6.3311e-04 - val_mse: 6.3311e-04 - 84ms/epoch - 7ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 6.1882e-04 - mse: 6.1882e-04 - val_loss: 6.1576e-04 - val_mse: 6.1576e-04 - 94ms/epoch - 8ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 6.1693e-04 - mse: 6.1693e-04 - val_loss: 6.2133e-04 - val_mse: 6.2133e-04 - 77ms/epoch - 6ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 6.1637e-04 - mse: 6.1637e-04 - val_loss: 6.2543e-04 - val_mse: 6.2543e-04 - 94ms/epoch - 8ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 6.1291e-04 - mse: 6.1291e-04 - val_loss: 6.1670e-04 - val_mse: 6.1670e-04 - 91ms/epoch - 8ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 6.1685e-04 - mse: 6.1685e-04 - val_loss: 6.1284e-04 - val_mse: 6.1284e-04 - 83ms/epoch - 7ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 6.1201e-04 - mse: 6.1201e-04 - val_loss: 6.1582e-04 - val_mse: 6.1582e-04 - 119ms/epoch - 10ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 6.0759e-04 - mse: 6.0759e-04 - val_loss: 6.1826e-04 - val_mse: 6.1826e-04 - 115ms/epoch - 10ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 6.1121e-04 - mse: 6.1121e-04 - val_loss: 6.0392e-04 - val_mse: 6.0392e-04 - 102ms/epoch - 9ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 6.0671e-04 - mse: 6.0671e-04 - val_loss: 6.3077e-04 - val_mse: 6.3077e-04 - 87ms/epoch - 7ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 6.0264e-04 - mse: 6.0264e-04 - val_loss: 6.0305e-04 - val_mse: 6.0305e-04 - 92ms/epoch - 8ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 6.0521e-04 - mse: 6.0521e-04 - val_loss: 6.0988e-04 - val_mse: 6.0988e-04 - 81ms/epoch - 7ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 6.0380e-04 - mse: 6.0380e-04 - val_loss: 6.1048e-04 - val_mse: 6.1048e-04 - 77ms/epoch - 6ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 6.0215e-04 - mse: 6.0215e-04 - val_loss: 6.0168e-04 - val_mse: 6.0168e-04 - 79ms/epoch - 7ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 5.9774e-04 - mse: 5.9774e-04 - val_loss: 6.0862e-04 - val_mse: 6.0862e-04 - 80ms/epoch - 7ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 5.9698e-04 - mse: 5.9698e-04 - val_loss: 5.9662e-04 - val_mse: 5.9662e-04 - 72ms/epoch - 6ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 5.9468e-04 - mse: 5.9468e-04 - val_loss: 5.9910e-04 - val_mse: 5.9910e-04 - 74ms/epoch - 6ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 5.9066e-04 - mse: 5.9066e-04 - val_loss: 6.0824e-04 - val_mse: 6.0824e-04 - 79ms/epoch - 7ms/step
# Epoch 394/2000
# ...
# Epoch 1881/2000
# 12/12 - 0s - loss: 4.5406e-04 - mse: 4.5406e-04 - val_loss: 4.5397e-04 - val_mse: 4.5397e-04 - 65ms/epoch - 5ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 4.4961e-04 - mse: 4.4961e-04 - val_loss: 4.4499e-04 - val_mse: 4.4499e-04 - 64ms/epoch - 5ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 4.3324e-04 - mse: 4.3324e-04 - val_loss: 4.5657e-04 - val_mse: 4.5657e-04 - 64ms/epoch - 5ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 4.3532e-04 - mse: 4.3532e-04 - val_loss: 4.4940e-04 - val_mse: 4.4940e-04 - 65ms/epoch - 5ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 4.4369e-04 - mse: 4.4369e-04 - val_loss: 4.5922e-04 - val_mse: 4.5922e-04 - 61ms/epoch - 5ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 4.4290e-04 - mse: 4.4290e-04 - val_loss: 5.2684e-04 - val_mse: 5.2684e-04 - 58ms/epoch - 5ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 4.5371e-04 - mse: 4.5371e-04 - val_loss: 4.8007e-04 - val_mse: 4.8007e-04 - 65ms/epoch - 5ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 4.4460e-04 - mse: 4.4460e-04 - val_loss: 4.7749e-04 - val_mse: 4.7749e-04 - 56ms/epoch - 5ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 4.5338e-04 - mse: 4.5338e-04 - val_loss: 4.5587e-04 - val_mse: 4.5587e-04 - 86ms/epoch - 7ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 4.4671e-04 - mse: 4.4671e-04 - val_loss: 4.7740e-04 - val_mse: 4.7740e-04 - 96ms/epoch - 8ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 4.4857e-04 - mse: 4.4857e-04 - val_loss: 4.5861e-04 - val_mse: 4.5861e-04 - 73ms/epoch - 6ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 4.3936e-04 - mse: 4.3936e-04 - val_loss: 4.5843e-04 - val_mse: 4.5843e-04 - 68ms/epoch - 6ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 4.4570e-04 - mse: 4.4570e-04 - val_loss: 4.9682e-04 - val_mse: 4.9682e-04 - 68ms/epoch - 6ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 4.3959e-04 - mse: 4.3959e-04 - val_loss: 4.6227e-04 - val_mse: 4.6227e-04 - 66ms/epoch - 5ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 4.3762e-04 - mse: 4.3762e-04 - val_loss: 4.4834e-04 - val_mse: 4.4834e-04 - 66ms/epoch - 5ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 4.2941e-04 - mse: 4.2941e-04 - val_loss: 4.5742e-04 - val_mse: 4.5742e-04 - 61ms/epoch - 5ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 4.3299e-04 - mse: 4.3299e-04 - val_loss: 4.5524e-04 - val_mse: 4.5524e-04 - 64ms/epoch - 5ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 4.3826e-04 - mse: 4.3826e-04 - val_loss: 4.6183e-04 - val_mse: 4.6183e-04 - 65ms/epoch - 5ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 4.3478e-04 - mse: 4.3478e-04 - val_loss: 4.5302e-04 - val_mse: 4.5302e-04 - 61ms/epoch - 5ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 4.3162e-04 - mse: 4.3162e-04 - val_loss: 4.5568e-04 - val_mse: 4.5568e-04 - 59ms/epoch - 5ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 4.3510e-04 - mse: 4.3510e-04 - val_loss: 4.6284e-04 - val_mse: 4.6284e-04 - 61ms/epoch - 5ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 4.3360e-04 - mse: 4.3360e-04 - val_loss: 4.5345e-04 - val_mse: 4.5345e-04 - 65ms/epoch - 5ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 4.3053e-04 - mse: 4.3053e-04 - val_loss: 4.7554e-04 - val_mse: 4.7554e-04 - 62ms/epoch - 5ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 4.3691e-04 - mse: 4.3691e-04 - val_loss: 4.5679e-04 - val_mse: 4.5679e-04 - 60ms/epoch - 5ms/step

# %%
# recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
plt.title('model loss')
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 10)                40
#
#  second_layer (Dense)        (None, 5)                 55
#
#  output_layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.019

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.084

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (0.2, 0.13))
plt.annotate("MAE = {:.3f}".format(error), (0.2, 0.14))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
plt.title('Validation of the prediction model')     
plt.grid(True)

plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_99')
