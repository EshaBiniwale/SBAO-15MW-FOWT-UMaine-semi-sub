# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

sns.set_style("darkgrid")

# %% [markdown]
#     215 : ESYS line1 SENSOR 84 - Tension at Fairlead - Trained on Max values

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_215.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Max']]

# %%
print('Maximum value of tension at fairlead (Line 1): %.6f' % df['Max'].max())
print('Minimum value of tension at fairlead (Line 1): %.6f' % df['Max'].min())
print('Range for tension at fairlead (Line 1): %.6f' % (df['Max'].max()-df['Max'].min()))
print('Mean for tension at fairlead (Line 1): %.6f' % (np.mean(df['Max'])))
# Out:
# Maximum value of tension at fairlead (Line 1): 12955712.275778
# Minimum value of tension at fairlead (Line 1): 1044765.596194
# Range for tension at fairlead (Line 1): 11910946.679584
# Mean for tension at fairlead (Line 1): 3601226.753687

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 0             800       800           0  3.525371e+06
# 1             800       800           1  3.344094e+06
# 2             800       800           2  3.291454e+06
# 3             800       800           3  3.395797e+06
# 4             800       800           4  3.211976e+06

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values      0
# R_anchor      0
# z_fairlead    0
# Max           0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 1194          850       840          14  1.032996e+07

# %% [markdown]
# # Sensitivity analysis

# %%
#varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

#varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

#varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
#Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum tension at fairlead for line 1', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='Max', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[0].set_title('Variation of T vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="Max", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[1].set_title('Variation of T vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="Max", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[2].set_title('Variation of T vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['Max']<= df['Max'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_215.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label (Line 1)')

#L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='Max',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Max Tension at fairlead (Line 1)', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
#plot heat map
plt.rcParams.update({'font.size': 14})
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#              count          mean           std           min           max
# L_values    1300.0  8.449231e+02  2.328807e+01  8.000000e+02  8.800000e+02
# R_anchor    1300.0  8.347692e+02  2.626962e+01  8.000000e+02  9.000000e+02
# z_fairlead  1300.0  9.500000e+00  5.768500e+00  0.000000e+00  1.900000e+01
# Max         1300.0  3.601227e+06  2.749765e+06  1.044766e+06  1.295571e+07

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['Max']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_215.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_215.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Max
# File_ID
# 0             0.0       0.0    0.000000 -0.027597
# 1             0.0       0.0    0.052632 -0.093547
# 2             0.0       0.0    0.105263 -0.112697
# 3             0.0       0.0    0.157895 -0.074737
# 4             0.0       0.0    0.210526 -0.141612

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %% [markdown]
# It draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / fan_in) where fan_in is the number of input units in the weight tensor.

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2500, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2500
# 12/12 - 1s - loss: 1.1160 - mse: 1.1160 - val_loss: 1.0723 - val_mse: 1.0723 - 746ms/epoch - 62ms/step
# Epoch 2/2500
# 12/12 - 0s - loss: 1.0459 - mse: 1.0459 - val_loss: 1.0329 - val_mse: 1.0329 - 50ms/epoch - 4ms/step
# Epoch 3/2500
# 12/12 - 0s - loss: 1.0243 - mse: 1.0243 - val_loss: 1.0241 - val_mse: 1.0241 - 62ms/epoch - 5ms/step
# Epoch 4/2500
# 12/12 - 0s - loss: 1.0176 - mse: 1.0176 - val_loss: 1.0199 - val_mse: 1.0199 - 50ms/epoch - 4ms/step
# Epoch 5/2500
# 12/12 - 0s - loss: 1.0131 - mse: 1.0131 - val_loss: 1.0166 - val_mse: 1.0166 - 70ms/epoch - 6ms/step
# Epoch 6/2500
# 12/12 - 0s - loss: 1.0089 - mse: 1.0089 - val_loss: 1.0133 - val_mse: 1.0133 - 74ms/epoch - 6ms/step
# Epoch 7/2500
# 12/12 - 0s - loss: 1.0048 - mse: 1.0048 - val_loss: 1.0098 - val_mse: 1.0098 - 56ms/epoch - 5ms/step
# Epoch 8/2500
# 12/12 - 0s - loss: 1.0006 - mse: 1.0006 - val_loss: 1.0062 - val_mse: 1.0062 - 58ms/epoch - 5ms/step
# Epoch 9/2500
# 12/12 - 0s - loss: 0.9956 - mse: 0.9956 - val_loss: 1.0020 - val_mse: 1.0020 - 58ms/epoch - 5ms/step
# Epoch 10/2500
# 12/12 - 0s - loss: 0.9901 - mse: 0.9901 - val_loss: 0.9976 - val_mse: 0.9976 - 53ms/epoch - 4ms/step
# Epoch 11/2500
# 12/12 - 0s - loss: 0.9837 - mse: 0.9837 - val_loss: 0.9922 - val_mse: 0.9922 - 115ms/epoch - 10ms/step
# Epoch 12/2500
# 12/12 - 0s - loss: 0.9764 - mse: 0.9764 - val_loss: 0.9868 - val_mse: 0.9868 - 69ms/epoch - 6ms/step
# Epoch 13/2500
# 12/12 - 0s - loss: 0.9691 - mse: 0.9691 - val_loss: 0.9812 - val_mse: 0.9812 - 61ms/epoch - 5ms/step
# Epoch 14/2500
# 12/12 - 0s - loss: 0.9616 - mse: 0.9616 - val_loss: 0.9758 - val_mse: 0.9758 - 50ms/epoch - 4ms/step
# Epoch 15/2500
# 12/12 - 0s - loss: 0.9528 - mse: 0.9528 - val_loss: 0.9706 - val_mse: 0.9706 - 54ms/epoch - 4ms/step
# Epoch 16/2500
# 12/12 - 0s - loss: 0.9446 - mse: 0.9446 - val_loss: 0.9668 - val_mse: 0.9668 - 56ms/epoch - 5ms/step
# Epoch 17/2500
# 12/12 - 0s - loss: 0.9370 - mse: 0.9370 - val_loss: 0.9622 - val_mse: 0.9622 - 53ms/epoch - 4ms/step
# Epoch 18/2500
# 12/12 - 0s - loss: 0.9286 - mse: 0.9286 - val_loss: 0.9574 - val_mse: 0.9574 - 60ms/epoch - 5ms/step
# Epoch 19/2500
# 12/12 - 0s - loss: 0.9223 - mse: 0.9223 - val_loss: 0.9522 - val_mse: 0.9522 - 67ms/epoch - 6ms/step
# Epoch 20/2500
# 12/12 - 0s - loss: 0.9147 - mse: 0.9147 - val_loss: 0.9500 - val_mse: 0.9500 - 47ms/epoch - 4ms/step
# Epoch 21/2500
# 12/12 - 0s - loss: 0.9088 - mse: 0.9088 - val_loss: 0.9493 - val_mse: 0.9493 - 62ms/epoch - 5ms/step
# Epoch 22/2500
# 12/12 - 0s - loss: 0.9033 - mse: 0.9033 - val_loss: 0.9447 - val_mse: 0.9447 - 56ms/epoch - 5ms/step
# Epoch 23/2500
# 12/12 - 0s - loss: 0.8974 - mse: 0.8974 - val_loss: 0.9423 - val_mse: 0.9423 - 53ms/epoch - 4ms/step
# Epoch 24/2500
# 12/12 - 0s - loss: 0.8919 - mse: 0.8919 - val_loss: 0.9426 - val_mse: 0.9426 - 74ms/epoch - 6ms/step
# Epoch 25/2500
# 12/12 - 0s - loss: 0.8881 - mse: 0.8881 - val_loss: 0.9400 - val_mse: 0.9400 - 51ms/epoch - 4ms/step
# Epoch 26/2500
# 12/12 - 0s - loss: 0.8834 - mse: 0.8834 - val_loss: 0.9385 - val_mse: 0.9385 - 67ms/epoch - 6ms/step
# Epoch 27/2500
# 12/12 - 0s - loss: 0.8793 - mse: 0.8793 - val_loss: 0.9358 - val_mse: 0.9358 - 93ms/epoch - 8ms/step
# Epoch 28/2500
# 12/12 - 0s - loss: 0.8750 - mse: 0.8750 - val_loss: 0.9354 - val_mse: 0.9354 - 84ms/epoch - 7ms/step
# Epoch 29/2500
# 12/12 - 0s - loss: 0.8715 - mse: 0.8715 - val_loss: 0.9301 - val_mse: 0.9301 - 71ms/epoch - 6ms/step
# Epoch 30/2500
# 12/12 - 0s - loss: 0.8675 - mse: 0.8675 - val_loss: 0.9278 - val_mse: 0.9278 - 74ms/epoch - 6ms/step
# Epoch 31/2500
# 12/12 - 0s - loss: 0.8632 - mse: 0.8632 - val_loss: 0.9244 - val_mse: 0.9244 - 58ms/epoch - 5ms/step
# Epoch 32/2500
# 12/12 - 0s - loss: 0.8604 - mse: 0.8604 - val_loss: 0.9223 - val_mse: 0.9223 - 61ms/epoch - 5ms/step
# Epoch 33/2500
# 12/12 - 0s - loss: 0.8564 - mse: 0.8564 - val_loss: 0.9190 - val_mse: 0.9190 - 65ms/epoch - 5ms/step
# Epoch 34/2500
# 12/12 - 0s - loss: 0.8537 - mse: 0.8537 - val_loss: 0.9148 - val_mse: 0.9148 - 73ms/epoch - 6ms/step
# Epoch 35/2500
# 12/12 - 0s - loss: 0.8506 - mse: 0.8506 - val_loss: 0.9138 - val_mse: 0.9138 - 73ms/epoch - 6ms/step
# Epoch 36/2500
# 12/12 - 0s - loss: 0.8456 - mse: 0.8456 - val_loss: 0.9146 - val_mse: 0.9146 - 73ms/epoch - 6ms/step
# Epoch 37/2500
# 12/12 - 0s - loss: 0.8421 - mse: 0.8421 - val_loss: 0.9087 - val_mse: 0.9087 - 74ms/epoch - 6ms/step
# Epoch 38/2500
# 12/12 - 0s - loss: 0.8382 - mse: 0.8382 - val_loss: 0.9040 - val_mse: 0.9040 - 74ms/epoch - 6ms/step
# Epoch 39/2500
# 12/12 - 0s - loss: 0.8345 - mse: 0.8345 - val_loss: 0.8995 - val_mse: 0.8995 - 58ms/epoch - 5ms/step
# Epoch 40/2500
# 12/12 - 0s - loss: 0.8312 - mse: 0.8312 - val_loss: 0.8966 - val_mse: 0.8966 - 57ms/epoch - 5ms/step
# Epoch 41/2500
# 12/12 - 0s - loss: 0.8283 - mse: 0.8283 - val_loss: 0.8957 - val_mse: 0.8957 - 61ms/epoch - 5ms/step
# Epoch 42/2500
# 12/12 - 0s - loss: 0.8241 - mse: 0.8241 - val_loss: 0.8904 - val_mse: 0.8904 - 69ms/epoch - 6ms/step
# Epoch 43/2500
# 12/12 - 0s - loss: 0.8208 - mse: 0.8208 - val_loss: 0.8872 - val_mse: 0.8872 - 72ms/epoch - 6ms/step
# Epoch 44/2500
# 12/12 - 0s - loss: 0.8169 - mse: 0.8169 - val_loss: 0.8865 - val_mse: 0.8865 - 58ms/epoch - 5ms/step
# Epoch 45/2500
# 12/12 - 0s - loss: 0.8137 - mse: 0.8137 - val_loss: 0.8835 - val_mse: 0.8835 - 79ms/epoch - 7ms/step
# Epoch 46/2500
# 12/12 - 0s - loss: 0.8114 - mse: 0.8114 - val_loss: 0.8799 - val_mse: 0.8799 - 387ms/epoch - 32ms/step
# Epoch 47/2500
# 12/12 - 0s - loss: 0.8077 - mse: 0.8077 - val_loss: 0.8679 - val_mse: 0.8679 - 242ms/epoch - 20ms/step
# Epoch 48/2500
# 12/12 - 0s - loss: 0.7979 - mse: 0.7979 - val_loss: 0.8630 - val_mse: 0.8630 - 211ms/epoch - 18ms/step
# Epoch 49/2500
# 12/12 - 0s - loss: 0.7920 - mse: 0.7920 - val_loss: 0.8542 - val_mse: 0.8542 - 118ms/epoch - 10ms/step
# Epoch 50/2500
# 12/12 - 0s - loss: 0.7854 - mse: 0.7854 - val_loss: 0.8498 - val_mse: 0.8498 - 110ms/epoch - 9ms/step
# Epoch 51/2500
# 12/12 - 0s - loss: 0.7812 - mse: 0.7812 - val_loss: 0.8501 - val_mse: 0.8501 - 87ms/epoch - 7ms/step
# Epoch 52/2500
# 12/12 - 0s - loss: 0.7763 - mse: 0.7763 - val_loss: 0.8440 - val_mse: 0.8440 - 93ms/epoch - 8ms/step
# Epoch 53/2500
# 12/12 - 0s - loss: 0.7708 - mse: 0.7708 - val_loss: 0.8406 - val_mse: 0.8406 - 89ms/epoch - 7ms/step
# Epoch 54/2500
# 12/12 - 0s - loss: 0.7673 - mse: 0.7673 - val_loss: 0.8286 - val_mse: 0.8286 - 112ms/epoch - 9ms/step
# Epoch 55/2500
# 12/12 - 0s - loss: 0.7603 - mse: 0.7603 - val_loss: 0.8280 - val_mse: 0.8280 - 101ms/epoch - 8ms/step
# Epoch 56/2500
# 12/12 - 0s - loss: 0.7575 - mse: 0.7575 - val_loss: 0.8310 - val_mse: 0.8310 - 90ms/epoch - 7ms/step
# Epoch 57/2500
# 12/12 - 0s - loss: 0.7529 - mse: 0.7529 - val_loss: 0.8132 - val_mse: 0.8132 - 136ms/epoch - 11ms/step
# Epoch 58/2500
# 12/12 - 0s - loss: 0.7501 - mse: 0.7501 - val_loss: 0.8188 - val_mse: 0.8188 - 128ms/epoch - 11ms/step
# Epoch 59/2500
# 12/12 - 0s - loss: 0.7458 - mse: 0.7458 - val_loss: 0.8074 - val_mse: 0.8074 - 120ms/epoch - 10ms/step
# Epoch 60/2500
# 12/12 - 0s - loss: 0.7402 - mse: 0.7402 - val_loss: 0.8107 - val_mse: 0.8107 - 94ms/epoch - 8ms/step
# Epoch 61/2500
# 12/12 - 0s - loss: 0.7382 - mse: 0.7382 - val_loss: 0.8034 - val_mse: 0.8034 - 144ms/epoch - 12ms/step
# Epoch 62/2500
# 12/12 - 0s - loss: 0.7352 - mse: 0.7352 - val_loss: 0.8014 - val_mse: 0.8014 - 88ms/epoch - 7ms/step
# Epoch 63/2500
# 12/12 - 0s - loss: 0.7316 - mse: 0.7316 - val_loss: 0.7947 - val_mse: 0.7947 - 75ms/epoch - 6ms/step
# Epoch 64/2500
# 12/12 - 0s - loss: 0.7285 - mse: 0.7285 - val_loss: 0.7878 - val_mse: 0.7878 - 74ms/epoch - 6ms/step
# Epoch 65/2500
# 12/12 - 0s - loss: 0.7242 - mse: 0.7242 - val_loss: 0.7808 - val_mse: 0.7808 - 77ms/epoch - 6ms/step
# Epoch 66/2500
# 12/12 - 0s - loss: 0.7203 - mse: 0.7203 - val_loss: 0.7839 - val_mse: 0.7839 - 82ms/epoch - 7ms/step
# Epoch 67/2500
# 12/12 - 0s - loss: 0.7182 - mse: 0.7182 - val_loss: 0.7754 - val_mse: 0.7754 - 78ms/epoch - 6ms/step
# Epoch 68/2500
# 12/12 - 0s - loss: 0.7155 - mse: 0.7155 - val_loss: 0.7736 - val_mse: 0.7736 - 96ms/epoch - 8ms/step
# Epoch 69/2500
# 12/12 - 0s - loss: 0.7112 - mse: 0.7112 - val_loss: 0.7673 - val_mse: 0.7673 - 90ms/epoch - 7ms/step
# Epoch 70/2500
# 12/12 - 0s - loss: 0.7078 - mse: 0.7078 - val_loss: 0.7671 - val_mse: 0.7671 - 80ms/epoch - 7ms/step
# Epoch 71/2500
# 12/12 - 0s - loss: 0.7067 - mse: 0.7067 - val_loss: 0.7626 - val_mse: 0.7626 - 82ms/epoch - 7ms/step
# Epoch 72/2500
# 12/12 - 0s - loss: 0.7016 - mse: 0.7016 - val_loss: 0.7691 - val_mse: 0.7691 - 96ms/epoch - 8ms/step
# Epoch 73/2500
# 12/12 - 0s - loss: 0.6999 - mse: 0.6999 - val_loss: 0.7655 - val_mse: 0.7655 - 78ms/epoch - 6ms/step
# Epoch 74/2500
# 12/12 - 0s - loss: 0.6966 - mse: 0.6966 - val_loss: 0.7521 - val_mse: 0.7521 - 74ms/epoch - 6ms/step
# Epoch 75/2500
# 12/12 - 0s - loss: 0.6939 - mse: 0.6939 - val_loss: 0.7502 - val_mse: 0.7502 - 80ms/epoch - 7ms/step
# Epoch 76/2500
# 12/12 - 0s - loss: 0.6921 - mse: 0.6921 - val_loss: 0.7510 - val_mse: 0.7510 - 79ms/epoch - 7ms/step
# Epoch 77/2500
# 12/12 - 0s - loss: 0.6908 - mse: 0.6908 - val_loss: 0.7420 - val_mse: 0.7420 - 65ms/epoch - 5ms/step
# Epoch 78/2500
# 12/12 - 0s - loss: 0.6863 - mse: 0.6863 - val_loss: 0.7463 - val_mse: 0.7463 - 59ms/epoch - 5ms/step
# Epoch 79/2500
# 12/12 - 0s - loss: 0.6813 - mse: 0.6813 - val_loss: 0.7327 - val_mse: 0.7327 - 71ms/epoch - 6ms/step
# Epoch 80/2500
# 12/12 - 0s - loss: 0.6812 - mse: 0.6812 - val_loss: 0.7310 - val_mse: 0.7310 - 104ms/epoch - 9ms/step
# Epoch 81/2500
# 12/12 - 0s - loss: 0.6775 - mse: 0.6775 - val_loss: 0.7276 - val_mse: 0.7276 - 129ms/epoch - 11ms/step
# Epoch 82/2500
# 12/12 - 0s - loss: 0.6723 - mse: 0.6723 - val_loss: 0.7297 - val_mse: 0.7297 - 117ms/epoch - 10ms/step
# Epoch 83/2500
# 12/12 - 0s - loss: 0.6711 - mse: 0.6711 - val_loss: 0.7198 - val_mse: 0.7198 - 90ms/epoch - 7ms/step
# Epoch 84/2500
# 12/12 - 0s - loss: 0.6684 - mse: 0.6684 - val_loss: 0.7274 - val_mse: 0.7274 - 93ms/epoch - 8ms/step
# Epoch 85/2500
# 12/12 - 0s - loss: 0.6631 - mse: 0.6631 - val_loss: 0.7145 - val_mse: 0.7145 - 119ms/epoch - 10ms/step
# Epoch 86/2500
# 12/12 - 0s - loss: 0.6622 - mse: 0.6622 - val_loss: 0.7157 - val_mse: 0.7157 - 107ms/epoch - 9ms/step
# Epoch 87/2500
# 12/12 - 0s - loss: 0.6588 - mse: 0.6588 - val_loss: 0.7119 - val_mse: 0.7119 - 160ms/epoch - 13ms/step
# Epoch 88/2500
# 12/12 - 0s - loss: 0.6558 - mse: 0.6558 - val_loss: 0.7109 - val_mse: 0.7109 - 159ms/epoch - 13ms/step
# Epoch 89/2500
# 12/12 - 0s - loss: 0.6555 - mse: 0.6555 - val_loss: 0.7048 - val_mse: 0.7048 - 121ms/epoch - 10ms/step
# Epoch 90/2500
# 12/12 - 0s - loss: 0.6555 - mse: 0.6555 - val_loss: 0.7102 - val_mse: 0.7102 - 104ms/epoch - 9ms/step
# Epoch 91/2500
# 12/12 - 0s - loss: 0.6494 - mse: 0.6494 - val_loss: 0.6949 - val_mse: 0.6949 - 108ms/epoch - 9ms/step
# Epoch 92/2500
# 12/12 - 0s - loss: 0.6462 - mse: 0.6462 - val_loss: 0.7015 - val_mse: 0.7015 - 102ms/epoch - 8ms/step
# Epoch 93/2500
# 12/12 - 0s - loss: 0.6431 - mse: 0.6431 - val_loss: 0.6956 - val_mse: 0.6956 - 109ms/epoch - 9ms/step
# Epoch 94/2500
# 12/12 - 0s - loss: 0.6404 - mse: 0.6404 - val_loss: 0.7002 - val_mse: 0.7002 - 102ms/epoch - 8ms/step
# Epoch 95/2500
# 12/12 - 0s - loss: 0.6391 - mse: 0.6391 - val_loss: 0.6891 - val_mse: 0.6891 - 109ms/epoch - 9ms/step
# Epoch 96/2500
# 12/12 - 0s - loss: 0.6356 - mse: 0.6356 - val_loss: 0.6922 - val_mse: 0.6922 - 100ms/epoch - 8ms/step
# Epoch 97/2500
# 12/12 - 0s - loss: 0.6351 - mse: 0.6351 - val_loss: 0.6862 - val_mse: 0.6862 - 95ms/epoch - 8ms/step
# Epoch 98/2500
# 12/12 - 0s - loss: 0.6313 - mse: 0.6313 - val_loss: 0.6890 - val_mse: 0.6890 - 95ms/epoch - 8ms/step
# Epoch 99/2500
# 12/12 - 0s - loss: 0.6291 - mse: 0.6291 - val_loss: 0.6828 - val_mse: 0.6828 - 141ms/epoch - 12ms/step
# Epoch 100/2500
# 12/12 - 0s - loss: 0.6266 - mse: 0.6266 - val_loss: 0.6816 - val_mse: 0.6816 - 165ms/epoch - 14ms/step
# Epoch 101/2500
# 12/12 - 0s - loss: 0.6276 - mse: 0.6276 - val_loss: 0.6891 - val_mse: 0.6891 - 113ms/epoch - 9ms/step
# Epoch 102/2500
# 12/12 - 0s - loss: 0.6195 - mse: 0.6195 - val_loss: 0.6701 - val_mse: 0.6701 - 104ms/epoch - 9ms/step
# Epoch 103/2500
# 12/12 - 0s - loss: 0.6192 - mse: 0.6192 - val_loss: 0.6800 - val_mse: 0.6800 - 97ms/epoch - 8ms/step
# Epoch 104/2500
# 12/12 - 0s - loss: 0.6176 - mse: 0.6176 - val_loss: 0.6709 - val_mse: 0.6709 - 88ms/epoch - 7ms/step
# Epoch 105/2500
# 12/12 - 0s - loss: 0.6165 - mse: 0.6165 - val_loss: 0.6741 - val_mse: 0.6741 - 104ms/epoch - 9ms/step
# Epoch 106/2500
# 12/12 - 0s - loss: 0.6121 - mse: 0.6121 - val_loss: 0.6703 - val_mse: 0.6703 - 95ms/epoch - 8ms/step
# Epoch 107/2500
# 12/12 - 0s - loss: 0.6110 - mse: 0.6110 - val_loss: 0.6682 - val_mse: 0.6682 - 88ms/epoch - 7ms/step
# Epoch 108/2500
# 12/12 - 0s - loss: 0.6083 - mse: 0.6083 - val_loss: 0.6697 - val_mse: 0.6697 - 90ms/epoch - 7ms/step
# Epoch 109/2500
# 12/12 - 0s - loss: 0.6106 - mse: 0.6106 - val_loss: 0.6662 - val_mse: 0.6662 - 103ms/epoch - 9ms/step
# Epoch 110/2500
# 12/12 - 0s - loss: 0.6056 - mse: 0.6056 - val_loss: 0.6641 - val_mse: 0.6641 - 95ms/epoch - 8ms/step
# Epoch 111/2500
# 12/12 - 0s - loss: 0.6030 - mse: 0.6030 - val_loss: 0.6600 - val_mse: 0.6600 - 115ms/epoch - 10ms/step
# Epoch 112/2500
# 12/12 - 0s - loss: 0.5992 - mse: 0.5992 - val_loss: 0.6616 - val_mse: 0.6616 - 143ms/epoch - 12ms/step
# Epoch 113/2500
# 12/12 - 0s - loss: 0.5974 - mse: 0.5974 - val_loss: 0.6595 - val_mse: 0.6595 - 131ms/epoch - 11ms/step
# Epoch 114/2500
# 12/12 - 0s - loss: 0.5958 - mse: 0.5958 - val_loss: 0.6568 - val_mse: 0.6568 - 118ms/epoch - 10ms/step
# Epoch 115/2500
# 12/12 - 0s - loss: 0.5978 - mse: 0.5978 - val_loss: 0.6565 - val_mse: 0.6565 - 100ms/epoch - 8ms/step
# Epoch 116/2500
# 12/12 - 0s - loss: 0.5926 - mse: 0.5926 - val_loss: 0.6504 - val_mse: 0.6504 - 113ms/epoch - 9ms/step
# Epoch 117/2500
# 12/12 - 0s - loss: 0.5909 - mse: 0.5909 - val_loss: 0.6478 - val_mse: 0.6478 - 128ms/epoch - 11ms/step
# Epoch 118/2500
# 12/12 - 0s - loss: 0.5883 - mse: 0.5883 - val_loss: 0.6495 - val_mse: 0.6495 - 135ms/epoch - 11ms/step
# Epoch 119/2500
# 12/12 - 0s - loss: 0.5859 - mse: 0.5859 - val_loss: 0.6431 - val_mse: 0.6431 - 115ms/epoch - 10ms/step
# Epoch 120/2500
# 12/12 - 0s - loss: 0.5840 - mse: 0.5840 - val_loss: 0.6461 - val_mse: 0.6461 - 101ms/epoch - 8ms/step
# Epoch 121/2500
# 12/12 - 0s - loss: 0.5839 - mse: 0.5839 - val_loss: 0.6490 - val_mse: 0.6490 - 91ms/epoch - 8ms/step
# Epoch 122/2500
# 12/12 - 0s - loss: 0.5820 - mse: 0.5820 - val_loss: 0.6374 - val_mse: 0.6374 - 177ms/epoch - 15ms/step
# Epoch 123/2500
# 12/12 - 0s - loss: 0.5808 - mse: 0.5808 - val_loss: 0.6480 - val_mse: 0.6480 - 130ms/epoch - 11ms/step
# Epoch 124/2500
# 12/12 - 0s - loss: 0.5774 - mse: 0.5774 - val_loss: 0.6395 - val_mse: 0.6395 - 112ms/epoch - 9ms/step
# Epoch 125/2500
# 12/12 - 0s - loss: 0.5760 - mse: 0.5760 - val_loss: 0.6356 - val_mse: 0.6356 - 112ms/epoch - 9ms/step
# Epoch 126/2500
# 12/12 - 0s - loss: 0.5758 - mse: 0.5758 - val_loss: 0.6416 - val_mse: 0.6416 - 116ms/epoch - 10ms/step
# Epoch 127/2500
# 12/12 - 0s - loss: 0.5735 - mse: 0.5735 - val_loss: 0.6326 - val_mse: 0.6326 - 145ms/epoch - 12ms/step
# Epoch 128/2500
# 12/12 - 0s - loss: 0.5721 - mse: 0.5721 - val_loss: 0.6379 - val_mse: 0.6379 - 114ms/epoch - 9ms/step
# Epoch 129/2500
# 12/12 - 0s - loss: 0.5702 - mse: 0.5702 - val_loss: 0.6293 - val_mse: 0.6293 - 107ms/epoch - 9ms/step
# Epoch 130/2500
# 12/12 - 0s - loss: 0.5682 - mse: 0.5682 - val_loss: 0.6361 - val_mse: 0.6361 - 139ms/epoch - 12ms/step
# Epoch 131/2500
# 12/12 - 0s - loss: 0.5663 - mse: 0.5663 - val_loss: 0.6299 - val_mse: 0.6299 - 152ms/epoch - 13ms/step
# Epoch 132/2500
# 12/12 - 0s - loss: 0.5650 - mse: 0.5650 - val_loss: 0.6295 - val_mse: 0.6295 - 133ms/epoch - 11ms/step
# Epoch 133/2500
# 12/12 - 0s - loss: 0.5624 - mse: 0.5624 - val_loss: 0.6262 - val_mse: 0.6262 - 135ms/epoch - 11ms/step
# Epoch 134/2500
# 12/12 - 0s - loss: 0.5602 - mse: 0.5602 - val_loss: 0.6328 - val_mse: 0.6328 - 158ms/epoch - 13ms/step
# Epoch 135/2500
# 12/12 - 0s - loss: 0.5625 - mse: 0.5625 - val_loss: 0.6283 - val_mse: 0.6283 - 120ms/epoch - 10ms/step
# Epoch 136/2500
# 12/12 - 0s - loss: 0.5587 - mse: 0.5587 - val_loss: 0.6298 - val_mse: 0.6298 - 102ms/epoch - 8ms/step
# Epoch 137/2500
# 12/12 - 0s - loss: 0.5556 - mse: 0.5556 - val_loss: 0.6231 - val_mse: 0.6231 - 97ms/epoch - 8ms/step
# Epoch 138/2500
# 12/12 - 0s - loss: 0.5559 - mse: 0.5559 - val_loss: 0.6201 - val_mse: 0.6201 - 108ms/epoch - 9ms/step
# Epoch 139/2500
# 12/12 - 0s - loss: 0.5521 - mse: 0.5521 - val_loss: 0.6184 - val_mse: 0.6184 - 109ms/epoch - 9ms/step
# Epoch 140/2500
# 12/12 - 0s - loss: 0.5527 - mse: 0.5527 - val_loss: 0.6192 - val_mse: 0.6192 - 184ms/epoch - 15ms/step
# Epoch 141/2500
# 12/12 - 0s - loss: 0.5525 - mse: 0.5525 - val_loss: 0.6201 - val_mse: 0.6201 - 284ms/epoch - 24ms/step
# Epoch 142/2500
# 12/12 - 0s - loss: 0.5529 - mse: 0.5529 - val_loss: 0.6208 - val_mse: 0.6208 - 143ms/epoch - 12ms/step
# Epoch 143/2500
# 12/12 - 0s - loss: 0.5483 - mse: 0.5483 - val_loss: 0.6132 - val_mse: 0.6132 - 144ms/epoch - 12ms/step
# Epoch 144/2500
# 12/12 - 0s - loss: 0.5492 - mse: 0.5492 - val_loss: 0.6097 - val_mse: 0.6097 - 127ms/epoch - 11ms/step
# Epoch 145/2500
# 12/12 - 0s - loss: 0.5426 - mse: 0.5426 - val_loss: 0.6190 - val_mse: 0.6190 - 128ms/epoch - 11ms/step
# Epoch 146/2500
# 12/12 - 0s - loss: 0.5420 - mse: 0.5420 - val_loss: 0.6166 - val_mse: 0.6166 - 120ms/epoch - 10ms/step
# Epoch 147/2500
# 12/12 - 0s - loss: 0.5393 - mse: 0.5393 - val_loss: 0.6105 - val_mse: 0.6105 - 97ms/epoch - 8ms/step
# Epoch 148/2500
# 12/12 - 0s - loss: 0.5380 - mse: 0.5380 - val_loss: 0.6101 - val_mse: 0.6101 - 109ms/epoch - 9ms/step
# Epoch 149/2500
# 12/12 - 0s - loss: 0.5356 - mse: 0.5356 - val_loss: 0.6050 - val_mse: 0.6050 - 138ms/epoch - 11ms/step
# Epoch 150/2500
# 12/12 - 0s - loss: 0.5354 - mse: 0.5354 - val_loss: 0.6033 - val_mse: 0.6033 - 122ms/epoch - 10ms/step
# Epoch 151/2500
# 12/12 - 0s - loss: 0.5330 - mse: 0.5330 - val_loss: 0.6072 - val_mse: 0.6072 - 114ms/epoch - 9ms/step
# Epoch 152/2500
# 12/12 - 0s - loss: 0.5355 - mse: 0.5355 - val_loss: 0.6005 - val_mse: 0.6005 - 104ms/epoch - 9ms/step
# Epoch 153/2500
# 12/12 - 0s - loss: 0.5319 - mse: 0.5319 - val_loss: 0.6069 - val_mse: 0.6069 - 87ms/epoch - 7ms/step
# Epoch 154/2500
# 12/12 - 0s - loss: 0.5291 - mse: 0.5291 - val_loss: 0.5972 - val_mse: 0.5972 - 96ms/epoch - 8ms/step
# Epoch 155/2500
# 12/12 - 0s - loss: 0.5275 - mse: 0.5275 - val_loss: 0.6017 - val_mse: 0.6017 - 92ms/epoch - 8ms/step
# Epoch 156/2500
# 12/12 - 0s - loss: 0.5261 - mse: 0.5261 - val_loss: 0.5994 - val_mse: 0.5994 - 91ms/epoch - 8ms/step
# Epoch 157/2500
# 12/12 - 0s - loss: 0.5239 - mse: 0.5239 - val_loss: 0.6033 - val_mse: 0.6033 - 74ms/epoch - 6ms/step
# Epoch 158/2500
# 12/12 - 0s - loss: 0.5231 - mse: 0.5231 - val_loss: 0.5953 - val_mse: 0.5953 - 74ms/epoch - 6ms/step
# Epoch 159/2500
# 12/12 - 0s - loss: 0.5220 - mse: 0.5220 - val_loss: 0.5933 - val_mse: 0.5933 - 74ms/epoch - 6ms/step
# Epoch 160/2500
# 12/12 - 0s - loss: 0.5205 - mse: 0.5205 - val_loss: 0.5916 - val_mse: 0.5916 - 74ms/epoch - 6ms/step
# Epoch 161/2500
# 12/12 - 0s - loss: 0.5175 - mse: 0.5175 - val_loss: 0.5969 - val_mse: 0.5969 - 71ms/epoch - 6ms/step
# Epoch 162/2500
# 12/12 - 0s - loss: 0.5177 - mse: 0.5177 - val_loss: 0.5966 - val_mse: 0.5966 - 85ms/epoch - 7ms/step
# Epoch 163/2500
# 12/12 - 0s - loss: 0.5141 - mse: 0.5141 - val_loss: 0.5906 - val_mse: 0.5906 - 69ms/epoch - 6ms/step
# Epoch 164/2500
# 12/12 - 0s - loss: 0.5140 - mse: 0.5140 - val_loss: 0.5885 - val_mse: 0.5885 - 85ms/epoch - 7ms/step
# Epoch 165/2500
# 12/12 - 0s - loss: 0.5152 - mse: 0.5152 - val_loss: 0.5896 - val_mse: 0.5896 - 87ms/epoch - 7ms/step
# Epoch 166/2500
# 12/12 - 0s - loss: 0.5143 - mse: 0.5143 - val_loss: 0.5900 - val_mse: 0.5900 - 78ms/epoch - 6ms/step
# Epoch 167/2500
# 12/12 - 0s - loss: 0.5138 - mse: 0.5138 - val_loss: 0.5932 - val_mse: 0.5932 - 93ms/epoch - 8ms/step
# Epoch 168/2500
# 12/12 - 0s - loss: 0.5107 - mse: 0.5107 - val_loss: 0.5925 - val_mse: 0.5925 - 83ms/epoch - 7ms/step
# Epoch 169/2500
# 12/12 - 0s - loss: 0.5085 - mse: 0.5085 - val_loss: 0.5804 - val_mse: 0.5804 - 88ms/epoch - 7ms/step
# Epoch 170/2500
# 12/12 - 0s - loss: 0.5076 - mse: 0.5076 - val_loss: 0.5786 - val_mse: 0.5786 - 104ms/epoch - 9ms/step
# Epoch 171/2500
# 12/12 - 0s - loss: 0.5046 - mse: 0.5046 - val_loss: 0.5798 - val_mse: 0.5798 - 133ms/epoch - 11ms/step
# Epoch 172/2500
# 12/12 - 0s - loss: 0.5050 - mse: 0.5050 - val_loss: 0.5885 - val_mse: 0.5885 - 96ms/epoch - 8ms/step
# Epoch 173/2500
# 12/12 - 0s - loss: 0.5015 - mse: 0.5015 - val_loss: 0.5776 - val_mse: 0.5776 - 107ms/epoch - 9ms/step
# Epoch 174/2500
# 12/12 - 0s - loss: 0.5003 - mse: 0.5003 - val_loss: 0.5798 - val_mse: 0.5798 - 103ms/epoch - 9ms/step
# Epoch 175/2500
# 12/12 - 0s - loss: 0.4990 - mse: 0.4990 - val_loss: 0.5722 - val_mse: 0.5722 - 90ms/epoch - 7ms/step
# Epoch 176/2500
# 12/12 - 0s - loss: 0.4971 - mse: 0.4971 - val_loss: 0.5772 - val_mse: 0.5772 - 87ms/epoch - 7ms/step
# Epoch 177/2500
# 12/12 - 0s - loss: 0.4958 - mse: 0.4958 - val_loss: 0.5733 - val_mse: 0.5733 - 87ms/epoch - 7ms/step
# Epoch 178/2500
# 12/12 - 0s - loss: 0.4934 - mse: 0.4934 - val_loss: 0.5728 - val_mse: 0.5728 - 85ms/epoch - 7ms/step
# Epoch 179/2500
# 12/12 - 0s - loss: 0.4920 - mse: 0.4920 - val_loss: 0.5780 - val_mse: 0.5780 - 77ms/epoch - 6ms/step
# Epoch 180/2500
# 12/12 - 0s - loss: 0.4908 - mse: 0.4908 - val_loss: 0.5739 - val_mse: 0.5739 - 95ms/epoch - 8ms/step
# Epoch 181/2500
# 12/12 - 0s - loss: 0.4884 - mse: 0.4884 - val_loss: 0.5716 - val_mse: 0.5716 - 95ms/epoch - 8ms/step
# Epoch 182/2500
# 12/12 - 0s - loss: 0.4875 - mse: 0.4875 - val_loss: 0.5694 - val_mse: 0.5694 - 75ms/epoch - 6ms/step
# Epoch 183/2500
# 12/12 - 0s - loss: 0.4886 - mse: 0.4886 - val_loss: 0.5709 - val_mse: 0.5709 - 86ms/epoch - 7ms/step
# Epoch 184/2500
# 12/12 - 0s - loss: 0.4873 - mse: 0.4873 - val_loss: 0.5624 - val_mse: 0.5624 - 77ms/epoch - 6ms/step
# Epoch 185/2500
# 12/12 - 0s - loss: 0.4829 - mse: 0.4829 - val_loss: 0.5650 - val_mse: 0.5650 - 85ms/epoch - 7ms/step
# Epoch 186/2500
# 12/12 - 0s - loss: 0.4808 - mse: 0.4808 - val_loss: 0.5697 - val_mse: 0.5697 - 92ms/epoch - 8ms/step
# Epoch 187/2500
# 12/12 - 0s - loss: 0.4822 - mse: 0.4822 - val_loss: 0.5688 - val_mse: 0.5688 - 84ms/epoch - 7ms/step
# Epoch 188/2500
# 12/12 - 0s - loss: 0.4796 - mse: 0.4796 - val_loss: 0.5620 - val_mse: 0.5620 - 108ms/epoch - 9ms/step
# Epoch 189/2500
# 12/12 - 0s - loss: 0.4803 - mse: 0.4803 - val_loss: 0.5623 - val_mse: 0.5623 - 92ms/epoch - 8ms/step
# Epoch 190/2500
# 12/12 - 0s - loss: 0.4820 - mse: 0.4820 - val_loss: 0.5704 - val_mse: 0.5704 - 90ms/epoch - 7ms/step
# Epoch 191/2500
# 12/12 - 0s - loss: 0.4778 - mse: 0.4778 - val_loss: 0.5605 - val_mse: 0.5605 - 93ms/epoch - 8ms/step
# Epoch 192/2500
# 12/12 - 0s - loss: 0.4734 - mse: 0.4734 - val_loss: 0.5585 - val_mse: 0.5585 - 97ms/epoch - 8ms/step
# Epoch 193/2500
# 12/12 - 0s - loss: 0.4728 - mse: 0.4728 - val_loss: 0.5606 - val_mse: 0.5606 - 93ms/epoch - 8ms/step
# Epoch 194/2500
# 12/12 - 0s - loss: 0.4695 - mse: 0.4695 - val_loss: 0.5562 - val_mse: 0.5562 - 254ms/epoch - 21ms/step
# Epoch 195/2500
# 12/12 - 0s - loss: 0.4697 - mse: 0.4697 - val_loss: 0.5549 - val_mse: 0.5549 - 114ms/epoch - 9ms/step
# Epoch 196/2500
# 12/12 - 0s - loss: 0.4676 - mse: 0.4676 - val_loss: 0.5552 - val_mse: 0.5552 - 97ms/epoch - 8ms/step
# Epoch 197/2500
# 12/12 - 0s - loss: 0.4668 - mse: 0.4668 - val_loss: 0.5529 - val_mse: 0.5529 - 171ms/epoch - 14ms/step
# Epoch 198/2500
# 12/12 - 0s - loss: 0.4645 - mse: 0.4645 - val_loss: 0.5524 - val_mse: 0.5524 - 158ms/epoch - 13ms/step
# Epoch 199/2500
# 12/12 - 0s - loss: 0.4634 - mse: 0.4634 - val_loss: 0.5475 - val_mse: 0.5475 - 282ms/epoch - 24ms/step
# Epoch 200/2500
# 12/12 - 0s - loss: 0.4620 - mse: 0.4620 - val_loss: 0.5518 - val_mse: 0.5518 - 147ms/epoch - 12ms/step
# Epoch 201/2500
# 12/12 - 0s - loss: 0.4618 - mse: 0.4618 - val_loss: 0.5507 - val_mse: 0.5507 - 132ms/epoch - 11ms/step
# Epoch 202/2500
# 12/12 - 0s - loss: 0.4600 - mse: 0.4600 - val_loss: 0.5531 - val_mse: 0.5531 - 150ms/epoch - 12ms/step
# Epoch 203/2500
# 12/12 - 0s - loss: 0.4612 - mse: 0.4612 - val_loss: 0.5475 - val_mse: 0.5475 - 207ms/epoch - 17ms/step
# Epoch 204/2500
# 12/12 - 0s - loss: 0.4584 - mse: 0.4584 - val_loss: 0.5469 - val_mse: 0.5469 - 206ms/epoch - 17ms/step
# Epoch 205/2500
# 12/12 - 0s - loss: 0.4551 - mse: 0.4551 - val_loss: 0.5455 - val_mse: 0.5455 - 150ms/epoch - 12ms/step
# Epoch 206/2500
# 12/12 - 0s - loss: 0.4550 - mse: 0.4550 - val_loss: 0.5406 - val_mse: 0.5406 - 146ms/epoch - 12ms/step
# Epoch 207/2500
# 12/12 - 0s - loss: 0.4533 - mse: 0.4533 - val_loss: 0.5462 - val_mse: 0.5462 - 202ms/epoch - 17ms/step
# Epoch 208/2500
# 12/12 - 0s - loss: 0.4524 - mse: 0.4524 - val_loss: 0.5472 - val_mse: 0.5472 - 357ms/epoch - 30ms/step
# Epoch 209/2500
# 12/12 - 0s - loss: 0.4516 - mse: 0.4516 - val_loss: 0.5354 - val_mse: 0.5354 - 208ms/epoch - 17ms/step
# Epoch 210/2500
# 12/12 - 0s - loss: 0.4521 - mse: 0.4521 - val_loss: 0.5366 - val_mse: 0.5366 - 193ms/epoch - 16ms/step
# Epoch 211/2500
# 12/12 - 0s - loss: 0.4490 - mse: 0.4490 - val_loss: 0.5388 - val_mse: 0.5388 - 192ms/epoch - 16ms/step
# Epoch 212/2500
# 12/12 - 0s - loss: 0.4524 - mse: 0.4524 - val_loss: 0.5348 - val_mse: 0.5348 - 154ms/epoch - 13ms/step
# Epoch 213/2500
# 12/12 - 0s - loss: 0.4507 - mse: 0.4507 - val_loss: 0.5343 - val_mse: 0.5343 - 137ms/epoch - 11ms/step
# Epoch 214/2500
# 12/12 - 0s - loss: 0.4439 - mse: 0.4439 - val_loss: 0.5323 - val_mse: 0.5323 - 164ms/epoch - 14ms/step
# Epoch 215/2500
# 12/12 - 0s - loss: 0.4445 - mse: 0.4445 - val_loss: 0.5378 - val_mse: 0.5378 - 134ms/epoch - 11ms/step
# Epoch 216/2500
# 12/12 - 0s - loss: 0.4441 - mse: 0.4441 - val_loss: 0.5355 - val_mse: 0.5355 - 137ms/epoch - 11ms/step
# Epoch 217/2500
# 12/12 - 0s - loss: 0.4435 - mse: 0.4435 - val_loss: 0.5415 - val_mse: 0.5415 - 119ms/epoch - 10ms/step
# Epoch 218/2500
# 12/12 - 0s - loss: 0.4394 - mse: 0.4394 - val_loss: 0.5286 - val_mse: 0.5286 - 99ms/epoch - 8ms/step
# Epoch 219/2500
# 12/12 - 0s - loss: 0.4392 - mse: 0.4392 - val_loss: 0.5310 - val_mse: 0.5310 - 94ms/epoch - 8ms/step
# Epoch 220/2500
# 12/12 - 0s - loss: 0.4376 - mse: 0.4376 - val_loss: 0.5324 - val_mse: 0.5324 - 106ms/epoch - 9ms/step
# Epoch 221/2500
# 12/12 - 0s - loss: 0.4348 - mse: 0.4348 - val_loss: 0.5256 - val_mse: 0.5256 - 138ms/epoch - 11ms/step
# Epoch 222/2500
# 12/12 - 0s - loss: 0.4371 - mse: 0.4371 - val_loss: 0.5319 - val_mse: 0.5319 - 170ms/epoch - 14ms/step
# Epoch 223/2500
# 12/12 - 0s - loss: 0.4366 - mse: 0.4366 - val_loss: 0.5256 - val_mse: 0.5256 - 158ms/epoch - 13ms/step
# Epoch 224/2500
# 12/12 - 0s - loss: 0.4316 - mse: 0.4316 - val_loss: 0.5292 - val_mse: 0.5292 - 147ms/epoch - 12ms/step
# Epoch 225/2500
# 12/12 - 0s - loss: 0.4313 - mse: 0.4313 - val_loss: 0.5259 - val_mse: 0.5259 - 145ms/epoch - 12ms/step
# Epoch 226/2500
# 12/12 - 0s - loss: 0.4304 - mse: 0.4304 - val_loss: 0.5248 - val_mse: 0.5248 - 133ms/epoch - 11ms/step
# Epoch 227/2500
# 12/12 - 0s - loss: 0.4281 - mse: 0.4281 - val_loss: 0.5260 - val_mse: 0.5260 - 147ms/epoch - 12ms/step
# Epoch 228/2500
# 12/12 - 0s - loss: 0.4301 - mse: 0.4301 - val_loss: 0.5266 - val_mse: 0.5266 - 140ms/epoch - 12ms/step
# Epoch 229/2500
# 12/12 - 0s - loss: 0.4309 - mse: 0.4309 - val_loss: 0.5259 - val_mse: 0.5259 - 129ms/epoch - 11ms/step
# Epoch 230/2500
# 12/12 - 0s - loss: 0.4248 - mse: 0.4248 - val_loss: 0.5226 - val_mse: 0.5226 - 137ms/epoch - 11ms/step
# Epoch 231/2500
# 12/12 - 0s - loss: 0.4240 - mse: 0.4240 - val_loss: 0.5271 - val_mse: 0.5271 - 157ms/epoch - 13ms/step
# Epoch 232/2500
# 12/12 - 0s - loss: 0.4231 - mse: 0.4231 - val_loss: 0.5267 - val_mse: 0.5267 - 135ms/epoch - 11ms/step
# Epoch 233/2500
# 12/12 - 0s - loss: 0.4209 - mse: 0.4209 - val_loss: 0.5227 - val_mse: 0.5227 - 119ms/epoch - 10ms/step
# Epoch 234/2500
# 12/12 - 0s - loss: 0.4231 - mse: 0.4231 - val_loss: 0.5228 - val_mse: 0.5228 - 113ms/epoch - 9ms/step
# Epoch 235/2500
# 12/12 - 0s - loss: 0.4240 - mse: 0.4240 - val_loss: 0.5276 - val_mse: 0.5276 - 125ms/epoch - 10ms/step
# Epoch 236/2500
# 12/12 - 0s - loss: 0.4203 - mse: 0.4203 - val_loss: 0.5183 - val_mse: 0.5183 - 120ms/epoch - 10ms/step
# Epoch 237/2500
# 12/12 - 0s - loss: 0.4191 - mse: 0.4191 - val_loss: 0.5177 - val_mse: 0.5177 - 113ms/epoch - 9ms/step
# Epoch 238/2500
# 12/12 - 0s - loss: 0.4180 - mse: 0.4180 - val_loss: 0.5219 - val_mse: 0.5219 - 126ms/epoch - 10ms/step
# Epoch 239/2500
# 12/12 - 0s - loss: 0.4147 - mse: 0.4147 - val_loss: 0.5194 - val_mse: 0.5194 - 119ms/epoch - 10ms/step
# Epoch 240/2500
# 12/12 - 0s - loss: 0.4161 - mse: 0.4161 - val_loss: 0.5184 - val_mse: 0.5184 - 110ms/epoch - 9ms/step
# Epoch 241/2500
# 12/12 - 0s - loss: 0.4137 - mse: 0.4137 - val_loss: 0.5213 - val_mse: 0.5213 - 108ms/epoch - 9ms/step
# Epoch 242/2500
# 12/12 - 0s - loss: 0.4136 - mse: 0.4136 - val_loss: 0.5203 - val_mse: 0.5203 - 116ms/epoch - 10ms/step
# Epoch 243/2500
# 12/12 - 0s - loss: 0.4121 - mse: 0.4121 - val_loss: 0.5096 - val_mse: 0.5096 - 140ms/epoch - 12ms/step
# Epoch 244/2500
# 12/12 - 0s - loss: 0.4102 - mse: 0.4102 - val_loss: 0.5194 - val_mse: 0.5194 - 126ms/epoch - 10ms/step
# Epoch 245/2500
# 12/12 - 0s - loss: 0.4080 - mse: 0.4080 - val_loss: 0.5140 - val_mse: 0.5140 - 183ms/epoch - 15ms/step
# Epoch 246/2500
# 12/12 - 0s - loss: 0.4089 - mse: 0.4089 - val_loss: 0.5127 - val_mse: 0.5127 - 130ms/epoch - 11ms/step
# Epoch 247/2500
# 12/12 - 0s - loss: 0.4079 - mse: 0.4079 - val_loss: 0.5118 - val_mse: 0.5118 - 114ms/epoch - 9ms/step
# Epoch 248/2500
# 12/12 - 0s - loss: 0.4062 - mse: 0.4062 - val_loss: 0.5164 - val_mse: 0.5164 - 114ms/epoch - 9ms/step
# Epoch 249/2500
# 12/12 - 0s - loss: 0.4046 - mse: 0.4046 - val_loss: 0.5143 - val_mse: 0.5143 - 119ms/epoch - 10ms/step
# Epoch 250/2500
# 12/12 - 0s - loss: 0.4037 - mse: 0.4037 - val_loss: 0.5062 - val_mse: 0.5062 - 115ms/epoch - 10ms/step
# Epoch 251/2500
# 12/12 - 0s - loss: 0.4049 - mse: 0.4049 - val_loss: 0.5109 - val_mse: 0.5109 - 117ms/epoch - 10ms/step
# Epoch 252/2500
# 12/12 - 0s - loss: 0.4026 - mse: 0.4026 - val_loss: 0.5074 - val_mse: 0.5074 - 115ms/epoch - 10ms/step
# Epoch 253/2500
# 12/12 - 0s - loss: 0.4037 - mse: 0.4037 - val_loss: 0.5129 - val_mse: 0.5129 - 112ms/epoch - 9ms/step
# Epoch 254/2500
# 12/12 - 0s - loss: 0.4025 - mse: 0.4025 - val_loss: 0.5042 - val_mse: 0.5042 - 116ms/epoch - 10ms/step
# Epoch 255/2500
# 12/12 - 0s - loss: 0.4019 - mse: 0.4019 - val_loss: 0.5028 - val_mse: 0.5028 - 122ms/epoch - 10ms/step
# Epoch 256/2500
# 12/12 - 0s - loss: 0.4022 - mse: 0.4022 - val_loss: 0.5109 - val_mse: 0.5109 - 118ms/epoch - 10ms/step
# Epoch 257/2500
# 12/12 - 0s - loss: 0.4014 - mse: 0.4014 - val_loss: 0.5044 - val_mse: 0.5044 - 120ms/epoch - 10ms/step
# Epoch 258/2500
# 12/12 - 0s - loss: 0.4003 - mse: 0.4003 - val_loss: 0.5183 - val_mse: 0.5183 - 139ms/epoch - 12ms/step
# Epoch 259/2500
# 12/12 - 0s - loss: 0.3948 - mse: 0.3948 - val_loss: 0.5022 - val_mse: 0.5022 - 115ms/epoch - 10ms/step
# Epoch 260/2500
# 12/12 - 0s - loss: 0.3964 - mse: 0.3964 - val_loss: 0.5082 - val_mse: 0.5082 - 110ms/epoch - 9ms/step
# Epoch 261/2500
# 12/12 - 0s - loss: 0.3950 - mse: 0.3950 - val_loss: 0.5019 - val_mse: 0.5019 - 108ms/epoch - 9ms/step
# Epoch 262/2500
# 12/12 - 0s - loss: 0.3970 - mse: 0.3970 - val_loss: 0.5059 - val_mse: 0.5059 - 116ms/epoch - 10ms/step
# Epoch 263/2500
# 12/12 - 0s - loss: 0.3927 - mse: 0.3927 - val_loss: 0.4989 - val_mse: 0.4989 - 127ms/epoch - 11ms/step
# Epoch 264/2500
# 12/12 - 0s - loss: 0.3910 - mse: 0.3910 - val_loss: 0.4990 - val_mse: 0.4990 - 116ms/epoch - 10ms/step
# Epoch 265/2500
# 12/12 - 0s - loss: 0.3899 - mse: 0.3899 - val_loss: 0.5061 - val_mse: 0.5061 - 113ms/epoch - 9ms/step
# Epoch 266/2500
# 12/12 - 0s - loss: 0.3934 - mse: 0.3934 - val_loss: 0.5025 - val_mse: 0.5025 - 113ms/epoch - 9ms/step
# Epoch 267/2500
# 12/12 - 0s - loss: 0.3942 - mse: 0.3942 - val_loss: 0.5027 - val_mse: 0.5027 - 153ms/epoch - 13ms/step
# Epoch 268/2500
# 12/12 - 0s - loss: 0.3895 - mse: 0.3895 - val_loss: 0.5066 - val_mse: 0.5066 - 186ms/epoch - 15ms/step
# Epoch 269/2500
# 12/12 - 0s - loss: 0.3869 - mse: 0.3869 - val_loss: 0.4970 - val_mse: 0.4970 - 342ms/epoch - 29ms/step
# Epoch 270/2500
# 12/12 - 0s - loss: 0.3853 - mse: 0.3853 - val_loss: 0.4983 - val_mse: 0.4983 - 293ms/epoch - 24ms/step
# Epoch 271/2500
# 12/12 - 0s - loss: 0.3852 - mse: 0.3852 - val_loss: 0.4974 - val_mse: 0.4974 - 204ms/epoch - 17ms/step
# Epoch 272/2500
# 12/12 - 0s - loss: 0.3862 - mse: 0.3862 - val_loss: 0.4969 - val_mse: 0.4969 - 132ms/epoch - 11ms/step
# Epoch 273/2500
# 12/12 - 0s - loss: 0.3828 - mse: 0.3828 - val_loss: 0.5026 - val_mse: 0.5026 - 233ms/epoch - 19ms/step
# Epoch 274/2500
# 12/12 - 0s - loss: 0.3875 - mse: 0.3875 - val_loss: 0.5080 - val_mse: 0.5080 - 147ms/epoch - 12ms/step
# Epoch 275/2500
# 12/12 - 0s - loss: 0.3830 - mse: 0.3830 - val_loss: 0.4924 - val_mse: 0.4924 - 122ms/epoch - 10ms/step
# Epoch 276/2500
# 12/12 - 0s - loss: 0.3836 - mse: 0.3836 - val_loss: 0.4945 - val_mse: 0.4945 - 117ms/epoch - 10ms/step
# Epoch 277/2500
# 12/12 - 0s - loss: 0.3802 - mse: 0.3802 - val_loss: 0.5017 - val_mse: 0.5017 - 129ms/epoch - 11ms/step
# Epoch 278/2500
# 12/12 - 0s - loss: 0.3790 - mse: 0.3790 - val_loss: 0.4964 - val_mse: 0.4964 - 117ms/epoch - 10ms/step
# Epoch 279/2500
# 12/12 - 0s - loss: 0.3792 - mse: 0.3792 - val_loss: 0.4889 - val_mse: 0.4889 - 126ms/epoch - 10ms/step
# Epoch 280/2500
# 12/12 - 0s - loss: 0.3760 - mse: 0.3760 - val_loss: 0.5012 - val_mse: 0.5012 - 126ms/epoch - 10ms/step
# Epoch 281/2500
# 12/12 - 0s - loss: 0.3828 - mse: 0.3828 - val_loss: 0.4954 - val_mse: 0.4954 - 125ms/epoch - 10ms/step
# Epoch 282/2500
# 12/12 - 0s - loss: 0.3774 - mse: 0.3774 - val_loss: 0.4947 - val_mse: 0.4947 - 158ms/epoch - 13ms/step
# Epoch 283/2500
# 12/12 - 0s - loss: 0.3780 - mse: 0.3780 - val_loss: 0.4917 - val_mse: 0.4917 - 140ms/epoch - 12ms/step
# Epoch 284/2500
# 12/12 - 0s - loss: 0.3749 - mse: 0.3749 - val_loss: 0.4939 - val_mse: 0.4939 - 298ms/epoch - 25ms/step
# Epoch 285/2500
# 12/12 - 0s - loss: 0.3785 - mse: 0.3785 - val_loss: 0.4932 - val_mse: 0.4932 - 158ms/epoch - 13ms/step
# Epoch 286/2500
# 12/12 - 0s - loss: 0.3811 - mse: 0.3811 - val_loss: 0.4971 - val_mse: 0.4971 - 110ms/epoch - 9ms/step
# Epoch 287/2500
# 12/12 - 0s - loss: 0.3773 - mse: 0.3773 - val_loss: 0.4968 - val_mse: 0.4968 - 111ms/epoch - 9ms/step
# Epoch 288/2500
# 12/12 - 0s - loss: 0.3766 - mse: 0.3766 - val_loss: 0.4838 - val_mse: 0.4838 - 111ms/epoch - 9ms/step
# Epoch 289/2500
# 12/12 - 0s - loss: 0.3721 - mse: 0.3721 - val_loss: 0.4917 - val_mse: 0.4917 - 121ms/epoch - 10ms/step
# Epoch 290/2500
# 12/12 - 0s - loss: 0.3716 - mse: 0.3716 - val_loss: 0.4938 - val_mse: 0.4938 - 117ms/epoch - 10ms/step
# Epoch 291/2500
# 12/12 - 0s - loss: 0.3696 - mse: 0.3696 - val_loss: 0.4866 - val_mse: 0.4866 - 112ms/epoch - 9ms/step
# Epoch 292/2500
# 12/12 - 0s - loss: 0.3685 - mse: 0.3685 - val_loss: 0.4871 - val_mse: 0.4871 - 110ms/epoch - 9ms/step
# Epoch 293/2500
# 12/12 - 0s - loss: 0.3720 - mse: 0.3720 - val_loss: 0.4860 - val_mse: 0.4860 - 120ms/epoch - 10ms/step
# Epoch 294/2500
# 12/12 - 0s - loss: 0.3701 - mse: 0.3701 - val_loss: 0.4871 - val_mse: 0.4871 - 133ms/epoch - 11ms/step
# Epoch 295/2500
# 12/12 - 0s - loss: 0.3661 - mse: 0.3661 - val_loss: 0.4951 - val_mse: 0.4951 - 131ms/epoch - 11ms/step
# Epoch 296/2500
# 12/12 - 0s - loss: 0.3666 - mse: 0.3666 - val_loss: 0.4848 - val_mse: 0.4848 - 116ms/epoch - 10ms/step
# Epoch 297/2500
# 12/12 - 0s - loss: 0.3654 - mse: 0.3654 - val_loss: 0.4822 - val_mse: 0.4822 - 116ms/epoch - 10ms/step
# Epoch 298/2500
# 12/12 - 0s - loss: 0.3644 - mse: 0.3644 - val_loss: 0.4853 - val_mse: 0.4853 - 110ms/epoch - 9ms/step
# Epoch 299/2500
# 12/12 - 0s - loss: 0.3655 - mse: 0.3655 - val_loss: 0.4840 - val_mse: 0.4840 - 139ms/epoch - 12ms/step
# Epoch 300/2500
# 12/12 - 0s - loss: 0.3644 - mse: 0.3644 - val_loss: 0.4828 - val_mse: 0.4828 - 202ms/epoch - 17ms/step
# Epoch 301/2500
# 12/12 - 0s - loss: 0.3607 - mse: 0.3607 - val_loss: 0.4862 - val_mse: 0.4862 - 154ms/epoch - 13ms/step
# Epoch 302/2500
# 12/12 - 0s - loss: 0.3609 - mse: 0.3609 - val_loss: 0.4831 - val_mse: 0.4831 - 99ms/epoch - 8ms/step
# Epoch 303/2500
# 12/12 - 0s - loss: 0.3601 - mse: 0.3601 - val_loss: 0.4817 - val_mse: 0.4817 - 85ms/epoch - 7ms/step
# Epoch 304/2500
# 12/12 - 0s - loss: 0.3603 - mse: 0.3603 - val_loss: 0.4871 - val_mse: 0.4871 - 77ms/epoch - 6ms/step
# Epoch 305/2500
# 12/12 - 0s - loss: 0.3618 - mse: 0.3618 - val_loss: 0.4803 - val_mse: 0.4803 - 70ms/epoch - 6ms/step
# Epoch 306/2500
# 12/12 - 0s - loss: 0.3570 - mse: 0.3570 - val_loss: 0.4818 - val_mse: 0.4818 - 74ms/epoch - 6ms/step
# Epoch 307/2500
# 12/12 - 0s - loss: 0.3612 - mse: 0.3612 - val_loss: 0.4791 - val_mse: 0.4791 - 62ms/epoch - 5ms/step
# Epoch 308/2500
# 12/12 - 0s - loss: 0.3580 - mse: 0.3580 - val_loss: 0.4785 - val_mse: 0.4785 - 59ms/epoch - 5ms/step
# Epoch 309/2500
# 12/12 - 0s - loss: 0.3596 - mse: 0.3596 - val_loss: 0.4850 - val_mse: 0.4850 - 55ms/epoch - 5ms/step
# Epoch 310/2500
# 12/12 - 0s - loss: 0.3611 - mse: 0.3611 - val_loss: 0.4854 - val_mse: 0.4854 - 60ms/epoch - 5ms/step
# Epoch 311/2500
# 12/12 - 0s - loss: 0.3590 - mse: 0.3590 - val_loss: 0.4761 - val_mse: 0.4761 - 58ms/epoch - 5ms/step
# Epoch 312/2500
# 12/12 - 0s - loss: 0.3559 - mse: 0.3559 - val_loss: 0.4823 - val_mse: 0.4823 - 61ms/epoch - 5ms/step
# Epoch 313/2500
# 12/12 - 0s - loss: 0.3563 - mse: 0.3563 - val_loss: 0.4751 - val_mse: 0.4751 - 74ms/epoch - 6ms/step
# Epoch 314/2500
# 12/12 - 0s - loss: 0.3593 - mse: 0.3593 - val_loss: 0.4751 - val_mse: 0.4751 - 77ms/epoch - 6ms/step
# Epoch 315/2500
# 12/12 - 0s - loss: 0.3549 - mse: 0.3549 - val_loss: 0.4744 - val_mse: 0.4744 - 72ms/epoch - 6ms/step
# Epoch 316/2500
# 12/12 - 0s - loss: 0.3545 - mse: 0.3545 - val_loss: 0.4818 - val_mse: 0.4818 - 68ms/epoch - 6ms/step
# Epoch 317/2500
# 12/12 - 0s - loss: 0.3545 - mse: 0.3545 - val_loss: 0.4710 - val_mse: 0.4710 - 73ms/epoch - 6ms/step
# Epoch 318/2500
# 12/12 - 0s - loss: 0.3513 - mse: 0.3513 - val_loss: 0.4742 - val_mse: 0.4742 - 75ms/epoch - 6ms/step
# Epoch 319/2500
# 12/12 - 0s - loss: 0.3502 - mse: 0.3502 - val_loss: 0.4740 - val_mse: 0.4740 - 63ms/epoch - 5ms/step
# Epoch 320/2500
# 12/12 - 0s - loss: 0.3500 - mse: 0.3500 - val_loss: 0.4750 - val_mse: 0.4750 - 71ms/epoch - 6ms/step
# Epoch 321/2500
# 12/12 - 0s - loss: 0.3488 - mse: 0.3488 - val_loss: 0.4768 - val_mse: 0.4768 - 81ms/epoch - 7ms/step
# Epoch 322/2500
# 12/12 - 0s - loss: 0.3504 - mse: 0.3504 - val_loss: 0.4736 - val_mse: 0.4736 - 88ms/epoch - 7ms/step
# Epoch 323/2500
# 12/12 - 0s - loss: 0.3513 - mse: 0.3513 - val_loss: 0.4762 - val_mse: 0.4762 - 131ms/epoch - 11ms/step
# Epoch 324/2500
# 12/12 - 0s - loss: 0.3483 - mse: 0.3483 - val_loss: 0.4772 - val_mse: 0.4772 - 104ms/epoch - 9ms/step
# Epoch 325/2500
# 12/12 - 0s - loss: 0.3510 - mse: 0.3510 - val_loss: 0.4759 - val_mse: 0.4759 - 72ms/epoch - 6ms/step
# Epoch 326/2500
# 12/12 - 0s - loss: 0.3527 - mse: 0.3527 - val_loss: 0.4759 - val_mse: 0.4759 - 84ms/epoch - 7ms/step
# Epoch 327/2500
# 12/12 - 0s - loss: 0.3473 - mse: 0.3473 - val_loss: 0.4883 - val_mse: 0.4883 - 273ms/epoch - 23ms/step
# Epoch 328/2500
# 12/12 - 0s - loss: 0.3527 - mse: 0.3527 - val_loss: 0.4666 - val_mse: 0.4666 - 90ms/epoch - 7ms/step
# Epoch 329/2500
# 12/12 - 0s - loss: 0.3457 - mse: 0.3457 - val_loss: 0.4708 - val_mse: 0.4708 - 70ms/epoch - 6ms/step
# Epoch 330/2500
# 12/12 - 0s - loss: 0.3444 - mse: 0.3444 - val_loss: 0.4682 - val_mse: 0.4682 - 77ms/epoch - 6ms/step
# Epoch 331/2500
# 12/12 - 0s - loss: 0.3429 - mse: 0.3429 - val_loss: 0.4554 - val_mse: 0.4554 - 86ms/epoch - 7ms/step
# Epoch 332/2500
# 12/12 - 0s - loss: 0.3439 - mse: 0.3439 - val_loss: 0.4611 - val_mse: 0.4611 - 75ms/epoch - 6ms/step
# Epoch 333/2500
# 12/12 - 0s - loss: 0.3409 - mse: 0.3409 - val_loss: 0.4625 - val_mse: 0.4625 - 72ms/epoch - 6ms/step
# Epoch 334/2500
# 12/12 - 0s - loss: 0.3408 - mse: 0.3408 - val_loss: 0.4625 - val_mse: 0.4625 - 81ms/epoch - 7ms/step
# Epoch 335/2500
# 12/12 - 0s - loss: 0.3408 - mse: 0.3408 - val_loss: 0.4647 - val_mse: 0.4647 - 84ms/epoch - 7ms/step
# Epoch 336/2500
# 12/12 - 0s - loss: 0.3439 - mse: 0.3439 - val_loss: 0.4713 - val_mse: 0.4713 - 70ms/epoch - 6ms/step
# Epoch 337/2500
# 12/12 - 0s - loss: 0.3402 - mse: 0.3402 - val_loss: 0.4619 - val_mse: 0.4619 - 86ms/epoch - 7ms/step
# Epoch 338/2500
# 12/12 - 0s - loss: 0.3378 - mse: 0.3378 - val_loss: 0.4590 - val_mse: 0.4590 - 69ms/epoch - 6ms/step
# Epoch 339/2500
# 12/12 - 0s - loss: 0.3395 - mse: 0.3395 - val_loss: 0.4565 - val_mse: 0.4565 - 62ms/epoch - 5ms/step
# Epoch 340/2500
# 12/12 - 0s - loss: 0.3369 - mse: 0.3369 - val_loss: 0.4610 - val_mse: 0.4610 - 63ms/epoch - 5ms/step
# Epoch 341/2500
# 12/12 - 0s - loss: 0.3361 - mse: 0.3361 - val_loss: 0.4608 - val_mse: 0.4608 - 67ms/epoch - 6ms/step
# Epoch 342/2500
# 12/12 - 0s - loss: 0.3385 - mse: 0.3385 - val_loss: 0.4598 - val_mse: 0.4598 - 60ms/epoch - 5ms/step
# Epoch 343/2500
# 12/12 - 0s - loss: 0.3376 - mse: 0.3376 - val_loss: 0.4584 - val_mse: 0.4584 - 69ms/epoch - 6ms/step
# Epoch 344/2500
# 12/12 - 0s - loss: 0.3369 - mse: 0.3369 - val_loss: 0.4614 - val_mse: 0.4614 - 59ms/epoch - 5ms/step
# Epoch 345/2500
# 12/12 - 0s - loss: 0.3356 - mse: 0.3356 - val_loss: 0.4554 - val_mse: 0.4554 - 61ms/epoch - 5ms/step
# Epoch 346/2500
# 12/12 - 0s - loss: 0.3336 - mse: 0.3336 - val_loss: 0.4593 - val_mse: 0.4593 - 68ms/epoch - 6ms/step
# Epoch 347/2500
# 12/12 - 0s - loss: 0.3318 - mse: 0.3318 - val_loss: 0.4571 - val_mse: 0.4571 - 59ms/epoch - 5ms/step
# Epoch 348/2500
# 12/12 - 0s - loss: 0.3312 - mse: 0.3312 - val_loss: 0.4519 - val_mse: 0.4519 - 85ms/epoch - 7ms/step
# Epoch 349/2500
# 12/12 - 0s - loss: 0.3311 - mse: 0.3311 - val_loss: 0.4557 - val_mse: 0.4557 - 99ms/epoch - 8ms/step
# Epoch 350/2500
# 12/12 - 0s - loss: 0.3328 - mse: 0.3328 - val_loss: 0.4481 - val_mse: 0.4481 - 75ms/epoch - 6ms/step
# Epoch 351/2500
# 12/12 - 0s - loss: 0.3299 - mse: 0.3299 - val_loss: 0.4566 - val_mse: 0.4566 - 60ms/epoch - 5ms/step
# Epoch 352/2500
# 12/12 - 0s - loss: 0.3340 - mse: 0.3340 - val_loss: 0.4523 - val_mse: 0.4523 - 73ms/epoch - 6ms/step
# Epoch 353/2500
# 12/12 - 0s - loss: 0.3354 - mse: 0.3354 - val_loss: 0.4499 - val_mse: 0.4499 - 58ms/epoch - 5ms/step
# Epoch 354/2500
# 12/12 - 0s - loss: 0.3298 - mse: 0.3298 - val_loss: 0.4498 - val_mse: 0.4498 - 72ms/epoch - 6ms/step
# Epoch 355/2500
# 12/12 - 0s - loss: 0.3281 - mse: 0.3281 - val_loss: 0.4438 - val_mse: 0.4438 - 84ms/epoch - 7ms/step
# Epoch 356/2500
# 12/12 - 0s - loss: 0.3272 - mse: 0.3272 - val_loss: 0.4508 - val_mse: 0.4508 - 70ms/epoch - 6ms/step
# Epoch 357/2500
# 12/12 - 0s - loss: 0.3263 - mse: 0.3263 - val_loss: 0.4407 - val_mse: 0.4407 - 77ms/epoch - 6ms/step
# Epoch 358/2500
# 12/12 - 0s - loss: 0.3289 - mse: 0.3289 - val_loss: 0.4434 - val_mse: 0.4434 - 90ms/epoch - 7ms/step
# Epoch 359/2500
# 12/12 - 0s - loss: 0.3255 - mse: 0.3255 - val_loss: 0.4388 - val_mse: 0.4388 - 81ms/epoch - 7ms/step
# Epoch 360/2500
# 12/12 - 0s - loss: 0.3251 - mse: 0.3251 - val_loss: 0.4505 - val_mse: 0.4505 - 78ms/epoch - 6ms/step
# Epoch 361/2500
# 12/12 - 0s - loss: 0.3249 - mse: 0.3249 - val_loss: 0.4446 - val_mse: 0.4446 - 76ms/epoch - 6ms/step
# Epoch 362/2500
# 12/12 - 0s - loss: 0.3262 - mse: 0.3262 - val_loss: 0.4436 - val_mse: 0.4436 - 93ms/epoch - 8ms/step
# Epoch 363/2500
# 12/12 - 0s - loss: 0.3256 - mse: 0.3256 - val_loss: 0.4443 - val_mse: 0.4443 - 105ms/epoch - 9ms/step
# Epoch 364/2500
# 12/12 - 0s - loss: 0.3229 - mse: 0.3229 - val_loss: 0.4431 - val_mse: 0.4431 - 96ms/epoch - 8ms/step
# Epoch 365/2500
# 12/12 - 0s - loss: 0.3219 - mse: 0.3219 - val_loss: 0.4392 - val_mse: 0.4392 - 81ms/epoch - 7ms/step
# Epoch 366/2500
# 12/12 - 0s - loss: 0.3179 - mse: 0.3179 - val_loss: 0.4566 - val_mse: 0.4566 - 68ms/epoch - 6ms/step
# Epoch 367/2500
# 12/12 - 0s - loss: 0.3235 - mse: 0.3235 - val_loss: 0.4394 - val_mse: 0.4394 - 74ms/epoch - 6ms/step
# Epoch 368/2500
# 12/12 - 0s - loss: 0.3188 - mse: 0.3188 - val_loss: 0.4357 - val_mse: 0.4357 - 93ms/epoch - 8ms/step
# Epoch 369/2500
# 12/12 - 0s - loss: 0.3225 - mse: 0.3225 - val_loss: 0.4443 - val_mse: 0.4443 - 67ms/epoch - 6ms/step
# Epoch 370/2500
# 12/12 - 0s - loss: 0.3206 - mse: 0.3206 - val_loss: 0.4392 - val_mse: 0.4392 - 71ms/epoch - 6ms/step
# Epoch 371/2500
# 12/12 - 0s - loss: 0.3174 - mse: 0.3174 - val_loss: 0.4368 - val_mse: 0.4368 - 61ms/epoch - 5ms/step
# Epoch 372/2500
# 12/12 - 0s - loss: 0.3174 - mse: 0.3174 - val_loss: 0.4370 - val_mse: 0.4370 - 81ms/epoch - 7ms/step
# Epoch 373/2500
# 12/12 - 0s - loss: 0.3170 - mse: 0.3170 - val_loss: 0.4385 - val_mse: 0.4385 - 113ms/epoch - 9ms/step
# Epoch 374/2500
# 12/12 - 0s - loss: 0.3209 - mse: 0.3209 - val_loss: 0.4401 - val_mse: 0.4401 - 66ms/epoch - 5ms/step
# Epoch 375/2500
# 12/12 - 0s - loss: 0.3174 - mse: 0.3174 - val_loss: 0.4311 - val_mse: 0.4311 - 71ms/epoch - 6ms/step
# Epoch 376/2500
# 12/12 - 0s - loss: 0.3157 - mse: 0.3157 - val_loss: 0.4255 - val_mse: 0.4255 - 61ms/epoch - 5ms/step
# Epoch 377/2500
# 12/12 - 0s - loss: 0.3163 - mse: 0.3163 - val_loss: 0.4331 - val_mse: 0.4331 - 66ms/epoch - 5ms/step
# Epoch 378/2500
# 12/12 - 0s - loss: 0.3129 - mse: 0.3129 - val_loss: 0.4334 - val_mse: 0.4334 - 63ms/epoch - 5ms/step
# Epoch 379/2500
# 12/12 - 0s - loss: 0.3132 - mse: 0.3132 - val_loss: 0.4279 - val_mse: 0.4279 - 65ms/epoch - 5ms/step
# Epoch 380/2500
# 12/12 - 0s - loss: 0.3132 - mse: 0.3132 - val_loss: 0.4331 - val_mse: 0.4331 - 65ms/epoch - 5ms/step
# Epoch 381/2500
# 12/12 - 0s - loss: 0.3124 - mse: 0.3124 - val_loss: 0.4422 - val_mse: 0.4422 - 61ms/epoch - 5ms/step
# Epoch 382/2500
# 12/12 - 0s - loss: 0.3139 - mse: 0.3139 - val_loss: 0.4278 - val_mse: 0.4278 - 66ms/epoch - 5ms/step
# Epoch 383/2500
# 12/12 - 0s - loss: 0.3131 - mse: 0.3131 - val_loss: 0.4271 - val_mse: 0.4271 - 63ms/epoch - 5ms/step
# Epoch 384/2500
# 12/12 - 0s - loss: 0.3090 - mse: 0.3090 - val_loss: 0.4274 - val_mse: 0.4274 - 78ms/epoch - 6ms/step
# Epoch 385/2500
# 12/12 - 0s - loss: 0.3097 - mse: 0.3097 - val_loss: 0.4305 - val_mse: 0.4305 - 85ms/epoch - 7ms/step
# Epoch 386/2500
# 12/12 - 0s - loss: 0.3073 - mse: 0.3073 - val_loss: 0.4262 - val_mse: 0.4262 - 66ms/epoch - 5ms/step
# Epoch 387/2500
# 12/12 - 0s - loss: 0.3072 - mse: 0.3072 - val_loss: 0.4200 - val_mse: 0.4200 - 63ms/epoch - 5ms/step
# Epoch 388/2500
# 12/12 - 0s - loss: 0.3087 - mse: 0.3087 - val_loss: 0.4263 - val_mse: 0.4263 - 64ms/epoch - 5ms/step
# Epoch 389/2500
# 12/12 - 0s - loss: 0.3071 - mse: 0.3071 - val_loss: 0.4249 - val_mse: 0.4249 - 56ms/epoch - 5ms/step
# Epoch 390/2500
# 12/12 - 0s - loss: 0.3095 - mse: 0.3095 - val_loss: 0.4215 - val_mse: 0.4215 - 70ms/epoch - 6ms/step
# Epoch 391/2500
# 12/12 - 0s - loss: 0.3090 - mse: 0.3090 - val_loss: 0.4257 - val_mse: 0.4257 - 64ms/epoch - 5ms/step
# Epoch 392/2500
# 12/12 - 0s - loss: 0.3062 - mse: 0.3062 - val_loss: 0.4166 - val_mse: 0.4166 - 65ms/epoch - 5ms/step
# Epoch 393/2500
# 12/12 - 0s - loss: 0.3039 - mse: 0.3039 - val_loss: 0.4272 - val_mse: 0.4272 - 61ms/epoch - 5ms/step
# Epoch 394/2500
# 12/12 - 0s - loss: 0.3035 - mse: 0.3035 - val_loss: 0.4170 - val_mse: 0.4170 - 58ms/epoch - 5ms/step
# Epoch 395/2500
# 12/12 - 0s - loss: 0.3040 - mse: 0.3040 - val_loss: 0.4152 - val_mse: 0.4152 - 49ms/epoch - 4ms/step
# Epoch 396/2500
# 12/12 - 0s - loss: 0.3064 - mse: 0.3064 - val_loss: 0.4313 - val_mse: 0.4313 - 51ms/epoch - 4ms/step
# Epoch 397/2500
# 12/12 - 0s - loss: 0.3067 - mse: 0.3067 - val_loss: 0.4169 - val_mse: 0.4169 - 52ms/epoch - 4ms/step
# Epoch 398/2500
# 12/12 - 0s - loss: 0.3041 - mse: 0.3041 - val_loss: 0.4263 - val_mse: 0.4263 - 47ms/epoch - 4ms/step
# Epoch 399/2500
# 12/12 - 0s - loss: 0.3086 - mse: 0.3086 - val_loss: 0.4170 - val_mse: 0.4170 - 48ms/epoch - 4ms/step
# Epoch 400/2500
# 12/12 - 0s - loss: 0.3062 - mse: 0.3062 - val_loss: 0.4152 - val_mse: 0.4152 - 68ms/epoch - 6ms/step
# Epoch 401/2500
# 12/12 - 0s - loss: 0.2999 - mse: 0.2999 - val_loss: 0.4131 - val_mse: 0.4131 - 72ms/epoch - 6ms/step
# Epoch 402/2500
# 12/12 - 0s - loss: 0.3014 - mse: 0.3014 - val_loss: 0.4148 - val_mse: 0.4148 - 56ms/epoch - 5ms/step
# Epoch 403/2500
# 12/12 - 0s - loss: 0.2977 - mse: 0.2977 - val_loss: 0.4119 - val_mse: 0.4119 - 60ms/epoch - 5ms/step
# Epoch 404/2500
# 12/12 - 0s - loss: 0.2981 - mse: 0.2981 - val_loss: 0.4109 - val_mse: 0.4109 - 55ms/epoch - 5ms/step
# Epoch 405/2500
# 12/12 - 0s - loss: 0.2996 - mse: 0.2996 - val_loss: 0.4149 - val_mse: 0.4149 - 57ms/epoch - 5ms/step
# Epoch 406/2500
# 12/12 - 0s - loss: 0.3012 - mse: 0.3012 - val_loss: 0.4244 - val_mse: 0.4244 - 52ms/epoch - 4ms/step
# Epoch 407/2500
# 12/12 - 0s - loss: 0.3020 - mse: 0.3020 - val_loss: 0.4104 - val_mse: 0.4104 - 61ms/epoch - 5ms/step
# Epoch 408/2500
# 12/12 - 0s - loss: 0.2963 - mse: 0.2963 - val_loss: 0.4153 - val_mse: 0.4153 - 53ms/epoch - 4ms/step
# Epoch 409/2500
# 12/12 - 0s - loss: 0.2961 - mse: 0.2961 - val_loss: 0.4157 - val_mse: 0.4157 - 68ms/epoch - 6ms/step
# Epoch 410/2500
# 12/12 - 0s - loss: 0.2944 - mse: 0.2944 - val_loss: 0.4098 - val_mse: 0.4098 - 62ms/epoch - 5ms/step
# Epoch 411/2500
# 12/12 - 0s - loss: 0.2945 - mse: 0.2945 - val_loss: 0.4121 - val_mse: 0.4121 - 74ms/epoch - 6ms/step
# Epoch 412/2500
# ...
# Epoch 2365/2500
# 12/12 - 0s - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0981 - val_mse: 0.0981 - 52ms/epoch - 4ms/step
# Epoch 2366/2500
# 12/12 - 0s - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0923 - val_mse: 0.0923 - 55ms/epoch - 5ms/step
# Epoch 2367/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0945 - val_mse: 0.0945 - 53ms/epoch - 4ms/step
# Epoch 2368/2500
# 12/12 - 0s - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0941 - val_mse: 0.0941 - 51ms/epoch - 4ms/step
# Epoch 2369/2500
# 12/12 - 0s - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0960 - val_mse: 0.0960 - 49ms/epoch - 4ms/step
# Epoch 2370/2500
# 12/12 - 0s - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0959 - val_mse: 0.0959 - 56ms/epoch - 5ms/step
# Epoch 2371/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0970 - val_mse: 0.0970 - 51ms/epoch - 4ms/step
# Epoch 2372/2500
# 12/12 - 0s - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0941 - val_mse: 0.0941 - 46ms/epoch - 4ms/step
# Epoch 2373/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0934 - val_mse: 0.0934 - 55ms/epoch - 5ms/step
# Epoch 2374/2500
# 12/12 - 0s - loss: 0.0648 - mse: 0.0648 - val_loss: 0.0913 - val_mse: 0.0913 - 56ms/epoch - 5ms/step
# Epoch 2375/2500
# 12/12 - 0s - loss: 0.0639 - mse: 0.0639 - val_loss: 0.0947 - val_mse: 0.0947 - 49ms/epoch - 4ms/step
# Epoch 2376/2500
# 12/12 - 0s - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0959 - val_mse: 0.0959 - 49ms/epoch - 4ms/step
# Epoch 2377/2500
# 12/12 - 0s - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0938 - val_mse: 0.0938 - 73ms/epoch - 6ms/step
# Epoch 2378/2500
# 12/12 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0936 - val_mse: 0.0936 - 71ms/epoch - 6ms/step
# Epoch 2379/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0939 - val_mse: 0.0939 - 50ms/epoch - 4ms/step
# Epoch 2380/2500
# 12/12 - 0s - loss: 0.0628 - mse: 0.0628 - val_loss: 0.0966 - val_mse: 0.0966 - 53ms/epoch - 4ms/step
# Epoch 2381/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0947 - val_mse: 0.0947 - 58ms/epoch - 5ms/step
# Epoch 2382/2500
# 12/12 - 0s - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0924 - val_mse: 0.0924 - 50ms/epoch - 4ms/step
# Epoch 2383/2500
# 12/12 - 0s - loss: 0.0671 - mse: 0.0671 - val_loss: 0.0999 - val_mse: 0.0999 - 57ms/epoch - 5ms/step
# Epoch 2384/2500
# 12/12 - 0s - loss: 0.0700 - mse: 0.0700 - val_loss: 0.0968 - val_mse: 0.0968 - 66ms/epoch - 5ms/step
# Epoch 2385/2500
# 12/12 - 0s - loss: 0.0680 - mse: 0.0680 - val_loss: 0.0954 - val_mse: 0.0954 - 89ms/epoch - 7ms/step
# Epoch 2386/2500
# 12/12 - 0s - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0930 - val_mse: 0.0930 - 82ms/epoch - 7ms/step
# Epoch 2387/2500
# 12/12 - 0s - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0966 - val_mse: 0.0966 - 60ms/epoch - 5ms/step
# Epoch 2388/2500
# 12/12 - 0s - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0937 - val_mse: 0.0937 - 63ms/epoch - 5ms/step
# Epoch 2389/2500
# 12/12 - 0s - loss: 0.0618 - mse: 0.0618 - val_loss: 0.0946 - val_mse: 0.0946 - 73ms/epoch - 6ms/step
# Epoch 2390/2500
# 12/12 - 0s - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0934 - val_mse: 0.0934 - 63ms/epoch - 5ms/step
# Epoch 2391/2500
# 12/12 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0937 - val_mse: 0.0937 - 74ms/epoch - 6ms/step
# Epoch 2392/2500
# 12/12 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0930 - val_mse: 0.0930 - 56ms/epoch - 5ms/step
# Epoch 2393/2500
# 12/12 - 0s - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0937 - val_mse: 0.0937 - 59ms/epoch - 5ms/step
# Epoch 2394/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0924 - val_mse: 0.0924 - 49ms/epoch - 4ms/step
# Epoch 2395/2500
# 12/12 - 0s - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0933 - val_mse: 0.0933 - 52ms/epoch - 4ms/step
# Epoch 2396/2500
# 12/12 - 0s - loss: 0.0618 - mse: 0.0618 - val_loss: 0.0929 - val_mse: 0.0929 - 99ms/epoch - 8ms/step
# Epoch 2397/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0928 - val_mse: 0.0928 - 74ms/epoch - 6ms/step
# Epoch 2398/2500
# 12/12 - 0s - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0945 - val_mse: 0.0945 - 57ms/epoch - 5ms/step
# Epoch 2399/2500
# 12/12 - 0s - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0928 - val_mse: 0.0928 - 52ms/epoch - 4ms/step
# Epoch 2400/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0958 - val_mse: 0.0958 - 53ms/epoch - 4ms/step
# Epoch 2401/2500
# 12/12 - 0s - loss: 0.0643 - mse: 0.0643 - val_loss: 0.0967 - val_mse: 0.0967 - 47ms/epoch - 4ms/step
# Epoch 2402/2500
# 12/12 - 0s - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0913 - val_mse: 0.0913 - 53ms/epoch - 4ms/step
# Epoch 2403/2500
# 12/12 - 0s - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0953 - val_mse: 0.0953 - 50ms/epoch - 4ms/step
# Epoch 2404/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0926 - val_mse: 0.0926 - 100ms/epoch - 8ms/step
# Epoch 2405/2500
# 12/12 - 0s - loss: 0.0621 - mse: 0.0621 - val_loss: 0.0938 - val_mse: 0.0938 - 83ms/epoch - 7ms/step
# Epoch 2406/2500
# 12/12 - 0s - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0902 - val_mse: 0.0902 - 69ms/epoch - 6ms/step
# Epoch 2407/2500
# 12/12 - 0s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0958 - val_mse: 0.0958 - 60ms/epoch - 5ms/step
# Epoch 2408/2500
# 12/12 - 0s - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0938 - val_mse: 0.0938 - 51ms/epoch - 4ms/step
# Epoch 2409/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0908 - val_mse: 0.0908 - 56ms/epoch - 5ms/step
# Epoch 2410/2500
# 12/12 - 0s - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0935 - val_mse: 0.0935 - 51ms/epoch - 4ms/step
# Epoch 2411/2500
# 12/12 - 0s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0912 - val_mse: 0.0912 - 53ms/epoch - 4ms/step
# Epoch 2412/2500
# 12/12 - 0s - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0926 - val_mse: 0.0926 - 55ms/epoch - 5ms/step
# Epoch 2413/2500
# 12/12 - 0s - loss: 0.0626 - mse: 0.0626 - val_loss: 0.0949 - val_mse: 0.0949 - 70ms/epoch - 6ms/step
# Epoch 2414/2500
# 12/12 - 0s - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0923 - val_mse: 0.0923 - 78ms/epoch - 6ms/step
# Epoch 2415/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0908 - val_mse: 0.0908 - 177ms/epoch - 15ms/step
# Epoch 2416/2500
# 12/12 - 0s - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0934 - val_mse: 0.0934 - 95ms/epoch - 8ms/step
# Epoch 2417/2500
# 12/12 - 0s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0915 - val_mse: 0.0915 - 80ms/epoch - 7ms/step
# Epoch 2418/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0922 - val_mse: 0.0922 - 89ms/epoch - 7ms/step
# Epoch 2419/2500
# 12/12 - 1s - loss: 0.0637 - mse: 0.0637 - val_loss: 0.0908 - val_mse: 0.0908 - 525ms/epoch - 44ms/step
# Epoch 2420/2500
# 12/12 - 0s - loss: 0.0634 - mse: 0.0634 - val_loss: 0.0919 - val_mse: 0.0919 - 116ms/epoch - 10ms/step
# Epoch 2421/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0909 - val_mse: 0.0909 - 102ms/epoch - 8ms/step
# Epoch 2422/2500
# 12/12 - 0s - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0933 - val_mse: 0.0933 - 92ms/epoch - 8ms/step
# Epoch 2423/2500
# 12/12 - 0s - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0902 - val_mse: 0.0902 - 98ms/epoch - 8ms/step
# Epoch 2424/2500
# 12/12 - 0s - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0967 - val_mse: 0.0967 - 80ms/epoch - 7ms/step
# Epoch 2425/2500
# 12/12 - 0s - loss: 0.0649 - mse: 0.0649 - val_loss: 0.0946 - val_mse: 0.0946 - 85ms/epoch - 7ms/step
# Epoch 2426/2500
# 12/12 - 0s - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0914 - val_mse: 0.0914 - 121ms/epoch - 10ms/step
# Epoch 2427/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0962 - val_mse: 0.0962 - 105ms/epoch - 9ms/step
# Epoch 2428/2500
# 12/12 - 0s - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0920 - val_mse: 0.0920 - 92ms/epoch - 8ms/step
# Epoch 2429/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0906 - val_mse: 0.0906 - 71ms/epoch - 6ms/step
# Epoch 2430/2500
# 12/12 - 0s - loss: 0.0630 - mse: 0.0630 - val_loss: 0.0921 - val_mse: 0.0921 - 73ms/epoch - 6ms/step
# Epoch 2431/2500
# 12/12 - 0s - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0908 - val_mse: 0.0908 - 88ms/epoch - 7ms/step
# Epoch 2432/2500
# 12/12 - 0s - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0914 - val_mse: 0.0914 - 85ms/epoch - 7ms/step
# Epoch 2433/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0943 - val_mse: 0.0943 - 111ms/epoch - 9ms/step
# Epoch 2434/2500
# 12/12 - 0s - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0897 - val_mse: 0.0897 - 144ms/epoch - 12ms/step
# Epoch 2435/2500
# 12/12 - 0s - loss: 0.0631 - mse: 0.0631 - val_loss: 0.0922 - val_mse: 0.0922 - 103ms/epoch - 9ms/step
# Epoch 2436/2500
# 12/12 - 0s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0977 - val_mse: 0.0977 - 152ms/epoch - 13ms/step
# Epoch 2437/2500
# 12/12 - 0s - loss: 0.0635 - mse: 0.0635 - val_loss: 0.0914 - val_mse: 0.0914 - 81ms/epoch - 7ms/step
# Epoch 2438/2500
# 12/12 - 0s - loss: 0.0644 - mse: 0.0644 - val_loss: 0.0906 - val_mse: 0.0906 - 93ms/epoch - 8ms/step
# Epoch 2439/2500
# 12/12 - 0s - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0926 - val_mse: 0.0926 - 192ms/epoch - 16ms/step
# Epoch 2440/2500
# 12/12 - 0s - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0922 - val_mse: 0.0922 - 199ms/epoch - 17ms/step
# Epoch 2441/2500
# 12/12 - 0s - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0910 - val_mse: 0.0910 - 150ms/epoch - 12ms/step
# Epoch 2442/2500
# 12/12 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0931 - val_mse: 0.0931 - 111ms/epoch - 9ms/step
# Epoch 2443/2500
# 12/12 - 0s - loss: 0.0642 - mse: 0.0642 - val_loss: 0.0897 - val_mse: 0.0897 - 71ms/epoch - 6ms/step
# Epoch 2444/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0928 - val_mse: 0.0928 - 115ms/epoch - 10ms/step
# Epoch 2445/2500
# 12/12 - 0s - loss: 0.0641 - mse: 0.0641 - val_loss: 0.0942 - val_mse: 0.0942 - 93ms/epoch - 8ms/step
# Epoch 2446/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0946 - val_mse: 0.0946 - 193ms/epoch - 16ms/step
# Epoch 2447/2500
# 12/12 - 0s - loss: 0.0630 - mse: 0.0630 - val_loss: 0.0921 - val_mse: 0.0921 - 108ms/epoch - 9ms/step
# Epoch 2448/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0934 - val_mse: 0.0934 - 60ms/epoch - 5ms/step
# Epoch 2449/2500
# 12/12 - 0s - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0927 - val_mse: 0.0927 - 80ms/epoch - 7ms/step
# Epoch 2450/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0971 - val_mse: 0.0971 - 67ms/epoch - 6ms/step
# Epoch 2451/2500
# 12/12 - 0s - loss: 0.0630 - mse: 0.0630 - val_loss: 0.0921 - val_mse: 0.0921 - 66ms/epoch - 5ms/step
# Epoch 2452/2500
# 12/12 - 0s - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0925 - val_mse: 0.0925 - 65ms/epoch - 5ms/step
# Epoch 2453/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0904 - val_mse: 0.0904 - 70ms/epoch - 6ms/step
# Epoch 2454/2500
# 12/12 - 0s - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0917 - val_mse: 0.0917 - 60ms/epoch - 5ms/step
# Epoch 2455/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0907 - val_mse: 0.0907 - 80ms/epoch - 7ms/step
# Epoch 2456/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0916 - val_mse: 0.0916 - 69ms/epoch - 6ms/step
# Epoch 2457/2500
# 12/12 - 0s - loss: 0.0653 - mse: 0.0653 - val_loss: 0.0910 - val_mse: 0.0910 - 72ms/epoch - 6ms/step
# Epoch 2458/2500
# 12/12 - 0s - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0926 - val_mse: 0.0926 - 69ms/epoch - 6ms/step
# Epoch 2459/2500
# 12/12 - 0s - loss: 0.0616 - mse: 0.0616 - val_loss: 0.0899 - val_mse: 0.0899 - 249ms/epoch - 21ms/step
# Epoch 2460/2500
# 12/12 - 0s - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0903 - val_mse: 0.0903 - 147ms/epoch - 12ms/step
# Epoch 2461/2500
# 12/12 - 0s - loss: 0.0614 - mse: 0.0614 - val_loss: 0.0920 - val_mse: 0.0920 - 106ms/epoch - 9ms/step
# Epoch 2462/2500
# 12/12 - 0s - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0933 - val_mse: 0.0933 - 99ms/epoch - 8ms/step
# Epoch 2463/2500
# 12/12 - 0s - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0904 - val_mse: 0.0904 - 73ms/epoch - 6ms/step
# Epoch 2464/2500
# 12/12 - 0s - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0909 - val_mse: 0.0909 - 79ms/epoch - 7ms/step
# Epoch 2465/2500
# 12/12 - 0s - loss: 0.0611 - mse: 0.0611 - val_loss: 0.0908 - val_mse: 0.0908 - 75ms/epoch - 6ms/step
# Epoch 2466/2500
# 12/12 - 0s - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0933 - val_mse: 0.0933 - 70ms/epoch - 6ms/step
# Epoch 2467/2500
# 12/12 - 0s - loss: 0.0623 - mse: 0.0623 - val_loss: 0.0950 - val_mse: 0.0950 - 62ms/epoch - 5ms/step
# Epoch 2468/2500
# 12/12 - 0s - loss: 0.0632 - mse: 0.0632 - val_loss: 0.0904 - val_mse: 0.0904 - 58ms/epoch - 5ms/step
# Epoch 2469/2500
# 12/12 - 0s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0927 - val_mse: 0.0927 - 67ms/epoch - 6ms/step
# Epoch 2470/2500
# 12/12 - 0s - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0911 - val_mse: 0.0911 - 62ms/epoch - 5ms/step
# Epoch 2471/2500
# 12/12 - 0s - loss: 0.0625 - mse: 0.0625 - val_loss: 0.0903 - val_mse: 0.0903 - 64ms/epoch - 5ms/step
# Epoch 2472/2500
# 12/12 - 0s - loss: 0.0604 - mse: 0.0604 - val_loss: 0.0905 - val_mse: 0.0905 - 58ms/epoch - 5ms/step
# Epoch 2473/2500
# 12/12 - 0s - loss: 0.0622 - mse: 0.0622 - val_loss: 0.0906 - val_mse: 0.0906 - 111ms/epoch - 9ms/step
# Epoch 2474/2500
# 12/12 - 0s - loss: 0.0618 - mse: 0.0618 - val_loss: 0.0897 - val_mse: 0.0897 - 75ms/epoch - 6ms/step
# Epoch 2475/2500
# 12/12 - 0s - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0922 - val_mse: 0.0922 - 68ms/epoch - 6ms/step
# Epoch 2476/2500
# 12/12 - 0s - loss: 0.0624 - mse: 0.0624 - val_loss: 0.0896 - val_mse: 0.0896 - 63ms/epoch - 5ms/step
# Epoch 2477/2500
# 12/12 - 0s - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0900 - val_mse: 0.0900 - 71ms/epoch - 6ms/step
# Epoch 2478/2500
# 12/12 - 0s - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0889 - val_mse: 0.0889 - 98ms/epoch - 8ms/step
# Epoch 2479/2500
# 12/12 - 0s - loss: 0.0618 - mse: 0.0618 - val_loss: 0.0893 - val_mse: 0.0893 - 86ms/epoch - 7ms/step
# Epoch 2480/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0922 - val_mse: 0.0922 - 157ms/epoch - 13ms/step
# Epoch 2481/2500
# 12/12 - 0s - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0884 - val_mse: 0.0884 - 135ms/epoch - 11ms/step
# Epoch 2482/2500
# 12/12 - 0s - loss: 0.0610 - mse: 0.0610 - val_loss: 0.0894 - val_mse: 0.0894 - 91ms/epoch - 8ms/step
# Epoch 2483/2500
# 12/12 - 0s - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0902 - val_mse: 0.0902 - 125ms/epoch - 10ms/step
# Epoch 2484/2500
# 12/12 - 0s - loss: 0.0602 - mse: 0.0602 - val_loss: 0.0888 - val_mse: 0.0888 - 117ms/epoch - 10ms/step
# Epoch 2485/2500
# 12/12 - 0s - loss: 0.0609 - mse: 0.0609 - val_loss: 0.0912 - val_mse: 0.0912 - 117ms/epoch - 10ms/step
# Epoch 2486/2500
# 12/12 - 0s - loss: 0.0599 - mse: 0.0599 - val_loss: 0.0895 - val_mse: 0.0895 - 95ms/epoch - 8ms/step
# Epoch 2487/2500
# 12/12 - 0s - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0902 - val_mse: 0.0902 - 91ms/epoch - 8ms/step
# Epoch 2488/2500
# 12/12 - 0s - loss: 0.0608 - mse: 0.0608 - val_loss: 0.0915 - val_mse: 0.0915 - 95ms/epoch - 8ms/step
# Epoch 2489/2500
# 12/12 - 0s - loss: 0.0619 - mse: 0.0619 - val_loss: 0.0899 - val_mse: 0.0899 - 102ms/epoch - 8ms/step
# Epoch 2490/2500
# 12/12 - 0s - loss: 0.0617 - mse: 0.0617 - val_loss: 0.0954 - val_mse: 0.0954 - 79ms/epoch - 7ms/step
# Epoch 2491/2500
# 12/12 - 0s - loss: 0.0628 - mse: 0.0628 - val_loss: 0.0889 - val_mse: 0.0889 - 87ms/epoch - 7ms/step
# Epoch 2492/2500
# 12/12 - 0s - loss: 0.0615 - mse: 0.0615 - val_loss: 0.0912 - val_mse: 0.0912 - 81ms/epoch - 7ms/step
# Epoch 2493/2500
# 12/12 - 0s - loss: 0.0627 - mse: 0.0627 - val_loss: 0.0892 - val_mse: 0.0892 - 78ms/epoch - 6ms/step
# Epoch 2494/2500
# 12/12 - 0s - loss: 0.0620 - mse: 0.0620 - val_loss: 0.0912 - val_mse: 0.0912 - 108ms/epoch - 9ms/step
# Epoch 2495/2500
# 12/12 - 0s - loss: 0.0613 - mse: 0.0613 - val_loss: 0.0914 - val_mse: 0.0914 - 149ms/epoch - 12ms/step
# Epoch 2496/2500
# 12/12 - 0s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0886 - val_mse: 0.0886 - 144ms/epoch - 12ms/step
# Epoch 2497/2500
# 12/12 - 0s - loss: 0.0633 - mse: 0.0633 - val_loss: 0.0903 - val_mse: 0.0903 - 105ms/epoch - 9ms/step
# Epoch 2498/2500
# 12/12 - 0s - loss: 0.0606 - mse: 0.0606 - val_loss: 0.0912 - val_mse: 0.0912 - 112ms/epoch - 9ms/step
# Epoch 2499/2500
# 12/12 - 0s - loss: 0.0612 - mse: 0.0612 - val_loss: 0.0899 - val_mse: 0.0899 - 94ms/epoch - 8ms/step
# Epoch 2500/2500
# 12/12 - 0s - loss: 0.0603 - mse: 0.0603 - val_loss: 0.0883 - val_mse: 0.0883 - 79ms/epoch - 7ms/step

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

#recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
# plt.title('model loss')
# plt.xlim([-20, 1800])
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 20)                80
#
#  second_layer (Dense)        (None, 10)                210
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.182

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.917

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
# plt.plot(y_test.iloc[:,0], y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2.5, -0.5))
plt.annotate("MAE = {:.3f}".format(error), (2.5, -0.8))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
# plt.title('Validation of the prediction model')     
plt.grid(True)

# plt.savefig('model validation.png', transparent=True)
plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(20,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_215')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_215\assets
