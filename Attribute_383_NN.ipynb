# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

sns.set_style("darkgrid")

# %% [markdown]
#     383 : ESYS line3 SENSOR 84 - Tension at Fairlead - Trained on Max values

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_383.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Max']]

# %%
print('Maximum value of tension at fairlead (Line 3): %.6f' % df['Max'].max())
print('Minimum value of tension at fairlead (Line 3): %.6f' % df['Max'].min())
print('Range for tension at fairlead (Line 3): %.6f' % (df['Max'].max()-df['Max'].min()))
print('Mean for tension at fairlead (Line 3): %.6f' % (np.mean(df['Max'])))
# Out:
# Maximum value of tension at fairlead (Line 3): 13671021.705236
# Minimum value of tension at fairlead (Line 3): 3195615.166382
# Range for tension at fairlead (Line 3): 10475406.538855
# Mean for tension at fairlead (Line 3): 5020619.265126

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 0             800       800           0  5.113137e+06
# 1             800       800           1  5.037895e+06
# 2             800       800           2  4.956254e+06
# 3             800       800           3  4.904103e+06
# 4             800       800           4  4.845286e+06

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values      0
# R_anchor      0
# z_fairlead    0
# Max           0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 1194          850       840          14  1.099747e+07

# %% [markdown]
# # Sensitivity analysis

# %%
#varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

#varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

#varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
#Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum tension at fairlead for line 3', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='Max', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[0].set_title('Variation of T vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="Max", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[1].set_title('Variation of T vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="Max", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum tension at fairlead [N]" , size = 12 )
axes[2].set_title('Variation of T vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['Max']<= df['Max'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_383.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label (Line 3)')

#L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='Max',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Max Tension at fairlead (Line 3)', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
#plot heat map
plt.rcParams.update({'font.size': 14})
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#              count          mean           std           min           max
# L_values    1300.0  8.449231e+02  2.328807e+01  8.000000e+02  8.800000e+02
# R_anchor    1300.0  8.347692e+02  2.626962e+01  8.000000e+02  9.000000e+02
# z_fairlead  1300.0  9.500000e+00  5.768500e+00  0.000000e+00  1.900000e+01
# Max         1300.0  5.020619e+06  2.332122e+06  3.195615e+06  1.367102e+07

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['Max']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_383.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_383.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Max
# File_ID
# 0             0.0       0.0    0.000000  0.039686
# 1             0.0       0.0    0.052632  0.007411
# 2             0.0       0.0    0.105263 -0.027610
# 3             0.0       0.0    0.157895 -0.049981
# 4             0.0       0.0    0.210526 -0.075211

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %% [markdown]
# It draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / fan_in) where fan_in is the number of input units in the weight tensor.

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 0.9834 - mse: 0.9834 - val_loss: 1.0361 - val_mse: 1.0361 - 502ms/epoch - 42ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 0.9586 - mse: 0.9586 - val_loss: 1.0233 - val_mse: 1.0233 - 53ms/epoch - 4ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 0.9390 - mse: 0.9390 - val_loss: 1.0103 - val_mse: 1.0103 - 54ms/epoch - 4ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 0.9199 - mse: 0.9199 - val_loss: 0.9982 - val_mse: 0.9982 - 40ms/epoch - 3ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 0.9032 - mse: 0.9032 - val_loss: 0.9852 - val_mse: 0.9852 - 43ms/epoch - 4ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 0.8867 - mse: 0.8867 - val_loss: 0.9701 - val_mse: 0.9701 - 52ms/epoch - 4ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 0.8636 - mse: 0.8636 - val_loss: 0.9539 - val_mse: 0.9539 - 42ms/epoch - 3ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 0.8368 - mse: 0.8368 - val_loss: 0.9305 - val_mse: 0.9305 - 44ms/epoch - 4ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.8142 - mse: 0.8142 - val_loss: 0.9062 - val_mse: 0.9062 - 39ms/epoch - 3ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.7971 - mse: 0.7971 - val_loss: 0.8833 - val_mse: 0.8833 - 38ms/epoch - 3ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.7766 - mse: 0.7766 - val_loss: 0.8699 - val_mse: 0.8699 - 37ms/epoch - 3ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.7601 - mse: 0.7601 - val_loss: 0.8550 - val_mse: 0.8550 - 43ms/epoch - 4ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.7472 - mse: 0.7472 - val_loss: 0.8400 - val_mse: 0.8400 - 40ms/epoch - 3ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.7332 - mse: 0.7332 - val_loss: 0.8290 - val_mse: 0.8290 - 44ms/epoch - 4ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.7231 - mse: 0.7231 - val_loss: 0.8192 - val_mse: 0.8192 - 51ms/epoch - 4ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.7133 - mse: 0.7133 - val_loss: 0.8058 - val_mse: 0.8058 - 37ms/epoch - 3ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.7008 - mse: 0.7008 - val_loss: 0.8045 - val_mse: 0.8045 - 48ms/epoch - 4ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.6921 - mse: 0.6921 - val_loss: 0.7923 - val_mse: 0.7923 - 41ms/epoch - 3ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.6867 - mse: 0.6867 - val_loss: 0.7793 - val_mse: 0.7793 - 40ms/epoch - 3ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.6761 - mse: 0.6761 - val_loss: 0.7761 - val_mse: 0.7761 - 52ms/epoch - 4ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.6693 - mse: 0.6693 - val_loss: 0.7644 - val_mse: 0.7644 - 38ms/epoch - 3ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.6621 - mse: 0.6621 - val_loss: 0.7606 - val_mse: 0.7606 - 40ms/epoch - 3ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.6560 - mse: 0.6560 - val_loss: 0.7509 - val_mse: 0.7509 - 43ms/epoch - 4ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.6502 - mse: 0.6502 - val_loss: 0.7424 - val_mse: 0.7424 - 42ms/epoch - 3ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.6449 - mse: 0.6449 - val_loss: 0.7378 - val_mse: 0.7378 - 41ms/epoch - 3ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.6428 - mse: 0.6428 - val_loss: 0.7365 - val_mse: 0.7365 - 37ms/epoch - 3ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.6340 - mse: 0.6340 - val_loss: 0.7245 - val_mse: 0.7245 - 42ms/epoch - 3ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.6299 - mse: 0.6299 - val_loss: 0.7184 - val_mse: 0.7184 - 41ms/epoch - 3ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.6247 - mse: 0.6247 - val_loss: 0.7125 - val_mse: 0.7125 - 38ms/epoch - 3ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.6208 - mse: 0.6208 - val_loss: 0.7091 - val_mse: 0.7091 - 35ms/epoch - 3ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.6163 - mse: 0.6163 - val_loss: 0.7106 - val_mse: 0.7106 - 51ms/epoch - 4ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.6131 - mse: 0.6131 - val_loss: 0.7055 - val_mse: 0.7055 - 41ms/epoch - 3ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.6095 - mse: 0.6095 - val_loss: 0.6974 - val_mse: 0.6974 - 44ms/epoch - 4ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.6072 - mse: 0.6072 - val_loss: 0.6945 - val_mse: 0.6945 - 52ms/epoch - 4ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.6028 - mse: 0.6028 - val_loss: 0.6901 - val_mse: 0.6901 - 53ms/epoch - 4ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.6008 - mse: 0.6008 - val_loss: 0.6882 - val_mse: 0.6882 - 40ms/epoch - 3ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.5989 - mse: 0.5989 - val_loss: 0.6908 - val_mse: 0.6908 - 39ms/epoch - 3ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.5964 - mse: 0.5964 - val_loss: 0.6788 - val_mse: 0.6788 - 41ms/epoch - 3ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.5929 - mse: 0.5929 - val_loss: 0.6850 - val_mse: 0.6850 - 35ms/epoch - 3ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.5905 - mse: 0.5905 - val_loss: 0.6797 - val_mse: 0.6797 - 40ms/epoch - 3ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.5881 - mse: 0.5881 - val_loss: 0.6838 - val_mse: 0.6838 - 38ms/epoch - 3ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.5870 - mse: 0.5870 - val_loss: 0.6783 - val_mse: 0.6783 - 34ms/epoch - 3ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.5849 - mse: 0.5849 - val_loss: 0.6736 - val_mse: 0.6736 - 37ms/epoch - 3ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.5824 - mse: 0.5824 - val_loss: 0.6693 - val_mse: 0.6693 - 36ms/epoch - 3ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.5800 - mse: 0.5800 - val_loss: 0.6711 - val_mse: 0.6711 - 38ms/epoch - 3ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.5765 - mse: 0.5765 - val_loss: 0.6648 - val_mse: 0.6648 - 41ms/epoch - 3ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.5744 - mse: 0.5744 - val_loss: 0.6654 - val_mse: 0.6654 - 39ms/epoch - 3ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.5710 - mse: 0.5710 - val_loss: 0.6642 - val_mse: 0.6642 - 40ms/epoch - 3ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.5691 - mse: 0.5691 - val_loss: 0.6644 - val_mse: 0.6644 - 40ms/epoch - 3ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.5677 - mse: 0.5677 - val_loss: 0.6632 - val_mse: 0.6632 - 42ms/epoch - 3ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.5680 - mse: 0.5680 - val_loss: 0.6591 - val_mse: 0.6591 - 37ms/epoch - 3ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.5633 - mse: 0.5633 - val_loss: 0.6565 - val_mse: 0.6565 - 38ms/epoch - 3ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.5605 - mse: 0.5605 - val_loss: 0.6550 - val_mse: 0.6550 - 37ms/epoch - 3ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.5574 - mse: 0.5574 - val_loss: 0.6497 - val_mse: 0.6497 - 37ms/epoch - 3ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.5582 - mse: 0.5582 - val_loss: 0.6522 - val_mse: 0.6522 - 39ms/epoch - 3ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.5534 - mse: 0.5534 - val_loss: 0.6513 - val_mse: 0.6513 - 40ms/epoch - 3ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.5534 - mse: 0.5534 - val_loss: 0.6505 - val_mse: 0.6505 - 38ms/epoch - 3ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.5491 - mse: 0.5491 - val_loss: 0.6516 - val_mse: 0.6516 - 34ms/epoch - 3ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.5512 - mse: 0.5512 - val_loss: 0.6493 - val_mse: 0.6493 - 37ms/epoch - 3ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.5441 - mse: 0.5441 - val_loss: 0.6418 - val_mse: 0.6418 - 40ms/epoch - 3ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.5430 - mse: 0.5430 - val_loss: 0.6431 - val_mse: 0.6431 - 38ms/epoch - 3ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.5406 - mse: 0.5406 - val_loss: 0.6491 - val_mse: 0.6491 - 38ms/epoch - 3ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.5356 - mse: 0.5356 - val_loss: 0.6382 - val_mse: 0.6382 - 41ms/epoch - 3ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.5353 - mse: 0.5353 - val_loss: 0.6412 - val_mse: 0.6412 - 32ms/epoch - 3ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.5320 - mse: 0.5320 - val_loss: 0.6390 - val_mse: 0.6390 - 39ms/epoch - 3ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.5317 - mse: 0.5317 - val_loss: 0.6345 - val_mse: 0.6345 - 35ms/epoch - 3ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.5277 - mse: 0.5277 - val_loss: 0.6354 - val_mse: 0.6354 - 43ms/epoch - 4ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.5266 - mse: 0.5266 - val_loss: 0.6321 - val_mse: 0.6321 - 38ms/epoch - 3ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.5250 - mse: 0.5250 - val_loss: 0.6278 - val_mse: 0.6278 - 36ms/epoch - 3ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.5211 - mse: 0.5211 - val_loss: 0.6348 - val_mse: 0.6348 - 38ms/epoch - 3ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.5189 - mse: 0.5189 - val_loss: 0.6240 - val_mse: 0.6240 - 38ms/epoch - 3ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.5180 - mse: 0.5180 - val_loss: 0.6270 - val_mse: 0.6270 - 38ms/epoch - 3ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.5154 - mse: 0.5154 - val_loss: 0.6227 - val_mse: 0.6227 - 38ms/epoch - 3ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.5131 - mse: 0.5131 - val_loss: 0.6260 - val_mse: 0.6260 - 34ms/epoch - 3ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.5124 - mse: 0.5124 - val_loss: 0.6200 - val_mse: 0.6200 - 41ms/epoch - 3ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.5080 - mse: 0.5080 - val_loss: 0.6262 - val_mse: 0.6262 - 42ms/epoch - 3ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.5073 - mse: 0.5073 - val_loss: 0.6213 - val_mse: 0.6213 - 35ms/epoch - 3ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.5066 - mse: 0.5066 - val_loss: 0.6144 - val_mse: 0.6144 - 40ms/epoch - 3ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.5043 - mse: 0.5043 - val_loss: 0.6165 - val_mse: 0.6165 - 36ms/epoch - 3ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.5006 - mse: 0.5006 - val_loss: 0.6121 - val_mse: 0.6121 - 44ms/epoch - 4ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.4992 - mse: 0.4992 - val_loss: 0.6139 - val_mse: 0.6139 - 47ms/epoch - 4ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.4971 - mse: 0.4971 - val_loss: 0.6119 - val_mse: 0.6119 - 34ms/epoch - 3ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.4937 - mse: 0.4937 - val_loss: 0.6091 - val_mse: 0.6091 - 38ms/epoch - 3ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.4921 - mse: 0.4921 - val_loss: 0.6076 - val_mse: 0.6076 - 38ms/epoch - 3ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.4916 - mse: 0.4916 - val_loss: 0.6046 - val_mse: 0.6046 - 36ms/epoch - 3ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.4880 - mse: 0.4880 - val_loss: 0.6062 - val_mse: 0.6062 - 37ms/epoch - 3ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.4863 - mse: 0.4863 - val_loss: 0.6019 - val_mse: 0.6019 - 37ms/epoch - 3ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.4826 - mse: 0.4826 - val_loss: 0.5960 - val_mse: 0.5960 - 37ms/epoch - 3ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.4823 - mse: 0.4823 - val_loss: 0.5966 - val_mse: 0.5966 - 51ms/epoch - 4ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.4807 - mse: 0.4807 - val_loss: 0.5973 - val_mse: 0.5973 - 55ms/epoch - 5ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.4784 - mse: 0.4784 - val_loss: 0.5917 - val_mse: 0.5917 - 42ms/epoch - 3ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.4749 - mse: 0.4749 - val_loss: 0.5961 - val_mse: 0.5961 - 37ms/epoch - 3ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.4715 - mse: 0.4715 - val_loss: 0.5907 - val_mse: 0.5907 - 40ms/epoch - 3ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.4691 - mse: 0.4691 - val_loss: 0.5861 - val_mse: 0.5861 - 36ms/epoch - 3ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.4687 - mse: 0.4687 - val_loss: 0.5844 - val_mse: 0.5844 - 36ms/epoch - 3ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.4696 - mse: 0.4696 - val_loss: 0.5903 - val_mse: 0.5903 - 39ms/epoch - 3ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.4666 - mse: 0.4666 - val_loss: 0.5791 - val_mse: 0.5791 - 36ms/epoch - 3ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.4610 - mse: 0.4610 - val_loss: 0.5835 - val_mse: 0.5835 - 39ms/epoch - 3ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.4621 - mse: 0.4621 - val_loss: 0.5817 - val_mse: 0.5817 - 39ms/epoch - 3ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.4567 - mse: 0.4567 - val_loss: 0.5750 - val_mse: 0.5750 - 41ms/epoch - 3ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.4558 - mse: 0.4558 - val_loss: 0.5797 - val_mse: 0.5797 - 37ms/epoch - 3ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.4522 - mse: 0.4522 - val_loss: 0.5732 - val_mse: 0.5732 - 36ms/epoch - 3ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.4500 - mse: 0.4500 - val_loss: 0.5736 - val_mse: 0.5736 - 36ms/epoch - 3ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.4487 - mse: 0.4487 - val_loss: 0.5705 - val_mse: 0.5705 - 36ms/epoch - 3ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.4473 - mse: 0.4473 - val_loss: 0.5694 - val_mse: 0.5694 - 38ms/epoch - 3ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.4449 - mse: 0.4449 - val_loss: 0.5689 - val_mse: 0.5689 - 38ms/epoch - 3ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.4457 - mse: 0.4457 - val_loss: 0.5671 - val_mse: 0.5671 - 33ms/epoch - 3ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.4439 - mse: 0.4439 - val_loss: 0.5625 - val_mse: 0.5625 - 42ms/epoch - 3ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.4397 - mse: 0.4397 - val_loss: 0.5651 - val_mse: 0.5651 - 45ms/epoch - 4ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.4392 - mse: 0.4392 - val_loss: 0.5615 - val_mse: 0.5615 - 38ms/epoch - 3ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.4363 - mse: 0.4363 - val_loss: 0.5623 - val_mse: 0.5623 - 41ms/epoch - 3ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.4343 - mse: 0.4343 - val_loss: 0.5597 - val_mse: 0.5597 - 38ms/epoch - 3ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.4338 - mse: 0.4338 - val_loss: 0.5587 - val_mse: 0.5587 - 40ms/epoch - 3ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.4308 - mse: 0.4308 - val_loss: 0.5604 - val_mse: 0.5604 - 40ms/epoch - 3ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.4302 - mse: 0.4302 - val_loss: 0.5553 - val_mse: 0.5553 - 40ms/epoch - 3ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.4287 - mse: 0.4287 - val_loss: 0.5534 - val_mse: 0.5534 - 41ms/epoch - 3ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.4278 - mse: 0.4278 - val_loss: 0.5514 - val_mse: 0.5514 - 37ms/epoch - 3ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.4301 - mse: 0.4301 - val_loss: 0.5576 - val_mse: 0.5576 - 41ms/epoch - 3ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.4323 - mse: 0.4323 - val_loss: 0.5489 - val_mse: 0.5489 - 40ms/epoch - 3ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.4248 - mse: 0.4248 - val_loss: 0.5563 - val_mse: 0.5563 - 39ms/epoch - 3ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.4194 - mse: 0.4194 - val_loss: 0.5453 - val_mse: 0.5453 - 45ms/epoch - 4ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.4189 - mse: 0.4189 - val_loss: 0.5465 - val_mse: 0.5465 - 41ms/epoch - 3ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.4189 - mse: 0.4189 - val_loss: 0.5455 - val_mse: 0.5455 - 40ms/epoch - 3ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.4181 - mse: 0.4181 - val_loss: 0.5428 - val_mse: 0.5428 - 39ms/epoch - 3ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.4140 - mse: 0.4140 - val_loss: 0.5424 - val_mse: 0.5424 - 41ms/epoch - 3ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.4116 - mse: 0.4116 - val_loss: 0.5393 - val_mse: 0.5393 - 38ms/epoch - 3ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.4096 - mse: 0.4096 - val_loss: 0.5416 - val_mse: 0.5416 - 42ms/epoch - 3ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.4116 - mse: 0.4116 - val_loss: 0.5397 - val_mse: 0.5397 - 36ms/epoch - 3ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.4097 - mse: 0.4097 - val_loss: 0.5321 - val_mse: 0.5321 - 43ms/epoch - 4ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.4058 - mse: 0.4058 - val_loss: 0.5374 - val_mse: 0.5374 - 45ms/epoch - 4ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.4036 - mse: 0.4036 - val_loss: 0.5326 - val_mse: 0.5326 - 35ms/epoch - 3ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.4016 - mse: 0.4016 - val_loss: 0.5324 - val_mse: 0.5324 - 48ms/epoch - 4ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.4002 - mse: 0.4002 - val_loss: 0.5275 - val_mse: 0.5275 - 41ms/epoch - 3ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.3983 - mse: 0.3983 - val_loss: 0.5289 - val_mse: 0.5289 - 41ms/epoch - 3ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.3965 - mse: 0.3965 - val_loss: 0.5284 - val_mse: 0.5284 - 42ms/epoch - 3ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.3969 - mse: 0.3969 - val_loss: 0.5286 - val_mse: 0.5286 - 38ms/epoch - 3ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.3939 - mse: 0.3939 - val_loss: 0.5268 - val_mse: 0.5268 - 40ms/epoch - 3ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.3920 - mse: 0.3920 - val_loss: 0.5270 - val_mse: 0.5270 - 41ms/epoch - 3ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.3915 - mse: 0.3915 - val_loss: 0.5224 - val_mse: 0.5224 - 39ms/epoch - 3ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.3902 - mse: 0.3902 - val_loss: 0.5225 - val_mse: 0.5225 - 41ms/epoch - 3ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.3876 - mse: 0.3876 - val_loss: 0.5221 - val_mse: 0.5221 - 36ms/epoch - 3ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.3872 - mse: 0.3872 - val_loss: 0.5184 - val_mse: 0.5184 - 47ms/epoch - 4ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.3840 - mse: 0.3840 - val_loss: 0.5217 - val_mse: 0.5217 - 38ms/epoch - 3ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.3836 - mse: 0.3836 - val_loss: 0.5182 - val_mse: 0.5182 - 42ms/epoch - 3ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.3822 - mse: 0.3822 - val_loss: 0.5168 - val_mse: 0.5168 - 44ms/epoch - 4ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.3800 - mse: 0.3800 - val_loss: 0.5108 - val_mse: 0.5108 - 32ms/epoch - 3ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.3790 - mse: 0.3790 - val_loss: 0.5117 - val_mse: 0.5117 - 38ms/epoch - 3ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.3766 - mse: 0.3766 - val_loss: 0.5103 - val_mse: 0.5103 - 38ms/epoch - 3ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.3766 - mse: 0.3766 - val_loss: 0.5073 - val_mse: 0.5073 - 39ms/epoch - 3ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.3737 - mse: 0.3737 - val_loss: 0.5121 - val_mse: 0.5121 - 39ms/epoch - 3ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.3717 - mse: 0.3717 - val_loss: 0.5065 - val_mse: 0.5065 - 34ms/epoch - 3ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.3744 - mse: 0.3744 - val_loss: 0.5086 - val_mse: 0.5086 - 45ms/epoch - 4ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.3692 - mse: 0.3692 - val_loss: 0.5045 - val_mse: 0.5045 - 53ms/epoch - 4ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.3672 - mse: 0.3672 - val_loss: 0.5065 - val_mse: 0.5065 - 53ms/epoch - 4ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.3665 - mse: 0.3665 - val_loss: 0.5032 - val_mse: 0.5032 - 46ms/epoch - 4ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.3651 - mse: 0.3651 - val_loss: 0.5010 - val_mse: 0.5010 - 36ms/epoch - 3ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.3647 - mse: 0.3647 - val_loss: 0.5000 - val_mse: 0.5000 - 38ms/epoch - 3ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.3612 - mse: 0.3612 - val_loss: 0.4962 - val_mse: 0.4962 - 38ms/epoch - 3ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.3605 - mse: 0.3605 - val_loss: 0.4991 - val_mse: 0.4991 - 37ms/epoch - 3ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.3585 - mse: 0.3585 - val_loss: 0.4967 - val_mse: 0.4967 - 39ms/epoch - 3ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.3585 - mse: 0.3585 - val_loss: 0.4945 - val_mse: 0.4945 - 32ms/epoch - 3ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.3566 - mse: 0.3566 - val_loss: 0.4940 - val_mse: 0.4940 - 38ms/epoch - 3ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.3544 - mse: 0.3544 - val_loss: 0.4942 - val_mse: 0.4942 - 37ms/epoch - 3ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.3532 - mse: 0.3532 - val_loss: 0.4906 - val_mse: 0.4906 - 37ms/epoch - 3ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.3544 - mse: 0.3544 - val_loss: 0.4915 - val_mse: 0.4915 - 39ms/epoch - 3ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.3524 - mse: 0.3524 - val_loss: 0.4902 - val_mse: 0.4902 - 37ms/epoch - 3ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.3501 - mse: 0.3501 - val_loss: 0.4845 - val_mse: 0.4845 - 36ms/epoch - 3ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.3488 - mse: 0.3488 - val_loss: 0.4926 - val_mse: 0.4926 - 43ms/epoch - 4ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.3487 - mse: 0.3487 - val_loss: 0.4838 - val_mse: 0.4838 - 43ms/epoch - 4ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.3455 - mse: 0.3455 - val_loss: 0.4893 - val_mse: 0.4893 - 41ms/epoch - 3ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.3442 - mse: 0.3442 - val_loss: 0.4829 - val_mse: 0.4829 - 40ms/epoch - 3ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.3430 - mse: 0.3430 - val_loss: 0.4825 - val_mse: 0.4825 - 44ms/epoch - 4ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.3431 - mse: 0.3431 - val_loss: 0.4801 - val_mse: 0.4801 - 44ms/epoch - 4ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.3412 - mse: 0.3412 - val_loss: 0.4806 - val_mse: 0.4806 - 39ms/epoch - 3ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.3389 - mse: 0.3389 - val_loss: 0.4802 - val_mse: 0.4802 - 38ms/epoch - 3ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.3374 - mse: 0.3374 - val_loss: 0.4758 - val_mse: 0.4758 - 34ms/epoch - 3ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.3353 - mse: 0.3353 - val_loss: 0.4774 - val_mse: 0.4774 - 38ms/epoch - 3ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.3344 - mse: 0.3344 - val_loss: 0.4760 - val_mse: 0.4760 - 47ms/epoch - 4ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.3327 - mse: 0.3327 - val_loss: 0.4740 - val_mse: 0.4740 - 36ms/epoch - 3ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.3321 - mse: 0.3321 - val_loss: 0.4737 - val_mse: 0.4737 - 50ms/epoch - 4ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.3308 - mse: 0.3308 - val_loss: 0.4736 - val_mse: 0.4736 - 44ms/epoch - 4ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.3308 - mse: 0.3308 - val_loss: 0.4740 - val_mse: 0.4740 - 39ms/epoch - 3ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.3283 - mse: 0.3283 - val_loss: 0.4746 - val_mse: 0.4746 - 44ms/epoch - 4ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.3266 - mse: 0.3266 - val_loss: 0.4744 - val_mse: 0.4744 - 40ms/epoch - 3ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.3271 - mse: 0.3271 - val_loss: 0.4723 - val_mse: 0.4723 - 39ms/epoch - 3ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.3278 - mse: 0.3278 - val_loss: 0.4687 - val_mse: 0.4687 - 41ms/epoch - 3ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.3243 - mse: 0.3243 - val_loss: 0.4680 - val_mse: 0.4680 - 38ms/epoch - 3ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.3243 - mse: 0.3243 - val_loss: 0.4659 - val_mse: 0.4659 - 36ms/epoch - 3ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.3226 - mse: 0.3226 - val_loss: 0.4638 - val_mse: 0.4638 - 33ms/epoch - 3ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.3231 - mse: 0.3231 - val_loss: 0.4641 - val_mse: 0.4641 - 42ms/epoch - 3ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.3207 - mse: 0.3207 - val_loss: 0.4620 - val_mse: 0.4620 - 37ms/epoch - 3ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.3191 - mse: 0.3191 - val_loss: 0.4682 - val_mse: 0.4682 - 36ms/epoch - 3ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.3165 - mse: 0.3165 - val_loss: 0.4605 - val_mse: 0.4605 - 38ms/epoch - 3ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.3172 - mse: 0.3172 - val_loss: 0.4644 - val_mse: 0.4644 - 41ms/epoch - 3ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.3146 - mse: 0.3146 - val_loss: 0.4610 - val_mse: 0.4610 - 38ms/epoch - 3ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.3133 - mse: 0.3133 - val_loss: 0.4585 - val_mse: 0.4585 - 38ms/epoch - 3ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.3131 - mse: 0.3131 - val_loss: 0.4607 - val_mse: 0.4607 - 40ms/epoch - 3ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.3105 - mse: 0.3105 - val_loss: 0.4578 - val_mse: 0.4578 - 41ms/epoch - 3ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.3098 - mse: 0.3098 - val_loss: 0.4546 - val_mse: 0.4546 - 41ms/epoch - 3ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.3086 - mse: 0.3086 - val_loss: 0.4571 - val_mse: 0.4571 - 37ms/epoch - 3ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.3077 - mse: 0.3077 - val_loss: 0.4547 - val_mse: 0.4547 - 43ms/epoch - 4ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.3074 - mse: 0.3074 - val_loss: 0.4542 - val_mse: 0.4542 - 46ms/epoch - 4ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.3059 - mse: 0.3059 - val_loss: 0.4534 - val_mse: 0.4534 - 41ms/epoch - 3ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.3056 - mse: 0.3056 - val_loss: 0.4526 - val_mse: 0.4526 - 39ms/epoch - 3ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.3036 - mse: 0.3036 - val_loss: 0.4518 - val_mse: 0.4518 - 47ms/epoch - 4ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.3014 - mse: 0.3014 - val_loss: 0.4518 - val_mse: 0.4518 - 58ms/epoch - 5ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.3000 - mse: 0.3000 - val_loss: 0.4470 - val_mse: 0.4470 - 42ms/epoch - 4ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.2987 - mse: 0.2987 - val_loss: 0.4467 - val_mse: 0.4467 - 41ms/epoch - 3ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.2978 - mse: 0.2978 - val_loss: 0.4422 - val_mse: 0.4422 - 41ms/epoch - 3ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.2970 - mse: 0.2970 - val_loss: 0.4427 - val_mse: 0.4427 - 34ms/epoch - 3ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.2970 - mse: 0.2970 - val_loss: 0.4413 - val_mse: 0.4413 - 37ms/epoch - 3ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.3001 - mse: 0.3001 - val_loss: 0.4407 - val_mse: 0.4407 - 43ms/epoch - 4ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.2950 - mse: 0.2950 - val_loss: 0.4386 - val_mse: 0.4386 - 36ms/epoch - 3ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.2922 - mse: 0.2922 - val_loss: 0.4379 - val_mse: 0.4379 - 38ms/epoch - 3ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.2909 - mse: 0.2909 - val_loss: 0.4362 - val_mse: 0.4362 - 35ms/epoch - 3ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.2903 - mse: 0.2903 - val_loss: 0.4351 - val_mse: 0.4351 - 37ms/epoch - 3ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.2908 - mse: 0.2908 - val_loss: 0.4342 - val_mse: 0.4342 - 36ms/epoch - 3ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.2875 - mse: 0.2875 - val_loss: 0.4328 - val_mse: 0.4328 - 36ms/epoch - 3ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.2856 - mse: 0.2856 - val_loss: 0.4345 - val_mse: 0.4345 - 39ms/epoch - 3ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.2854 - mse: 0.2854 - val_loss: 0.4337 - val_mse: 0.4337 - 33ms/epoch - 3ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.2845 - mse: 0.2845 - val_loss: 0.4285 - val_mse: 0.4285 - 38ms/epoch - 3ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.2818 - mse: 0.2818 - val_loss: 0.4305 - val_mse: 0.4305 - 45ms/epoch - 4ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.2808 - mse: 0.2808 - val_loss: 0.4268 - val_mse: 0.4268 - 37ms/epoch - 3ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.2818 - mse: 0.2818 - val_loss: 0.4288 - val_mse: 0.4288 - 38ms/epoch - 3ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.2831 - mse: 0.2831 - val_loss: 0.4258 - val_mse: 0.4258 - 39ms/epoch - 3ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.2775 - mse: 0.2775 - val_loss: 0.4255 - val_mse: 0.4255 - 39ms/epoch - 3ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.2760 - mse: 0.2760 - val_loss: 0.4234 - val_mse: 0.4234 - 39ms/epoch - 3ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.2774 - mse: 0.2774 - val_loss: 0.4222 - val_mse: 0.4222 - 36ms/epoch - 3ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.2730 - mse: 0.2730 - val_loss: 0.4203 - val_mse: 0.4203 - 38ms/epoch - 3ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.2718 - mse: 0.2718 - val_loss: 0.4203 - val_mse: 0.4203 - 37ms/epoch - 3ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.2719 - mse: 0.2719 - val_loss: 0.4175 - val_mse: 0.4175 - 37ms/epoch - 3ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.2704 - mse: 0.2704 - val_loss: 0.4167 - val_mse: 0.4167 - 34ms/epoch - 3ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.2706 - mse: 0.2706 - val_loss: 0.4174 - val_mse: 0.4174 - 40ms/epoch - 3ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.2681 - mse: 0.2681 - val_loss: 0.4140 - val_mse: 0.4140 - 35ms/epoch - 3ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.2665 - mse: 0.2665 - val_loss: 0.4109 - val_mse: 0.4109 - 39ms/epoch - 3ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.2652 - mse: 0.2652 - val_loss: 0.4120 - val_mse: 0.4120 - 37ms/epoch - 3ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.2637 - mse: 0.2637 - val_loss: 0.4115 - val_mse: 0.4115 - 41ms/epoch - 3ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.2616 - mse: 0.2616 - val_loss: 0.4081 - val_mse: 0.4081 - 38ms/epoch - 3ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.2610 - mse: 0.2610 - val_loss: 0.4089 - val_mse: 0.4089 - 40ms/epoch - 3ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.2605 - mse: 0.2605 - val_loss: 0.4053 - val_mse: 0.4053 - 39ms/epoch - 3ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.2604 - mse: 0.2604 - val_loss: 0.4040 - val_mse: 0.4040 - 39ms/epoch - 3ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.2605 - mse: 0.2605 - val_loss: 0.4049 - val_mse: 0.4049 - 35ms/epoch - 3ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.2585 - mse: 0.2585 - val_loss: 0.4007 - val_mse: 0.4007 - 41ms/epoch - 3ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.2561 - mse: 0.2561 - val_loss: 0.4018 - val_mse: 0.4018 - 37ms/epoch - 3ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.2574 - mse: 0.2574 - val_loss: 0.3957 - val_mse: 0.3957 - 37ms/epoch - 3ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.2521 - mse: 0.2521 - val_loss: 0.4018 - val_mse: 0.4018 - 40ms/epoch - 3ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 0.2506 - mse: 0.2506 - val_loss: 0.3925 - val_mse: 0.3925 - 35ms/epoch - 3ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 0.2502 - mse: 0.2502 - val_loss: 0.3948 - val_mse: 0.3948 - 38ms/epoch - 3ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 0.2483 - mse: 0.2483 - val_loss: 0.3901 - val_mse: 0.3901 - 38ms/epoch - 3ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 0.2478 - mse: 0.2478 - val_loss: 0.3922 - val_mse: 0.3922 - 40ms/epoch - 3ms/step
# Epoch 251/2000
# 12/12 - 0s - loss: 0.2448 - mse: 0.2448 - val_loss: 0.3873 - val_mse: 0.3873 - 36ms/epoch - 3ms/step
# Epoch 252/2000
# 12/12 - 0s - loss: 0.2445 - mse: 0.2445 - val_loss: 0.3841 - val_mse: 0.3841 - 40ms/epoch - 3ms/step
# Epoch 253/2000
# 12/12 - 0s - loss: 0.2439 - mse: 0.2439 - val_loss: 0.3874 - val_mse: 0.3874 - 36ms/epoch - 3ms/step
# Epoch 254/2000
# 12/12 - 0s - loss: 0.2418 - mse: 0.2418 - val_loss: 0.3836 - val_mse: 0.3836 - 36ms/epoch - 3ms/step
# Epoch 255/2000
# 12/12 - 0s - loss: 0.2428 - mse: 0.2428 - val_loss: 0.3885 - val_mse: 0.3885 - 39ms/epoch - 3ms/step
# Epoch 256/2000
# 12/12 - 0s - loss: 0.2441 - mse: 0.2441 - val_loss: 0.3871 - val_mse: 0.3871 - 42ms/epoch - 3ms/step
# Epoch 257/2000
# 12/12 - 0s - loss: 0.2407 - mse: 0.2407 - val_loss: 0.3831 - val_mse: 0.3831 - 40ms/epoch - 3ms/step
# Epoch 258/2000
# 12/12 - 0s - loss: 0.2371 - mse: 0.2371 - val_loss: 0.3804 - val_mse: 0.3804 - 34ms/epoch - 3ms/step
# Epoch 259/2000
# 12/12 - 0s - loss: 0.2356 - mse: 0.2356 - val_loss: 0.3804 - val_mse: 0.3804 - 37ms/epoch - 3ms/step
# Epoch 260/2000
# 12/12 - 0s - loss: 0.2354 - mse: 0.2354 - val_loss: 0.3815 - val_mse: 0.3815 - 41ms/epoch - 3ms/step
# Epoch 261/2000
# 12/12 - 0s - loss: 0.2332 - mse: 0.2332 - val_loss: 0.3780 - val_mse: 0.3780 - 36ms/epoch - 3ms/step
# Epoch 262/2000
# 12/12 - 0s - loss: 0.2320 - mse: 0.2320 - val_loss: 0.3763 - val_mse: 0.3763 - 37ms/epoch - 3ms/step
# Epoch 263/2000
# 12/12 - 0s - loss: 0.2310 - mse: 0.2310 - val_loss: 0.3745 - val_mse: 0.3745 - 32ms/epoch - 3ms/step
# Epoch 264/2000
# 12/12 - 0s - loss: 0.2299 - mse: 0.2299 - val_loss: 0.3751 - val_mse: 0.3751 - 40ms/epoch - 3ms/step
# Epoch 265/2000
# 12/12 - 0s - loss: 0.2287 - mse: 0.2287 - val_loss: 0.3722 - val_mse: 0.3722 - 43ms/epoch - 4ms/step
# Epoch 266/2000
# 12/12 - 0s - loss: 0.2285 - mse: 0.2285 - val_loss: 0.3693 - val_mse: 0.3693 - 49ms/epoch - 4ms/step
# Epoch 267/2000
# 12/12 - 0s - loss: 0.2275 - mse: 0.2275 - val_loss: 0.3697 - val_mse: 0.3697 - 47ms/epoch - 4ms/step
# Epoch 268/2000
# 12/12 - 0s - loss: 0.2261 - mse: 0.2261 - val_loss: 0.3681 - val_mse: 0.3681 - 46ms/epoch - 4ms/step
# Epoch 269/2000
# 12/12 - 0s - loss: 0.2232 - mse: 0.2232 - val_loss: 0.3671 - val_mse: 0.3671 - 39ms/epoch - 3ms/step
# Epoch 270/2000
# 12/12 - 0s - loss: 0.2226 - mse: 0.2226 - val_loss: 0.3639 - val_mse: 0.3639 - 37ms/epoch - 3ms/step
# Epoch 271/2000
# 12/12 - 0s - loss: 0.2216 - mse: 0.2216 - val_loss: 0.3697 - val_mse: 0.3697 - 50ms/epoch - 4ms/step
# Epoch 272/2000
# 12/12 - 0s - loss: 0.2203 - mse: 0.2203 - val_loss: 0.3629 - val_mse: 0.3629 - 39ms/epoch - 3ms/step
# Epoch 273/2000
# 12/12 - 0s - loss: 0.2199 - mse: 0.2199 - val_loss: 0.3652 - val_mse: 0.3652 - 38ms/epoch - 3ms/step
# Epoch 274/2000
# 12/12 - 0s - loss: 0.2215 - mse: 0.2215 - val_loss: 0.3615 - val_mse: 0.3615 - 36ms/epoch - 3ms/step
# Epoch 275/2000
# 12/12 - 0s - loss: 0.2174 - mse: 0.2174 - val_loss: 0.3594 - val_mse: 0.3594 - 40ms/epoch - 3ms/step
# Epoch 276/2000
# 12/12 - 0s - loss: 0.2164 - mse: 0.2164 - val_loss: 0.3587 - val_mse: 0.3587 - 50ms/epoch - 4ms/step
# Epoch 277/2000
# 12/12 - 0s - loss: 0.2150 - mse: 0.2150 - val_loss: 0.3579 - val_mse: 0.3579 - 45ms/epoch - 4ms/step
# Epoch 278/2000
# 12/12 - 0s - loss: 0.2131 - mse: 0.2131 - val_loss: 0.3560 - val_mse: 0.3560 - 34ms/epoch - 3ms/step
# Epoch 279/2000
# 12/12 - 0s - loss: 0.2118 - mse: 0.2118 - val_loss: 0.3529 - val_mse: 0.3529 - 39ms/epoch - 3ms/step
# Epoch 280/2000
# 12/12 - 0s - loss: 0.2101 - mse: 0.2101 - val_loss: 0.3517 - val_mse: 0.3517 - 38ms/epoch - 3ms/step
# Epoch 281/2000
# 12/12 - 0s - loss: 0.2100 - mse: 0.2100 - val_loss: 0.3503 - val_mse: 0.3503 - 36ms/epoch - 3ms/step
# Epoch 282/2000
# 12/12 - 0s - loss: 0.2089 - mse: 0.2089 - val_loss: 0.3496 - val_mse: 0.3496 - 36ms/epoch - 3ms/step
# Epoch 283/2000
# 12/12 - 0s - loss: 0.2077 - mse: 0.2077 - val_loss: 0.3489 - val_mse: 0.3489 - 38ms/epoch - 3ms/step
# Epoch 284/2000
# 12/12 - 0s - loss: 0.2056 - mse: 0.2056 - val_loss: 0.3479 - val_mse: 0.3479 - 36ms/epoch - 3ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 0.2048 - mse: 0.2048 - val_loss: 0.3461 - val_mse: 0.3461 - 35ms/epoch - 3ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 0.2039 - mse: 0.2039 - val_loss: 0.3483 - val_mse: 0.3483 - 48ms/epoch - 4ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 0.2019 - mse: 0.2019 - val_loss: 0.3420 - val_mse: 0.3420 - 36ms/epoch - 3ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 0.2017 - mse: 0.2017 - val_loss: 0.3447 - val_mse: 0.3447 - 38ms/epoch - 3ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 0.2000 - mse: 0.2000 - val_loss: 0.3396 - val_mse: 0.3396 - 36ms/epoch - 3ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 0.2001 - mse: 0.2001 - val_loss: 0.3406 - val_mse: 0.3406 - 36ms/epoch - 3ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 0.2008 - mse: 0.2008 - val_loss: 0.3409 - val_mse: 0.3409 - 45ms/epoch - 4ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 0.1974 - mse: 0.1974 - val_loss: 0.3389 - val_mse: 0.3389 - 47ms/epoch - 4ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 0.1976 - mse: 0.1976 - val_loss: 0.3363 - val_mse: 0.3363 - 34ms/epoch - 3ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 0.1965 - mse: 0.1965 - val_loss: 0.3346 - val_mse: 0.3346 - 39ms/epoch - 3ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 0.1937 - mse: 0.1937 - val_loss: 0.3358 - val_mse: 0.3358 - 38ms/epoch - 3ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 0.1921 - mse: 0.1921 - val_loss: 0.3342 - val_mse: 0.3342 - 39ms/epoch - 3ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 0.1924 - mse: 0.1924 - val_loss: 0.3292 - val_mse: 0.3292 - 43ms/epoch - 4ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 0.1892 - mse: 0.1892 - val_loss: 0.3312 - val_mse: 0.3312 - 39ms/epoch - 3ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 0.1892 - mse: 0.1892 - val_loss: 0.3273 - val_mse: 0.3273 - 45ms/epoch - 4ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 0.1879 - mse: 0.1879 - val_loss: 0.3305 - val_mse: 0.3305 - 43ms/epoch - 4ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 0.1869 - mse: 0.1869 - val_loss: 0.3280 - val_mse: 0.3280 - 45ms/epoch - 4ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 0.1877 - mse: 0.1877 - val_loss: 0.3296 - val_mse: 0.3296 - 50ms/epoch - 4ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 0.1856 - mse: 0.1856 - val_loss: 0.3228 - val_mse: 0.3228 - 42ms/epoch - 3ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 0.1854 - mse: 0.1854 - val_loss: 0.3209 - val_mse: 0.3209 - 37ms/epoch - 3ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 0.1842 - mse: 0.1842 - val_loss: 0.3269 - val_mse: 0.3269 - 40ms/epoch - 3ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 0.1823 - mse: 0.1823 - val_loss: 0.3176 - val_mse: 0.3176 - 42ms/epoch - 3ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 0.1816 - mse: 0.1816 - val_loss: 0.3188 - val_mse: 0.3188 - 39ms/epoch - 3ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 0.1803 - mse: 0.1803 - val_loss: 0.3158 - val_mse: 0.3158 - 41ms/epoch - 3ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 0.1782 - mse: 0.1782 - val_loss: 0.3139 - val_mse: 0.3139 - 43ms/epoch - 4ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 0.1767 - mse: 0.1767 - val_loss: 0.3107 - val_mse: 0.3107 - 46ms/epoch - 4ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 0.1760 - mse: 0.1760 - val_loss: 0.3079 - val_mse: 0.3079 - 41ms/epoch - 3ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 0.1747 - mse: 0.1747 - val_loss: 0.3085 - val_mse: 0.3085 - 40ms/epoch - 3ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 0.1752 - mse: 0.1752 - val_loss: 0.3065 - val_mse: 0.3065 - 41ms/epoch - 3ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 0.1725 - mse: 0.1725 - val_loss: 0.3078 - val_mse: 0.3078 - 49ms/epoch - 4ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 0.1733 - mse: 0.1733 - val_loss: 0.3049 - val_mse: 0.3049 - 39ms/epoch - 3ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 0.1716 - mse: 0.1716 - val_loss: 0.3030 - val_mse: 0.3030 - 62ms/epoch - 5ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 0.1714 - mse: 0.1714 - val_loss: 0.3006 - val_mse: 0.3006 - 46ms/epoch - 4ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 0.1694 - mse: 0.1694 - val_loss: 0.2999 - val_mse: 0.2999 - 38ms/epoch - 3ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 0.1675 - mse: 0.1675 - val_loss: 0.3011 - val_mse: 0.3011 - 36ms/epoch - 3ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 0.1660 - mse: 0.1660 - val_loss: 0.3004 - val_mse: 0.3004 - 39ms/epoch - 3ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 0.1653 - mse: 0.1653 - val_loss: 0.2937 - val_mse: 0.2937 - 39ms/epoch - 3ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 0.1646 - mse: 0.1646 - val_loss: 0.2959 - val_mse: 0.2959 - 35ms/epoch - 3ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 0.1639 - mse: 0.1639 - val_loss: 0.2931 - val_mse: 0.2931 - 50ms/epoch - 4ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 0.1623 - mse: 0.1623 - val_loss: 0.2933 - val_mse: 0.2933 - 36ms/epoch - 3ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 0.1624 - mse: 0.1624 - val_loss: 0.2913 - val_mse: 0.2913 - 38ms/epoch - 3ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 0.1620 - mse: 0.1620 - val_loss: 0.2909 - val_mse: 0.2909 - 38ms/epoch - 3ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 0.1609 - mse: 0.1609 - val_loss: 0.2880 - val_mse: 0.2880 - 36ms/epoch - 3ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 0.1584 - mse: 0.1584 - val_loss: 0.2879 - val_mse: 0.2879 - 44ms/epoch - 4ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 0.1572 - mse: 0.1572 - val_loss: 0.2853 - val_mse: 0.2853 - 42ms/epoch - 3ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 0.1567 - mse: 0.1567 - val_loss: 0.2863 - val_mse: 0.2863 - 38ms/epoch - 3ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 0.1555 - mse: 0.1555 - val_loss: 0.2823 - val_mse: 0.2823 - 36ms/epoch - 3ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 0.1540 - mse: 0.1540 - val_loss: 0.2807 - val_mse: 0.2807 - 37ms/epoch - 3ms/step
# Epoch 333/2000
# 12/12 - 0s - loss: 0.1546 - mse: 0.1546 - val_loss: 0.2780 - val_mse: 0.2780 - 39ms/epoch - 3ms/step
# Epoch 334/2000
# 12/12 - 0s - loss: 0.1521 - mse: 0.1521 - val_loss: 0.2796 - val_mse: 0.2796 - 35ms/epoch - 3ms/step
# Epoch 335/2000
# 12/12 - 0s - loss: 0.1512 - mse: 0.1512 - val_loss: 0.2761 - val_mse: 0.2761 - 38ms/epoch - 3ms/step
# Epoch 336/2000
# 12/12 - 0s - loss: 0.1504 - mse: 0.1504 - val_loss: 0.2776 - val_mse: 0.2776 - 46ms/epoch - 4ms/step
# Epoch 337/2000
# 12/12 - 0s - loss: 0.1485 - mse: 0.1485 - val_loss: 0.2730 - val_mse: 0.2730 - 44ms/epoch - 4ms/step
# Epoch 338/2000
# 12/12 - 0s - loss: 0.1478 - mse: 0.1478 - val_loss: 0.2723 - val_mse: 0.2723 - 37ms/epoch - 3ms/step
# Epoch 339/2000
# 12/12 - 0s - loss: 0.1460 - mse: 0.1460 - val_loss: 0.2745 - val_mse: 0.2745 - 37ms/epoch - 3ms/step
# Epoch 340/2000
# 12/12 - 0s - loss: 0.1465 - mse: 0.1465 - val_loss: 0.2700 - val_mse: 0.2700 - 39ms/epoch - 3ms/step
# Epoch 341/2000
# 12/12 - 0s - loss: 0.1452 - mse: 0.1452 - val_loss: 0.2704 - val_mse: 0.2704 - 46ms/epoch - 4ms/step
# Epoch 342/2000
# 12/12 - 0s - loss: 0.1456 - mse: 0.1456 - val_loss: 0.2674 - val_mse: 0.2674 - 48ms/epoch - 4ms/step
# Epoch 343/2000
# 12/12 - 0s - loss: 0.1426 - mse: 0.1426 - val_loss: 0.2680 - val_mse: 0.2680 - 32ms/epoch - 3ms/step
# Epoch 344/2000
# 12/12 - 0s - loss: 0.1427 - mse: 0.1427 - val_loss: 0.2674 - val_mse: 0.2674 - 40ms/epoch - 3ms/step
# Epoch 345/2000
# 12/12 - 0s - loss: 0.1422 - mse: 0.1422 - val_loss: 0.2665 - val_mse: 0.2665 - 41ms/epoch - 3ms/step
# Epoch 346/2000
# 12/12 - 0s - loss: 0.1410 - mse: 0.1410 - val_loss: 0.2638 - val_mse: 0.2638 - 38ms/epoch - 3ms/step
# Epoch 347/2000
# 12/12 - 0s - loss: 0.1397 - mse: 0.1397 - val_loss: 0.2628 - val_mse: 0.2628 - 49ms/epoch - 4ms/step
# Epoch 348/2000
# 12/12 - 0s - loss: 0.1398 - mse: 0.1398 - val_loss: 0.2623 - val_mse: 0.2623 - 45ms/epoch - 4ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 0.1388 - mse: 0.1388 - val_loss: 0.2596 - val_mse: 0.2596 - 38ms/epoch - 3ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 0.1368 - mse: 0.1368 - val_loss: 0.2626 - val_mse: 0.2626 - 47ms/epoch - 4ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 0.1359 - mse: 0.1359 - val_loss: 0.2602 - val_mse: 0.2602 - 38ms/epoch - 3ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 0.1374 - mse: 0.1374 - val_loss: 0.2570 - val_mse: 0.2570 - 42ms/epoch - 3ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 0.1342 - mse: 0.1342 - val_loss: 0.2588 - val_mse: 0.2588 - 41ms/epoch - 3ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 0.1337 - mse: 0.1337 - val_loss: 0.2533 - val_mse: 0.2533 - 36ms/epoch - 3ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 0.1331 - mse: 0.1331 - val_loss: 0.2535 - val_mse: 0.2535 - 42ms/epoch - 3ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 0.1319 - mse: 0.1319 - val_loss: 0.2534 - val_mse: 0.2534 - 37ms/epoch - 3ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 0.1320 - mse: 0.1320 - val_loss: 0.2551 - val_mse: 0.2551 - 36ms/epoch - 3ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 0.1309 - mse: 0.1309 - val_loss: 0.2504 - val_mse: 0.2504 - 40ms/epoch - 3ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 0.1290 - mse: 0.1290 - val_loss: 0.2517 - val_mse: 0.2517 - 37ms/epoch - 3ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 0.1282 - mse: 0.1282 - val_loss: 0.2489 - val_mse: 0.2489 - 36ms/epoch - 3ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 0.1273 - mse: 0.1273 - val_loss: 0.2478 - val_mse: 0.2478 - 38ms/epoch - 3ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 0.1269 - mse: 0.1269 - val_loss: 0.2451 - val_mse: 0.2451 - 35ms/epoch - 3ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 0.1257 - mse: 0.1257 - val_loss: 0.2445 - val_mse: 0.2445 - 38ms/epoch - 3ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 0.1268 - mse: 0.1268 - val_loss: 0.2442 - val_mse: 0.2442 - 43ms/epoch - 4ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 0.1269 - mse: 0.1269 - val_loss: 0.2421 - val_mse: 0.2421 - 39ms/epoch - 3ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 0.1234 - mse: 0.1234 - val_loss: 0.2410 - val_mse: 0.2410 - 39ms/epoch - 3ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 0.1224 - mse: 0.1224 - val_loss: 0.2408 - val_mse: 0.2408 - 44ms/epoch - 4ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 0.1238 - mse: 0.1238 - val_loss: 0.2404 - val_mse: 0.2404 - 42ms/epoch - 4ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 0.1220 - mse: 0.1220 - val_loss: 0.2392 - val_mse: 0.2392 - 38ms/epoch - 3ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 0.1207 - mse: 0.1207 - val_loss: 0.2378 - val_mse: 0.2378 - 36ms/epoch - 3ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 0.1210 - mse: 0.1210 - val_loss: 0.2386 - val_mse: 0.2386 - 38ms/epoch - 3ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 0.1210 - mse: 0.1210 - val_loss: 0.2385 - val_mse: 0.2385 - 40ms/epoch - 3ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 0.1192 - mse: 0.1192 - val_loss: 0.2367 - val_mse: 0.2367 - 38ms/epoch - 3ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 0.1170 - mse: 0.1170 - val_loss: 0.2353 - val_mse: 0.2353 - 39ms/epoch - 3ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 0.1171 - mse: 0.1171 - val_loss: 0.2346 - val_mse: 0.2346 - 38ms/epoch - 3ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 0.1155 - mse: 0.1155 - val_loss: 0.2355 - val_mse: 0.2355 - 43ms/epoch - 4ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 0.1162 - mse: 0.1162 - val_loss: 0.2331 - val_mse: 0.2331 - 38ms/epoch - 3ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 0.1151 - mse: 0.1151 - val_loss: 0.2335 - val_mse: 0.2335 - 39ms/epoch - 3ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 0.1151 - mse: 0.1151 - val_loss: 0.2348 - val_mse: 0.2348 - 41ms/epoch - 3ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 0.1138 - mse: 0.1138 - val_loss: 0.2261 - val_mse: 0.2261 - 39ms/epoch - 3ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 0.1129 - mse: 0.1129 - val_loss: 0.2304 - val_mse: 0.2304 - 41ms/epoch - 3ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 0.1106 - mse: 0.1106 - val_loss: 0.2252 - val_mse: 0.2252 - 38ms/epoch - 3ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 0.1113 - mse: 0.1113 - val_loss: 0.2261 - val_mse: 0.2261 - 39ms/epoch - 3ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 0.1098 - mse: 0.1098 - val_loss: 0.2241 - val_mse: 0.2241 - 38ms/epoch - 3ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 0.1094 - mse: 0.1094 - val_loss: 0.2272 - val_mse: 0.2272 - 38ms/epoch - 3ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 0.1089 - mse: 0.1089 - val_loss: 0.2248 - val_mse: 0.2248 - 46ms/epoch - 4ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 0.1086 - mse: 0.1086 - val_loss: 0.2242 - val_mse: 0.2242 - 56ms/epoch - 5ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 0.1087 - mse: 0.1087 - val_loss: 0.2230 - val_mse: 0.2230 - 45ms/epoch - 4ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 0.1078 - mse: 0.1078 - val_loss: 0.2228 - val_mse: 0.2228 - 42ms/epoch - 3ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 0.1085 - mse: 0.1085 - val_loss: 0.2253 - val_mse: 0.2253 - 40ms/epoch - 3ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 0.1066 - mse: 0.1066 - val_loss: 0.2224 - val_mse: 0.2224 - 40ms/epoch - 3ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 0.1057 - mse: 0.1057 - val_loss: 0.2203 - val_mse: 0.2203 - 46ms/epoch - 4ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 0.1045 - mse: 0.1045 - val_loss: 0.2185 - val_mse: 0.2185 - 51ms/epoch - 4ms/step
# Epoch 394/2000
# 12/12 - 0s - loss: 0.1040 - mse: 0.1040 - val_loss: 0.2150 - val_mse: 0.2150 - 40ms/epoch - 3ms/step
# Epoch 395/2000
# 12/12 - 0s - loss: 0.1035 - mse: 0.1035 - val_loss: 0.2159 - val_mse: 0.2159 - 47ms/epoch - 4ms/step
# Epoch 396/2000
# 12/12 - 0s - loss: 0.1027 - mse: 0.1027 - val_loss: 0.2147 - val_mse: 0.2147 - 37ms/epoch - 3ms/step
# Epoch 397/2000
# 12/12 - 0s - loss: 0.1022 - mse: 0.1022 - val_loss: 0.2162 - val_mse: 0.2162 - 39ms/epoch - 3ms/step
# Epoch 398/2000
# 12/12 - 0s - loss: 0.1021 - mse: 0.1021 - val_loss: 0.2127 - val_mse: 0.2127 - 41ms/epoch - 3ms/step
# Epoch 399/2000
# 12/12 - 0s - loss: 0.1012 - mse: 0.1012 - val_loss: 0.2153 - val_mse: 0.2153 - 43ms/epoch - 4ms/step
# Epoch 400/2000
# 12/12 - 0s - loss: 0.1004 - mse: 0.1004 - val_loss: 0.2133 - val_mse: 0.2133 - 38ms/epoch - 3ms/step
# Epoch 401/2000
# 12/12 - 0s - loss: 0.0995 - mse: 0.0995 - val_loss: 0.2152 - val_mse: 0.2152 - 43ms/epoch - 4ms/step
# Epoch 402/2000
# 12/12 - 0s - loss: 0.0991 - mse: 0.0991 - val_loss: 0.2117 - val_mse: 0.2117 - 42ms/epoch - 3ms/step
# Epoch 403/2000
# 12/12 - 0s - loss: 0.0990 - mse: 0.0990 - val_loss: 0.2107 - val_mse: 0.2107 - 41ms/epoch - 3ms/step
# Epoch 404/2000
# 12/12 - 0s - loss: 0.0982 - mse: 0.0982 - val_loss: 0.2130 - val_mse: 0.2130 - 38ms/epoch - 3ms/step
# Epoch 405/2000
# 12/12 - 0s - loss: 0.0987 - mse: 0.0987 - val_loss: 0.2140 - val_mse: 0.2140 - 37ms/epoch - 3ms/step
# Epoch 406/2000
# 12/12 - 0s - loss: 0.0964 - mse: 0.0964 - val_loss: 0.2076 - val_mse: 0.2076 - 37ms/epoch - 3ms/step
# Epoch 407/2000
# 12/12 - 0s - loss: 0.0972 - mse: 0.0972 - val_loss: 0.2068 - val_mse: 0.2068 - 38ms/epoch - 3ms/step
# Epoch 408/2000
# 12/12 - 0s - loss: 0.0967 - mse: 0.0967 - val_loss: 0.2066 - val_mse: 0.2066 - 39ms/epoch - 3ms/step
# Epoch 409/2000
# 12/12 - 0s - loss: 0.0962 - mse: 0.0962 - val_loss: 0.2076 - val_mse: 0.2076 - 39ms/epoch - 3ms/step
# Epoch 410/2000
# 12/12 - 0s - loss: 0.0953 - mse: 0.0953 - val_loss: 0.2059 - val_mse: 0.2059 - 38ms/epoch - 3ms/step
# Epoch 411/2000
# 12/12 - 0s - loss: 0.0947 - mse: 0.0947 - val_loss: 0.2090 - val_mse: 0.2090 - 43ms/epoch - 4ms/step
# Epoch 412/2000
# 12/12 - 0s - loss: 0.0950 - mse: 0.0950 - val_loss: 0.2073 - val_mse: 0.2073 - 39ms/epoch - 3ms/step
# Epoch 413/2000
# 12/12 - 0s - loss: 0.0946 - mse: 0.0946 - val_loss: 0.2077 - val_mse: 0.2077 - 38ms/epoch - 3ms/step
# Epoch 414/2000
# 12/12 - 0s - loss: 0.0924 - mse: 0.0924 - val_loss: 0.2019 - val_mse: 0.2019 - 43ms/epoch - 4ms/step
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 12/12 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0202 - val_mse: 0.0202 - 66ms/epoch - 5ms/step
# Epoch 1866/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0194 - val_mse: 0.0194 - 62ms/epoch - 5ms/step
# Epoch 1867/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0199 - val_mse: 0.0199 - 58ms/epoch - 5ms/step
# Epoch 1868/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0189 - val_mse: 0.0189 - 61ms/epoch - 5ms/step
# Epoch 1869/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0194 - val_mse: 0.0194 - 57ms/epoch - 5ms/step
# Epoch 1870/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0223 - val_mse: 0.0223 - 58ms/epoch - 5ms/step
# Epoch 1871/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0191 - val_mse: 0.0191 - 57ms/epoch - 5ms/step
# Epoch 1872/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0211 - val_mse: 0.0211 - 56ms/epoch - 5ms/step
# Epoch 1873/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0200 - val_mse: 0.0200 - 60ms/epoch - 5ms/step
# Epoch 1874/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0201 - val_mse: 0.0201 - 62ms/epoch - 5ms/step
# Epoch 1875/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0192 - val_mse: 0.0192 - 56ms/epoch - 5ms/step
# Epoch 1876/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0203 - val_mse: 0.0203 - 63ms/epoch - 5ms/step
# Epoch 1877/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0196 - val_mse: 0.0196 - 54ms/epoch - 4ms/step
# Epoch 1878/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0199 - val_mse: 0.0199 - 58ms/epoch - 5ms/step
# Epoch 1879/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0198 - val_mse: 0.0198 - 55ms/epoch - 5ms/step
# Epoch 1880/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0195 - val_mse: 0.0195 - 87ms/epoch - 7ms/step
# Epoch 1881/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0198 - val_mse: 0.0198 - 69ms/epoch - 6ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0191 - val_mse: 0.0191 - 69ms/epoch - 6ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0184 - val_mse: 0.0184 - 69ms/epoch - 6ms/step
# Epoch 1884/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0206 - val_mse: 0.0206 - 70ms/epoch - 6ms/step
# Epoch 1885/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0182 - val_mse: 0.0182 - 64ms/epoch - 5ms/step
# Epoch 1886/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0202 - val_mse: 0.0202 - 65ms/epoch - 5ms/step
# Epoch 1887/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0192 - val_mse: 0.0192 - 61ms/epoch - 5ms/step
# Epoch 1888/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0190 - val_mse: 0.0190 - 69ms/epoch - 6ms/step
# Epoch 1889/2000
# 12/12 - 0s - loss: 0.0052 - mse: 0.0052 - val_loss: 0.0223 - val_mse: 0.0223 - 62ms/epoch - 5ms/step
# Epoch 1890/2000
# 12/12 - 0s - loss: 0.0062 - mse: 0.0062 - val_loss: 0.0198 - val_mse: 0.0198 - 82ms/epoch - 7ms/step
# Epoch 1891/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0205 - val_mse: 0.0205 - 83ms/epoch - 7ms/step
# Epoch 1892/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0206 - val_mse: 0.0206 - 66ms/epoch - 5ms/step
# Epoch 1893/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0200 - val_mse: 0.0200 - 76ms/epoch - 6ms/step
# Epoch 1894/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0195 - val_mse: 0.0195 - 65ms/epoch - 5ms/step
# Epoch 1895/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0201 - val_mse: 0.0201 - 61ms/epoch - 5ms/step
# Epoch 1896/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0202 - val_mse: 0.0202 - 58ms/epoch - 5ms/step
# Epoch 1897/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0187 - val_mse: 0.0187 - 61ms/epoch - 5ms/step
# Epoch 1898/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0196 - val_mse: 0.0196 - 64ms/epoch - 5ms/step
# Epoch 1899/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0193 - val_mse: 0.0193 - 76ms/epoch - 6ms/step
# Epoch 1900/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0191 - val_mse: 0.0191 - 76ms/epoch - 6ms/step
# Epoch 1901/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0196 - val_mse: 0.0196 - 94ms/epoch - 8ms/step
# Epoch 1902/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0197 - val_mse: 0.0197 - 78ms/epoch - 6ms/step
# Epoch 1903/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0194 - val_mse: 0.0194 - 72ms/epoch - 6ms/step
# Epoch 1904/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0197 - val_mse: 0.0197 - 79ms/epoch - 7ms/step
# Epoch 1905/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0189 - val_mse: 0.0189 - 84ms/epoch - 7ms/step
# Epoch 1906/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0204 - val_mse: 0.0204 - 70ms/epoch - 6ms/step
# Epoch 1907/2000
# 12/12 - 0s - loss: 0.0051 - mse: 0.0051 - val_loss: 0.0209 - val_mse: 0.0209 - 67ms/epoch - 6ms/step
# Epoch 1908/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0195 - val_mse: 0.0195 - 63ms/epoch - 5ms/step
# Epoch 1909/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0208 - val_mse: 0.0208 - 63ms/epoch - 5ms/step
# Epoch 1910/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0206 - val_mse: 0.0206 - 65ms/epoch - 5ms/step
# Epoch 1911/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0197 - val_mse: 0.0197 - 53ms/epoch - 4ms/step
# Epoch 1912/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0184 - val_mse: 0.0184 - 62ms/epoch - 5ms/step
# Epoch 1913/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0198 - val_mse: 0.0198 - 59ms/epoch - 5ms/step
# Epoch 1914/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0188 - val_mse: 0.0188 - 52ms/epoch - 4ms/step
# Epoch 1915/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0190 - val_mse: 0.0190 - 57ms/epoch - 5ms/step
# Epoch 1916/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0210 - val_mse: 0.0210 - 52ms/epoch - 4ms/step
# Epoch 1917/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0186 - val_mse: 0.0186 - 55ms/epoch - 5ms/step
# Epoch 1918/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0202 - val_mse: 0.0202 - 49ms/epoch - 4ms/step
# Epoch 1919/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0186 - val_mse: 0.0186 - 44ms/epoch - 4ms/step
# Epoch 1920/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0208 - val_mse: 0.0208 - 44ms/epoch - 4ms/step
# Epoch 1921/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0179 - val_mse: 0.0179 - 48ms/epoch - 4ms/step
# Epoch 1922/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0190 - val_mse: 0.0190 - 46ms/epoch - 4ms/step
# Epoch 1923/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0184 - val_mse: 0.0184 - 45ms/epoch - 4ms/step
# Epoch 1924/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0187 - val_mse: 0.0187 - 43ms/epoch - 4ms/step
# Epoch 1925/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0184 - val_mse: 0.0184 - 54ms/epoch - 4ms/step
# Epoch 1926/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0191 - val_mse: 0.0191 - 50ms/epoch - 4ms/step
# Epoch 1927/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0197 - val_mse: 0.0197 - 49ms/epoch - 4ms/step
# Epoch 1928/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0202 - val_mse: 0.0202 - 44ms/epoch - 4ms/step
# Epoch 1929/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0176 - val_mse: 0.0176 - 66ms/epoch - 5ms/step
# Epoch 1930/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0191 - val_mse: 0.0191 - 57ms/epoch - 5ms/step
# Epoch 1931/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0181 - val_mse: 0.0181 - 53ms/epoch - 4ms/step
# Epoch 1932/2000
# 12/12 - 0s - loss: 0.0049 - mse: 0.0049 - val_loss: 0.0187 - val_mse: 0.0187 - 45ms/epoch - 4ms/step
# Epoch 1933/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0208 - val_mse: 0.0208 - 51ms/epoch - 4ms/step
# Epoch 1934/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0178 - val_mse: 0.0178 - 44ms/epoch - 4ms/step
# Epoch 1935/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0187 - val_mse: 0.0187 - 44ms/epoch - 4ms/step
# Epoch 1936/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0193 - val_mse: 0.0193 - 51ms/epoch - 4ms/step
# Epoch 1937/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0187 - val_mse: 0.0187 - 45ms/epoch - 4ms/step
# Epoch 1938/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0201 - val_mse: 0.0201 - 44ms/epoch - 4ms/step
# Epoch 1939/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0186 - val_mse: 0.0186 - 46ms/epoch - 4ms/step
# Epoch 1940/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0178 - val_mse: 0.0178 - 50ms/epoch - 4ms/step
# Epoch 1941/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0186 - val_mse: 0.0186 - 51ms/epoch - 4ms/step
# Epoch 1942/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0175 - val_mse: 0.0175 - 51ms/epoch - 4ms/step
# Epoch 1943/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0183 - val_mse: 0.0183 - 53ms/epoch - 4ms/step
# Epoch 1944/2000
# 12/12 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0180 - val_mse: 0.0180 - 51ms/epoch - 4ms/step
# Epoch 1945/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0191 - val_mse: 0.0191 - 51ms/epoch - 4ms/step
# Epoch 1946/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0196 - val_mse: 0.0196 - 62ms/epoch - 5ms/step
# Epoch 1947/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0179 - val_mse: 0.0179 - 55ms/epoch - 5ms/step
# Epoch 1948/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0196 - val_mse: 0.0196 - 55ms/epoch - 5ms/step
# Epoch 1949/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0184 - val_mse: 0.0184 - 54ms/epoch - 4ms/step
# Epoch 1950/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0190 - val_mse: 0.0190 - 69ms/epoch - 6ms/step
# Epoch 1951/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0177 - val_mse: 0.0177 - 79ms/epoch - 7ms/step
# Epoch 1952/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0187 - val_mse: 0.0187 - 69ms/epoch - 6ms/step
# Epoch 1953/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0194 - val_mse: 0.0194 - 63ms/epoch - 5ms/step
# Epoch 1954/2000
# 12/12 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0187 - val_mse: 0.0187 - 67ms/epoch - 6ms/step
# Epoch 1955/2000
# 12/12 - 0s - loss: 0.0046 - mse: 0.0046 - val_loss: 0.0173 - val_mse: 0.0173 - 62ms/epoch - 5ms/step
# Epoch 1956/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0184 - val_mse: 0.0184 - 60ms/epoch - 5ms/step
# Epoch 1957/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0192 - val_mse: 0.0192 - 62ms/epoch - 5ms/step
# Epoch 1958/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0175 - val_mse: 0.0175 - 61ms/epoch - 5ms/step
# Epoch 1959/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0178 - val_mse: 0.0178 - 58ms/epoch - 5ms/step
# Epoch 1960/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0173 - val_mse: 0.0173 - 59ms/epoch - 5ms/step
# Epoch 1961/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0173 - val_mse: 0.0173 - 62ms/epoch - 5ms/step
# Epoch 1962/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0189 - val_mse: 0.0189 - 60ms/epoch - 5ms/step
# Epoch 1963/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0175 - val_mse: 0.0175 - 76ms/epoch - 6ms/step
# Epoch 1964/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0183 - val_mse: 0.0183 - 75ms/epoch - 6ms/step
# Epoch 1965/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0195 - val_mse: 0.0195 - 70ms/epoch - 6ms/step
# Epoch 1966/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0182 - val_mse: 0.0182 - 62ms/epoch - 5ms/step
# Epoch 1967/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0183 - val_mse: 0.0183 - 68ms/epoch - 6ms/step
# Epoch 1968/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0164 - val_mse: 0.0164 - 63ms/epoch - 5ms/step
# Epoch 1969/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0202 - val_mse: 0.0202 - 63ms/epoch - 5ms/step
# Epoch 1970/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0185 - val_mse: 0.0185 - 60ms/epoch - 5ms/step
# Epoch 1971/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0180 - val_mse: 0.0180 - 59ms/epoch - 5ms/step
# Epoch 1972/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0189 - val_mse: 0.0189 - 61ms/epoch - 5ms/step
# Epoch 1973/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0170 - val_mse: 0.0170 - 56ms/epoch - 5ms/step
# Epoch 1974/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0172 - val_mse: 0.0172 - 60ms/epoch - 5ms/step
# Epoch 1975/2000
# 12/12 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0175 - val_mse: 0.0175 - 61ms/epoch - 5ms/step
# Epoch 1976/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0180 - val_mse: 0.0180 - 57ms/epoch - 5ms/step
# Epoch 1977/2000
# 12/12 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0170 - val_mse: 0.0170 - 59ms/epoch - 5ms/step
# Epoch 1978/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0174 - val_mse: 0.0174 - 60ms/epoch - 5ms/step
# Epoch 1979/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0177 - val_mse: 0.0177 - 73ms/epoch - 6ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 0.0040 - mse: 0.0040 - val_loss: 0.0183 - val_mse: 0.0183 - 71ms/epoch - 6ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0176 - val_mse: 0.0176 - 66ms/epoch - 5ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 0.0045 - mse: 0.0045 - val_loss: 0.0184 - val_mse: 0.0184 - 62ms/epoch - 5ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0179 - val_mse: 0.0179 - 67ms/epoch - 6ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 0.0041 - mse: 0.0041 - val_loss: 0.0171 - val_mse: 0.0171 - 70ms/epoch - 6ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0180 - val_mse: 0.0180 - 63ms/epoch - 5ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0186 - val_mse: 0.0186 - 64ms/epoch - 5ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0173 - val_mse: 0.0173 - 62ms/epoch - 5ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0181 - val_mse: 0.0181 - 59ms/epoch - 5ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0182 - val_mse: 0.0182 - 59ms/epoch - 5ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0186 - val_mse: 0.0186 - 58ms/epoch - 5ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0181 - val_mse: 0.0181 - 62ms/epoch - 5ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 0.0054 - mse: 0.0054 - val_loss: 0.0213 - val_mse: 0.0213 - 68ms/epoch - 6ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0157 - val_mse: 0.0157 - 74ms/epoch - 6ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 0.0048 - mse: 0.0048 - val_loss: 0.0171 - val_mse: 0.0171 - 66ms/epoch - 5ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 0.0050 - mse: 0.0050 - val_loss: 0.0187 - val_mse: 0.0187 - 62ms/epoch - 5ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0171 - val_mse: 0.0171 - 67ms/epoch - 6ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0185 - val_mse: 0.0185 - 65ms/epoch - 5ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 0.0043 - mse: 0.0043 - val_loss: 0.0177 - val_mse: 0.0177 - 64ms/epoch - 5ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 0.0042 - mse: 0.0042 - val_loss: 0.0175 - val_mse: 0.0175 - 71ms/epoch - 6ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 0.0044 - mse: 0.0044 - val_loss: 0.0181 - val_mse: 0.0181 - 64ms/epoch - 5ms/step

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

#recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
# plt.title('model loss')
# plt.xlim([-20, 1800])
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 20)                80
#
#  second_layer (Dense)        (None, 10)                210
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.071

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.988

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
# plt.plot(y_test.iloc[:,0], y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2.5, -0.5))
plt.annotate("MAE = {:.3f}".format(error), (2.5, -0.8))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
# plt.title('Validation of the prediction model')     
plt.grid(True)

# plt.savefig('model validation.png', transparent=True)
plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_383')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_383\assets
