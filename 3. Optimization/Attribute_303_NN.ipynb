# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

sns.set_style("darkgrid")

# %% [markdown]
#     303 : ESYS line3 SENSOR 4 - Tension at Anchor - Trained on Max values

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_303.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Max']]

# %%
print('Maximum value of tension at anchor (Line 3): %.6f' % df['Max'].max())
print('Minimum value of tension at anchor (Line 3): %.6f' % df['Max'].min())
print('Range for tension at anchor (Line 3): %.6f' % (df['Max'].max()-df['Max'].min()))
print('Mean for tension at anchor (Line 3): %.6f' % (np.mean(df['Max'])))
# Out:
# Maximum value of tension at anchor (Line 3): 12471344.292144
# Minimum value of tension at anchor (Line 3): 2028951.368467
# Range for tension at anchor (Line 3): 10442392.923677
# Mean for tension at anchor (Line 3): 3858435.144974

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 0             800       800           0  3.829497e+06
# 1             800       800           1  3.811405e+06
# 2             800       800           2  3.775262e+06
# 3             800       800           3  3.716968e+06
# 4             800       800           4  3.663927e+06

# %%
df.shape
# Out:
# (1300, 4)

# %%
df.isna().sum()
# Out:
# L_values      0
# R_anchor      0
# z_fairlead    0
# Max           0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead           Max
# File_ID
# 1194          850       840          14  9.821572e+06

# %% [markdown]
# # Sensitivity analysis

# %%
#varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

#varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

#varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
#Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum tension at anchor for line 3', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='Max', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[0].set_title('Variation of T vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="Max", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[1].set_title('Variation of T vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="Max", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum tension at anchor [N]" , size = 12 )
axes[2].set_title('Variation of T vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['Max']<= df['Max'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_303.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label')

#L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='Max',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Max Tension at anchor (Line 3)', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
#pairplot to inspect relationship between dependant and independant variable
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
#plot heat map
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#              count          mean           std           min           max
# L_values    1300.0  8.449231e+02  2.328807e+01  8.000000e+02  8.800000e+02
# R_anchor    1300.0  8.347692e+02  2.626962e+01  8.000000e+02  9.000000e+02
# z_fairlead  1300.0  9.500000e+00  5.768500e+00  0.000000e+00  1.900000e+01
# Max         1300.0  3.858435e+06  2.329150e+06  2.028951e+06  1.247134e+07

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['Max']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_303.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_303.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead       Max
# File_ID
# 0             0.0       0.0    0.000000 -0.012429
# 1             0.0       0.0    0.052632 -0.020200
# 2             0.0       0.0    0.105263 -0.035724
# 3             0.0       0.0    0.157895 -0.060761
# 4             0.0       0.0    0.210526 -0.083543

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %% [markdown]
# he_normal :It draws samples from a truncated normal distribution centered on 0 with stddev = sqrt(2 / fan_in) where fan_in is the number of input units in the weight tensor.

# %%
# define the keras model
model = Sequential()
model.add(Dense(20, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 0.9874 - mse: 0.9874 - val_loss: 1.0553 - val_mse: 1.0553 - 513ms/epoch - 43ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 0.9504 - mse: 0.9504 - val_loss: 1.0272 - val_mse: 1.0272 - 39ms/epoch - 3ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 0.9258 - mse: 0.9258 - val_loss: 1.0138 - val_mse: 1.0138 - 54ms/epoch - 4ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 0.9088 - mse: 0.9088 - val_loss: 1.0024 - val_mse: 1.0024 - 49ms/epoch - 4ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 0.8934 - mse: 0.8934 - val_loss: 0.9958 - val_mse: 0.9958 - 44ms/epoch - 4ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 0.8818 - mse: 0.8818 - val_loss: 0.9888 - val_mse: 0.9888 - 47ms/epoch - 4ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 0.8706 - mse: 0.8706 - val_loss: 0.9825 - val_mse: 0.9825 - 48ms/epoch - 4ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 0.8624 - mse: 0.8624 - val_loss: 0.9780 - val_mse: 0.9780 - 47ms/epoch - 4ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.8554 - mse: 0.8554 - val_loss: 0.9680 - val_mse: 0.9680 - 60ms/epoch - 5ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.8486 - mse: 0.8486 - val_loss: 0.9677 - val_mse: 0.9677 - 53ms/epoch - 4ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.8390 - mse: 0.8390 - val_loss: 0.9580 - val_mse: 0.9580 - 46ms/epoch - 4ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.8339 - mse: 0.8339 - val_loss: 0.9564 - val_mse: 0.9564 - 63ms/epoch - 5ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.8279 - mse: 0.8279 - val_loss: 0.9510 - val_mse: 0.9510 - 51ms/epoch - 4ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.8204 - mse: 0.8204 - val_loss: 0.9437 - val_mse: 0.9437 - 44ms/epoch - 4ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.8154 - mse: 0.8154 - val_loss: 0.9361 - val_mse: 0.9361 - 44ms/epoch - 4ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.8083 - mse: 0.8083 - val_loss: 0.9325 - val_mse: 0.9325 - 51ms/epoch - 4ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.8018 - mse: 0.8018 - val_loss: 0.9256 - val_mse: 0.9256 - 41ms/epoch - 3ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.7964 - mse: 0.7964 - val_loss: 0.9219 - val_mse: 0.9219 - 45ms/epoch - 4ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.7882 - mse: 0.7882 - val_loss: 0.9151 - val_mse: 0.9151 - 76ms/epoch - 6ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.7829 - mse: 0.7829 - val_loss: 0.9101 - val_mse: 0.9101 - 54ms/epoch - 4ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.7758 - mse: 0.7758 - val_loss: 0.9035 - val_mse: 0.9035 - 46ms/epoch - 4ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.7693 - mse: 0.7693 - val_loss: 0.8959 - val_mse: 0.8959 - 46ms/epoch - 4ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.7643 - mse: 0.7643 - val_loss: 0.8911 - val_mse: 0.8911 - 41ms/epoch - 3ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.7568 - mse: 0.7568 - val_loss: 0.8825 - val_mse: 0.8825 - 44ms/epoch - 4ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.7510 - mse: 0.7510 - val_loss: 0.8767 - val_mse: 0.8767 - 47ms/epoch - 4ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.7443 - mse: 0.7443 - val_loss: 0.8731 - val_mse: 0.8731 - 38ms/epoch - 3ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.7392 - mse: 0.7392 - val_loss: 0.8646 - val_mse: 0.8646 - 51ms/epoch - 4ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.7331 - mse: 0.7331 - val_loss: 0.8636 - val_mse: 0.8636 - 38ms/epoch - 3ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.7274 - mse: 0.7274 - val_loss: 0.8592 - val_mse: 0.8592 - 60ms/epoch - 5ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.7228 - mse: 0.7228 - val_loss: 0.8493 - val_mse: 0.8493 - 48ms/epoch - 4ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.7163 - mse: 0.7163 - val_loss: 0.8437 - val_mse: 0.8437 - 44ms/epoch - 4ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.7120 - mse: 0.7120 - val_loss: 0.8349 - val_mse: 0.8349 - 44ms/epoch - 4ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.7073 - mse: 0.7073 - val_loss: 0.8357 - val_mse: 0.8357 - 46ms/epoch - 4ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.7000 - mse: 0.7000 - val_loss: 0.8232 - val_mse: 0.8232 - 47ms/epoch - 4ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.6964 - mse: 0.6964 - val_loss: 0.8205 - val_mse: 0.8205 - 38ms/epoch - 3ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.6871 - mse: 0.6871 - val_loss: 0.8127 - val_mse: 0.8127 - 49ms/epoch - 4ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.6824 - mse: 0.6824 - val_loss: 0.8104 - val_mse: 0.8104 - 47ms/epoch - 4ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.6775 - mse: 0.6775 - val_loss: 0.8059 - val_mse: 0.8059 - 50ms/epoch - 4ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.6733 - mse: 0.6733 - val_loss: 0.7983 - val_mse: 0.7983 - 39ms/epoch - 3ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.6679 - mse: 0.6679 - val_loss: 0.7938 - val_mse: 0.7938 - 46ms/epoch - 4ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.6630 - mse: 0.6630 - val_loss: 0.7912 - val_mse: 0.7912 - 51ms/epoch - 4ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.6584 - mse: 0.6584 - val_loss: 0.7831 - val_mse: 0.7831 - 47ms/epoch - 4ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.6543 - mse: 0.6543 - val_loss: 0.7801 - val_mse: 0.7801 - 45ms/epoch - 4ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.6502 - mse: 0.6502 - val_loss: 0.7742 - val_mse: 0.7742 - 44ms/epoch - 4ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.6446 - mse: 0.6446 - val_loss: 0.7746 - val_mse: 0.7746 - 43ms/epoch - 4ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.6422 - mse: 0.6422 - val_loss: 0.7712 - val_mse: 0.7712 - 50ms/epoch - 4ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.6392 - mse: 0.6392 - val_loss: 0.7606 - val_mse: 0.7606 - 45ms/epoch - 4ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.6347 - mse: 0.6347 - val_loss: 0.7625 - val_mse: 0.7625 - 45ms/epoch - 4ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.6325 - mse: 0.6325 - val_loss: 0.7561 - val_mse: 0.7561 - 44ms/epoch - 4ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.6266 - mse: 0.6266 - val_loss: 0.7546 - val_mse: 0.7546 - 47ms/epoch - 4ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.6201 - mse: 0.6201 - val_loss: 0.7444 - val_mse: 0.7444 - 51ms/epoch - 4ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.6166 - mse: 0.6166 - val_loss: 0.7446 - val_mse: 0.7446 - 41ms/epoch - 3ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.6149 - mse: 0.6149 - val_loss: 0.7417 - val_mse: 0.7417 - 44ms/epoch - 4ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.6084 - mse: 0.6084 - val_loss: 0.7349 - val_mse: 0.7349 - 45ms/epoch - 4ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.6068 - mse: 0.6068 - val_loss: 0.7376 - val_mse: 0.7376 - 48ms/epoch - 4ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.6040 - mse: 0.6040 - val_loss: 0.7260 - val_mse: 0.7260 - 87ms/epoch - 7ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.6006 - mse: 0.6006 - val_loss: 0.7263 - val_mse: 0.7263 - 53ms/epoch - 4ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.5985 - mse: 0.5985 - val_loss: 0.7279 - val_mse: 0.7279 - 43ms/epoch - 4ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.5919 - mse: 0.5919 - val_loss: 0.7187 - val_mse: 0.7187 - 41ms/epoch - 3ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.5887 - mse: 0.5887 - val_loss: 0.7233 - val_mse: 0.7233 - 45ms/epoch - 4ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.5866 - mse: 0.5866 - val_loss: 0.7168 - val_mse: 0.7168 - 43ms/epoch - 4ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.5852 - mse: 0.5852 - val_loss: 0.7166 - val_mse: 0.7166 - 41ms/epoch - 3ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.5820 - mse: 0.5820 - val_loss: 0.7096 - val_mse: 0.7096 - 43ms/epoch - 4ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.5810 - mse: 0.5810 - val_loss: 0.7077 - val_mse: 0.7077 - 42ms/epoch - 3ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.5806 - mse: 0.5806 - val_loss: 0.7065 - val_mse: 0.7065 - 44ms/epoch - 4ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.5793 - mse: 0.5793 - val_loss: 0.7118 - val_mse: 0.7118 - 44ms/epoch - 4ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.5778 - mse: 0.5778 - val_loss: 0.6982 - val_mse: 0.6982 - 43ms/epoch - 4ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.5720 - mse: 0.5720 - val_loss: 0.7075 - val_mse: 0.7075 - 42ms/epoch - 3ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.5729 - mse: 0.5729 - val_loss: 0.6945 - val_mse: 0.6945 - 40ms/epoch - 3ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.5695 - mse: 0.5695 - val_loss: 0.6945 - val_mse: 0.6945 - 47ms/epoch - 4ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.5664 - mse: 0.5664 - val_loss: 0.6909 - val_mse: 0.6909 - 46ms/epoch - 4ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.5635 - mse: 0.5635 - val_loss: 0.6962 - val_mse: 0.6962 - 44ms/epoch - 4ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.5634 - mse: 0.5634 - val_loss: 0.6865 - val_mse: 0.6865 - 49ms/epoch - 4ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.5593 - mse: 0.5593 - val_loss: 0.6845 - val_mse: 0.6845 - 40ms/epoch - 3ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.5606 - mse: 0.5606 - val_loss: 0.6900 - val_mse: 0.6900 - 45ms/epoch - 4ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.5566 - mse: 0.5566 - val_loss: 0.6781 - val_mse: 0.6781 - 46ms/epoch - 4ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.5569 - mse: 0.5569 - val_loss: 0.6761 - val_mse: 0.6761 - 42ms/epoch - 3ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.5561 - mse: 0.5561 - val_loss: 0.6820 - val_mse: 0.6820 - 46ms/epoch - 4ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.5531 - mse: 0.5531 - val_loss: 0.6784 - val_mse: 0.6784 - 42ms/epoch - 3ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.5515 - mse: 0.5515 - val_loss: 0.6758 - val_mse: 0.6758 - 45ms/epoch - 4ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.5502 - mse: 0.5502 - val_loss: 0.6733 - val_mse: 0.6733 - 46ms/epoch - 4ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.5477 - mse: 0.5477 - val_loss: 0.6771 - val_mse: 0.6771 - 42ms/epoch - 3ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.5452 - mse: 0.5452 - val_loss: 0.6685 - val_mse: 0.6685 - 42ms/epoch - 4ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.5444 - mse: 0.5444 - val_loss: 0.6721 - val_mse: 0.6721 - 47ms/epoch - 4ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.5445 - mse: 0.5445 - val_loss: 0.6674 - val_mse: 0.6674 - 44ms/epoch - 4ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.5438 - mse: 0.5438 - val_loss: 0.6689 - val_mse: 0.6689 - 50ms/epoch - 4ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.5430 - mse: 0.5430 - val_loss: 0.6718 - val_mse: 0.6718 - 37ms/epoch - 3ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.5397 - mse: 0.5397 - val_loss: 0.6660 - val_mse: 0.6660 - 48ms/epoch - 4ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.5374 - mse: 0.5374 - val_loss: 0.6623 - val_mse: 0.6623 - 42ms/epoch - 3ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.5392 - mse: 0.5392 - val_loss: 0.6669 - val_mse: 0.6669 - 43ms/epoch - 4ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.5378 - mse: 0.5378 - val_loss: 0.6579 - val_mse: 0.6579 - 48ms/epoch - 4ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.5345 - mse: 0.5345 - val_loss: 0.6611 - val_mse: 0.6611 - 39ms/epoch - 3ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.5316 - mse: 0.5316 - val_loss: 0.6595 - val_mse: 0.6595 - 49ms/epoch - 4ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.5307 - mse: 0.5307 - val_loss: 0.6557 - val_mse: 0.6557 - 44ms/epoch - 4ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.5291 - mse: 0.5291 - val_loss: 0.6502 - val_mse: 0.6502 - 50ms/epoch - 4ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.5308 - mse: 0.5308 - val_loss: 0.6500 - val_mse: 0.6500 - 40ms/epoch - 3ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.5267 - mse: 0.5267 - val_loss: 0.6534 - val_mse: 0.6534 - 46ms/epoch - 4ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.5263 - mse: 0.5263 - val_loss: 0.6577 - val_mse: 0.6577 - 48ms/epoch - 4ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.5260 - mse: 0.5260 - val_loss: 0.6478 - val_mse: 0.6478 - 40ms/epoch - 3ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.5222 - mse: 0.5222 - val_loss: 0.6505 - val_mse: 0.6505 - 49ms/epoch - 4ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.5223 - mse: 0.5223 - val_loss: 0.6437 - val_mse: 0.6437 - 84ms/epoch - 7ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.5203 - mse: 0.5203 - val_loss: 0.6529 - val_mse: 0.6529 - 54ms/epoch - 4ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.5216 - mse: 0.5216 - val_loss: 0.6464 - val_mse: 0.6464 - 43ms/epoch - 4ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.5188 - mse: 0.5188 - val_loss: 0.6405 - val_mse: 0.6405 - 39ms/epoch - 3ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.5165 - mse: 0.5165 - val_loss: 0.6435 - val_mse: 0.6435 - 45ms/epoch - 4ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.5186 - mse: 0.5186 - val_loss: 0.6368 - val_mse: 0.6368 - 45ms/epoch - 4ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.5144 - mse: 0.5144 - val_loss: 0.6397 - val_mse: 0.6397 - 43ms/epoch - 4ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.5144 - mse: 0.5144 - val_loss: 0.6409 - val_mse: 0.6409 - 40ms/epoch - 3ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.5158 - mse: 0.5158 - val_loss: 0.6336 - val_mse: 0.6336 - 49ms/epoch - 4ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.5139 - mse: 0.5139 - val_loss: 0.6446 - val_mse: 0.6446 - 48ms/epoch - 4ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.5111 - mse: 0.5111 - val_loss: 0.6317 - val_mse: 0.6317 - 41ms/epoch - 3ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.5095 - mse: 0.5095 - val_loss: 0.6309 - val_mse: 0.6309 - 50ms/epoch - 4ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.5082 - mse: 0.5082 - val_loss: 0.6294 - val_mse: 0.6294 - 49ms/epoch - 4ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.5066 - mse: 0.5066 - val_loss: 0.6331 - val_mse: 0.6331 - 44ms/epoch - 4ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.5051 - mse: 0.5051 - val_loss: 0.6289 - val_mse: 0.6289 - 44ms/epoch - 4ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.5055 - mse: 0.5055 - val_loss: 0.6246 - val_mse: 0.6246 - 49ms/epoch - 4ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.5135 - mse: 0.5135 - val_loss: 0.6310 - val_mse: 0.6310 - 39ms/epoch - 3ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.5032 - mse: 0.5032 - val_loss: 0.6250 - val_mse: 0.6250 - 44ms/epoch - 4ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.4997 - mse: 0.4997 - val_loss: 0.6256 - val_mse: 0.6256 - 45ms/epoch - 4ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.5009 - mse: 0.5009 - val_loss: 0.6368 - val_mse: 0.6368 - 49ms/epoch - 4ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.4984 - mse: 0.4984 - val_loss: 0.6200 - val_mse: 0.6200 - 45ms/epoch - 4ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.4974 - mse: 0.4974 - val_loss: 0.6248 - val_mse: 0.6248 - 50ms/epoch - 4ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.4956 - mse: 0.4956 - val_loss: 0.6225 - val_mse: 0.6225 - 41ms/epoch - 3ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.4932 - mse: 0.4932 - val_loss: 0.6194 - val_mse: 0.6194 - 50ms/epoch - 4ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.4922 - mse: 0.4922 - val_loss: 0.6214 - val_mse: 0.6214 - 48ms/epoch - 4ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.4906 - mse: 0.4906 - val_loss: 0.6122 - val_mse: 0.6122 - 43ms/epoch - 4ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.4898 - mse: 0.4898 - val_loss: 0.6245 - val_mse: 0.6245 - 44ms/epoch - 4ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.4871 - mse: 0.4871 - val_loss: 0.6125 - val_mse: 0.6125 - 45ms/epoch - 4ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.4853 - mse: 0.4853 - val_loss: 0.6144 - val_mse: 0.6144 - 47ms/epoch - 4ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.4844 - mse: 0.4844 - val_loss: 0.6124 - val_mse: 0.6124 - 40ms/epoch - 3ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.4814 - mse: 0.4814 - val_loss: 0.6109 - val_mse: 0.6109 - 42ms/epoch - 3ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.4796 - mse: 0.4796 - val_loss: 0.6073 - val_mse: 0.6073 - 46ms/epoch - 4ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.4791 - mse: 0.4791 - val_loss: 0.6055 - val_mse: 0.6055 - 39ms/epoch - 3ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.4820 - mse: 0.4820 - val_loss: 0.6029 - val_mse: 0.6029 - 51ms/epoch - 4ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.4755 - mse: 0.4755 - val_loss: 0.6069 - val_mse: 0.6069 - 45ms/epoch - 4ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.4738 - mse: 0.4738 - val_loss: 0.6042 - val_mse: 0.6042 - 50ms/epoch - 4ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.4727 - mse: 0.4727 - val_loss: 0.6034 - val_mse: 0.6034 - 48ms/epoch - 4ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.4710 - mse: 0.4710 - val_loss: 0.5985 - val_mse: 0.5985 - 46ms/epoch - 4ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.4731 - mse: 0.4731 - val_loss: 0.6008 - val_mse: 0.6008 - 39ms/epoch - 3ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.4692 - mse: 0.4692 - val_loss: 0.5975 - val_mse: 0.5975 - 42ms/epoch - 3ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.4736 - mse: 0.4736 - val_loss: 0.6058 - val_mse: 0.6058 - 75ms/epoch - 6ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.4674 - mse: 0.4674 - val_loss: 0.5924 - val_mse: 0.5924 - 53ms/epoch - 4ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.4683 - mse: 0.4683 - val_loss: 0.5950 - val_mse: 0.5950 - 47ms/epoch - 4ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.4660 - mse: 0.4660 - val_loss: 0.5974 - val_mse: 0.5974 - 45ms/epoch - 4ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.4689 - mse: 0.4689 - val_loss: 0.5926 - val_mse: 0.5926 - 44ms/epoch - 4ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.4652 - mse: 0.4652 - val_loss: 0.5895 - val_mse: 0.5895 - 45ms/epoch - 4ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.4588 - mse: 0.4588 - val_loss: 0.5885 - val_mse: 0.5885 - 42ms/epoch - 3ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.4613 - mse: 0.4613 - val_loss: 0.6037 - val_mse: 0.6037 - 45ms/epoch - 4ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.4611 - mse: 0.4611 - val_loss: 0.5907 - val_mse: 0.5907 - 41ms/epoch - 3ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.4597 - mse: 0.4597 - val_loss: 0.5851 - val_mse: 0.5851 - 48ms/epoch - 4ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.4612 - mse: 0.4612 - val_loss: 0.5962 - val_mse: 0.5962 - 47ms/epoch - 4ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.4552 - mse: 0.4552 - val_loss: 0.5805 - val_mse: 0.5805 - 43ms/epoch - 4ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.4518 - mse: 0.4518 - val_loss: 0.5871 - val_mse: 0.5871 - 49ms/epoch - 4ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.4511 - mse: 0.4511 - val_loss: 0.5814 - val_mse: 0.5814 - 52ms/epoch - 4ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.4501 - mse: 0.4501 - val_loss: 0.5869 - val_mse: 0.5869 - 50ms/epoch - 4ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.4515 - mse: 0.4515 - val_loss: 0.5847 - val_mse: 0.5847 - 41ms/epoch - 3ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.4487 - mse: 0.4487 - val_loss: 0.5789 - val_mse: 0.5789 - 48ms/epoch - 4ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.4486 - mse: 0.4486 - val_loss: 0.5764 - val_mse: 0.5764 - 44ms/epoch - 4ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.4432 - mse: 0.4432 - val_loss: 0.5833 - val_mse: 0.5833 - 43ms/epoch - 4ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.4427 - mse: 0.4427 - val_loss: 0.5750 - val_mse: 0.5750 - 43ms/epoch - 4ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.4414 - mse: 0.4414 - val_loss: 0.5786 - val_mse: 0.5786 - 49ms/epoch - 4ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.4408 - mse: 0.4408 - val_loss: 0.5749 - val_mse: 0.5749 - 40ms/epoch - 3ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.4380 - mse: 0.4380 - val_loss: 0.5691 - val_mse: 0.5691 - 51ms/epoch - 4ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.4391 - mse: 0.4391 - val_loss: 0.5732 - val_mse: 0.5732 - 41ms/epoch - 3ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.4422 - mse: 0.4422 - val_loss: 0.5754 - val_mse: 0.5754 - 47ms/epoch - 4ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.4356 - mse: 0.4356 - val_loss: 0.5695 - val_mse: 0.5695 - 48ms/epoch - 4ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.4339 - mse: 0.4339 - val_loss: 0.5660 - val_mse: 0.5660 - 43ms/epoch - 4ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.4324 - mse: 0.4324 - val_loss: 0.5612 - val_mse: 0.5612 - 47ms/epoch - 4ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.4311 - mse: 0.4311 - val_loss: 0.5682 - val_mse: 0.5682 - 39ms/epoch - 3ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.4307 - mse: 0.4307 - val_loss: 0.5665 - val_mse: 0.5665 - 51ms/epoch - 4ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.4283 - mse: 0.4283 - val_loss: 0.5611 - val_mse: 0.5611 - 41ms/epoch - 3ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.4270 - mse: 0.4270 - val_loss: 0.5663 - val_mse: 0.5663 - 45ms/epoch - 4ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.4299 - mse: 0.4299 - val_loss: 0.5606 - val_mse: 0.5606 - 71ms/epoch - 6ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.4323 - mse: 0.4323 - val_loss: 0.5629 - val_mse: 0.5629 - 63ms/epoch - 5ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.4245 - mse: 0.4245 - val_loss: 0.5563 - val_mse: 0.5563 - 52ms/epoch - 4ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.4218 - mse: 0.4218 - val_loss: 0.5605 - val_mse: 0.5605 - 42ms/epoch - 3ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.4223 - mse: 0.4223 - val_loss: 0.5548 - val_mse: 0.5548 - 43ms/epoch - 4ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.4222 - mse: 0.4222 - val_loss: 0.5525 - val_mse: 0.5525 - 50ms/epoch - 4ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.4189 - mse: 0.4189 - val_loss: 0.5594 - val_mse: 0.5594 - 39ms/epoch - 3ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.4212 - mse: 0.4212 - val_loss: 0.5468 - val_mse: 0.5468 - 52ms/epoch - 4ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.4187 - mse: 0.4187 - val_loss: 0.5599 - val_mse: 0.5599 - 46ms/epoch - 4ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.4177 - mse: 0.4177 - val_loss: 0.5464 - val_mse: 0.5464 - 45ms/epoch - 4ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.4148 - mse: 0.4148 - val_loss: 0.5506 - val_mse: 0.5506 - 51ms/epoch - 4ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.4148 - mse: 0.4148 - val_loss: 0.5505 - val_mse: 0.5505 - 39ms/epoch - 3ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.4123 - mse: 0.4123 - val_loss: 0.5445 - val_mse: 0.5445 - 51ms/epoch - 4ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.4131 - mse: 0.4131 - val_loss: 0.5574 - val_mse: 0.5574 - 46ms/epoch - 4ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.4137 - mse: 0.4137 - val_loss: 0.5451 - val_mse: 0.5451 - 44ms/epoch - 4ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.4118 - mse: 0.4118 - val_loss: 0.5427 - val_mse: 0.5427 - 47ms/epoch - 4ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.4112 - mse: 0.4112 - val_loss: 0.5423 - val_mse: 0.5423 - 48ms/epoch - 4ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.4073 - mse: 0.4073 - val_loss: 0.5429 - val_mse: 0.5429 - 45ms/epoch - 4ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.4061 - mse: 0.4061 - val_loss: 0.5407 - val_mse: 0.5407 - 44ms/epoch - 4ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.4055 - mse: 0.4055 - val_loss: 0.5381 - val_mse: 0.5381 - 40ms/epoch - 3ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.4068 - mse: 0.4068 - val_loss: 0.5363 - val_mse: 0.5363 - 42ms/epoch - 4ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.4035 - mse: 0.4035 - val_loss: 0.5349 - val_mse: 0.5349 - 45ms/epoch - 4ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.4033 - mse: 0.4033 - val_loss: 0.5349 - val_mse: 0.5349 - 48ms/epoch - 4ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.4041 - mse: 0.4041 - val_loss: 0.5295 - val_mse: 0.5295 - 50ms/epoch - 4ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.4007 - mse: 0.4007 - val_loss: 0.5332 - val_mse: 0.5332 - 45ms/epoch - 4ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.3992 - mse: 0.3992 - val_loss: 0.5361 - val_mse: 0.5361 - 46ms/epoch - 4ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.3978 - mse: 0.3978 - val_loss: 0.5263 - val_mse: 0.5263 - 45ms/epoch - 4ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.4006 - mse: 0.4006 - val_loss: 0.5268 - val_mse: 0.5268 - 46ms/epoch - 4ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.3969 - mse: 0.3969 - val_loss: 0.5267 - val_mse: 0.5267 - 49ms/epoch - 4ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.4007 - mse: 0.4007 - val_loss: 0.5210 - val_mse: 0.5210 - 47ms/epoch - 4ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.3968 - mse: 0.3968 - val_loss: 0.5241 - val_mse: 0.5241 - 41ms/epoch - 3ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.3941 - mse: 0.3941 - val_loss: 0.5248 - val_mse: 0.5248 - 48ms/epoch - 4ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.3938 - mse: 0.3938 - val_loss: 0.5239 - val_mse: 0.5239 - 47ms/epoch - 4ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.3923 - mse: 0.3923 - val_loss: 0.5190 - val_mse: 0.5190 - 39ms/epoch - 3ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.3906 - mse: 0.3906 - val_loss: 0.5202 - val_mse: 0.5202 - 48ms/epoch - 4ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.3915 - mse: 0.3915 - val_loss: 0.5188 - val_mse: 0.5188 - 44ms/epoch - 4ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.3888 - mse: 0.3888 - val_loss: 0.5147 - val_mse: 0.5147 - 40ms/epoch - 3ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.3880 - mse: 0.3880 - val_loss: 0.5152 - val_mse: 0.5152 - 53ms/epoch - 4ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.3875 - mse: 0.3875 - val_loss: 0.5131 - val_mse: 0.5131 - 46ms/epoch - 4ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.3876 - mse: 0.3876 - val_loss: 0.5141 - val_mse: 0.5141 - 50ms/epoch - 4ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.3906 - mse: 0.3906 - val_loss: 0.5102 - val_mse: 0.5102 - 39ms/epoch - 3ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.3880 - mse: 0.3880 - val_loss: 0.5128 - val_mse: 0.5128 - 43ms/epoch - 4ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.3854 - mse: 0.3854 - val_loss: 0.5117 - val_mse: 0.5117 - 44ms/epoch - 4ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.3828 - mse: 0.3828 - val_loss: 0.5095 - val_mse: 0.5095 - 46ms/epoch - 4ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.3819 - mse: 0.3819 - val_loss: 0.5067 - val_mse: 0.5067 - 44ms/epoch - 4ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.3813 - mse: 0.3813 - val_loss: 0.5122 - val_mse: 0.5122 - 46ms/epoch - 4ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.3839 - mse: 0.3839 - val_loss: 0.5120 - val_mse: 0.5120 - 49ms/epoch - 4ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.3796 - mse: 0.3796 - val_loss: 0.5043 - val_mse: 0.5043 - 51ms/epoch - 4ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.3801 - mse: 0.3801 - val_loss: 0.5020 - val_mse: 0.5020 - 42ms/epoch - 3ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.3787 - mse: 0.3787 - val_loss: 0.5037 - val_mse: 0.5037 - 47ms/epoch - 4ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.3755 - mse: 0.3755 - val_loss: 0.4972 - val_mse: 0.4972 - 45ms/epoch - 4ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.3769 - mse: 0.3769 - val_loss: 0.5049 - val_mse: 0.5049 - 48ms/epoch - 4ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.3744 - mse: 0.3744 - val_loss: 0.4951 - val_mse: 0.4951 - 43ms/epoch - 4ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.3768 - mse: 0.3768 - val_loss: 0.4973 - val_mse: 0.4973 - 44ms/epoch - 4ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.3762 - mse: 0.3762 - val_loss: 0.4958 - val_mse: 0.4958 - 45ms/epoch - 4ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.3714 - mse: 0.3714 - val_loss: 0.4979 - val_mse: 0.4979 - 45ms/epoch - 4ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.3712 - mse: 0.3712 - val_loss: 0.4949 - val_mse: 0.4949 - 39ms/epoch - 3ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.3695 - mse: 0.3695 - val_loss: 0.4987 - val_mse: 0.4987 - 47ms/epoch - 4ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.3684 - mse: 0.3684 - val_loss: 0.4893 - val_mse: 0.4893 - 42ms/epoch - 3ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.3683 - mse: 0.3683 - val_loss: 0.4914 - val_mse: 0.4914 - 48ms/epoch - 4ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.3689 - mse: 0.3689 - val_loss: 0.4948 - val_mse: 0.4948 - 45ms/epoch - 4ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.3690 - mse: 0.3690 - val_loss: 0.4899 - val_mse: 0.4899 - 54ms/epoch - 4ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.3681 - mse: 0.3681 - val_loss: 0.4887 - val_mse: 0.4887 - 39ms/epoch - 3ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.3652 - mse: 0.3652 - val_loss: 0.4938 - val_mse: 0.4938 - 45ms/epoch - 4ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.3657 - mse: 0.3657 - val_loss: 0.4887 - val_mse: 0.4887 - 47ms/epoch - 4ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.3666 - mse: 0.3666 - val_loss: 0.4862 - val_mse: 0.4862 - 44ms/epoch - 4ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.3623 - mse: 0.3623 - val_loss: 0.4864 - val_mse: 0.4864 - 51ms/epoch - 4ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.3620 - mse: 0.3620 - val_loss: 0.4833 - val_mse: 0.4833 - 47ms/epoch - 4ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.3619 - mse: 0.3619 - val_loss: 0.4829 - val_mse: 0.4829 - 46ms/epoch - 4ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.3626 - mse: 0.3626 - val_loss: 0.4837 - val_mse: 0.4837 - 48ms/epoch - 4ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.3594 - mse: 0.3594 - val_loss: 0.4828 - val_mse: 0.4828 - 46ms/epoch - 4ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.3592 - mse: 0.3592 - val_loss: 0.4781 - val_mse: 0.4781 - 50ms/epoch - 4ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.3565 - mse: 0.3565 - val_loss: 0.4796 - val_mse: 0.4796 - 44ms/epoch - 4ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.3556 - mse: 0.3556 - val_loss: 0.4795 - val_mse: 0.4795 - 67ms/epoch - 6ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 0.3546 - mse: 0.3546 - val_loss: 0.4743 - val_mse: 0.4743 - 67ms/epoch - 6ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 0.3540 - mse: 0.3540 - val_loss: 0.4777 - val_mse: 0.4777 - 55ms/epoch - 5ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 0.3553 - mse: 0.3553 - val_loss: 0.4778 - val_mse: 0.4778 - 44ms/epoch - 4ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 0.3520 - mse: 0.3520 - val_loss: 0.4703 - val_mse: 0.4703 - 43ms/epoch - 4ms/step
# Epoch 251/2000
# 12/12 - 0s - loss: 0.3521 - mse: 0.3521 - val_loss: 0.4695 - val_mse: 0.4695 - 45ms/epoch - 4ms/step
# Epoch 252/2000
# 12/12 - 0s - loss: 0.3529 - mse: 0.3529 - val_loss: 0.4709 - val_mse: 0.4709 - 47ms/epoch - 4ms/step
# Epoch 253/2000
# 12/12 - 0s - loss: 0.3527 - mse: 0.3527 - val_loss: 0.4737 - val_mse: 0.4737 - 39ms/epoch - 3ms/step
# Epoch 254/2000
# 12/12 - 0s - loss: 0.3515 - mse: 0.3515 - val_loss: 0.4691 - val_mse: 0.4691 - 49ms/epoch - 4ms/step
# Epoch 255/2000
# 12/12 - 0s - loss: 0.3488 - mse: 0.3488 - val_loss: 0.4636 - val_mse: 0.4636 - 48ms/epoch - 4ms/step
# Epoch 256/2000
# 12/12 - 0s - loss: 0.3496 - mse: 0.3496 - val_loss: 0.4718 - val_mse: 0.4718 - 47ms/epoch - 4ms/step
# Epoch 257/2000
# 12/12 - 0s - loss: 0.3494 - mse: 0.3494 - val_loss: 0.4626 - val_mse: 0.4626 - 47ms/epoch - 4ms/step
# Epoch 258/2000
# 12/12 - 0s - loss: 0.3497 - mse: 0.3497 - val_loss: 0.4631 - val_mse: 0.4631 - 49ms/epoch - 4ms/step
# Epoch 259/2000
# 12/12 - 0s - loss: 0.3491 - mse: 0.3491 - val_loss: 0.4669 - val_mse: 0.4669 - 47ms/epoch - 4ms/step
# Epoch 260/2000
# 12/12 - 0s - loss: 0.3463 - mse: 0.3463 - val_loss: 0.4634 - val_mse: 0.4634 - 51ms/epoch - 4ms/step
# Epoch 261/2000
# 12/12 - 0s - loss: 0.3444 - mse: 0.3444 - val_loss: 0.4608 - val_mse: 0.4608 - 49ms/epoch - 4ms/step
# Epoch 262/2000
# 12/12 - 0s - loss: 0.3437 - mse: 0.3437 - val_loss: 0.4631 - val_mse: 0.4631 - 46ms/epoch - 4ms/step
# Epoch 263/2000
# 12/12 - 0s - loss: 0.3439 - mse: 0.3439 - val_loss: 0.4670 - val_mse: 0.4670 - 43ms/epoch - 4ms/step
# Epoch 264/2000
# 12/12 - 0s - loss: 0.3449 - mse: 0.3449 - val_loss: 0.4580 - val_mse: 0.4580 - 45ms/epoch - 4ms/step
# Epoch 265/2000
# 12/12 - 0s - loss: 0.3420 - mse: 0.3420 - val_loss: 0.4587 - val_mse: 0.4587 - 43ms/epoch - 4ms/step
# Epoch 266/2000
# 12/12 - 0s - loss: 0.3422 - mse: 0.3422 - val_loss: 0.4622 - val_mse: 0.4622 - 46ms/epoch - 4ms/step
# Epoch 267/2000
# 12/12 - 0s - loss: 0.3409 - mse: 0.3409 - val_loss: 0.4623 - val_mse: 0.4623 - 43ms/epoch - 4ms/step
# Epoch 268/2000
# 12/12 - 0s - loss: 0.3388 - mse: 0.3388 - val_loss: 0.4562 - val_mse: 0.4562 - 56ms/epoch - 5ms/step
# Epoch 269/2000
# 12/12 - 0s - loss: 0.3402 - mse: 0.3402 - val_loss: 0.4551 - val_mse: 0.4551 - 48ms/epoch - 4ms/step
# Epoch 270/2000
# 12/12 - 0s - loss: 0.3398 - mse: 0.3398 - val_loss: 0.4520 - val_mse: 0.4520 - 41ms/epoch - 3ms/step
# Epoch 271/2000
# 12/12 - 0s - loss: 0.3378 - mse: 0.3378 - val_loss: 0.4485 - val_mse: 0.4485 - 45ms/epoch - 4ms/step
# Epoch 272/2000
# 12/12 - 0s - loss: 0.3373 - mse: 0.3373 - val_loss: 0.4548 - val_mse: 0.4548 - 46ms/epoch - 4ms/step
# Epoch 273/2000
# 12/12 - 0s - loss: 0.3375 - mse: 0.3375 - val_loss: 0.4519 - val_mse: 0.4519 - 48ms/epoch - 4ms/step
# Epoch 274/2000
# 12/12 - 0s - loss: 0.3396 - mse: 0.3396 - val_loss: 0.4484 - val_mse: 0.4484 - 47ms/epoch - 4ms/step
# Epoch 275/2000
# 12/12 - 0s - loss: 0.3336 - mse: 0.3336 - val_loss: 0.4487 - val_mse: 0.4487 - 38ms/epoch - 3ms/step
# Epoch 276/2000
# 12/12 - 0s - loss: 0.3362 - mse: 0.3362 - val_loss: 0.4692 - val_mse: 0.4692 - 46ms/epoch - 4ms/step
# Epoch 277/2000
# 12/12 - 0s - loss: 0.3343 - mse: 0.3343 - val_loss: 0.4442 - val_mse: 0.4442 - 52ms/epoch - 4ms/step
# Epoch 278/2000
# 12/12 - 0s - loss: 0.3316 - mse: 0.3316 - val_loss: 0.4453 - val_mse: 0.4453 - 43ms/epoch - 4ms/step
# Epoch 279/2000
# 12/12 - 0s - loss: 0.3315 - mse: 0.3315 - val_loss: 0.4501 - val_mse: 0.4501 - 66ms/epoch - 5ms/step
# Epoch 280/2000
# 12/12 - 0s - loss: 0.3322 - mse: 0.3322 - val_loss: 0.4419 - val_mse: 0.4419 - 80ms/epoch - 7ms/step
# Epoch 281/2000
# 12/12 - 0s - loss: 0.3309 - mse: 0.3309 - val_loss: 0.4403 - val_mse: 0.4403 - 67ms/epoch - 6ms/step
# Epoch 282/2000
# 12/12 - 0s - loss: 0.3309 - mse: 0.3309 - val_loss: 0.4483 - val_mse: 0.4483 - 69ms/epoch - 6ms/step
# Epoch 283/2000
# 12/12 - 0s - loss: 0.3293 - mse: 0.3293 - val_loss: 0.4465 - val_mse: 0.4465 - 67ms/epoch - 6ms/step
# Epoch 284/2000
# 12/12 - 0s - loss: 0.3290 - mse: 0.3290 - val_loss: 0.4378 - val_mse: 0.4378 - 77ms/epoch - 6ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 0.3280 - mse: 0.3280 - val_loss: 0.4396 - val_mse: 0.4396 - 74ms/epoch - 6ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 0.3287 - mse: 0.3287 - val_loss: 0.4384 - val_mse: 0.4384 - 65ms/epoch - 5ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 0.3277 - mse: 0.3277 - val_loss: 0.4480 - val_mse: 0.4480 - 71ms/epoch - 6ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 0.3268 - mse: 0.3268 - val_loss: 0.4329 - val_mse: 0.4329 - 67ms/epoch - 6ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 0.3256 - mse: 0.3256 - val_loss: 0.4376 - val_mse: 0.4376 - 68ms/epoch - 6ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 0.3227 - mse: 0.3227 - val_loss: 0.4320 - val_mse: 0.4320 - 61ms/epoch - 5ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 0.3242 - mse: 0.3242 - val_loss: 0.4329 - val_mse: 0.4329 - 64ms/epoch - 5ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 0.3255 - mse: 0.3255 - val_loss: 0.4312 - val_mse: 0.4312 - 63ms/epoch - 5ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 0.3213 - mse: 0.3213 - val_loss: 0.4314 - val_mse: 0.4314 - 71ms/epoch - 6ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 0.3215 - mse: 0.3215 - val_loss: 0.4360 - val_mse: 0.4360 - 61ms/epoch - 5ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 0.3258 - mse: 0.3258 - val_loss: 0.4308 - val_mse: 0.4308 - 70ms/epoch - 6ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 0.3203 - mse: 0.3203 - val_loss: 0.4284 - val_mse: 0.4284 - 69ms/epoch - 6ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 0.3225 - mse: 0.3225 - val_loss: 0.4282 - val_mse: 0.4282 - 73ms/epoch - 6ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 0.3230 - mse: 0.3230 - val_loss: 0.4376 - val_mse: 0.4376 - 64ms/epoch - 5ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 0.3236 - mse: 0.3236 - val_loss: 0.4279 - val_mse: 0.4279 - 69ms/epoch - 6ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 0.3190 - mse: 0.3190 - val_loss: 0.4288 - val_mse: 0.4288 - 70ms/epoch - 6ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 0.3176 - mse: 0.3176 - val_loss: 0.4212 - val_mse: 0.4212 - 67ms/epoch - 6ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 0.3169 - mse: 0.3169 - val_loss: 0.4300 - val_mse: 0.4300 - 61ms/epoch - 5ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 0.3172 - mse: 0.3172 - val_loss: 0.4232 - val_mse: 0.4232 - 68ms/epoch - 6ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 0.3179 - mse: 0.3179 - val_loss: 0.4208 - val_mse: 0.4208 - 64ms/epoch - 5ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 0.3199 - mse: 0.3199 - val_loss: 0.4232 - val_mse: 0.4232 - 68ms/epoch - 6ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 0.3138 - mse: 0.3138 - val_loss: 0.4216 - val_mse: 0.4216 - 66ms/epoch - 5ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 0.3133 - mse: 0.3133 - val_loss: 0.4220 - val_mse: 0.4220 - 68ms/epoch - 6ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 0.3126 - mse: 0.3126 - val_loss: 0.4202 - val_mse: 0.4202 - 61ms/epoch - 5ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 0.3114 - mse: 0.3114 - val_loss: 0.4204 - val_mse: 0.4204 - 66ms/epoch - 5ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 0.3140 - mse: 0.3140 - val_loss: 0.4164 - val_mse: 0.4164 - 73ms/epoch - 6ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 0.3096 - mse: 0.3096 - val_loss: 0.4185 - val_mse: 0.4185 - 60ms/epoch - 5ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 0.3087 - mse: 0.3087 - val_loss: 0.4166 - val_mse: 0.4166 - 65ms/epoch - 5ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 0.3077 - mse: 0.3077 - val_loss: 0.4141 - val_mse: 0.4141 - 62ms/epoch - 5ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 0.3083 - mse: 0.3083 - val_loss: 0.4154 - val_mse: 0.4154 - 66ms/epoch - 5ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 0.3109 - mse: 0.3109 - val_loss: 0.4117 - val_mse: 0.4117 - 70ms/epoch - 6ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 0.3079 - mse: 0.3079 - val_loss: 0.4107 - val_mse: 0.4107 - 67ms/epoch - 6ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 0.3090 - mse: 0.3090 - val_loss: 0.4124 - val_mse: 0.4124 - 62ms/epoch - 5ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 0.3069 - mse: 0.3069 - val_loss: 0.4164 - val_mse: 0.4164 - 64ms/epoch - 5ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 0.3095 - mse: 0.3095 - val_loss: 0.4096 - val_mse: 0.4096 - 65ms/epoch - 5ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 0.3069 - mse: 0.3069 - val_loss: 0.4053 - val_mse: 0.4053 - 66ms/epoch - 5ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 0.3057 - mse: 0.3057 - val_loss: 0.4100 - val_mse: 0.4100 - 60ms/epoch - 5ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 0.3049 - mse: 0.3049 - val_loss: 0.4073 - val_mse: 0.4073 - 74ms/epoch - 6ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 0.3045 - mse: 0.3045 - val_loss: 0.4076 - val_mse: 0.4076 - 65ms/epoch - 5ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 0.3025 - mse: 0.3025 - val_loss: 0.4093 - val_mse: 0.4093 - 66ms/epoch - 5ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 0.3019 - mse: 0.3019 - val_loss: 0.4029 - val_mse: 0.4029 - 62ms/epoch - 5ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 0.3054 - mse: 0.3054 - val_loss: 0.4023 - val_mse: 0.4023 - 70ms/epoch - 6ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 0.3019 - mse: 0.3019 - val_loss: 0.4033 - val_mse: 0.4033 - 62ms/epoch - 5ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 0.3000 - mse: 0.3000 - val_loss: 0.4096 - val_mse: 0.4096 - 72ms/epoch - 6ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 0.3011 - mse: 0.3011 - val_loss: 0.4045 - val_mse: 0.4045 - 63ms/epoch - 5ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 0.3009 - mse: 0.3009 - val_loss: 0.4039 - val_mse: 0.4039 - 66ms/epoch - 5ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 0.3018 - mse: 0.3018 - val_loss: 0.3967 - val_mse: 0.3967 - 67ms/epoch - 6ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 0.2989 - mse: 0.2989 - val_loss: 0.3980 - val_mse: 0.3980 - 67ms/epoch - 6ms/step
# Epoch 333/2000
# 12/12 - 0s - loss: 0.2995 - mse: 0.2995 - val_loss: 0.3964 - val_mse: 0.3964 - 64ms/epoch - 5ms/step
# Epoch 334/2000
# 12/12 - 0s - loss: 0.2957 - mse: 0.2957 - val_loss: 0.3994 - val_mse: 0.3994 - 65ms/epoch - 5ms/step
# Epoch 335/2000
# 12/12 - 0s - loss: 0.2945 - mse: 0.2945 - val_loss: 0.3960 - val_mse: 0.3960 - 62ms/epoch - 5ms/step
# Epoch 336/2000
# 12/12 - 0s - loss: 0.2938 - mse: 0.2938 - val_loss: 0.3956 - val_mse: 0.3956 - 69ms/epoch - 6ms/step
# Epoch 337/2000
# 12/12 - 0s - loss: 0.2942 - mse: 0.2942 - val_loss: 0.3979 - val_mse: 0.3979 - 113ms/epoch - 9ms/step
# Epoch 338/2000
# 12/12 - 0s - loss: 0.2955 - mse: 0.2955 - val_loss: 0.4071 - val_mse: 0.4071 - 85ms/epoch - 7ms/step
# Epoch 339/2000
# 12/12 - 0s - loss: 0.3007 - mse: 0.3007 - val_loss: 0.3971 - val_mse: 0.3971 - 76ms/epoch - 6ms/step
# Epoch 340/2000
# 12/12 - 0s - loss: 0.2944 - mse: 0.2944 - val_loss: 0.3980 - val_mse: 0.3980 - 74ms/epoch - 6ms/step
# Epoch 341/2000
# 12/12 - 0s - loss: 0.2915 - mse: 0.2915 - val_loss: 0.3916 - val_mse: 0.3916 - 74ms/epoch - 6ms/step
# Epoch 342/2000
# 12/12 - 0s - loss: 0.2914 - mse: 0.2914 - val_loss: 0.3989 - val_mse: 0.3989 - 76ms/epoch - 6ms/step
# Epoch 343/2000
# 12/12 - 0s - loss: 0.2910 - mse: 0.2910 - val_loss: 0.3904 - val_mse: 0.3904 - 70ms/epoch - 6ms/step
# Epoch 344/2000
# 12/12 - 0s - loss: 0.2925 - mse: 0.2925 - val_loss: 0.3915 - val_mse: 0.3915 - 67ms/epoch - 6ms/step
# Epoch 345/2000
# 12/12 - 0s - loss: 0.2912 - mse: 0.2912 - val_loss: 0.3885 - val_mse: 0.3885 - 69ms/epoch - 6ms/step
# Epoch 346/2000
# 12/12 - 0s - loss: 0.2901 - mse: 0.2901 - val_loss: 0.3879 - val_mse: 0.3879 - 65ms/epoch - 5ms/step
# Epoch 347/2000
# 12/12 - 0s - loss: 0.2895 - mse: 0.2895 - val_loss: 0.3844 - val_mse: 0.3844 - 66ms/epoch - 5ms/step
# Epoch 348/2000
# 12/12 - 0s - loss: 0.2889 - mse: 0.2889 - val_loss: 0.3890 - val_mse: 0.3890 - 68ms/epoch - 6ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 0.2885 - mse: 0.2885 - val_loss: 0.3878 - val_mse: 0.3878 - 69ms/epoch - 6ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 0.2867 - mse: 0.2867 - val_loss: 0.3846 - val_mse: 0.3846 - 64ms/epoch - 5ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 0.2871 - mse: 0.2871 - val_loss: 0.3893 - val_mse: 0.3893 - 64ms/epoch - 5ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 0.2893 - mse: 0.2893 - val_loss: 0.3975 - val_mse: 0.3975 - 70ms/epoch - 6ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 0.2883 - mse: 0.2883 - val_loss: 0.3845 - val_mse: 0.3845 - 62ms/epoch - 5ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 0.2852 - mse: 0.2852 - val_loss: 0.3961 - val_mse: 0.3961 - 72ms/epoch - 6ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 0.2887 - mse: 0.2887 - val_loss: 0.3843 - val_mse: 0.3843 - 64ms/epoch - 5ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 0.2858 - mse: 0.2858 - val_loss: 0.3821 - val_mse: 0.3821 - 66ms/epoch - 5ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 0.2842 - mse: 0.2842 - val_loss: 0.3803 - val_mse: 0.3803 - 66ms/epoch - 6ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 0.2850 - mse: 0.2850 - val_loss: 0.3794 - val_mse: 0.3794 - 62ms/epoch - 5ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 0.2843 - mse: 0.2843 - val_loss: 0.3840 - val_mse: 0.3840 - 67ms/epoch - 6ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 0.2822 - mse: 0.2822 - val_loss: 0.3804 - val_mse: 0.3804 - 58ms/epoch - 5ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 0.2826 - mse: 0.2826 - val_loss: 0.3797 - val_mse: 0.3797 - 63ms/epoch - 5ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 0.2819 - mse: 0.2819 - val_loss: 0.3784 - val_mse: 0.3784 - 59ms/epoch - 5ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 0.2803 - mse: 0.2803 - val_loss: 0.3747 - val_mse: 0.3747 - 62ms/epoch - 5ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 0.2794 - mse: 0.2794 - val_loss: 0.3790 - val_mse: 0.3790 - 65ms/epoch - 5ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 0.2786 - mse: 0.2786 - val_loss: 0.3758 - val_mse: 0.3758 - 64ms/epoch - 5ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 0.2789 - mse: 0.2789 - val_loss: 0.3760 - val_mse: 0.3760 - 70ms/epoch - 6ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 0.2791 - mse: 0.2791 - val_loss: 0.3894 - val_mse: 0.3894 - 64ms/epoch - 5ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 0.2815 - mse: 0.2815 - val_loss: 0.3747 - val_mse: 0.3747 - 65ms/epoch - 5ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 0.2804 - mse: 0.2804 - val_loss: 0.3733 - val_mse: 0.3733 - 72ms/epoch - 6ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 0.2780 - mse: 0.2780 - val_loss: 0.3746 - val_mse: 0.3746 - 89ms/epoch - 7ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 0.2792 - mse: 0.2792 - val_loss: 0.3791 - val_mse: 0.3791 - 88ms/epoch - 7ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 0.2770 - mse: 0.2770 - val_loss: 0.3760 - val_mse: 0.3760 - 86ms/epoch - 7ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 0.2776 - mse: 0.2776 - val_loss: 0.3758 - val_mse: 0.3758 - 70ms/epoch - 6ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 0.2770 - mse: 0.2770 - val_loss: 0.3675 - val_mse: 0.3675 - 76ms/epoch - 6ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 0.2756 - mse: 0.2756 - val_loss: 0.3709 - val_mse: 0.3709 - 70ms/epoch - 6ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 0.2733 - mse: 0.2733 - val_loss: 0.3717 - val_mse: 0.3717 - 68ms/epoch - 6ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 0.2745 - mse: 0.2745 - val_loss: 0.3684 - val_mse: 0.3684 - 71ms/epoch - 6ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 0.2730 - mse: 0.2730 - val_loss: 0.3740 - val_mse: 0.3740 - 70ms/epoch - 6ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 0.2748 - mse: 0.2748 - val_loss: 0.3648 - val_mse: 0.3648 - 68ms/epoch - 6ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 0.2734 - mse: 0.2734 - val_loss: 0.3683 - val_mse: 0.3683 - 64ms/epoch - 5ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 0.2709 - mse: 0.2709 - val_loss: 0.3674 - val_mse: 0.3674 - 69ms/epoch - 6ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 0.2701 - mse: 0.2701 - val_loss: 0.3654 - val_mse: 0.3654 - 69ms/epoch - 6ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 0.2699 - mse: 0.2699 - val_loss: 0.3655 - val_mse: 0.3655 - 75ms/epoch - 6ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 0.2690 - mse: 0.2690 - val_loss: 0.3637 - val_mse: 0.3637 - 77ms/epoch - 6ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 0.2708 - mse: 0.2708 - val_loss: 0.3676 - val_mse: 0.3676 - 80ms/epoch - 7ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 0.2732 - mse: 0.2732 - val_loss: 0.3722 - val_mse: 0.3722 - 75ms/epoch - 6ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 0.2755 - mse: 0.2755 - val_loss: 0.3653 - val_mse: 0.3653 - 74ms/epoch - 6ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 0.2741 - mse: 0.2741 - val_loss: 0.3682 - val_mse: 0.3682 - 68ms/epoch - 6ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 0.2695 - mse: 0.2695 - val_loss: 0.3600 - val_mse: 0.3600 - 77ms/epoch - 6ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 0.2675 - mse: 0.2675 - val_loss: 0.3622 - val_mse: 0.3622 - 82ms/epoch - 7ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 0.2659 - mse: 0.2659 - val_loss: 0.3593 - val_mse: 0.3593 - 82ms/epoch - 7ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 0.2661 - mse: 0.2661 - val_loss: 0.3599 - val_mse: 0.3599 - 78ms/epoch - 7ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 0.2664 - mse: 0.2664 - val_loss: 0.3624 - val_mse: 0.3624 - 77ms/epoch - 6ms/step
# Epoch 394/2000
# 12/12 - 0s - loss: 0.2650 - mse: 0.2650 - val_loss: 0.3585 - val_mse: 0.3585 - 71ms/epoch - 6ms/step
# Epoch 395/2000
# 12/12 - 0s - loss: 0.2648 - mse: 0.2648 - val_loss: 0.3622 - val_mse: 0.3622 - 79ms/epoch - 7ms/step
# Epoch 396/2000
# 12/12 - 0s - loss: 0.2658 - mse: 0.2658 - val_loss: 0.3560 - val_mse: 0.3560 - 120ms/epoch - 10ms/step
# Epoch 397/2000
# 12/12 - 0s - loss: 0.2655 - mse: 0.2655 - val_loss: 0.3615 - val_mse: 0.3615 - 86ms/epoch - 7ms/step
# Epoch 398/2000
# 12/12 - 0s - loss: 0.2665 - mse: 0.2665 - val_loss: 0.3539 - val_mse: 0.3539 - 104ms/epoch - 9ms/step
# Epoch 399/2000
# 12/12 - 0s - loss: 0.2623 - mse: 0.2623 - val_loss: 0.3574 - val_mse: 0.3574 - 75ms/epoch - 6ms/step
# Epoch 400/2000
# 12/12 - 0s - loss: 0.2625 - mse: 0.2625 - val_loss: 0.3530 - val_mse: 0.3530 - 92ms/epoch - 8ms/step
# Epoch 401/2000
# 12/12 - 0s - loss: 0.2619 - mse: 0.2619 - val_loss: 0.3532 - val_mse: 0.3532 - 74ms/epoch - 6ms/step
# Epoch 402/2000
# 12/12 - 0s - loss: 0.2625 - mse: 0.2625 - val_loss: 0.3528 - val_mse: 0.3528 - 80ms/epoch - 7ms/step
# Epoch 403/2000
# 12/12 - 0s - loss: 0.2614 - mse: 0.2614 - val_loss: 0.3560 - val_mse: 0.3560 - 81ms/epoch - 7ms/step
# Epoch 404/2000
# 12/12 - 0s - loss: 0.2618 - mse: 0.2618 - val_loss: 0.3559 - val_mse: 0.3559 - 89ms/epoch - 7ms/step
# Epoch 405/2000
# 12/12 - 0s - loss: 0.2590 - mse: 0.2590 - val_loss: 0.3544 - val_mse: 0.3544 - 82ms/epoch - 7ms/step
# Epoch 406/2000
# 12/12 - 0s - loss: 0.2604 - mse: 0.2604 - val_loss: 0.3580 - val_mse: 0.3580 - 115ms/epoch - 10ms/step
# Epoch 407/2000
# 12/12 - 0s - loss: 0.2610 - mse: 0.2610 - val_loss: 0.3509 - val_mse: 0.3509 - 101ms/epoch - 8ms/step
# Epoch 408/2000
# 12/12 - 0s - loss: 0.2597 - mse: 0.2597 - val_loss: 0.3542 - val_mse: 0.3542 - 107ms/epoch - 9ms/step
# Epoch 409/2000
# 12/12 - 0s - loss: 0.2591 - mse: 0.2591 - val_loss: 0.3504 - val_mse: 0.3504 - 84ms/epoch - 7ms/step
# Epoch 410/2000
# 12/12 - 0s - loss: 0.2571 - mse: 0.2571 - val_loss: 0.3494 - val_mse: 0.3494 - 88ms/epoch - 7ms/step
# Epoch 411/2000
# 12/12 - 0s - loss: 0.2580 - mse: 0.2580 - val_loss: 0.3579 - val_mse: 0.3579 - 75ms/epoch - 6ms/step
# Epoch 412/2000
# 12/12 - 0s - loss: 0.2580 - mse: 0.2580 - val_loss: 0.3477 - val_mse: 0.3477 - 75ms/epoch - 6ms/step
# Epoch 413/2000
# 12/12 - 0s - loss: 0.2568 - mse: 0.2568 - val_loss: 0.3469 - val_mse: 0.3469 - 75ms/epoch - 6ms/step
# Epoch 414/2000
# 12/12 - 0s - loss: 0.2549 - mse: 0.2549 - val_loss: 0.3557 - val_mse: 0.3557 - 74ms/epoch - 6ms/step
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 12/12 - 0s - loss: 0.0429 - mse: 0.0429 - val_loss: 0.0928 - val_mse: 0.0928 - 80ms/epoch - 7ms/step
# Epoch 1866/2000
# 12/12 - 0s - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0894 - val_mse: 0.0894 - 103ms/epoch - 9ms/step
# Epoch 1867/2000
# 12/12 - 0s - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0921 - val_mse: 0.0921 - 100ms/epoch - 8ms/step
# Epoch 1868/2000
# 12/12 - 0s - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0900 - val_mse: 0.0900 - 105ms/epoch - 9ms/step
# Epoch 1869/2000
# 12/12 - 0s - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0914 - val_mse: 0.0914 - 85ms/epoch - 7ms/step
# Epoch 1870/2000
# 12/12 - 0s - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0913 - val_mse: 0.0913 - 73ms/epoch - 6ms/step
# Epoch 1871/2000
# 12/12 - 0s - loss: 0.0437 - mse: 0.0437 - val_loss: 0.0949 - val_mse: 0.0949 - 76ms/epoch - 6ms/step
# Epoch 1872/2000
# 12/12 - 0s - loss: 0.0460 - mse: 0.0460 - val_loss: 0.0936 - val_mse: 0.0936 - 71ms/epoch - 6ms/step
# Epoch 1873/2000
# 12/12 - 0s - loss: 0.0448 - mse: 0.0448 - val_loss: 0.0910 - val_mse: 0.0910 - 74ms/epoch - 6ms/step
# Epoch 1874/2000
# 12/12 - 0s - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0885 - val_mse: 0.0885 - 92ms/epoch - 8ms/step
# Epoch 1875/2000
# 12/12 - 0s - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0891 - val_mse: 0.0891 - 89ms/epoch - 7ms/step
# Epoch 1876/2000
# 12/12 - 0s - loss: 0.0429 - mse: 0.0429 - val_loss: 0.0878 - val_mse: 0.0878 - 71ms/epoch - 6ms/step
# Epoch 1877/2000
# 12/12 - 0s - loss: 0.0451 - mse: 0.0451 - val_loss: 0.0894 - val_mse: 0.0894 - 78ms/epoch - 6ms/step
# Epoch 1878/2000
# 12/12 - 0s - loss: 0.0445 - mse: 0.0445 - val_loss: 0.0899 - val_mse: 0.0899 - 81ms/epoch - 7ms/step
# Epoch 1879/2000
# 12/12 - 0s - loss: 0.0437 - mse: 0.0437 - val_loss: 0.0892 - val_mse: 0.0892 - 83ms/epoch - 7ms/step
# Epoch 1880/2000
# 12/12 - 0s - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0884 - val_mse: 0.0884 - 77ms/epoch - 6ms/step
# Epoch 1881/2000
# 12/12 - 0s - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0870 - val_mse: 0.0870 - 76ms/epoch - 6ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0914 - val_mse: 0.0914 - 72ms/epoch - 6ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0878 - val_mse: 0.0878 - 70ms/epoch - 6ms/step
# Epoch 1884/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0879 - val_mse: 0.0879 - 73ms/epoch - 6ms/step
# Epoch 1885/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0863 - val_mse: 0.0863 - 105ms/epoch - 9ms/step
# Epoch 1886/2000
# 12/12 - 0s - loss: 0.0430 - mse: 0.0430 - val_loss: 0.0869 - val_mse: 0.0869 - 94ms/epoch - 8ms/step
# Epoch 1887/2000
# 12/12 - 0s - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0872 - val_mse: 0.0872 - 79ms/epoch - 7ms/step
# Epoch 1888/2000
# 12/12 - 0s - loss: 0.0428 - mse: 0.0428 - val_loss: 0.0871 - val_mse: 0.0871 - 78ms/epoch - 7ms/step
# Epoch 1889/2000
# 12/12 - 0s - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0859 - val_mse: 0.0859 - 82ms/epoch - 7ms/step
# Epoch 1890/2000
# 12/12 - 0s - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0856 - val_mse: 0.0856 - 91ms/epoch - 8ms/step
# Epoch 1891/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0864 - val_mse: 0.0864 - 88ms/epoch - 7ms/step
# Epoch 1892/2000
# 12/12 - 0s - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0863 - val_mse: 0.0863 - 115ms/epoch - 10ms/step
# Epoch 1893/2000
# 12/12 - 0s - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0902 - val_mse: 0.0902 - 83ms/epoch - 7ms/step
# Epoch 1894/2000
# 12/12 - 0s - loss: 0.0439 - mse: 0.0439 - val_loss: 0.0876 - val_mse: 0.0876 - 88ms/epoch - 7ms/step
# Epoch 1895/2000
# 12/12 - 0s - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0908 - val_mse: 0.0908 - 90ms/epoch - 7ms/step
# Epoch 1896/2000
# 12/12 - 0s - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0878 - val_mse: 0.0878 - 79ms/epoch - 7ms/step
# Epoch 1897/2000
# 12/12 - 0s - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0865 - val_mse: 0.0865 - 72ms/epoch - 6ms/step
# Epoch 1898/2000
# 12/12 - 0s - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0858 - val_mse: 0.0858 - 77ms/epoch - 6ms/step
# Epoch 1899/2000
# 12/12 - 0s - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0862 - val_mse: 0.0862 - 105ms/epoch - 9ms/step
# Epoch 1900/2000
# 12/12 - 0s - loss: 0.0403 - mse: 0.0403 - val_loss: 0.0864 - val_mse: 0.0864 - 109ms/epoch - 9ms/step
# Epoch 1901/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0902 - val_mse: 0.0902 - 92ms/epoch - 8ms/step
# Epoch 1902/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0891 - val_mse: 0.0891 - 88ms/epoch - 7ms/step
# Epoch 1903/2000
# 12/12 - 0s - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0857 - val_mse: 0.0857 - 91ms/epoch - 8ms/step
# Epoch 1904/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0871 - val_mse: 0.0871 - 104ms/epoch - 9ms/step
# Epoch 1905/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0905 - val_mse: 0.0905 - 81ms/epoch - 7ms/step
# Epoch 1906/2000
# 12/12 - 0s - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0885 - val_mse: 0.0885 - 76ms/epoch - 6ms/step
# Epoch 1907/2000
# 12/12 - 0s - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0880 - val_mse: 0.0880 - 92ms/epoch - 8ms/step
# Epoch 1908/2000
# 12/12 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0874 - val_mse: 0.0874 - 82ms/epoch - 7ms/step
# Epoch 1909/2000
# 12/12 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0855 - val_mse: 0.0855 - 137ms/epoch - 11ms/step
# Epoch 1910/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0874 - val_mse: 0.0874 - 106ms/epoch - 9ms/step
# Epoch 1911/2000
# 12/12 - 0s - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0873 - val_mse: 0.0873 - 105ms/epoch - 9ms/step
# Epoch 1912/2000
# 12/12 - 0s - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0867 - val_mse: 0.0867 - 90ms/epoch - 7ms/step
# Epoch 1913/2000
# 12/12 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0864 - val_mse: 0.0864 - 85ms/epoch - 7ms/step
# Epoch 1914/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0857 - val_mse: 0.0857 - 100ms/epoch - 8ms/step
# Epoch 1915/2000
# 12/12 - 0s - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0825 - val_mse: 0.0825 - 115ms/epoch - 10ms/step
# Epoch 1916/2000
# 12/12 - 0s - loss: 0.0405 - mse: 0.0405 - val_loss: 0.0831 - val_mse: 0.0831 - 126ms/epoch - 10ms/step
# Epoch 1917/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0844 - val_mse: 0.0844 - 128ms/epoch - 11ms/step
# Epoch 1918/2000
# 12/12 - 0s - loss: 0.0404 - mse: 0.0404 - val_loss: 0.0832 - val_mse: 0.0832 - 106ms/epoch - 9ms/step
# Epoch 1919/2000
# 12/12 - 0s - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0837 - val_mse: 0.0837 - 111ms/epoch - 9ms/step
# Epoch 1920/2000
# 12/12 - 0s - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0857 - val_mse: 0.0857 - 109ms/epoch - 9ms/step
# Epoch 1921/2000
# 12/12 - 0s - loss: 0.0412 - mse: 0.0412 - val_loss: 0.0867 - val_mse: 0.0867 - 93ms/epoch - 8ms/step
# Epoch 1922/2000
# 12/12 - 0s - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0836 - val_mse: 0.0836 - 97ms/epoch - 8ms/step
# Epoch 1923/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0837 - val_mse: 0.0837 - 98ms/epoch - 8ms/step
# Epoch 1924/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0837 - val_mse: 0.0837 - 89ms/epoch - 7ms/step
# Epoch 1925/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0845 - val_mse: 0.0845 - 108ms/epoch - 9ms/step
# Epoch 1926/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0861 - val_mse: 0.0861 - 109ms/epoch - 9ms/step
# Epoch 1927/2000
# 12/12 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0851 - val_mse: 0.0851 - 124ms/epoch - 10ms/step
# Epoch 1928/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0851 - val_mse: 0.0851 - 121ms/epoch - 10ms/step
# Epoch 1929/2000
# 12/12 - 0s - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0839 - val_mse: 0.0839 - 189ms/epoch - 16ms/step
# Epoch 1930/2000
# 12/12 - 0s - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0882 - val_mse: 0.0882 - 150ms/epoch - 12ms/step
# Epoch 1931/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0861 - val_mse: 0.0861 - 132ms/epoch - 11ms/step
# Epoch 1932/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0865 - val_mse: 0.0865 - 166ms/epoch - 14ms/step
# Epoch 1933/2000
# 12/12 - 0s - loss: 0.0407 - mse: 0.0407 - val_loss: 0.0831 - val_mse: 0.0831 - 101ms/epoch - 8ms/step
# Epoch 1934/2000
# 12/12 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0832 - val_mse: 0.0832 - 110ms/epoch - 9ms/step
# Epoch 1935/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0832 - val_mse: 0.0832 - 137ms/epoch - 11ms/step
# Epoch 1936/2000
# 12/12 - 0s - loss: 0.0411 - mse: 0.0411 - val_loss: 0.0853 - val_mse: 0.0853 - 212ms/epoch - 18ms/step
# Epoch 1937/2000
# 12/12 - 0s - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0874 - val_mse: 0.0874 - 134ms/epoch - 11ms/step
# Epoch 1938/2000
# 12/12 - 0s - loss: 0.0421 - mse: 0.0421 - val_loss: 0.0863 - val_mse: 0.0863 - 140ms/epoch - 12ms/step
# Epoch 1939/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0839 - val_mse: 0.0839 - 128ms/epoch - 11ms/step
# Epoch 1940/2000
# 12/12 - 0s - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0850 - val_mse: 0.0850 - 92ms/epoch - 8ms/step
# Epoch 1941/2000
# 12/12 - 0s - loss: 0.0410 - mse: 0.0410 - val_loss: 0.0871 - val_mse: 0.0871 - 98ms/epoch - 8ms/step
# Epoch 1942/2000
# 12/12 - 0s - loss: 0.0402 - mse: 0.0402 - val_loss: 0.0844 - val_mse: 0.0844 - 87ms/epoch - 7ms/step
# Epoch 1943/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0824 - val_mse: 0.0824 - 95ms/epoch - 8ms/step
# Epoch 1944/2000
# 12/12 - 0s - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0824 - val_mse: 0.0824 - 117ms/epoch - 10ms/step
# Epoch 1945/2000
# 12/12 - 0s - loss: 0.0400 - mse: 0.0400 - val_loss: 0.0827 - val_mse: 0.0827 - 82ms/epoch - 7ms/step
# Epoch 1946/2000
# 12/12 - 0s - loss: 0.0393 - mse: 0.0393 - val_loss: 0.0825 - val_mse: 0.0825 - 96ms/epoch - 8ms/step
# Epoch 1947/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0866 - val_mse: 0.0866 - 117ms/epoch - 10ms/step
# Epoch 1948/2000
# 12/12 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0838 - val_mse: 0.0838 - 105ms/epoch - 9ms/step
# Epoch 1949/2000
# 12/12 - 0s - loss: 0.0405 - mse: 0.0405 - val_loss: 0.0851 - val_mse: 0.0851 - 88ms/epoch - 7ms/step
# Epoch 1950/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0830 - val_mse: 0.0830 - 81ms/epoch - 7ms/step
# Epoch 1951/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0822 - val_mse: 0.0822 - 85ms/epoch - 7ms/step
# Epoch 1952/2000
# 12/12 - 0s - loss: 0.0391 - mse: 0.0391 - val_loss: 0.0826 - val_mse: 0.0826 - 76ms/epoch - 6ms/step
# Epoch 1953/2000
# 12/12 - 0s - loss: 0.0394 - mse: 0.0394 - val_loss: 0.0867 - val_mse: 0.0867 - 73ms/epoch - 6ms/step
# Epoch 1954/2000
# 12/12 - 0s - loss: 0.0407 - mse: 0.0407 - val_loss: 0.0830 - val_mse: 0.0830 - 73ms/epoch - 6ms/step
# Epoch 1955/2000
# 12/12 - 0s - loss: 0.0397 - mse: 0.0397 - val_loss: 0.0844 - val_mse: 0.0844 - 74ms/epoch - 6ms/step
# Epoch 1956/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0823 - val_mse: 0.0823 - 83ms/epoch - 7ms/step
# Epoch 1957/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0831 - val_mse: 0.0831 - 70ms/epoch - 6ms/step
# Epoch 1958/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0890 - val_mse: 0.0890 - 74ms/epoch - 6ms/step
# Epoch 1959/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0828 - val_mse: 0.0828 - 85ms/epoch - 7ms/step
# Epoch 1960/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0850 - val_mse: 0.0850 - 77ms/epoch - 6ms/step
# Epoch 1961/2000
# 12/12 - 0s - loss: 0.0453 - mse: 0.0453 - val_loss: 0.0805 - val_mse: 0.0805 - 113ms/epoch - 9ms/step
# Epoch 1962/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0866 - val_mse: 0.0866 - 104ms/epoch - 9ms/step
# Epoch 1963/2000
# 12/12 - 0s - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0853 - val_mse: 0.0853 - 99ms/epoch - 8ms/step
# Epoch 1964/2000
# 12/12 - 0s - loss: 0.0408 - mse: 0.0408 - val_loss: 0.0884 - val_mse: 0.0884 - 98ms/epoch - 8ms/step
# Epoch 1965/2000
# 12/12 - 0s - loss: 0.0428 - mse: 0.0428 - val_loss: 0.0825 - val_mse: 0.0825 - 81ms/epoch - 7ms/step
# Epoch 1966/2000
# 12/12 - 0s - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0813 - val_mse: 0.0813 - 77ms/epoch - 6ms/step
# Epoch 1967/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0858 - val_mse: 0.0858 - 79ms/epoch - 7ms/step
# Epoch 1968/2000
# 12/12 - 0s - loss: 0.0404 - mse: 0.0404 - val_loss: 0.0812 - val_mse: 0.0812 - 79ms/epoch - 7ms/step
# Epoch 1969/2000
# 12/12 - 0s - loss: 0.0387 - mse: 0.0387 - val_loss: 0.0818 - val_mse: 0.0818 - 69ms/epoch - 6ms/step
# Epoch 1970/2000
# 12/12 - 0s - loss: 0.0381 - mse: 0.0381 - val_loss: 0.0818 - val_mse: 0.0818 - 78ms/epoch - 6ms/step
# Epoch 1971/2000
# 12/12 - 0s - loss: 0.0385 - mse: 0.0385 - val_loss: 0.0831 - val_mse: 0.0831 - 74ms/epoch - 6ms/step
# Epoch 1972/2000
# 12/12 - 0s - loss: 0.0387 - mse: 0.0387 - val_loss: 0.0824 - val_mse: 0.0824 - 90ms/epoch - 7ms/step
# Epoch 1973/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0833 - val_mse: 0.0833 - 76ms/epoch - 6ms/step
# Epoch 1974/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0841 - val_mse: 0.0841 - 74ms/epoch - 6ms/step
# Epoch 1975/2000
# 12/12 - 0s - loss: 0.0399 - mse: 0.0399 - val_loss: 0.0858 - val_mse: 0.0858 - 76ms/epoch - 6ms/step
# Epoch 1976/2000
# 12/12 - 0s - loss: 0.0395 - mse: 0.0395 - val_loss: 0.0819 - val_mse: 0.0819 - 81ms/epoch - 7ms/step
# Epoch 1977/2000
# 12/12 - 0s - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0817 - val_mse: 0.0817 - 143ms/epoch - 12ms/step
# Epoch 1978/2000
# 12/12 - 0s - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0816 - val_mse: 0.0816 - 105ms/epoch - 9ms/step
# Epoch 1979/2000
# 12/12 - 0s - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0828 - val_mse: 0.0828 - 89ms/epoch - 7ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 0.0386 - mse: 0.0386 - val_loss: 0.0832 - val_mse: 0.0832 - 81ms/epoch - 7ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 0.0397 - mse: 0.0397 - val_loss: 0.0836 - val_mse: 0.0836 - 99ms/epoch - 8ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 0.0399 - mse: 0.0399 - val_loss: 0.0853 - val_mse: 0.0853 - 126ms/epoch - 10ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 0.0396 - mse: 0.0396 - val_loss: 0.0846 - val_mse: 0.0846 - 90ms/epoch - 7ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0832 - val_mse: 0.0832 - 81ms/epoch - 7ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0836 - val_mse: 0.0836 - 87ms/epoch - 7ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 0.0382 - mse: 0.0382 - val_loss: 0.0829 - val_mse: 0.0829 - 93ms/epoch - 8ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 0.0380 - mse: 0.0380 - val_loss: 0.0821 - val_mse: 0.0821 - 80ms/epoch - 7ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 0.0401 - mse: 0.0401 - val_loss: 0.0870 - val_mse: 0.0870 - 89ms/epoch - 7ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0843 - val_mse: 0.0843 - 155ms/epoch - 13ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 0.0405 - mse: 0.0405 - val_loss: 0.0845 - val_mse: 0.0845 - 101ms/epoch - 8ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0846 - val_mse: 0.0846 - 79ms/epoch - 7ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 0.0388 - mse: 0.0388 - val_loss: 0.0796 - val_mse: 0.0796 - 94ms/epoch - 8ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0800 - val_mse: 0.0800 - 81ms/epoch - 7ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 0.0402 - mse: 0.0402 - val_loss: 0.0812 - val_mse: 0.0812 - 76ms/epoch - 6ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 0.0383 - mse: 0.0383 - val_loss: 0.0855 - val_mse: 0.0855 - 84ms/epoch - 7ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0864 - val_mse: 0.0864 - 78ms/epoch - 6ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 0.0406 - mse: 0.0406 - val_loss: 0.0846 - val_mse: 0.0846 - 74ms/epoch - 6ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 0.0392 - mse: 0.0392 - val_loss: 0.0815 - val_mse: 0.0815 - 126ms/epoch - 11ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 0.0390 - mse: 0.0390 - val_loss: 0.0832 - val_mse: 0.0832 - 99ms/epoch - 8ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 0.0384 - mse: 0.0384 - val_loss: 0.0896 - val_mse: 0.0896 - 78ms/epoch - 6ms/step

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

#recored of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
# plt.title('model loss')
# plt.xlim([-20, 1800])
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 20)                80
#
#  second_layer (Dense)        (None, 10)                210
#
#  output_layer (Dense)        (None, 1)                 11
#
# =================================================================
# Total params: 301
# Trainable params: 301
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
# plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.116

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.957

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
# plt.plot(y_test.iloc[:,0], y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2.5, -0.5))
plt.annotate("MAE = {:.3f}".format(error), (2.5, -0.8))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
# plt.title('Validation of the prediction model')     
plt.grid(True)

# plt.savefig('model validation.png', transparent=True)
plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_303')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_303\assets
