# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14)

# %% [markdown]
#     95  : ESYS floater SENSOR 1	Surge displacement - Trained on absolute values of max

# %%
feature = pd.read_csv("L_R_z_values_pass.csv", index_col=0)
label = pd.read_csv("Result_index_95.csv", index_col=1)
df = pd.merge(feature,label,on="File_ID",how="inner")
df = df[['L_values','R_anchor','z_fairlead','Min', 'Max']]

# %%
df['Min'] = df['Min'].abs()
df['Max'] = df['Max'].abs()

# %%
print('Maximum value of abs(minimum surge): %.6f' % df['Min'].max())
print('Minimum value of abs(minimum surge): %.6f' % df['Min'].min())
print('Range for minimum abs(surge): %.6f' % (df['Min'].max()-df['Min'].min()))

print('\nMaximum value of abs(maximum surge): %.6f' % df['Max'].max())
print('Minimum value of abs(maximum surge): %.6f' % df['Max'].min())
print('Range for maximum abs(surge): %.6f' % (df['Max'].max()-df['Max'].min()))
# Out:
# Maximum value of abs(minimum surge): 172.707758
# Minimum value of abs(minimum surge): 2.410471
# Range for minimum abs(surge): 170.297287
#
# Maximum value of abs(maximum surge): 74.457658
# Minimum value of abs(maximum surge): 0.018160
# Range for maximum abs(surge): 74.439498

# %%
df['max (min, max)'] = df[['Min','Max']].max(axis=1)

# %%
df = df.drop(["Min", "Max"], axis=1)

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead  max (min, max)
# File_ID
# 0             800       800           0       12.418763
# 1             800       800           1       12.690100
# 2             800       800           2       12.930000
# 3             800       800           3       13.234048
# 4             800       800           4       13.610351

# %%
df.shape
# Out:
# (1300, 4)

# %%
print('Maximum value of max(abs(max, min)) surge: %.6f' % df['max (min, max)'].max())
print('Minimum value of max(abs(max, min)) surge: %.6f' % df['max (min, max)'].min())
print('Range for max(abs(max, min)) surge: %.6f' % (df['max (min, max)'].max()-df['max (min, max)'].min()))
print('Mean for max(abs(max, min)) surge: %.6f' % (np.mean(df['max (min, max)'])))
# Out:
# Maximum value of max(abs(max, min)) surge: 172.707758
# Minimum value of max(abs(max, min)) surge: 2.410471
# Range for max(abs(max, min)) surge: 170.297287
# Mean for max(abs(max, min)) surge: 49.088049

# %%
df.isna().sum()
# Out:
# L_values          0
# R_anchor          0
# z_fairlead        0
# max (min, max)    0
# dtype: int64

# %% [markdown]
# # Reference value for 15 MW turbine

# %%
reference_value = df[(df['R_anchor']== 840) & (df['L_values']== 850) & (df['z_fairlead']== 14 ) ].iloc[-1]

df.iloc[[df.index.get_loc(reference_value.name)]]
# Out:
#          L_values  R_anchor  z_fairlead  max (min, max)
# File_ID
# 1194          850       840          14        4.605106

# %% [markdown]
# # Sensitivity analysis

# %%
# varying z_fairlead
df1 = df[(df['R_anchor']== 840) & (df['L_values']== 850) ]

# varying L
df2 = df[(df['R_anchor']== 840) & (df['z_fairlead']== 14) ]

# varying R_anchor
df3 = df[(df['L_values']== 850) & (df['z_fairlead']== 14) ]

# %%
# Sensitivity plot
fig, axes = plt.subplots(1, 3, figsize=(20, 4), sharey=True)
fig.suptitle('Sensitivity analysis for maximum surge of platform', size = 16)

# z_fairlead
sns.regplot(ax=axes[0], x='z_fairlead', y='max (min, max)', data=df1, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[0].set_xlabel( "Position of z$_{fairlead}$ from SWL [m]" , size = 12 )
axes[0].set_ylabel( "Maximum surge of platform [m]" , size = 12 )
axes[0].set_title('Variation of surge vs z$_{fairlead}$', size = 14)

# L_values
sns.regplot(ax=axes[1],x="L_values", y="max (min, max)", data=df2, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[1].set_xlabel( "Length of line, L [m]" , size = 12 )
axes[1].set_ylabel( "Maximum surge of platform [m]" , size = 12 )
axes[1].set_title('Variation of surge vs L', size = 14)

# R_anchor
sns.regplot(ax=axes[2],x="R_anchor", y="max (min, max)", data=df3, scatter_kws={"color": "black"}, line_kws={"color": "#01497C"})
axes[2].set_xlabel( "Distance of anchor from C/L of structure, R$_{anchor}$ [m]" , size = 12 )
axes[2].set_ylabel( "Maximum surge of platform [m]" , size = 12 )
axes[2].set_title('Variation of surge vs R$_{anchor}$', size = 14)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Check for good design in data (reference 15 MW value)

# %%
df4 = df[(df['L_values']< 850) & (df['max (min, max)']<= df['max (min, max)'].values[df.index.get_loc(reference_value.name)]) ]

df4.to_csv('Reference_values_att_95.csv',index=True)

# %% [markdown]
# # Data analysis

# %%
fig, ax = plt.subplots(1, 4,  figsize=(30,5))
fig.suptitle('Count plots for features and label ')

# L
sns.countplot(ax=ax[0], x='L_values',data=df, color='#89C2D9', alpha=0.7)
ax[0].set_title('L [m]', size = 12)

# R_anchor
sns.countplot(ax=ax[1], x='R_anchor',data=df, color='#468FAF', alpha=0.7)
ax[1].set_title('R$_{anchor}$ [m]', size = 12)

# z_fairlead
sns.countplot(ax=ax[2], x='z_fairlead',data=df, color='#2A6F97', alpha=0.7)
ax[2].set_title('z$_{fairlead}$ [m]', size = 12)

# count tension
df.hist(ax=ax[3], column='max (min, max)',bins=40, color='#01497C', alpha=0.7)
ax[3].set_title('Maximum surge of platform [m]', size = 14)

plt.tight_layout()

# %%
import warnings
warnings.filterwarnings("ignore")

#pairplot to inspect relationship between feature and label
plt.rcParams.update({'font.size': 14})
plt.rcParams.update({'axes.grid':True})
plt.figure(figsize=(10,10))
plt.rcParams.update({'font.size': 16})
sns.pairplot(df, kind='reg', corner=True)
# plt.savefig('Pairplot.png', transparent=True)
plt.show()

# %%
# plot heat map
plt.rcParams.update({'font.size': 14})
sns.heatmap(df.corr(), annot=True, fmt=".3g", linewidths=.5, cmap="YlGnBu", cbar=False)
plt.show()

# %%
df.describe().transpose()[['count', 'mean', 'std', 'min', 'max']]
# Out:
#                  count        mean        std         min         max
# L_values        1300.0  844.923077  23.288073  800.000000  880.000000
# R_anchor        1300.0  834.769231  26.269621  800.000000  900.000000
# z_fairlead      1300.0    9.500000   5.768500    0.000000   19.000000
# max (min, max)  1300.0   49.088049  46.730264    2.410471  172.707758

# %% [markdown]
# # Feature Scaleing

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
features=['L_values','R_anchor','z_fairlead']
labels=['max (min, max)']

# %%
feature_scaler=MinMaxScaler()
label_scaler=StandardScaler()

# %%
df[features]=feature_scaler.fit_transform(df[features].values)
df[labels]=label_scaler.fit_transform(df[labels].values)

# %%
import pickle 

pickle.dump(feature_scaler, open('feature_scaler_95.pkl','wb'))
pickle.dump(label_scaler, open('label_scaler_95.pkl','wb'))

# %%
df.head()
# Out:
#          L_values  R_anchor  z_fairlead  max (min, max)
# File_ID
# 0             0.0       0.0    0.000000       -0.785003
# 1             0.0       0.0    0.052632       -0.779194
# 2             0.0       0.0    0.105263       -0.774059
# 3             0.0       0.0    0.157895       -0.767550
# 4             0.0       0.0    0.210526       -0.759494

# %% [markdown]
# # Split data into train and test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df[features],df[labels],test_size=0.2,random_state=42)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
print("y_train shape:",y_train.shape)
print("y_test shape:",y_test.shape)
# Out:
# x_train shape: (1040, 3)
# x_test shape: (260, 3)
# y_train shape: (1040, 1)
# y_test shape: (260, 1)

# %%
x_train=x_train.values.reshape(x_train.shape[0],x_train.shape[1],1)
x_test=x_test.values.reshape(x_test.shape[0],x_test.shape[1],1)

# %%
print("x_train shape:",x_train.shape)
print("x_test shape:",x_test.shape)
# Out:
# x_train shape: (1040, 3, 1)
# x_test shape: (260, 3, 1)

# %% [markdown]
# # Model build

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import History

# %%
# define the keras model
model = Sequential()
model.add(Dense(10, input_dim=x_train.shape[1], activation='relu', kernel_initializer='he_normal', name = 'first_layer'))
model.add(Dense(5, activation='relu', kernel_initializer='he_normal', name = 'second_layer'))
model.add(Dense(1, activation='linear', name = 'output_layer'))

# compile the keras model
model.compile(
loss = keras.losses.MeanSquaredError(),
metrics =  ['mse'],
optimizer=keras.optimizers.Adam(learning_rate=0.001)
)

# fit the keras model on the dataset
history = History()
model.fit(x_train, y_train, epochs=2000, batch_size=64, verbose=2, callbacks=[history], validation_split=0.3, shuffle=True)
# Out:
# Epoch 1/2000
# 12/12 - 1s - loss: 1.2067 - mse: 1.2067 - val_loss: 1.0935 - val_mse: 1.0935 - 614ms/epoch - 51ms/step
# Epoch 2/2000
# 12/12 - 0s - loss: 1.1288 - mse: 1.1288 - val_loss: 1.0494 - val_mse: 1.0494 - 35ms/epoch - 3ms/step
# Epoch 3/2000
# 12/12 - 0s - loss: 1.0806 - mse: 1.0806 - val_loss: 1.0211 - val_mse: 1.0211 - 41ms/epoch - 3ms/step
# Epoch 4/2000
# 12/12 - 0s - loss: 1.0454 - mse: 1.0454 - val_loss: 0.9989 - val_mse: 0.9989 - 39ms/epoch - 3ms/step
# Epoch 5/2000
# 12/12 - 0s - loss: 1.0150 - mse: 1.0150 - val_loss: 0.9812 - val_mse: 0.9812 - 35ms/epoch - 3ms/step
# Epoch 6/2000
# 12/12 - 0s - loss: 0.9888 - mse: 0.9888 - val_loss: 0.9654 - val_mse: 0.9654 - 41ms/epoch - 3ms/step
# Epoch 7/2000
# 12/12 - 0s - loss: 0.9642 - mse: 0.9642 - val_loss: 0.9524 - val_mse: 0.9524 - 36ms/epoch - 3ms/step
# Epoch 8/2000
# 12/12 - 0s - loss: 0.9424 - mse: 0.9424 - val_loss: 0.9417 - val_mse: 0.9417 - 40ms/epoch - 3ms/step
# Epoch 9/2000
# 12/12 - 0s - loss: 0.9244 - mse: 0.9244 - val_loss: 0.9327 - val_mse: 0.9327 - 38ms/epoch - 3ms/step
# Epoch 10/2000
# 12/12 - 0s - loss: 0.9063 - mse: 0.9063 - val_loss: 0.9247 - val_mse: 0.9247 - 40ms/epoch - 3ms/step
# Epoch 11/2000
# 12/12 - 0s - loss: 0.8900 - mse: 0.8900 - val_loss: 0.9143 - val_mse: 0.9143 - 41ms/epoch - 3ms/step
# Epoch 12/2000
# 12/12 - 0s - loss: 0.8742 - mse: 0.8742 - val_loss: 0.9028 - val_mse: 0.9028 - 39ms/epoch - 3ms/step
# Epoch 13/2000
# 12/12 - 0s - loss: 0.8582 - mse: 0.8582 - val_loss: 0.8929 - val_mse: 0.8929 - 45ms/epoch - 4ms/step
# Epoch 14/2000
# 12/12 - 0s - loss: 0.8430 - mse: 0.8430 - val_loss: 0.8819 - val_mse: 0.8819 - 37ms/epoch - 3ms/step
# Epoch 15/2000
# 12/12 - 0s - loss: 0.8276 - mse: 0.8276 - val_loss: 0.8714 - val_mse: 0.8714 - 41ms/epoch - 3ms/step
# Epoch 16/2000
# 12/12 - 0s - loss: 0.8126 - mse: 0.8126 - val_loss: 0.8569 - val_mse: 0.8569 - 42ms/epoch - 3ms/step
# Epoch 17/2000
# 12/12 - 0s - loss: 0.7971 - mse: 0.7971 - val_loss: 0.8489 - val_mse: 0.8489 - 37ms/epoch - 3ms/step
# Epoch 18/2000
# 12/12 - 0s - loss: 0.7825 - mse: 0.7825 - val_loss: 0.8339 - val_mse: 0.8339 - 39ms/epoch - 3ms/step
# Epoch 19/2000
# 12/12 - 0s - loss: 0.7675 - mse: 0.7675 - val_loss: 0.8193 - val_mse: 0.8193 - 40ms/epoch - 3ms/step
# Epoch 20/2000
# 12/12 - 0s - loss: 0.7530 - mse: 0.7530 - val_loss: 0.8058 - val_mse: 0.8058 - 38ms/epoch - 3ms/step
# Epoch 21/2000
# 12/12 - 0s - loss: 0.7390 - mse: 0.7390 - val_loss: 0.7960 - val_mse: 0.7960 - 42ms/epoch - 3ms/step
# Epoch 22/2000
# 12/12 - 0s - loss: 0.7240 - mse: 0.7240 - val_loss: 0.7816 - val_mse: 0.7816 - 36ms/epoch - 3ms/step
# Epoch 23/2000
# 12/12 - 0s - loss: 0.7105 - mse: 0.7105 - val_loss: 0.7670 - val_mse: 0.7670 - 40ms/epoch - 3ms/step
# Epoch 24/2000
# 12/12 - 0s - loss: 0.6971 - mse: 0.6971 - val_loss: 0.7557 - val_mse: 0.7557 - 38ms/epoch - 3ms/step
# Epoch 25/2000
# 12/12 - 0s - loss: 0.6839 - mse: 0.6839 - val_loss: 0.7446 - val_mse: 0.7446 - 39ms/epoch - 3ms/step
# Epoch 26/2000
# 12/12 - 0s - loss: 0.6714 - mse: 0.6714 - val_loss: 0.7372 - val_mse: 0.7372 - 58ms/epoch - 5ms/step
# Epoch 27/2000
# 12/12 - 0s - loss: 0.6581 - mse: 0.6581 - val_loss: 0.7241 - val_mse: 0.7241 - 106ms/epoch - 9ms/step
# Epoch 28/2000
# 12/12 - 0s - loss: 0.6463 - mse: 0.6463 - val_loss: 0.7152 - val_mse: 0.7152 - 95ms/epoch - 8ms/step
# Epoch 29/2000
# 12/12 - 0s - loss: 0.6344 - mse: 0.6344 - val_loss: 0.6968 - val_mse: 0.6968 - 77ms/epoch - 6ms/step
# Epoch 30/2000
# 12/12 - 0s - loss: 0.6229 - mse: 0.6229 - val_loss: 0.6870 - val_mse: 0.6870 - 72ms/epoch - 6ms/step
# Epoch 31/2000
# 12/12 - 0s - loss: 0.6129 - mse: 0.6129 - val_loss: 0.6721 - val_mse: 0.6721 - 74ms/epoch - 6ms/step
# Epoch 32/2000
# 12/12 - 0s - loss: 0.6026 - mse: 0.6026 - val_loss: 0.6673 - val_mse: 0.6673 - 59ms/epoch - 5ms/step
# Epoch 33/2000
# 12/12 - 0s - loss: 0.5923 - mse: 0.5923 - val_loss: 0.6603 - val_mse: 0.6603 - 58ms/epoch - 5ms/step
# Epoch 34/2000
# 12/12 - 0s - loss: 0.5841 - mse: 0.5841 - val_loss: 0.6564 - val_mse: 0.6564 - 68ms/epoch - 6ms/step
# Epoch 35/2000
# 12/12 - 0s - loss: 0.5754 - mse: 0.5754 - val_loss: 0.6432 - val_mse: 0.6432 - 75ms/epoch - 6ms/step
# Epoch 36/2000
# 12/12 - 0s - loss: 0.5675 - mse: 0.5675 - val_loss: 0.6332 - val_mse: 0.6332 - 63ms/epoch - 5ms/step
# Epoch 37/2000
# 12/12 - 0s - loss: 0.5606 - mse: 0.5606 - val_loss: 0.6213 - val_mse: 0.6213 - 82ms/epoch - 7ms/step
# Epoch 38/2000
# 12/12 - 0s - loss: 0.5534 - mse: 0.5534 - val_loss: 0.6144 - val_mse: 0.6144 - 53ms/epoch - 4ms/step
# Epoch 39/2000
# 12/12 - 0s - loss: 0.5462 - mse: 0.5462 - val_loss: 0.6117 - val_mse: 0.6117 - 60ms/epoch - 5ms/step
# Epoch 40/2000
# 12/12 - 0s - loss: 0.5398 - mse: 0.5398 - val_loss: 0.6065 - val_mse: 0.6065 - 50ms/epoch - 4ms/step
# Epoch 41/2000
# 12/12 - 0s - loss: 0.5344 - mse: 0.5344 - val_loss: 0.6042 - val_mse: 0.6042 - 51ms/epoch - 4ms/step
# Epoch 42/2000
# 12/12 - 0s - loss: 0.5295 - mse: 0.5295 - val_loss: 0.5937 - val_mse: 0.5937 - 60ms/epoch - 5ms/step
# Epoch 43/2000
# 12/12 - 0s - loss: 0.5243 - mse: 0.5243 - val_loss: 0.5870 - val_mse: 0.5870 - 44ms/epoch - 4ms/step
# Epoch 44/2000
# 12/12 - 0s - loss: 0.5183 - mse: 0.5183 - val_loss: 0.5837 - val_mse: 0.5837 - 46ms/epoch - 4ms/step
# Epoch 45/2000
# 12/12 - 0s - loss: 0.5137 - mse: 0.5137 - val_loss: 0.5768 - val_mse: 0.5768 - 47ms/epoch - 4ms/step
# Epoch 46/2000
# 12/12 - 0s - loss: 0.5094 - mse: 0.5094 - val_loss: 0.5745 - val_mse: 0.5745 - 79ms/epoch - 7ms/step
# Epoch 47/2000
# 12/12 - 0s - loss: 0.5061 - mse: 0.5061 - val_loss: 0.5672 - val_mse: 0.5672 - 70ms/epoch - 6ms/step
# Epoch 48/2000
# 12/12 - 0s - loss: 0.5015 - mse: 0.5015 - val_loss: 0.5696 - val_mse: 0.5696 - 49ms/epoch - 4ms/step
# Epoch 49/2000
# 12/12 - 0s - loss: 0.4969 - mse: 0.4969 - val_loss: 0.5605 - val_mse: 0.5605 - 41ms/epoch - 3ms/step
# Epoch 50/2000
# 12/12 - 0s - loss: 0.4928 - mse: 0.4928 - val_loss: 0.5539 - val_mse: 0.5539 - 38ms/epoch - 3ms/step
# Epoch 51/2000
# 12/12 - 0s - loss: 0.4893 - mse: 0.4893 - val_loss: 0.5525 - val_mse: 0.5525 - 43ms/epoch - 4ms/step
# Epoch 52/2000
# 12/12 - 0s - loss: 0.4860 - mse: 0.4860 - val_loss: 0.5468 - val_mse: 0.5468 - 42ms/epoch - 3ms/step
# Epoch 53/2000
# 12/12 - 0s - loss: 0.4822 - mse: 0.4822 - val_loss: 0.5478 - val_mse: 0.5478 - 41ms/epoch - 3ms/step
# Epoch 54/2000
# 12/12 - 0s - loss: 0.4794 - mse: 0.4794 - val_loss: 0.5365 - val_mse: 0.5365 - 50ms/epoch - 4ms/step
# Epoch 55/2000
# 12/12 - 0s - loss: 0.4741 - mse: 0.4741 - val_loss: 0.5361 - val_mse: 0.5361 - 45ms/epoch - 4ms/step
# Epoch 56/2000
# 12/12 - 0s - loss: 0.4709 - mse: 0.4709 - val_loss: 0.5343 - val_mse: 0.5343 - 44ms/epoch - 4ms/step
# Epoch 57/2000
# 12/12 - 0s - loss: 0.4675 - mse: 0.4675 - val_loss: 0.5341 - val_mse: 0.5341 - 43ms/epoch - 4ms/step
# Epoch 58/2000
# 12/12 - 0s - loss: 0.4648 - mse: 0.4648 - val_loss: 0.5302 - val_mse: 0.5302 - 58ms/epoch - 5ms/step
# Epoch 59/2000
# 12/12 - 0s - loss: 0.4615 - mse: 0.4615 - val_loss: 0.5210 - val_mse: 0.5210 - 48ms/epoch - 4ms/step
# Epoch 60/2000
# 12/12 - 0s - loss: 0.4581 - mse: 0.4581 - val_loss: 0.5175 - val_mse: 0.5175 - 47ms/epoch - 4ms/step
# Epoch 61/2000
# 12/12 - 0s - loss: 0.4555 - mse: 0.4555 - val_loss: 0.5187 - val_mse: 0.5187 - 42ms/epoch - 3ms/step
# Epoch 62/2000
# 12/12 - 0s - loss: 0.4524 - mse: 0.4524 - val_loss: 0.5152 - val_mse: 0.5152 - 48ms/epoch - 4ms/step
# Epoch 63/2000
# 12/12 - 0s - loss: 0.4498 - mse: 0.4498 - val_loss: 0.5074 - val_mse: 0.5074 - 52ms/epoch - 4ms/step
# Epoch 64/2000
# 12/12 - 0s - loss: 0.4467 - mse: 0.4467 - val_loss: 0.5088 - val_mse: 0.5088 - 50ms/epoch - 4ms/step
# Epoch 65/2000
# 12/12 - 0s - loss: 0.4444 - mse: 0.4444 - val_loss: 0.5113 - val_mse: 0.5113 - 51ms/epoch - 4ms/step
# Epoch 66/2000
# 12/12 - 0s - loss: 0.4415 - mse: 0.4415 - val_loss: 0.5027 - val_mse: 0.5027 - 47ms/epoch - 4ms/step
# Epoch 67/2000
# 12/12 - 0s - loss: 0.4393 - mse: 0.4393 - val_loss: 0.5011 - val_mse: 0.5011 - 47ms/epoch - 4ms/step
# Epoch 68/2000
# 12/12 - 0s - loss: 0.4365 - mse: 0.4365 - val_loss: 0.4970 - val_mse: 0.4970 - 63ms/epoch - 5ms/step
# Epoch 69/2000
# 12/12 - 0s - loss: 0.4354 - mse: 0.4354 - val_loss: 0.4929 - val_mse: 0.4929 - 56ms/epoch - 5ms/step
# Epoch 70/2000
# 12/12 - 0s - loss: 0.4322 - mse: 0.4322 - val_loss: 0.4944 - val_mse: 0.4944 - 46ms/epoch - 4ms/step
# Epoch 71/2000
# 12/12 - 0s - loss: 0.4309 - mse: 0.4309 - val_loss: 0.4974 - val_mse: 0.4974 - 40ms/epoch - 3ms/step
# Epoch 72/2000
# 12/12 - 0s - loss: 0.4281 - mse: 0.4281 - val_loss: 0.4865 - val_mse: 0.4865 - 44ms/epoch - 4ms/step
# Epoch 73/2000
# 12/12 - 0s - loss: 0.4268 - mse: 0.4268 - val_loss: 0.4842 - val_mse: 0.4842 - 49ms/epoch - 4ms/step
# Epoch 74/2000
# 12/12 - 0s - loss: 0.4246 - mse: 0.4246 - val_loss: 0.4828 - val_mse: 0.4828 - 47ms/epoch - 4ms/step
# Epoch 75/2000
# 12/12 - 0s - loss: 0.4214 - mse: 0.4214 - val_loss: 0.4887 - val_mse: 0.4887 - 45ms/epoch - 4ms/step
# Epoch 76/2000
# 12/12 - 0s - loss: 0.4206 - mse: 0.4206 - val_loss: 0.4886 - val_mse: 0.4886 - 50ms/epoch - 4ms/step
# Epoch 77/2000
# 12/12 - 0s - loss: 0.4179 - mse: 0.4179 - val_loss: 0.4777 - val_mse: 0.4777 - 56ms/epoch - 5ms/step
# Epoch 78/2000
# 12/12 - 0s - loss: 0.4163 - mse: 0.4163 - val_loss: 0.4793 - val_mse: 0.4793 - 52ms/epoch - 4ms/step
# Epoch 79/2000
# 12/12 - 0s - loss: 0.4145 - mse: 0.4145 - val_loss: 0.4769 - val_mse: 0.4769 - 47ms/epoch - 4ms/step
# Epoch 80/2000
# 12/12 - 0s - loss: 0.4125 - mse: 0.4125 - val_loss: 0.4818 - val_mse: 0.4818 - 51ms/epoch - 4ms/step
# Epoch 81/2000
# 12/12 - 0s - loss: 0.4108 - mse: 0.4108 - val_loss: 0.4749 - val_mse: 0.4749 - 45ms/epoch - 4ms/step
# Epoch 82/2000
# 12/12 - 0s - loss: 0.4086 - mse: 0.4086 - val_loss: 0.4705 - val_mse: 0.4705 - 56ms/epoch - 5ms/step
# Epoch 83/2000
# 12/12 - 0s - loss: 0.4070 - mse: 0.4070 - val_loss: 0.4751 - val_mse: 0.4751 - 45ms/epoch - 4ms/step
# Epoch 84/2000
# 12/12 - 0s - loss: 0.4050 - mse: 0.4050 - val_loss: 0.4717 - val_mse: 0.4717 - 53ms/epoch - 4ms/step
# Epoch 85/2000
# 12/12 - 0s - loss: 0.4031 - mse: 0.4031 - val_loss: 0.4676 - val_mse: 0.4676 - 49ms/epoch - 4ms/step
# Epoch 86/2000
# 12/12 - 0s - loss: 0.4016 - mse: 0.4016 - val_loss: 0.4642 - val_mse: 0.4642 - 43ms/epoch - 4ms/step
# Epoch 87/2000
# 12/12 - 0s - loss: 0.4003 - mse: 0.4003 - val_loss: 0.4641 - val_mse: 0.4641 - 50ms/epoch - 4ms/step
# Epoch 88/2000
# 12/12 - 0s - loss: 0.3985 - mse: 0.3985 - val_loss: 0.4597 - val_mse: 0.4597 - 53ms/epoch - 4ms/step
# Epoch 89/2000
# 12/12 - 0s - loss: 0.3968 - mse: 0.3968 - val_loss: 0.4615 - val_mse: 0.4615 - 52ms/epoch - 4ms/step
# Epoch 90/2000
# 12/12 - 0s - loss: 0.3954 - mse: 0.3954 - val_loss: 0.4617 - val_mse: 0.4617 - 46ms/epoch - 4ms/step
# Epoch 91/2000
# 12/12 - 0s - loss: 0.3940 - mse: 0.3940 - val_loss: 0.4629 - val_mse: 0.4629 - 46ms/epoch - 4ms/step
# Epoch 92/2000
# 12/12 - 0s - loss: 0.3921 - mse: 0.3921 - val_loss: 0.4565 - val_mse: 0.4565 - 46ms/epoch - 4ms/step
# Epoch 93/2000
# 12/12 - 0s - loss: 0.3904 - mse: 0.3904 - val_loss: 0.4560 - val_mse: 0.4560 - 50ms/epoch - 4ms/step
# Epoch 94/2000
# 12/12 - 0s - loss: 0.3891 - mse: 0.3891 - val_loss: 0.4538 - val_mse: 0.4538 - 55ms/epoch - 5ms/step
# Epoch 95/2000
# 12/12 - 0s - loss: 0.3874 - mse: 0.3874 - val_loss: 0.4527 - val_mse: 0.4527 - 55ms/epoch - 5ms/step
# Epoch 96/2000
# 12/12 - 0s - loss: 0.3859 - mse: 0.3859 - val_loss: 0.4494 - val_mse: 0.4494 - 50ms/epoch - 4ms/step
# Epoch 97/2000
# 12/12 - 0s - loss: 0.3845 - mse: 0.3845 - val_loss: 0.4477 - val_mse: 0.4477 - 52ms/epoch - 4ms/step
# Epoch 98/2000
# 12/12 - 0s - loss: 0.3830 - mse: 0.3830 - val_loss: 0.4440 - val_mse: 0.4440 - 50ms/epoch - 4ms/step
# Epoch 99/2000
# 12/12 - 0s - loss: 0.3829 - mse: 0.3829 - val_loss: 0.4467 - val_mse: 0.4467 - 49ms/epoch - 4ms/step
# Epoch 100/2000
# 12/12 - 0s - loss: 0.3799 - mse: 0.3799 - val_loss: 0.4423 - val_mse: 0.4423 - 47ms/epoch - 4ms/step
# Epoch 101/2000
# 12/12 - 0s - loss: 0.3781 - mse: 0.3781 - val_loss: 0.4422 - val_mse: 0.4422 - 51ms/epoch - 4ms/step
# Epoch 102/2000
# 12/12 - 0s - loss: 0.3765 - mse: 0.3765 - val_loss: 0.4428 - val_mse: 0.4428 - 57ms/epoch - 5ms/step
# Epoch 103/2000
# 12/12 - 0s - loss: 0.3751 - mse: 0.3751 - val_loss: 0.4411 - val_mse: 0.4411 - 50ms/epoch - 4ms/step
# Epoch 104/2000
# 12/12 - 0s - loss: 0.3731 - mse: 0.3731 - val_loss: 0.4353 - val_mse: 0.4353 - 48ms/epoch - 4ms/step
# Epoch 105/2000
# 12/12 - 0s - loss: 0.3716 - mse: 0.3716 - val_loss: 0.4361 - val_mse: 0.4361 - 58ms/epoch - 5ms/step
# Epoch 106/2000
# 12/12 - 0s - loss: 0.3702 - mse: 0.3702 - val_loss: 0.4331 - val_mse: 0.4331 - 48ms/epoch - 4ms/step
# Epoch 107/2000
# 12/12 - 0s - loss: 0.3684 - mse: 0.3684 - val_loss: 0.4342 - val_mse: 0.4342 - 52ms/epoch - 4ms/step
# Epoch 108/2000
# 12/12 - 0s - loss: 0.3682 - mse: 0.3682 - val_loss: 0.4332 - val_mse: 0.4332 - 46ms/epoch - 4ms/step
# Epoch 109/2000
# 12/12 - 0s - loss: 0.3656 - mse: 0.3656 - val_loss: 0.4282 - val_mse: 0.4282 - 51ms/epoch - 4ms/step
# Epoch 110/2000
# 12/12 - 0s - loss: 0.3641 - mse: 0.3641 - val_loss: 0.4302 - val_mse: 0.4302 - 46ms/epoch - 4ms/step
# Epoch 111/2000
# 12/12 - 0s - loss: 0.3616 - mse: 0.3616 - val_loss: 0.4269 - val_mse: 0.4269 - 44ms/epoch - 4ms/step
# Epoch 112/2000
# 12/12 - 0s - loss: 0.3612 - mse: 0.3612 - val_loss: 0.4266 - val_mse: 0.4266 - 45ms/epoch - 4ms/step
# Epoch 113/2000
# 12/12 - 0s - loss: 0.3589 - mse: 0.3589 - val_loss: 0.4212 - val_mse: 0.4212 - 47ms/epoch - 4ms/step
# Epoch 114/2000
# 12/12 - 0s - loss: 0.3569 - mse: 0.3569 - val_loss: 0.4222 - val_mse: 0.4222 - 44ms/epoch - 4ms/step
# Epoch 115/2000
# 12/12 - 0s - loss: 0.3558 - mse: 0.3558 - val_loss: 0.4227 - val_mse: 0.4227 - 52ms/epoch - 4ms/step
# Epoch 116/2000
# 12/12 - 0s - loss: 0.3533 - mse: 0.3533 - val_loss: 0.4192 - val_mse: 0.4192 - 43ms/epoch - 4ms/step
# Epoch 117/2000
# 12/12 - 0s - loss: 0.3524 - mse: 0.3524 - val_loss: 0.4166 - val_mse: 0.4166 - 52ms/epoch - 4ms/step
# Epoch 118/2000
# 12/12 - 0s - loss: 0.3515 - mse: 0.3515 - val_loss: 0.4146 - val_mse: 0.4146 - 71ms/epoch - 6ms/step
# Epoch 119/2000
# 12/12 - 0s - loss: 0.3494 - mse: 0.3494 - val_loss: 0.4190 - val_mse: 0.4190 - 81ms/epoch - 7ms/step
# Epoch 120/2000
# 12/12 - 0s - loss: 0.3471 - mse: 0.3471 - val_loss: 0.4144 - val_mse: 0.4144 - 48ms/epoch - 4ms/step
# Epoch 121/2000
# 12/12 - 0s - loss: 0.3461 - mse: 0.3461 - val_loss: 0.4103 - val_mse: 0.4103 - 42ms/epoch - 3ms/step
# Epoch 122/2000
# 12/12 - 0s - loss: 0.3447 - mse: 0.3447 - val_loss: 0.4165 - val_mse: 0.4165 - 53ms/epoch - 4ms/step
# Epoch 123/2000
# 12/12 - 0s - loss: 0.3428 - mse: 0.3428 - val_loss: 0.4107 - val_mse: 0.4107 - 41ms/epoch - 3ms/step
# Epoch 124/2000
# 12/12 - 0s - loss: 0.3403 - mse: 0.3403 - val_loss: 0.4055 - val_mse: 0.4055 - 44ms/epoch - 4ms/step
# Epoch 125/2000
# 12/12 - 0s - loss: 0.3387 - mse: 0.3387 - val_loss: 0.4023 - val_mse: 0.4023 - 47ms/epoch - 4ms/step
# Epoch 126/2000
# 12/12 - 0s - loss: 0.3373 - mse: 0.3373 - val_loss: 0.4054 - val_mse: 0.4054 - 45ms/epoch - 4ms/step
# Epoch 127/2000
# 12/12 - 0s - loss: 0.3354 - mse: 0.3354 - val_loss: 0.4038 - val_mse: 0.4038 - 50ms/epoch - 4ms/step
# Epoch 128/2000
# 12/12 - 0s - loss: 0.3337 - mse: 0.3337 - val_loss: 0.4014 - val_mse: 0.4014 - 52ms/epoch - 4ms/step
# Epoch 129/2000
# 12/12 - 0s - loss: 0.3328 - mse: 0.3328 - val_loss: 0.4028 - val_mse: 0.4028 - 69ms/epoch - 6ms/step
# Epoch 130/2000
# 12/12 - 0s - loss: 0.3302 - mse: 0.3302 - val_loss: 0.3929 - val_mse: 0.3929 - 57ms/epoch - 5ms/step
# Epoch 131/2000
# 12/12 - 0s - loss: 0.3283 - mse: 0.3283 - val_loss: 0.3954 - val_mse: 0.3954 - 60ms/epoch - 5ms/step
# Epoch 132/2000
# 12/12 - 0s - loss: 0.3274 - mse: 0.3274 - val_loss: 0.3958 - val_mse: 0.3958 - 59ms/epoch - 5ms/step
# Epoch 133/2000
# 12/12 - 0s - loss: 0.3255 - mse: 0.3255 - val_loss: 0.3876 - val_mse: 0.3876 - 68ms/epoch - 6ms/step
# Epoch 134/2000
# 12/12 - 0s - loss: 0.3239 - mse: 0.3239 - val_loss: 0.3932 - val_mse: 0.3932 - 65ms/epoch - 5ms/step
# Epoch 135/2000
# 12/12 - 0s - loss: 0.3221 - mse: 0.3221 - val_loss: 0.3877 - val_mse: 0.3877 - 85ms/epoch - 7ms/step
# Epoch 136/2000
# 12/12 - 0s - loss: 0.3198 - mse: 0.3198 - val_loss: 0.3851 - val_mse: 0.3851 - 79ms/epoch - 7ms/step
# Epoch 137/2000
# 12/12 - 0s - loss: 0.3180 - mse: 0.3180 - val_loss: 0.3858 - val_mse: 0.3858 - 69ms/epoch - 6ms/step
# Epoch 138/2000
# 12/12 - 0s - loss: 0.3164 - mse: 0.3164 - val_loss: 0.3774 - val_mse: 0.3774 - 78ms/epoch - 6ms/step
# Epoch 139/2000
# 12/12 - 0s - loss: 0.3145 - mse: 0.3145 - val_loss: 0.3783 - val_mse: 0.3783 - 66ms/epoch - 5ms/step
# Epoch 140/2000
# 12/12 - 0s - loss: 0.3138 - mse: 0.3138 - val_loss: 0.3837 - val_mse: 0.3837 - 65ms/epoch - 5ms/step
# Epoch 141/2000
# 12/12 - 0s - loss: 0.3122 - mse: 0.3122 - val_loss: 0.3753 - val_mse: 0.3753 - 86ms/epoch - 7ms/step
# Epoch 142/2000
# 12/12 - 0s - loss: 0.3097 - mse: 0.3097 - val_loss: 0.3771 - val_mse: 0.3771 - 76ms/epoch - 6ms/step
# Epoch 143/2000
# 12/12 - 0s - loss: 0.3073 - mse: 0.3073 - val_loss: 0.3711 - val_mse: 0.3711 - 68ms/epoch - 6ms/step
# Epoch 144/2000
# 12/12 - 0s - loss: 0.3058 - mse: 0.3058 - val_loss: 0.3722 - val_mse: 0.3722 - 65ms/epoch - 5ms/step
# Epoch 145/2000
# 12/12 - 0s - loss: 0.3040 - mse: 0.3040 - val_loss: 0.3654 - val_mse: 0.3654 - 67ms/epoch - 6ms/step
# Epoch 146/2000
# 12/12 - 0s - loss: 0.3027 - mse: 0.3027 - val_loss: 0.3677 - val_mse: 0.3677 - 72ms/epoch - 6ms/step
# Epoch 147/2000
# 12/12 - 0s - loss: 0.3007 - mse: 0.3007 - val_loss: 0.3643 - val_mse: 0.3643 - 79ms/epoch - 7ms/step
# Epoch 148/2000
# 12/12 - 0s - loss: 0.2991 - mse: 0.2991 - val_loss: 0.3645 - val_mse: 0.3645 - 62ms/epoch - 5ms/step
# Epoch 149/2000
# 12/12 - 0s - loss: 0.2964 - mse: 0.2964 - val_loss: 0.3588 - val_mse: 0.3588 - 69ms/epoch - 6ms/step
# Epoch 150/2000
# 12/12 - 0s - loss: 0.2953 - mse: 0.2953 - val_loss: 0.3598 - val_mse: 0.3598 - 67ms/epoch - 6ms/step
# Epoch 151/2000
# 12/12 - 0s - loss: 0.2937 - mse: 0.2937 - val_loss: 0.3551 - val_mse: 0.3551 - 60ms/epoch - 5ms/step
# Epoch 152/2000
# 12/12 - 0s - loss: 0.2910 - mse: 0.2910 - val_loss: 0.3569 - val_mse: 0.3569 - 67ms/epoch - 6ms/step
# Epoch 153/2000
# 12/12 - 0s - loss: 0.2898 - mse: 0.2898 - val_loss: 0.3564 - val_mse: 0.3564 - 63ms/epoch - 5ms/step
# Epoch 154/2000
# 12/12 - 0s - loss: 0.2881 - mse: 0.2881 - val_loss: 0.3483 - val_mse: 0.3483 - 73ms/epoch - 6ms/step
# Epoch 155/2000
# 12/12 - 0s - loss: 0.2863 - mse: 0.2863 - val_loss: 0.3507 - val_mse: 0.3507 - 69ms/epoch - 6ms/step
# Epoch 156/2000
# 12/12 - 0s - loss: 0.2843 - mse: 0.2843 - val_loss: 0.3475 - val_mse: 0.3475 - 68ms/epoch - 6ms/step
# Epoch 157/2000
# 12/12 - 0s - loss: 0.2842 - mse: 0.2842 - val_loss: 0.3428 - val_mse: 0.3428 - 67ms/epoch - 6ms/step
# Epoch 158/2000
# 12/12 - 0s - loss: 0.2808 - mse: 0.2808 - val_loss: 0.3485 - val_mse: 0.3485 - 66ms/epoch - 5ms/step
# Epoch 159/2000
# 12/12 - 0s - loss: 0.2787 - mse: 0.2787 - val_loss: 0.3377 - val_mse: 0.3377 - 64ms/epoch - 5ms/step
# Epoch 160/2000
# 12/12 - 0s - loss: 0.2795 - mse: 0.2795 - val_loss: 0.3367 - val_mse: 0.3367 - 64ms/epoch - 5ms/step
# Epoch 161/2000
# 12/12 - 0s - loss: 0.2756 - mse: 0.2756 - val_loss: 0.3407 - val_mse: 0.3407 - 68ms/epoch - 6ms/step
# Epoch 162/2000
# 12/12 - 0s - loss: 0.2739 - mse: 0.2739 - val_loss: 0.3361 - val_mse: 0.3361 - 63ms/epoch - 5ms/step
# Epoch 163/2000
# 12/12 - 0s - loss: 0.2731 - mse: 0.2731 - val_loss: 0.3302 - val_mse: 0.3302 - 90ms/epoch - 7ms/step
# Epoch 164/2000
# 12/12 - 0s - loss: 0.2692 - mse: 0.2692 - val_loss: 0.3380 - val_mse: 0.3380 - 83ms/epoch - 7ms/step
# Epoch 165/2000
# 12/12 - 0s - loss: 0.2692 - mse: 0.2692 - val_loss: 0.3345 - val_mse: 0.3345 - 77ms/epoch - 6ms/step
# Epoch 166/2000
# 12/12 - 0s - loss: 0.2665 - mse: 0.2665 - val_loss: 0.3270 - val_mse: 0.3270 - 71ms/epoch - 6ms/step
# Epoch 167/2000
# 12/12 - 0s - loss: 0.2647 - mse: 0.2647 - val_loss: 0.3249 - val_mse: 0.3249 - 69ms/epoch - 6ms/step
# Epoch 168/2000
# 12/12 - 0s - loss: 0.2630 - mse: 0.2630 - val_loss: 0.3248 - val_mse: 0.3248 - 68ms/epoch - 6ms/step
# Epoch 169/2000
# 12/12 - 0s - loss: 0.2616 - mse: 0.2616 - val_loss: 0.3246 - val_mse: 0.3246 - 70ms/epoch - 6ms/step
# Epoch 170/2000
# 12/12 - 0s - loss: 0.2627 - mse: 0.2627 - val_loss: 0.3174 - val_mse: 0.3174 - 69ms/epoch - 6ms/step
# Epoch 171/2000
# 12/12 - 0s - loss: 0.2588 - mse: 0.2588 - val_loss: 0.3225 - val_mse: 0.3225 - 73ms/epoch - 6ms/step
# Epoch 172/2000
# 12/12 - 0s - loss: 0.2562 - mse: 0.2562 - val_loss: 0.3149 - val_mse: 0.3149 - 76ms/epoch - 6ms/step
# Epoch 173/2000
# 12/12 - 0s - loss: 0.2547 - mse: 0.2547 - val_loss: 0.3155 - val_mse: 0.3155 - 67ms/epoch - 6ms/step
# Epoch 174/2000
# 12/12 - 0s - loss: 0.2528 - mse: 0.2528 - val_loss: 0.3120 - val_mse: 0.3120 - 69ms/epoch - 6ms/step
# Epoch 175/2000
# 12/12 - 0s - loss: 0.2531 - mse: 0.2531 - val_loss: 0.3083 - val_mse: 0.3083 - 70ms/epoch - 6ms/step
# Epoch 176/2000
# 12/12 - 0s - loss: 0.2497 - mse: 0.2497 - val_loss: 0.3110 - val_mse: 0.3110 - 62ms/epoch - 5ms/step
# Epoch 177/2000
# 12/12 - 0s - loss: 0.2474 - mse: 0.2474 - val_loss: 0.3084 - val_mse: 0.3084 - 64ms/epoch - 5ms/step
# Epoch 178/2000
# 12/12 - 0s - loss: 0.2466 - mse: 0.2466 - val_loss: 0.3059 - val_mse: 0.3059 - 69ms/epoch - 6ms/step
# Epoch 179/2000
# 12/12 - 0s - loss: 0.2439 - mse: 0.2439 - val_loss: 0.3032 - val_mse: 0.3032 - 63ms/epoch - 5ms/step
# Epoch 180/2000
# 12/12 - 0s - loss: 0.2427 - mse: 0.2427 - val_loss: 0.3020 - val_mse: 0.3020 - 65ms/epoch - 5ms/step
# Epoch 181/2000
# 12/12 - 0s - loss: 0.2407 - mse: 0.2407 - val_loss: 0.3011 - val_mse: 0.3011 - 61ms/epoch - 5ms/step
# Epoch 182/2000
# 12/12 - 0s - loss: 0.2395 - mse: 0.2395 - val_loss: 0.3053 - val_mse: 0.3053 - 61ms/epoch - 5ms/step
# Epoch 183/2000
# 12/12 - 0s - loss: 0.2381 - mse: 0.2381 - val_loss: 0.2990 - val_mse: 0.2990 - 67ms/epoch - 6ms/step
# Epoch 184/2000
# 12/12 - 0s - loss: 0.2356 - mse: 0.2356 - val_loss: 0.2951 - val_mse: 0.2951 - 62ms/epoch - 5ms/step
# Epoch 185/2000
# 12/12 - 0s - loss: 0.2341 - mse: 0.2341 - val_loss: 0.2919 - val_mse: 0.2919 - 68ms/epoch - 6ms/step
# Epoch 186/2000
# 12/12 - 0s - loss: 0.2323 - mse: 0.2323 - val_loss: 0.2882 - val_mse: 0.2882 - 60ms/epoch - 5ms/step
# Epoch 187/2000
# 12/12 - 0s - loss: 0.2311 - mse: 0.2311 - val_loss: 0.2894 - val_mse: 0.2894 - 63ms/epoch - 5ms/step
# Epoch 188/2000
# 12/12 - 0s - loss: 0.2302 - mse: 0.2302 - val_loss: 0.2924 - val_mse: 0.2924 - 60ms/epoch - 5ms/step
# Epoch 189/2000
# 12/12 - 0s - loss: 0.2287 - mse: 0.2287 - val_loss: 0.2821 - val_mse: 0.2821 - 64ms/epoch - 5ms/step
# Epoch 190/2000
# 12/12 - 0s - loss: 0.2264 - mse: 0.2264 - val_loss: 0.2849 - val_mse: 0.2849 - 67ms/epoch - 6ms/step
# Epoch 191/2000
# 12/12 - 0s - loss: 0.2256 - mse: 0.2256 - val_loss: 0.2850 - val_mse: 0.2850 - 64ms/epoch - 5ms/step
# Epoch 192/2000
# 12/12 - 0s - loss: 0.2247 - mse: 0.2247 - val_loss: 0.2774 - val_mse: 0.2774 - 63ms/epoch - 5ms/step
# Epoch 193/2000
# 12/12 - 0s - loss: 0.2213 - mse: 0.2213 - val_loss: 0.2806 - val_mse: 0.2806 - 65ms/epoch - 5ms/step
# Epoch 194/2000
# 12/12 - 0s - loss: 0.2201 - mse: 0.2201 - val_loss: 0.2774 - val_mse: 0.2774 - 65ms/epoch - 5ms/step
# Epoch 195/2000
# 12/12 - 0s - loss: 0.2182 - mse: 0.2182 - val_loss: 0.2768 - val_mse: 0.2768 - 61ms/epoch - 5ms/step
# Epoch 196/2000
# 12/12 - 0s - loss: 0.2172 - mse: 0.2172 - val_loss: 0.2742 - val_mse: 0.2742 - 64ms/epoch - 5ms/step
# Epoch 197/2000
# 12/12 - 0s - loss: 0.2183 - mse: 0.2183 - val_loss: 0.2696 - val_mse: 0.2696 - 67ms/epoch - 6ms/step
# Epoch 198/2000
# 12/12 - 0s - loss: 0.2140 - mse: 0.2140 - val_loss: 0.2716 - val_mse: 0.2716 - 66ms/epoch - 5ms/step
# Epoch 199/2000
# 12/12 - 0s - loss: 0.2132 - mse: 0.2132 - val_loss: 0.2721 - val_mse: 0.2721 - 67ms/epoch - 6ms/step
# Epoch 200/2000
# 12/12 - 0s - loss: 0.2131 - mse: 0.2131 - val_loss: 0.2675 - val_mse: 0.2675 - 67ms/epoch - 6ms/step
# Epoch 201/2000
# 12/12 - 0s - loss: 0.2115 - mse: 0.2115 - val_loss: 0.2672 - val_mse: 0.2672 - 66ms/epoch - 5ms/step
# Epoch 202/2000
# 12/12 - 0s - loss: 0.2082 - mse: 0.2082 - val_loss: 0.2634 - val_mse: 0.2634 - 63ms/epoch - 5ms/step
# Epoch 203/2000
# 12/12 - 0s - loss: 0.2073 - mse: 0.2073 - val_loss: 0.2626 - val_mse: 0.2626 - 66ms/epoch - 5ms/step
# Epoch 204/2000
# 12/12 - 0s - loss: 0.2052 - mse: 0.2052 - val_loss: 0.2575 - val_mse: 0.2575 - 68ms/epoch - 6ms/step
# Epoch 205/2000
# 12/12 - 0s - loss: 0.2060 - mse: 0.2060 - val_loss: 0.2598 - val_mse: 0.2598 - 69ms/epoch - 6ms/step
# Epoch 206/2000
# 12/12 - 0s - loss: 0.2038 - mse: 0.2038 - val_loss: 0.2559 - val_mse: 0.2559 - 99ms/epoch - 8ms/step
# Epoch 207/2000
# 12/12 - 0s - loss: 0.2028 - mse: 0.2028 - val_loss: 0.2553 - val_mse: 0.2553 - 97ms/epoch - 8ms/step
# Epoch 208/2000
# 12/12 - 0s - loss: 0.2002 - mse: 0.2002 - val_loss: 0.2526 - val_mse: 0.2526 - 74ms/epoch - 6ms/step
# Epoch 209/2000
# 12/12 - 0s - loss: 0.1986 - mse: 0.1986 - val_loss: 0.2562 - val_mse: 0.2562 - 79ms/epoch - 7ms/step
# Epoch 210/2000
# 12/12 - 0s - loss: 0.1979 - mse: 0.1979 - val_loss: 0.2467 - val_mse: 0.2467 - 75ms/epoch - 6ms/step
# Epoch 211/2000
# 12/12 - 0s - loss: 0.1957 - mse: 0.1957 - val_loss: 0.2484 - val_mse: 0.2484 - 72ms/epoch - 6ms/step
# Epoch 212/2000
# 12/12 - 0s - loss: 0.1947 - mse: 0.1947 - val_loss: 0.2505 - val_mse: 0.2505 - 74ms/epoch - 6ms/step
# Epoch 213/2000
# 12/12 - 0s - loss: 0.1933 - mse: 0.1933 - val_loss: 0.2469 - val_mse: 0.2469 - 80ms/epoch - 7ms/step
# Epoch 214/2000
# 12/12 - 0s - loss: 0.1915 - mse: 0.1915 - val_loss: 0.2431 - val_mse: 0.2431 - 76ms/epoch - 6ms/step
# Epoch 215/2000
# 12/12 - 0s - loss: 0.1899 - mse: 0.1899 - val_loss: 0.2415 - val_mse: 0.2415 - 78ms/epoch - 6ms/step
# Epoch 216/2000
# 12/12 - 0s - loss: 0.1889 - mse: 0.1889 - val_loss: 0.2391 - val_mse: 0.2391 - 79ms/epoch - 7ms/step
# Epoch 217/2000
# 12/12 - 0s - loss: 0.1878 - mse: 0.1878 - val_loss: 0.2378 - val_mse: 0.2378 - 76ms/epoch - 6ms/step
# Epoch 218/2000
# 12/12 - 0s - loss: 0.1868 - mse: 0.1868 - val_loss: 0.2350 - val_mse: 0.2350 - 71ms/epoch - 6ms/step
# Epoch 219/2000
# 12/12 - 0s - loss: 0.1850 - mse: 0.1850 - val_loss: 0.2386 - val_mse: 0.2386 - 77ms/epoch - 6ms/step
# Epoch 220/2000
# 12/12 - 0s - loss: 0.1848 - mse: 0.1848 - val_loss: 0.2317 - val_mse: 0.2317 - 74ms/epoch - 6ms/step
# Epoch 221/2000
# 12/12 - 0s - loss: 0.1820 - mse: 0.1820 - val_loss: 0.2348 - val_mse: 0.2348 - 70ms/epoch - 6ms/step
# Epoch 222/2000
# 12/12 - 0s - loss: 0.1817 - mse: 0.1817 - val_loss: 0.2295 - val_mse: 0.2295 - 70ms/epoch - 6ms/step
# Epoch 223/2000
# 12/12 - 0s - loss: 0.1804 - mse: 0.1804 - val_loss: 0.2289 - val_mse: 0.2289 - 72ms/epoch - 6ms/step
# Epoch 224/2000
# 12/12 - 0s - loss: 0.1787 - mse: 0.1787 - val_loss: 0.2274 - val_mse: 0.2274 - 62ms/epoch - 5ms/step
# Epoch 225/2000
# 12/12 - 0s - loss: 0.1771 - mse: 0.1771 - val_loss: 0.2257 - val_mse: 0.2257 - 69ms/epoch - 6ms/step
# Epoch 226/2000
# 12/12 - 0s - loss: 0.1757 - mse: 0.1757 - val_loss: 0.2211 - val_mse: 0.2211 - 65ms/epoch - 5ms/step
# Epoch 227/2000
# 12/12 - 0s - loss: 0.1753 - mse: 0.1753 - val_loss: 0.2220 - val_mse: 0.2220 - 71ms/epoch - 6ms/step
# Epoch 228/2000
# 12/12 - 0s - loss: 0.1738 - mse: 0.1738 - val_loss: 0.2197 - val_mse: 0.2197 - 65ms/epoch - 5ms/step
# Epoch 229/2000
# 12/12 - 0s - loss: 0.1735 - mse: 0.1735 - val_loss: 0.2189 - val_mse: 0.2189 - 65ms/epoch - 5ms/step
# Epoch 230/2000
# 12/12 - 0s - loss: 0.1716 - mse: 0.1716 - val_loss: 0.2171 - val_mse: 0.2171 - 63ms/epoch - 5ms/step
# Epoch 231/2000
# 12/12 - 0s - loss: 0.1704 - mse: 0.1704 - val_loss: 0.2172 - val_mse: 0.2172 - 59ms/epoch - 5ms/step
# Epoch 232/2000
# 12/12 - 0s - loss: 0.1689 - mse: 0.1689 - val_loss: 0.2156 - val_mse: 0.2156 - 65ms/epoch - 5ms/step
# Epoch 233/2000
# 12/12 - 0s - loss: 0.1679 - mse: 0.1679 - val_loss: 0.2126 - val_mse: 0.2126 - 63ms/epoch - 5ms/step
# Epoch 234/2000
# 12/12 - 0s - loss: 0.1666 - mse: 0.1666 - val_loss: 0.2117 - val_mse: 0.2117 - 63ms/epoch - 5ms/step
# Epoch 235/2000
# 12/12 - 0s - loss: 0.1656 - mse: 0.1656 - val_loss: 0.2102 - val_mse: 0.2102 - 68ms/epoch - 6ms/step
# Epoch 236/2000
# 12/12 - 0s - loss: 0.1641 - mse: 0.1641 - val_loss: 0.2089 - val_mse: 0.2089 - 70ms/epoch - 6ms/step
# Epoch 237/2000
# 12/12 - 0s - loss: 0.1632 - mse: 0.1632 - val_loss: 0.2049 - val_mse: 0.2049 - 67ms/epoch - 6ms/step
# Epoch 238/2000
# 12/12 - 0s - loss: 0.1626 - mse: 0.1626 - val_loss: 0.2048 - val_mse: 0.2048 - 66ms/epoch - 5ms/step
# Epoch 239/2000
# 12/12 - 0s - loss: 0.1605 - mse: 0.1605 - val_loss: 0.2011 - val_mse: 0.2011 - 65ms/epoch - 5ms/step
# Epoch 240/2000
# 12/12 - 0s - loss: 0.1611 - mse: 0.1611 - val_loss: 0.1999 - val_mse: 0.1999 - 108ms/epoch - 9ms/step
# Epoch 241/2000
# 12/12 - 0s - loss: 0.1584 - mse: 0.1584 - val_loss: 0.2040 - val_mse: 0.2040 - 79ms/epoch - 7ms/step
# Epoch 242/2000
# 12/12 - 0s - loss: 0.1594 - mse: 0.1594 - val_loss: 0.1992 - val_mse: 0.1992 - 80ms/epoch - 7ms/step
# Epoch 243/2000
# 12/12 - 0s - loss: 0.1572 - mse: 0.1572 - val_loss: 0.1977 - val_mse: 0.1977 - 82ms/epoch - 7ms/step
# Epoch 244/2000
# 12/12 - 0s - loss: 0.1556 - mse: 0.1556 - val_loss: 0.1962 - val_mse: 0.1962 - 75ms/epoch - 6ms/step
# Epoch 245/2000
# 12/12 - 0s - loss: 0.1559 - mse: 0.1559 - val_loss: 0.1934 - val_mse: 0.1934 - 76ms/epoch - 6ms/step
# Epoch 246/2000
# 12/12 - 0s - loss: 0.1536 - mse: 0.1536 - val_loss: 0.1926 - val_mse: 0.1926 - 70ms/epoch - 6ms/step
# Epoch 247/2000
# 12/12 - 0s - loss: 0.1530 - mse: 0.1530 - val_loss: 0.1920 - val_mse: 0.1920 - 67ms/epoch - 6ms/step
# Epoch 248/2000
# 12/12 - 0s - loss: 0.1534 - mse: 0.1534 - val_loss: 0.1896 - val_mse: 0.1896 - 66ms/epoch - 5ms/step
# Epoch 249/2000
# 12/12 - 0s - loss: 0.1513 - mse: 0.1513 - val_loss: 0.1918 - val_mse: 0.1918 - 67ms/epoch - 6ms/step
# Epoch 250/2000
# 12/12 - 0s - loss: 0.1496 - mse: 0.1496 - val_loss: 0.1874 - val_mse: 0.1874 - 68ms/epoch - 6ms/step
# Epoch 251/2000
# 12/12 - 0s - loss: 0.1484 - mse: 0.1484 - val_loss: 0.1864 - val_mse: 0.1864 - 71ms/epoch - 6ms/step
# Epoch 252/2000
# 12/12 - 0s - loss: 0.1488 - mse: 0.1488 - val_loss: 0.1849 - val_mse: 0.1849 - 72ms/epoch - 6ms/step
# Epoch 253/2000
# 12/12 - 0s - loss: 0.1491 - mse: 0.1491 - val_loss: 0.1868 - val_mse: 0.1868 - 76ms/epoch - 6ms/step
# Epoch 254/2000
# 12/12 - 0s - loss: 0.1455 - mse: 0.1455 - val_loss: 0.1813 - val_mse: 0.1813 - 72ms/epoch - 6ms/step
# Epoch 255/2000
# 12/12 - 0s - loss: 0.1451 - mse: 0.1451 - val_loss: 0.1810 - val_mse: 0.1810 - 66ms/epoch - 5ms/step
# Epoch 256/2000
# 12/12 - 0s - loss: 0.1441 - mse: 0.1441 - val_loss: 0.1819 - val_mse: 0.1819 - 72ms/epoch - 6ms/step
# Epoch 257/2000
# 12/12 - 0s - loss: 0.1432 - mse: 0.1432 - val_loss: 0.1786 - val_mse: 0.1786 - 72ms/epoch - 6ms/step
# Epoch 258/2000
# 12/12 - 0s - loss: 0.1424 - mse: 0.1424 - val_loss: 0.1791 - val_mse: 0.1791 - 65ms/epoch - 5ms/step
# Epoch 259/2000
# 12/12 - 0s - loss: 0.1421 - mse: 0.1421 - val_loss: 0.1766 - val_mse: 0.1766 - 67ms/epoch - 6ms/step
# Epoch 260/2000
# 12/12 - 0s - loss: 0.1406 - mse: 0.1406 - val_loss: 0.1746 - val_mse: 0.1746 - 72ms/epoch - 6ms/step
# Epoch 261/2000
# 12/12 - 0s - loss: 0.1405 - mse: 0.1405 - val_loss: 0.1745 - val_mse: 0.1745 - 67ms/epoch - 6ms/step
# Epoch 262/2000
# 12/12 - 0s - loss: 0.1391 - mse: 0.1391 - val_loss: 0.1724 - val_mse: 0.1724 - 69ms/epoch - 6ms/step
# Epoch 263/2000
# 12/12 - 0s - loss: 0.1379 - mse: 0.1379 - val_loss: 0.1735 - val_mse: 0.1735 - 69ms/epoch - 6ms/step
# Epoch 264/2000
# 12/12 - 0s - loss: 0.1383 - mse: 0.1383 - val_loss: 0.1736 - val_mse: 0.1736 - 73ms/epoch - 6ms/step
# Epoch 265/2000
# 12/12 - 0s - loss: 0.1380 - mse: 0.1380 - val_loss: 0.1686 - val_mse: 0.1686 - 69ms/epoch - 6ms/step
# Epoch 266/2000
# 12/12 - 0s - loss: 0.1361 - mse: 0.1361 - val_loss: 0.1706 - val_mse: 0.1706 - 84ms/epoch - 7ms/step
# Epoch 267/2000
# 12/12 - 0s - loss: 0.1353 - mse: 0.1353 - val_loss: 0.1686 - val_mse: 0.1686 - 96ms/epoch - 8ms/step
# Epoch 268/2000
# 12/12 - 0s - loss: 0.1340 - mse: 0.1340 - val_loss: 0.1660 - val_mse: 0.1660 - 82ms/epoch - 7ms/step
# Epoch 269/2000
# 12/12 - 0s - loss: 0.1332 - mse: 0.1332 - val_loss: 0.1662 - val_mse: 0.1662 - 83ms/epoch - 7ms/step
# Epoch 270/2000
# 12/12 - 0s - loss: 0.1327 - mse: 0.1327 - val_loss: 0.1656 - val_mse: 0.1656 - 81ms/epoch - 7ms/step
# Epoch 271/2000
# 12/12 - 0s - loss: 0.1317 - mse: 0.1317 - val_loss: 0.1651 - val_mse: 0.1651 - 71ms/epoch - 6ms/step
# Epoch 272/2000
# 12/12 - 0s - loss: 0.1314 - mse: 0.1314 - val_loss: 0.1631 - val_mse: 0.1631 - 72ms/epoch - 6ms/step
# Epoch 273/2000
# 12/12 - 0s - loss: 0.1309 - mse: 0.1309 - val_loss: 0.1614 - val_mse: 0.1614 - 72ms/epoch - 6ms/step
# Epoch 274/2000
# 12/12 - 0s - loss: 0.1302 - mse: 0.1302 - val_loss: 0.1640 - val_mse: 0.1640 - 69ms/epoch - 6ms/step
# Epoch 275/2000
# 12/12 - 0s - loss: 0.1303 - mse: 0.1303 - val_loss: 0.1596 - val_mse: 0.1596 - 65ms/epoch - 5ms/step
# Epoch 276/2000
# 12/12 - 0s - loss: 0.1288 - mse: 0.1288 - val_loss: 0.1608 - val_mse: 0.1608 - 68ms/epoch - 6ms/step
# Epoch 277/2000
# 12/12 - 0s - loss: 0.1280 - mse: 0.1280 - val_loss: 0.1578 - val_mse: 0.1578 - 68ms/epoch - 6ms/step
# Epoch 278/2000
# 12/12 - 0s - loss: 0.1275 - mse: 0.1275 - val_loss: 0.1591 - val_mse: 0.1591 - 74ms/epoch - 6ms/step
# Epoch 279/2000
# 12/12 - 0s - loss: 0.1270 - mse: 0.1270 - val_loss: 0.1556 - val_mse: 0.1556 - 75ms/epoch - 6ms/step
# Epoch 280/2000
# 12/12 - 0s - loss: 0.1260 - mse: 0.1260 - val_loss: 0.1564 - val_mse: 0.1564 - 81ms/epoch - 7ms/step
# Epoch 281/2000
# 12/12 - 0s - loss: 0.1255 - mse: 0.1255 - val_loss: 0.1551 - val_mse: 0.1551 - 80ms/epoch - 7ms/step
# Epoch 282/2000
# 12/12 - 0s - loss: 0.1261 - mse: 0.1261 - val_loss: 0.1554 - val_mse: 0.1554 - 66ms/epoch - 5ms/step
# Epoch 283/2000
# 12/12 - 0s - loss: 0.1260 - mse: 0.1260 - val_loss: 0.1538 - val_mse: 0.1538 - 58ms/epoch - 5ms/step
# Epoch 284/2000
# 12/12 - 0s - loss: 0.1241 - mse: 0.1241 - val_loss: 0.1532 - val_mse: 0.1532 - 62ms/epoch - 5ms/step
# Epoch 285/2000
# 12/12 - 0s - loss: 0.1236 - mse: 0.1236 - val_loss: 0.1513 - val_mse: 0.1513 - 59ms/epoch - 5ms/step
# Epoch 286/2000
# 12/12 - 0s - loss: 0.1228 - mse: 0.1228 - val_loss: 0.1506 - val_mse: 0.1506 - 66ms/epoch - 5ms/step
# Epoch 287/2000
# 12/12 - 0s - loss: 0.1215 - mse: 0.1215 - val_loss: 0.1525 - val_mse: 0.1525 - 68ms/epoch - 6ms/step
# Epoch 288/2000
# 12/12 - 0s - loss: 0.1223 - mse: 0.1223 - val_loss: 0.1492 - val_mse: 0.1492 - 67ms/epoch - 6ms/step
# Epoch 289/2000
# 12/12 - 0s - loss: 0.1206 - mse: 0.1206 - val_loss: 0.1495 - val_mse: 0.1495 - 65ms/epoch - 5ms/step
# Epoch 290/2000
# 12/12 - 0s - loss: 0.1200 - mse: 0.1200 - val_loss: 0.1493 - val_mse: 0.1493 - 58ms/epoch - 5ms/step
# Epoch 291/2000
# 12/12 - 0s - loss: 0.1196 - mse: 0.1196 - val_loss: 0.1470 - val_mse: 0.1470 - 59ms/epoch - 5ms/step
# Epoch 292/2000
# 12/12 - 0s - loss: 0.1191 - mse: 0.1191 - val_loss: 0.1465 - val_mse: 0.1465 - 60ms/epoch - 5ms/step
# Epoch 293/2000
# 12/12 - 0s - loss: 0.1186 - mse: 0.1186 - val_loss: 0.1478 - val_mse: 0.1478 - 61ms/epoch - 5ms/step
# Epoch 294/2000
# 12/12 - 0s - loss: 0.1183 - mse: 0.1183 - val_loss: 0.1448 - val_mse: 0.1448 - 68ms/epoch - 6ms/step
# Epoch 295/2000
# 12/12 - 0s - loss: 0.1187 - mse: 0.1187 - val_loss: 0.1452 - val_mse: 0.1452 - 61ms/epoch - 5ms/step
# Epoch 296/2000
# 12/12 - 0s - loss: 0.1173 - mse: 0.1173 - val_loss: 0.1447 - val_mse: 0.1447 - 65ms/epoch - 5ms/step
# Epoch 297/2000
# 12/12 - 0s - loss: 0.1167 - mse: 0.1167 - val_loss: 0.1428 - val_mse: 0.1428 - 60ms/epoch - 5ms/step
# Epoch 298/2000
# 12/12 - 0s - loss: 0.1161 - mse: 0.1161 - val_loss: 0.1419 - val_mse: 0.1419 - 64ms/epoch - 5ms/step
# Epoch 299/2000
# 12/12 - 0s - loss: 0.1155 - mse: 0.1155 - val_loss: 0.1423 - val_mse: 0.1423 - 58ms/epoch - 5ms/step
# Epoch 300/2000
# 12/12 - 0s - loss: 0.1151 - mse: 0.1151 - val_loss: 0.1407 - val_mse: 0.1407 - 60ms/epoch - 5ms/step
# Epoch 301/2000
# 12/12 - 0s - loss: 0.1150 - mse: 0.1150 - val_loss: 0.1405 - val_mse: 0.1405 - 59ms/epoch - 5ms/step
# Epoch 302/2000
# 12/12 - 0s - loss: 0.1142 - mse: 0.1142 - val_loss: 0.1391 - val_mse: 0.1391 - 60ms/epoch - 5ms/step
# Epoch 303/2000
# 12/12 - 0s - loss: 0.1140 - mse: 0.1140 - val_loss: 0.1418 - val_mse: 0.1418 - 59ms/epoch - 5ms/step
# Epoch 304/2000
# 12/12 - 0s - loss: 0.1149 - mse: 0.1149 - val_loss: 0.1390 - val_mse: 0.1390 - 63ms/epoch - 5ms/step
# Epoch 305/2000
# 12/12 - 0s - loss: 0.1148 - mse: 0.1148 - val_loss: 0.1378 - val_mse: 0.1378 - 75ms/epoch - 6ms/step
# Epoch 306/2000
# 12/12 - 0s - loss: 0.1122 - mse: 0.1122 - val_loss: 0.1386 - val_mse: 0.1386 - 99ms/epoch - 8ms/step
# Epoch 307/2000
# 12/12 - 0s - loss: 0.1120 - mse: 0.1120 - val_loss: 0.1366 - val_mse: 0.1366 - 83ms/epoch - 7ms/step
# Epoch 308/2000
# 12/12 - 0s - loss: 0.1122 - mse: 0.1122 - val_loss: 0.1363 - val_mse: 0.1363 - 69ms/epoch - 6ms/step
# Epoch 309/2000
# 12/12 - 0s - loss: 0.1112 - mse: 0.1112 - val_loss: 0.1358 - val_mse: 0.1358 - 69ms/epoch - 6ms/step
# Epoch 310/2000
# 12/12 - 0s - loss: 0.1109 - mse: 0.1109 - val_loss: 0.1373 - val_mse: 0.1373 - 63ms/epoch - 5ms/step
# Epoch 311/2000
# 12/12 - 0s - loss: 0.1105 - mse: 0.1105 - val_loss: 0.1336 - val_mse: 0.1336 - 64ms/epoch - 5ms/step
# Epoch 312/2000
# 12/12 - 0s - loss: 0.1105 - mse: 0.1105 - val_loss: 0.1342 - val_mse: 0.1342 - 60ms/epoch - 5ms/step
# Epoch 313/2000
# 12/12 - 0s - loss: 0.1098 - mse: 0.1098 - val_loss: 0.1337 - val_mse: 0.1337 - 64ms/epoch - 5ms/step
# Epoch 314/2000
# 12/12 - 0s - loss: 0.1102 - mse: 0.1102 - val_loss: 0.1330 - val_mse: 0.1330 - 62ms/epoch - 5ms/step
# Epoch 315/2000
# 12/12 - 0s - loss: 0.1087 - mse: 0.1087 - val_loss: 0.1319 - val_mse: 0.1319 - 62ms/epoch - 5ms/step
# Epoch 316/2000
# 12/12 - 0s - loss: 0.1089 - mse: 0.1089 - val_loss: 0.1333 - val_mse: 0.1333 - 64ms/epoch - 5ms/step
# Epoch 317/2000
# 12/12 - 0s - loss: 0.1080 - mse: 0.1080 - val_loss: 0.1316 - val_mse: 0.1316 - 61ms/epoch - 5ms/step
# Epoch 318/2000
# 12/12 - 0s - loss: 0.1083 - mse: 0.1083 - val_loss: 0.1313 - val_mse: 0.1313 - 63ms/epoch - 5ms/step
# Epoch 319/2000
# 12/12 - 0s - loss: 0.1076 - mse: 0.1076 - val_loss: 0.1301 - val_mse: 0.1301 - 63ms/epoch - 5ms/step
# Epoch 320/2000
# 12/12 - 0s - loss: 0.1069 - mse: 0.1069 - val_loss: 0.1288 - val_mse: 0.1288 - 63ms/epoch - 5ms/step
# Epoch 321/2000
# 12/12 - 0s - loss: 0.1072 - mse: 0.1072 - val_loss: 0.1299 - val_mse: 0.1299 - 63ms/epoch - 5ms/step
# Epoch 322/2000
# 12/12 - 0s - loss: 0.1068 - mse: 0.1068 - val_loss: 0.1268 - val_mse: 0.1268 - 64ms/epoch - 5ms/step
# Epoch 323/2000
# 12/12 - 0s - loss: 0.1059 - mse: 0.1059 - val_loss: 0.1293 - val_mse: 0.1293 - 63ms/epoch - 5ms/step
# Epoch 324/2000
# 12/12 - 0s - loss: 0.1056 - mse: 0.1056 - val_loss: 0.1273 - val_mse: 0.1273 - 63ms/epoch - 5ms/step
# Epoch 325/2000
# 12/12 - 0s - loss: 0.1051 - mse: 0.1051 - val_loss: 0.1261 - val_mse: 0.1261 - 64ms/epoch - 5ms/step
# Epoch 326/2000
# 12/12 - 0s - loss: 0.1045 - mse: 0.1045 - val_loss: 0.1272 - val_mse: 0.1272 - 64ms/epoch - 5ms/step
# Epoch 327/2000
# 12/12 - 0s - loss: 0.1047 - mse: 0.1047 - val_loss: 0.1267 - val_mse: 0.1267 - 66ms/epoch - 5ms/step
# Epoch 328/2000
# 12/12 - 0s - loss: 0.1044 - mse: 0.1044 - val_loss: 0.1256 - val_mse: 0.1256 - 66ms/epoch - 5ms/step
# Epoch 329/2000
# 12/12 - 0s - loss: 0.1041 - mse: 0.1041 - val_loss: 0.1275 - val_mse: 0.1275 - 71ms/epoch - 6ms/step
# Epoch 330/2000
# 12/12 - 0s - loss: 0.1033 - mse: 0.1033 - val_loss: 0.1245 - val_mse: 0.1245 - 62ms/epoch - 5ms/step
# Epoch 331/2000
# 12/12 - 0s - loss: 0.1031 - mse: 0.1031 - val_loss: 0.1250 - val_mse: 0.1250 - 62ms/epoch - 5ms/step
# Epoch 332/2000
# 12/12 - 0s - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1246 - val_mse: 0.1246 - 62ms/epoch - 5ms/step
# Epoch 333/2000
# 12/12 - 0s - loss: 0.1023 - mse: 0.1023 - val_loss: 0.1233 - val_mse: 0.1233 - 58ms/epoch - 5ms/step
# Epoch 334/2000
# 12/12 - 0s - loss: 0.1022 - mse: 0.1022 - val_loss: 0.1235 - val_mse: 0.1235 - 62ms/epoch - 5ms/step
# Epoch 335/2000
# 12/12 - 0s - loss: 0.1022 - mse: 0.1022 - val_loss: 0.1226 - val_mse: 0.1226 - 64ms/epoch - 5ms/step
# Epoch 336/2000
# 12/12 - 0s - loss: 0.1020 - mse: 0.1020 - val_loss: 0.1226 - val_mse: 0.1226 - 66ms/epoch - 5ms/step
# Epoch 337/2000
# 12/12 - 0s - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1221 - val_mse: 0.1221 - 84ms/epoch - 7ms/step
# Epoch 338/2000
# 12/12 - 0s - loss: 0.1009 - mse: 0.1009 - val_loss: 0.1210 - val_mse: 0.1210 - 91ms/epoch - 8ms/step
# Epoch 339/2000
# 12/12 - 0s - loss: 0.1005 - mse: 0.1005 - val_loss: 0.1200 - val_mse: 0.1200 - 69ms/epoch - 6ms/step
# Epoch 340/2000
# 12/12 - 0s - loss: 0.1011 - mse: 0.1011 - val_loss: 0.1202 - val_mse: 0.1202 - 67ms/epoch - 6ms/step
# Epoch 341/2000
# 12/12 - 0s - loss: 0.1004 - mse: 0.1004 - val_loss: 0.1193 - val_mse: 0.1193 - 65ms/epoch - 5ms/step
# Epoch 342/2000
# 12/12 - 0s - loss: 0.1000 - mse: 0.1000 - val_loss: 0.1184 - val_mse: 0.1184 - 68ms/epoch - 6ms/step
# Epoch 343/2000
# 12/12 - 0s - loss: 0.0995 - mse: 0.0995 - val_loss: 0.1200 - val_mse: 0.1200 - 66ms/epoch - 5ms/step
# Epoch 344/2000
# 12/12 - 0s - loss: 0.0993 - mse: 0.0993 - val_loss: 0.1178 - val_mse: 0.1178 - 68ms/epoch - 6ms/step
# Epoch 345/2000
# 12/12 - 0s - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1176 - val_mse: 0.1176 - 77ms/epoch - 6ms/step
# Epoch 346/2000
# 12/12 - 0s - loss: 0.0991 - mse: 0.0991 - val_loss: 0.1173 - val_mse: 0.1173 - 67ms/epoch - 6ms/step
# Epoch 347/2000
# 12/12 - 0s - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1181 - val_mse: 0.1181 - 61ms/epoch - 5ms/step
# Epoch 348/2000
# 12/12 - 0s - loss: 0.0992 - mse: 0.0992 - val_loss: 0.1169 - val_mse: 0.1169 - 66ms/epoch - 5ms/step
# Epoch 349/2000
# 12/12 - 0s - loss: 0.0981 - mse: 0.0981 - val_loss: 0.1163 - val_mse: 0.1163 - 60ms/epoch - 5ms/step
# Epoch 350/2000
# 12/12 - 0s - loss: 0.0979 - mse: 0.0979 - val_loss: 0.1155 - val_mse: 0.1155 - 64ms/epoch - 5ms/step
# Epoch 351/2000
# 12/12 - 0s - loss: 0.0977 - mse: 0.0977 - val_loss: 0.1165 - val_mse: 0.1165 - 61ms/epoch - 5ms/step
# Epoch 352/2000
# 12/12 - 0s - loss: 0.0972 - mse: 0.0972 - val_loss: 0.1157 - val_mse: 0.1157 - 61ms/epoch - 5ms/step
# Epoch 353/2000
# 12/12 - 0s - loss: 0.0971 - mse: 0.0971 - val_loss: 0.1160 - val_mse: 0.1160 - 66ms/epoch - 5ms/step
# Epoch 354/2000
# 12/12 - 0s - loss: 0.0969 - mse: 0.0969 - val_loss: 0.1147 - val_mse: 0.1147 - 64ms/epoch - 5ms/step
# Epoch 355/2000
# 12/12 - 0s - loss: 0.0965 - mse: 0.0965 - val_loss: 0.1140 - val_mse: 0.1140 - 64ms/epoch - 5ms/step
# Epoch 356/2000
# 12/12 - 0s - loss: 0.0964 - mse: 0.0964 - val_loss: 0.1142 - val_mse: 0.1142 - 67ms/epoch - 6ms/step
# Epoch 357/2000
# 12/12 - 0s - loss: 0.0961 - mse: 0.0961 - val_loss: 0.1130 - val_mse: 0.1130 - 66ms/epoch - 5ms/step
# Epoch 358/2000
# 12/12 - 0s - loss: 0.0963 - mse: 0.0963 - val_loss: 0.1147 - val_mse: 0.1147 - 66ms/epoch - 5ms/step
# Epoch 359/2000
# 12/12 - 0s - loss: 0.0958 - mse: 0.0958 - val_loss: 0.1126 - val_mse: 0.1126 - 61ms/epoch - 5ms/step
# Epoch 360/2000
# 12/12 - 0s - loss: 0.0952 - mse: 0.0952 - val_loss: 0.1129 - val_mse: 0.1129 - 62ms/epoch - 5ms/step
# Epoch 361/2000
# 12/12 - 0s - loss: 0.0953 - mse: 0.0953 - val_loss: 0.1133 - val_mse: 0.1133 - 62ms/epoch - 5ms/step
# Epoch 362/2000
# 12/12 - 0s - loss: 0.0948 - mse: 0.0948 - val_loss: 0.1123 - val_mse: 0.1123 - 64ms/epoch - 5ms/step
# Epoch 363/2000
# 12/12 - 0s - loss: 0.0948 - mse: 0.0948 - val_loss: 0.1128 - val_mse: 0.1128 - 67ms/epoch - 6ms/step
# Epoch 364/2000
# 12/12 - 0s - loss: 0.0945 - mse: 0.0945 - val_loss: 0.1119 - val_mse: 0.1119 - 66ms/epoch - 5ms/step
# Epoch 365/2000
# 12/12 - 0s - loss: 0.0948 - mse: 0.0948 - val_loss: 0.1110 - val_mse: 0.1110 - 64ms/epoch - 5ms/step
# Epoch 366/2000
# 12/12 - 0s - loss: 0.0942 - mse: 0.0942 - val_loss: 0.1117 - val_mse: 0.1117 - 64ms/epoch - 5ms/step
# Epoch 367/2000
# 12/12 - 0s - loss: 0.0949 - mse: 0.0949 - val_loss: 0.1106 - val_mse: 0.1106 - 68ms/epoch - 6ms/step
# Epoch 368/2000
# 12/12 - 0s - loss: 0.0939 - mse: 0.0939 - val_loss: 0.1113 - val_mse: 0.1113 - 62ms/epoch - 5ms/step
# Epoch 369/2000
# 12/12 - 0s - loss: 0.0944 - mse: 0.0944 - val_loss: 0.1095 - val_mse: 0.1095 - 69ms/epoch - 6ms/step
# Epoch 370/2000
# 12/12 - 0s - loss: 0.0938 - mse: 0.0938 - val_loss: 0.1100 - val_mse: 0.1100 - 90ms/epoch - 7ms/step
# Epoch 371/2000
# 12/12 - 0s - loss: 0.0932 - mse: 0.0932 - val_loss: 0.1093 - val_mse: 0.1093 - 76ms/epoch - 6ms/step
# Epoch 372/2000
# 12/12 - 0s - loss: 0.0933 - mse: 0.0933 - val_loss: 0.1083 - val_mse: 0.1083 - 68ms/epoch - 6ms/step
# Epoch 373/2000
# 12/12 - 0s - loss: 0.0927 - mse: 0.0927 - val_loss: 0.1092 - val_mse: 0.1092 - 69ms/epoch - 6ms/step
# Epoch 374/2000
# 12/12 - 0s - loss: 0.0929 - mse: 0.0929 - val_loss: 0.1093 - val_mse: 0.1093 - 63ms/epoch - 5ms/step
# Epoch 375/2000
# 12/12 - 0s - loss: 0.0929 - mse: 0.0929 - val_loss: 0.1082 - val_mse: 0.1082 - 67ms/epoch - 6ms/step
# Epoch 376/2000
# 12/12 - 0s - loss: 0.0937 - mse: 0.0937 - val_loss: 0.1081 - val_mse: 0.1081 - 66ms/epoch - 5ms/step
# Epoch 377/2000
# 12/12 - 0s - loss: 0.0926 - mse: 0.0926 - val_loss: 0.1070 - val_mse: 0.1070 - 72ms/epoch - 6ms/step
# Epoch 378/2000
# 12/12 - 0s - loss: 0.0930 - mse: 0.0930 - val_loss: 0.1096 - val_mse: 0.1096 - 69ms/epoch - 6ms/step
# Epoch 379/2000
# 12/12 - 0s - loss: 0.0929 - mse: 0.0929 - val_loss: 0.1065 - val_mse: 0.1065 - 63ms/epoch - 5ms/step
# Epoch 380/2000
# 12/12 - 0s - loss: 0.0916 - mse: 0.0916 - val_loss: 0.1080 - val_mse: 0.1080 - 62ms/epoch - 5ms/step
# Epoch 381/2000
# 12/12 - 0s - loss: 0.0915 - mse: 0.0915 - val_loss: 0.1058 - val_mse: 0.1058 - 63ms/epoch - 5ms/step
# Epoch 382/2000
# 12/12 - 0s - loss: 0.0920 - mse: 0.0920 - val_loss: 0.1074 - val_mse: 0.1074 - 62ms/epoch - 5ms/step
# Epoch 383/2000
# 12/12 - 0s - loss: 0.0921 - mse: 0.0921 - val_loss: 0.1053 - val_mse: 0.1053 - 66ms/epoch - 5ms/step
# Epoch 384/2000
# 12/12 - 0s - loss: 0.0916 - mse: 0.0916 - val_loss: 0.1084 - val_mse: 0.1084 - 68ms/epoch - 6ms/step
# Epoch 385/2000
# 12/12 - 0s - loss: 0.0918 - mse: 0.0918 - val_loss: 0.1054 - val_mse: 0.1054 - 64ms/epoch - 5ms/step
# Epoch 386/2000
# 12/12 - 0s - loss: 0.0924 - mse: 0.0924 - val_loss: 0.1043 - val_mse: 0.1043 - 66ms/epoch - 5ms/step
# Epoch 387/2000
# 12/12 - 0s - loss: 0.0912 - mse: 0.0912 - val_loss: 0.1073 - val_mse: 0.1073 - 62ms/epoch - 5ms/step
# Epoch 388/2000
# 12/12 - 0s - loss: 0.0913 - mse: 0.0913 - val_loss: 0.1043 - val_mse: 0.1043 - 64ms/epoch - 5ms/step
# Epoch 389/2000
# 12/12 - 0s - loss: 0.0910 - mse: 0.0910 - val_loss: 0.1048 - val_mse: 0.1048 - 69ms/epoch - 6ms/step
# Epoch 390/2000
# 12/12 - 0s - loss: 0.0899 - mse: 0.0899 - val_loss: 0.1036 - val_mse: 0.1036 - 68ms/epoch - 6ms/step
# Epoch 391/2000
# 12/12 - 0s - loss: 0.0898 - mse: 0.0898 - val_loss: 0.1032 - val_mse: 0.1032 - 63ms/epoch - 5ms/step
# Epoch 392/2000
# 12/12 - 0s - loss: 0.0898 - mse: 0.0898 - val_loss: 0.1025 - val_mse: 0.1025 - 69ms/epoch - 6ms/step
# Epoch 393/2000
# 12/12 - 0s - loss: 0.0899 - mse: 0.0899 - val_loss: 0.1027 - val_mse: 0.1027 - 65ms/epoch - 5ms/step
# Epoch 394/2000
# 12/12 - 0s - loss: 0.0908 - mse: 0.0908 - val_loss: 0.1027 - val_mse: 0.1027 - 66ms/epoch - 5ms/step
# Epoch 395/2000
# 12/12 - 0s - loss: 0.0905 - mse: 0.0905 - val_loss: 0.1043 - val_mse: 0.1043 - 60ms/epoch - 5ms/step
# Epoch 396/2000
# 12/12 - 0s - loss: 0.0902 - mse: 0.0902 - val_loss: 0.1013 - val_mse: 0.1013 - 62ms/epoch - 5ms/step
# Epoch 397/2000
# 12/12 - 0s - loss: 0.0892 - mse: 0.0892 - val_loss: 0.1036 - val_mse: 0.1036 - 62ms/epoch - 5ms/step
# Epoch 398/2000
# 12/12 - 0s - loss: 0.0890 - mse: 0.0890 - val_loss: 0.1013 - val_mse: 0.1013 - 66ms/epoch - 5ms/step
# Epoch 399/2000
# 12/12 - 0s - loss: 0.0887 - mse: 0.0887 - val_loss: 0.1011 - val_mse: 0.1011 - 62ms/epoch - 5ms/step
# Epoch 400/2000
# 12/12 - 0s - loss: 0.0884 - mse: 0.0884 - val_loss: 0.1006 - val_mse: 0.1006 - 71ms/epoch - 6ms/step
# Epoch 401/2000
# 12/12 - 0s - loss: 0.0883 - mse: 0.0883 - val_loss: 0.1009 - val_mse: 0.1009 - 106ms/epoch - 9ms/step
# Epoch 402/2000
# 12/12 - 0s - loss: 0.0882 - mse: 0.0882 - val_loss: 0.1003 - val_mse: 0.1003 - 81ms/epoch - 7ms/step
# Epoch 403/2000
# 12/12 - 0s - loss: 0.0884 - mse: 0.0884 - val_loss: 0.1006 - val_mse: 0.1006 - 73ms/epoch - 6ms/step
# Epoch 404/2000
# 12/12 - 0s - loss: 0.0878 - mse: 0.0878 - val_loss: 0.0994 - val_mse: 0.0994 - 71ms/epoch - 6ms/step
# Epoch 405/2000
# 12/12 - 0s - loss: 0.0881 - mse: 0.0881 - val_loss: 0.0996 - val_mse: 0.0996 - 68ms/epoch - 6ms/step
# Epoch 406/2000
# 12/12 - 0s - loss: 0.0876 - mse: 0.0876 - val_loss: 0.0994 - val_mse: 0.0994 - 65ms/epoch - 5ms/step
# Epoch 407/2000
# 12/12 - 0s - loss: 0.0878 - mse: 0.0878 - val_loss: 0.0995 - val_mse: 0.0995 - 63ms/epoch - 5ms/step
# Epoch 408/2000
# 12/12 - 0s - loss: 0.0873 - mse: 0.0873 - val_loss: 0.0997 - val_mse: 0.0997 - 65ms/epoch - 5ms/step
# Epoch 409/2000
# 12/12 - 0s - loss: 0.0876 - mse: 0.0876 - val_loss: 0.0990 - val_mse: 0.0990 - 73ms/epoch - 6ms/step
# Epoch 410/2000
# 12/12 - 0s - loss: 0.0870 - mse: 0.0870 - val_loss: 0.0991 - val_mse: 0.0991 - 69ms/epoch - 6ms/step
# Epoch 411/2000
# 12/12 - 0s - loss: 0.0869 - mse: 0.0869 - val_loss: 0.0983 - val_mse: 0.0983 - 68ms/epoch - 6ms/step
# Epoch 412/2000
# 12/12 - 0s - loss: 0.0868 - mse: 0.0868 - val_loss: 0.0981 - val_mse: 0.0981 - 60ms/epoch - 5ms/step
# Epoch 413/2000
# 12/12 - 0s - loss: 0.0866 - mse: 0.0866 - val_loss: 0.0985 - val_mse: 0.0985 - 60ms/epoch - 5ms/step
# Epoch 414/2000
# 12/12 - 0s - loss: 0.0866 - mse: 0.0866 - val_loss: 0.0981 - val_mse: 0.0981 - 69ms/epoch - 6ms/step
# Epoch 415/2000
# ...
# Epoch 1865/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0240 - val_mse: 0.0240 - 81ms/epoch - 7ms/step
# Epoch 1866/2000
# 12/12 - 0s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0240 - val_mse: 0.0240 - 68ms/epoch - 6ms/step
# Epoch 1867/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 75ms/epoch - 6ms/step
# Epoch 1868/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0235 - val_mse: 0.0235 - 67ms/epoch - 6ms/step
# Epoch 1869/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0236 - val_mse: 0.0236 - 70ms/epoch - 6ms/step
# Epoch 1870/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0241 - val_mse: 0.0241 - 63ms/epoch - 5ms/step
# Epoch 1871/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 63ms/epoch - 5ms/step
# Epoch 1872/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0235 - val_mse: 0.0235 - 66ms/epoch - 5ms/step
# Epoch 1873/2000
# 12/12 - 0s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0237 - val_mse: 0.0237 - 61ms/epoch - 5ms/step
# Epoch 1874/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0247 - val_mse: 0.0247 - 65ms/epoch - 5ms/step
# Epoch 1875/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0236 - val_mse: 0.0236 - 97ms/epoch - 8ms/step
# Epoch 1876/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 79ms/epoch - 7ms/step
# Epoch 1877/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0239 - val_mse: 0.0239 - 67ms/epoch - 6ms/step
# Epoch 1878/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0234 - val_mse: 0.0234 - 71ms/epoch - 6ms/step
# Epoch 1879/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 67ms/epoch - 6ms/step
# Epoch 1880/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0235 - val_mse: 0.0235 - 81ms/epoch - 7ms/step
# Epoch 1881/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 67ms/epoch - 6ms/step
# Epoch 1882/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0237 - val_mse: 0.0237 - 71ms/epoch - 6ms/step
# Epoch 1883/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 75ms/epoch - 6ms/step
# Epoch 1884/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 74ms/epoch - 6ms/step
# Epoch 1885/2000
# 12/12 - 0s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0248 - val_mse: 0.0248 - 65ms/epoch - 5ms/step
# Epoch 1886/2000
# 12/12 - 0s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0235 - val_mse: 0.0235 - 69ms/epoch - 6ms/step
# Epoch 1887/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0239 - val_mse: 0.0239 - 68ms/epoch - 6ms/step
# Epoch 1888/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0237 - val_mse: 0.0237 - 76ms/epoch - 6ms/step
# Epoch 1889/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 73ms/epoch - 6ms/step
# Epoch 1890/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 68ms/epoch - 6ms/step
# Epoch 1891/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 73ms/epoch - 6ms/step
# Epoch 1892/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 91ms/epoch - 8ms/step
# Epoch 1893/2000
# 12/12 - 0s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0237 - val_mse: 0.0237 - 117ms/epoch - 10ms/step
# Epoch 1894/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0237 - val_mse: 0.0237 - 110ms/epoch - 9ms/step
# Epoch 1895/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 89ms/epoch - 7ms/step
# Epoch 1896/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 90ms/epoch - 7ms/step
# Epoch 1897/2000
# 12/12 - 0s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0240 - val_mse: 0.0240 - 97ms/epoch - 8ms/step
# Epoch 1898/2000
# 12/12 - 0s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0236 - val_mse: 0.0236 - 92ms/epoch - 8ms/step
# Epoch 1899/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0241 - val_mse: 0.0241 - 80ms/epoch - 7ms/step
# Epoch 1900/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 77ms/epoch - 6ms/step
# Epoch 1901/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0235 - val_mse: 0.0235 - 74ms/epoch - 6ms/step
# Epoch 1902/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0235 - val_mse: 0.0235 - 69ms/epoch - 6ms/step
# Epoch 1903/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 69ms/epoch - 6ms/step
# Epoch 1904/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0236 - val_mse: 0.0236 - 64ms/epoch - 5ms/step
# Epoch 1905/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 64ms/epoch - 5ms/step
# Epoch 1906/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0234 - val_mse: 0.0234 - 65ms/epoch - 5ms/step
# Epoch 1907/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0238 - val_mse: 0.0238 - 61ms/epoch - 5ms/step
# Epoch 1908/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0236 - val_mse: 0.0236 - 63ms/epoch - 5ms/step
# Epoch 1909/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0239 - val_mse: 0.0239 - 82ms/epoch - 7ms/step
# Epoch 1910/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 80ms/epoch - 7ms/step
# Epoch 1911/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 77ms/epoch - 6ms/step
# Epoch 1912/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0239 - val_mse: 0.0239 - 74ms/epoch - 6ms/step
# Epoch 1913/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0236 - val_mse: 0.0236 - 107ms/epoch - 9ms/step
# Epoch 1914/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 93ms/epoch - 8ms/step
# Epoch 1915/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 85ms/epoch - 7ms/step
# Epoch 1916/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0235 - val_mse: 0.0235 - 78ms/epoch - 6ms/step
# Epoch 1917/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0237 - val_mse: 0.0237 - 79ms/epoch - 7ms/step
# Epoch 1918/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0237 - val_mse: 0.0237 - 72ms/epoch - 6ms/step
# Epoch 1919/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0234 - val_mse: 0.0234 - 68ms/epoch - 6ms/step
# Epoch 1920/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 66ms/epoch - 5ms/step
# Epoch 1921/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 73ms/epoch - 6ms/step
# Epoch 1922/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 90ms/epoch - 7ms/step
# Epoch 1923/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0240 - val_mse: 0.0240 - 71ms/epoch - 6ms/step
# Epoch 1924/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0236 - val_mse: 0.0236 - 66ms/epoch - 5ms/step
# Epoch 1925/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 69ms/epoch - 6ms/step
# Epoch 1926/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 62ms/epoch - 5ms/step
# Epoch 1927/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 63ms/epoch - 5ms/step
# Epoch 1928/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 63ms/epoch - 5ms/step
# Epoch 1929/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 58ms/epoch - 5ms/step
# Epoch 1930/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 57ms/epoch - 5ms/step
# Epoch 1931/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 62ms/epoch - 5ms/step
# Epoch 1932/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 60ms/epoch - 5ms/step
# Epoch 1933/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0239 - val_mse: 0.0239 - 76ms/epoch - 6ms/step
# Epoch 1934/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 62ms/epoch - 5ms/step
# Epoch 1935/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 65ms/epoch - 5ms/step
# Epoch 1936/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0240 - val_mse: 0.0240 - 59ms/epoch - 5ms/step
# Epoch 1937/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0235 - val_mse: 0.0235 - 63ms/epoch - 5ms/step
# Epoch 1938/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 103ms/epoch - 9ms/step
# Epoch 1939/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 77ms/epoch - 6ms/step
# Epoch 1940/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 71ms/epoch - 6ms/step
# Epoch 1941/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 69ms/epoch - 6ms/step
# Epoch 1942/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0242 - val_mse: 0.0242 - 67ms/epoch - 6ms/step
# Epoch 1943/2000
# 12/12 - 0s - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0237 - val_mse: 0.0237 - 77ms/epoch - 6ms/step
# Epoch 1944/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0240 - val_mse: 0.0240 - 67ms/epoch - 6ms/step
# Epoch 1945/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0234 - val_mse: 0.0234 - 68ms/epoch - 6ms/step
# Epoch 1946/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 65ms/epoch - 5ms/step
# Epoch 1947/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0235 - val_mse: 0.0235 - 70ms/epoch - 6ms/step
# Epoch 1948/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0234 - val_mse: 0.0234 - 60ms/epoch - 5ms/step
# Epoch 1949/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0234 - val_mse: 0.0234 - 60ms/epoch - 5ms/step
# Epoch 1950/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 62ms/epoch - 5ms/step
# Epoch 1951/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0239 - val_mse: 0.0239 - 87ms/epoch - 7ms/step
# Epoch 1952/2000
# 12/12 - 0s - loss: 0.0236 - mse: 0.0236 - val_loss: 0.0239 - val_mse: 0.0239 - 80ms/epoch - 7ms/step
# Epoch 1953/2000
# 12/12 - 0s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0255 - val_mse: 0.0255 - 68ms/epoch - 6ms/step
# Epoch 1954/2000
# 12/12 - 0s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0243 - val_mse: 0.0243 - 73ms/epoch - 6ms/step
# Epoch 1955/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0243 - val_mse: 0.0243 - 68ms/epoch - 6ms/step
# Epoch 1956/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0234 - val_mse: 0.0234 - 63ms/epoch - 5ms/step
# Epoch 1957/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 65ms/epoch - 5ms/step
# Epoch 1958/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0235 - val_mse: 0.0235 - 62ms/epoch - 5ms/step
# Epoch 1959/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0234 - val_mse: 0.0234 - 65ms/epoch - 5ms/step
# Epoch 1960/2000
# 12/12 - 0s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0243 - val_mse: 0.0243 - 61ms/epoch - 5ms/step
# Epoch 1961/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0235 - val_mse: 0.0235 - 62ms/epoch - 5ms/step
# Epoch 1962/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0238 - val_mse: 0.0238 - 62ms/epoch - 5ms/step
# Epoch 1963/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0234 - val_mse: 0.0234 - 62ms/epoch - 5ms/step
# Epoch 1964/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 61ms/epoch - 5ms/step
# Epoch 1965/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0236 - val_mse: 0.0236 - 61ms/epoch - 5ms/step
# Epoch 1966/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0239 - val_mse: 0.0239 - 62ms/epoch - 5ms/step
# Epoch 1967/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0237 - val_mse: 0.0237 - 92ms/epoch - 8ms/step
# Epoch 1968/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0235 - val_mse: 0.0235 - 82ms/epoch - 7ms/step
# Epoch 1969/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0235 - val_mse: 0.0235 - 70ms/epoch - 6ms/step
# Epoch 1970/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 70ms/epoch - 6ms/step
# Epoch 1971/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0238 - val_mse: 0.0238 - 68ms/epoch - 6ms/step
# Epoch 1972/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0236 - val_mse: 0.0236 - 65ms/epoch - 5ms/step
# Epoch 1973/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 62ms/epoch - 5ms/step
# Epoch 1974/2000
# 12/12 - 0s - loss: 0.0238 - mse: 0.0238 - val_loss: 0.0243 - val_mse: 0.0243 - 60ms/epoch - 5ms/step
# Epoch 1975/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0236 - val_mse: 0.0236 - 63ms/epoch - 5ms/step
# Epoch 1976/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0238 - val_mse: 0.0238 - 63ms/epoch - 5ms/step
# Epoch 1977/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0235 - val_mse: 0.0235 - 61ms/epoch - 5ms/step
# Epoch 1978/2000
# 12/12 - 0s - loss: 0.0240 - mse: 0.0240 - val_loss: 0.0248 - val_mse: 0.0248 - 59ms/epoch - 5ms/step
# Epoch 1979/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0238 - val_mse: 0.0238 - 59ms/epoch - 5ms/step
# Epoch 1980/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0240 - val_mse: 0.0240 - 59ms/epoch - 5ms/step
# Epoch 1981/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0236 - val_mse: 0.0236 - 62ms/epoch - 5ms/step
# Epoch 1982/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0235 - val_mse: 0.0235 - 62ms/epoch - 5ms/step
# Epoch 1983/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0235 - val_mse: 0.0235 - 66ms/epoch - 5ms/step
# Epoch 1984/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0236 - val_mse: 0.0236 - 62ms/epoch - 5ms/step
# Epoch 1985/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0236 - val_mse: 0.0236 - 65ms/epoch - 5ms/step
# Epoch 1986/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0237 - val_mse: 0.0237 - 68ms/epoch - 6ms/step
# Epoch 1987/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 72ms/epoch - 6ms/step
# Epoch 1988/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0239 - val_mse: 0.0239 - 66ms/epoch - 5ms/step
# Epoch 1989/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 62ms/epoch - 5ms/step
# Epoch 1990/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0237 - val_mse: 0.0237 - 66ms/epoch - 5ms/step
# Epoch 1991/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0238 - val_mse: 0.0238 - 60ms/epoch - 5ms/step
# Epoch 1992/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 62ms/epoch - 5ms/step
# Epoch 1993/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0239 - val_mse: 0.0239 - 64ms/epoch - 5ms/step
# Epoch 1994/2000
# 12/12 - 0s - loss: 0.0233 - mse: 0.0233 - val_loss: 0.0238 - val_mse: 0.0238 - 63ms/epoch - 5ms/step
# Epoch 1995/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0240 - val_mse: 0.0240 - 66ms/epoch - 5ms/step
# Epoch 1996/2000
# 12/12 - 0s - loss: 0.0232 - mse: 0.0232 - val_loss: 0.0237 - val_mse: 0.0237 - 64ms/epoch - 5ms/step
# Epoch 1997/2000
# 12/12 - 0s - loss: 0.0234 - mse: 0.0234 - val_loss: 0.0238 - val_mse: 0.0238 - 62ms/epoch - 5ms/step
# Epoch 1998/2000
# 12/12 - 0s - loss: 0.0241 - mse: 0.0241 - val_loss: 0.0248 - val_mse: 0.0248 - 73ms/epoch - 6ms/step
# Epoch 1999/2000
# 12/12 - 0s - loss: 0.0239 - mse: 0.0239 - val_loss: 0.0243 - val_mse: 0.0243 - 70ms/epoch - 6ms/step
# Epoch 2000/2000
# 12/12 - 0s - loss: 0.0235 - mse: 0.0235 - val_loss: 0.0239 - val_mse: 0.0239 - 67ms/epoch - 6ms/step

# %%
# record of history of validation vs training loss
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

# record of history of validation vs training loss
plt.figure(figsize=(12,4))
plt.plot(history.history['loss'], linewidth=1.5)
plt.plot(history.history['val_loss'], ":")
plt.title('model loss')
plt.ylabel('Loss function')
plt.xlabel('Epoch')
plt.legend(['Training data', 'Validation data'], loc='best', fancybox=True, framealpha=0.6)
plt.grid(True)
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  first_layer (Dense)         (None, 10)                40
#
#  second_layer (Dense)        (None, 5)                 55
#
#  output_layer (Dense)        (None, 1)                 6
#
# =================================================================
# Total params: 101
# Trainable params: 101
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Prediction

# %%
yhat = model.predict(x_test)

# %% [markdown]
# # Model performance

# %%
from sklearn.metrics import mean_absolute_error, r2_score

# %%
error = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % error)
# Out:
# MAE: 0.087

# %%
r2 = r2_score(y_test, yhat)
print('R-squared: %.3f' % r2)
# Out:
# R-squared: 0.974

# %%
y_new_inverse = label_scaler.inverse_transform(yhat)

# %%
sns.set_style("ticks", {"grid.color": ".8", "grid.linestyle": "--"})
plt.rc('xtick', labelsize=14) 
plt.rc('ytick', labelsize=14) 

plt.figure(figsize=(9,9))
plt.rcParams.update({'font.size': 14})
plt.axes(aspect='equal')
sns.lineplot(x=y_test.iloc[:,0], y=y_test.iloc[:,0], linewidth=3, color='#01497C', label='$y_{true}$')
plt.scatter(x=y_test.iloc[:,0], y=yhat[:,0], c="red", label='$\hat{y}$', s=70, alpha = 0.4)

plt.annotate("r$^2$ = {:.3f}".format(r2), (2, -0.75))
plt.annotate("MAE = {:.3f}".format(error), (2, -1))

plt.xlabel('$y_{true}$')
plt.ylabel('$\hat{y}$')

plt.legend(loc='upper left', fancybox=True, framealpha=0.6)
plt.title('Validation of the prediction model')     
plt.grid(True)

plt.show()

# %%
x_ax = range(len(yhat))
plt.figure(figsize=(10,6))
plt.scatter(x_ax, y_test, s=5, color="blue", label="original")
plt.plot(x_ax, yhat, lw=0.8, color="red", label="predicted")
plt.legend()
plt.show()

# %%
# save model
model.save('model_attribute_95')
# Out:
# INFO:tensorflow:Assets written to: model_attribute_95\assets
